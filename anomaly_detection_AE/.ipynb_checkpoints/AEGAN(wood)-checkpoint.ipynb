# %%
import sys
sys.path.append('../')

import os
import time
import numpy as np

from torch.utils.data import DataLoader
from torch.autograd import Variable
from torch import autograd

import torch
import torch.nn as nn


from utils.tools import get_config, default_loader, is_image_file, normalize
from tensorboardX import SummaryWriter
import matplotlib.pyplot as plt
import torchvision.utils as vutils

from sklearn.metrics import roc_auc_score
sys.path.append('../PerceptualSimilarity')
import models as PerceptualSimilarity

# personal library
from networks import autoencoder, simulator, discriminator
from dataloader import MVTecDataset

# %%
# 限制可以使用的 GPU
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0,1"

# %%
# HYPER parameters
num_epochs = 50000
batch_size = 32
val_batch_size = 4
ae_lr = 1e-4
s_lr = 5e-4
d_lr = 5e-4
weight_decay = 1e-5
UPSET=True
expName = 'AEGAN-exp(carpet)'
writer = SummaryWriter('checkpoint/'+expName)
TYPE='carpet'

# %%
trainDatset = MVTecDataset.MVTecDataset(TYPE=TYPE, isTrain='train')
testDatset = MVTecDataset.MVTecDataset(TYPE=TYPE, isTrain='test')
valDataset = MVTecDataset.MVTecDataset(TYPE=TYPE, isTrain='val')

val_loader = DataLoader(
    dataset=valDataset,
    batch_size=val_batch_size, 
    shuffle=True,
    num_workers=4
)
train_loader = DataLoader(
    dataset=trainDatset,
    batch_size=batch_size, 
    shuffle=True,
    num_workers=4
)
test_loader = DataLoader(
    dataset=testDatset,
    batch_size=1,
    shuffle=True,
    num_workers=4
)

# %%
# Model
AE = autoencoder.Autoencoder().cuda()
S = nn.DataParallel(simulator.Simulator(3, 8)).cuda()
D = nn.DataParallel(discriminator.Discriminator(6, 16)).cuda()

# Loss
adversarial_loss = torch.nn.BCELoss()
L2_loss = nn.MSELoss(reduction='none')
perceptual_loss = PerceptualSimilarity.PerceptualLoss(model='net-lin', net='alex', use_gpu=True, gpu_ids=[0])

# Optimizer
optimizer_AE = torch.optim.Adam(
    AE.parameters(), 
    lr=ae_lr,
    weight_decay=weight_decay
)
optimizer_S = torch.optim.Adam(
    S.parameters(), 
    lr=s_lr,
    weight_decay=weight_decay
)
optimizer_D = torch.optim.Adam(
    D.parameters(), 
    lr=d_lr,
    weight_decay=weight_decay
)


Tensor = torch.cuda.FloatTensor
# Out:
# Setting up Perceptual loss...
# Loading model from: /workspace/PerceptualSimilarity/models/weights/v0.1/alex.pth
# ...[net-lin [alex]] initialized
# ...Done

# %%
AE.load_state_dict(torch.load('./save_weight/AE-carpet-z-2x2-exp1/AE_2400.npy', map_location="cuda:0"), False)

AE = nn.DataParallel(AE)

# %%
# To Solve: RuntimeError: cuDNN error: CUDNN_STATUS_EXECUTION_FAILED
torch.backends.cudnn.enabled = False 

# 拿掉煩人的 warning
import warnings
warnings.filterwarnings("ignore")

# %%
LAMBDA = 10

def calc_gradient_penalty(netD, real_data, fake_data):
    # print "real_data: ", real_data.size(), fake_data.size()
    BATCH_SIZE = real_data.size(0)
    alpha = torch.rand(BATCH_SIZE, 1)
    alpha = alpha.expand(BATCH_SIZE, real_data.nelement()//BATCH_SIZE).contiguous().view(BATCH_SIZE, 6, 256, 256)
    alpha = alpha.cuda()

    interpolates = alpha * real_data + ((1 - alpha) * fake_data)

    interpolates = interpolates.cuda()
    interpolates = autograd.Variable(interpolates, requires_grad=True)

    disc_interpolates = netD(interpolates)

    gradients = autograd.grad(
        outputs=disc_interpolates, 
        inputs=interpolates,
        grad_outputs=torch.ones(disc_interpolates.size()).cuda(),
        create_graph=True, 
        retain_graph=True, 
        only_inputs=True
    )[0]
    gradients = gradients.view(gradients.size(0), -1)

    gradient_penalty = ((gradients.norm(2, dim=1) - 1) ** 2).mean() * LAMBDA
    return gradient_penalty

def difNormalize(input_matrix, threshold=None):
    _min = torch.min(input_matrix)
    _max = torch.max(input_matrix)
    
    input_matrix = (input_matrix - _min) / (_max - _min)
    
    if threshold != None:
        input_matrix[input_matrix < threshold] = 0
        input_matrix[input_matrix >= threshold] = 1
        
    return input_matrix

# %%
for epoch in range(num_epochs): 
    start = time.time()
    ######## GAN ################
    one = torch.FloatTensor([1])
    mone = one * -1
    
    one = one.cuda()
    mone = mone.cuda()
    
    one = one.mean()
    mone = mone.mean()
    ## ==== GAN --> D =====
    for i in range(3):
        for index, img in enumerate(train_loader):
            AE.eval(), S.train(), D.train()

            img = Variable(img).cuda()

            # ====== AE ======
            blur_image = AE(img)

            _bs, _c, _w, _h = blur_image.shape
            noise = torch.zeros(_bs, 1, _w, _h )
            noise = noise + (0.01**0.5)*torch.randn(_bs, 1, _w, _h)
            noise = noise.cuda()

            blur_image_with_noise = torch.cat([blur_image, noise], 1)
            fake_image = S(blur_image_with_noise) # 當成是 residual
            
            fake_image = fake_image + blur_image # blur image + residual
            
            fake_pair = torch.cat([img, fake_image], 1)
            real_pair = torch.cat([img, img[torch.randperm(img.size(0)), :, :, :]], 1) if UPSET else torch.cat([img, img], 1)
            # ====== Train D ======
            for p in D.parameters():
                p.requires_grad = True

            optimizer_AE.zero_grad()
            optimizer_S.zero_grad()
            optimizer_D.zero_grad()


            real_D = D(real_pair)
            real_D = real_D.mean()
            real_D.backward(mone)


            fake_D = D(fake_pair)
            fake_D = fake_D.mean()
            fake_D.backward(one)

            gradient_penalty = calc_gradient_penalty(D, real_pair, fake_pair)
            gradient_penalty.backward()

            cost_D = fake_D - real_D + gradient_penalty
            Wasserstein_D = real_D - fake_D
            optimizer_D.step()
    
    ## ==== GAN --> G =====
    for index, img in enumerate(train_loader):
        AE.eval(), S.train(), D.train()

        img = Variable(img).cuda()
        # ======AE======
        blur_image = AE(img)

        _bs, _c, _w, _h = blur_image.shape
        noise = torch.zeros(_bs, 1, _w, _h )
        noise = noise + (0.01**0.5)*torch.randn(_bs, 1, _w, _h)
        noise = noise.cuda()

        blur_image_with_noise = torch.cat([blur_image, noise], 1)
        fake_image = S(blur_image_with_noise)
        
        fake_image = fake_image + blur_image
        
        fake_pair = torch.cat([img, fake_image], 1)
        # ====== Train G ======
        for p in D.parameters():
            p.requires_grad = False
            
        G = D(fake_pair)
        G = G.mean()
        
        optimizer_AE.zero_grad()
        optimizer_S.zero_grad()
        optimizer_D.zero_grad()
        
        G.backward(mone)
        
        cost_G = -G
        optimizer_S.step()
        
    
    # validation set
    for index, val_img in enumerate(val_loader):
        AE.eval(), S.eval(), D.eval()

        val_img = Variable(val_img).cuda()
        # ======AE======
        val_blur_image = AE(val_img)

        _bs, _c, _w, _h = val_blur_image.shape
        noise = torch.zeros(_bs, 1, _w, _h )
        noise = noise + (0.01**0.5)*torch.randn(_bs, 1, _w, _h)
        noise = noise.cuda()

        val_blur_image_with_noise = torch.cat([val_blur_image, noise], 1)

        val_fake_image = S(val_blur_image_with_noise)       
        val_fake_image = val_fake_image + val_blur_image
        
        
        val_fake_pair = torch.cat([val_img, val_fake_image], 1)
        val_real_pair = torch.cat([val_img, val_img[torch.randperm(val_img.size(0)), :, :, :]], 1) if UPSET else torch.cat([val_img, val_img], 1)
        
        val_real_D = D(val_real_pair)
        val_real_D = val_real_D.mean()
        
        val_fake_D = D(val_fake_pair)
        val_fake_D = val_fake_D.mean()
        
        val_gradient_penalty = calc_gradient_penalty(D, val_real_pair, val_fake_pair)
        
        # =========== Losses =========
        val_Wasserstein_D = val_real_D - val_fake_D
        
        val_cost_G = -val_fake_D
        val_cost_D = val_fake_D - val_real_D + val_gradient_penalty
    
    # evaluate
    test_total_AUC = 0
    test_total_AUC2 = 0
    test_total_image = 0

    for index, (test_img, mask) in enumerate(test_loader):
        AE.eval(), S.eval(), D.eval()
        test_img = Variable(test_img).cuda()
        test_blur_image = AE(test_img)

        _bs, _c, _w, _h = test_blur_image.shape
        noise = torch.zeros(_bs, 1, _w, _h )
        noise = noise + (0.01**0.5)*torch.randn(_bs, 1, _w, _h)
        noise = noise.cuda()

        test_blur_image_with_noise = torch.cat([test_blur_image, noise], 1)

        test_fake_image = S(test_blur_image_with_noise)       
        test_fake_image = test_fake_image + test_blur_image

        # 計算 dif (相似度以及 L2)
        dif, _ = perceptual_loss.forward(test_fake_image, test_img)
        l2Dif = L2_loss(test_fake_image, test_img)
        l2Dif = torch.mean(l2Dif, 1, True)
        
        pred_mask2 = difNormalize(dif)
        pred_mask2 = torch.flatten(pred_mask2[0])
        
        pred_mask = difNormalize(dif[0] * l2Dif[0])
        pred_mask = torch.flatten(pred_mask)
        
        mask = torch.mean(mask, 1, True)
        true_mask = mask[0].cpu().detach().numpy().flatten()
        true_mask = true_mask.astype(int)

        AUC = roc_auc_score(true_mask, pred_mask.cpu().detach().numpy())
        AUC2 = roc_auc_score(true_mask, pred_mask2.cpu().detach().numpy())

        test_total_AUC += AUC
        test_total_AUC2 += AUC2
        test_total_image += 1
    
    # =================== GAN log========================
    end = time.time()
    print('epoch [{}/{}] s_loss:{:.4f} d_loss:{:.4f} val_s_loss:{:.4f} val_d_loss:{:.4f} cost:{:.2f}'.format(epoch+1, num_epochs, cost_G.item(), cost_D.item(), val_cost_G.item(), val_cost_D.item(), end-start ))
    writer.add_scalars('eval', {
        "auc_roc_score": test_total_AUC / test_total_image,
        "auc_roc_score(w/o L2)": test_total_AUC2 / test_total_image,
    }, epoch)
    
    writer.add_scalars('loss', {
        "Wasserstein Distance": Wasserstein_D.item(),
        "Val Wasserstein Distance": val_Wasserstein_D.item(),
        "gradient penalty": gradient_penalty,
        "val gradient penalty": val_gradient_penalty
    }, epoch)
    
    writer.add_scalars('gan loss', {
        "g_loss": cost_G.item(),
        "d_loss": cost_D.item(),
        "val_g_loss": val_cost_G.item(),
        "val_d_loss": val_cost_D.item()
    }, epoch)

    writer.add_images('Blur', blur_image, epoch)
    writer.add_images('Reconstruct', fake_image, epoch)
    writer.add_images('Origin', img, epoch)

    writer.add_images('Val Blur', val_blur_image, epoch)
    writer.add_images('Val Reconstruct', val_fake_image, epoch)
    writer.add_images('Val Origin', val_img, epoch)


        
    if epoch % 10 == 0:
        if not os.path.exists('./save_weight/{}'.format(expName)):
            os.makedirs('./save_weight/{}'.format(expName))
        torch.save(S.state_dict(), './save_weight/{}/S_{}.npy'.format(expName, epoch))
        torch.save(D.state_dict(), './save_weight/{}/D_{}.npy'.format(expName, epoch))
# Out:
# epoch [1/50000] s_loss:1254.8077 d_loss:-374.9126 val_s_loss:1638.3367 val_d_loss:-504.5738 cost:33.99
# epoch [2/50000] s_loss:833.5659 d_loss:-362.5111 val_s_loss:682.9695 val_d_loss:214.7719 cost:31.30
# epoch [3/50000] s_loss:567.4767 d_loss:-208.4183 val_s_loss:602.2328 val_d_loss:-93.3866 cost:31.48
# epoch [4/50000] s_loss:422.2994 d_loss:-259.6989 val_s_loss:405.0606 val_d_loss:-60.2716 cost:31.83
# epoch [5/50000] s_loss:493.8718 d_loss:-203.1932 val_s_loss:604.0786 val_d_loss:-267.7314 cost:31.37
# epoch [6/50000] s_loss:428.6718 d_loss:-189.3337 val_s_loss:392.6738 val_d_loss:-84.8176 cost:31.41
# epoch [7/50000] s_loss:339.6361 d_loss:-163.1362 val_s_loss:312.9329 val_d_loss:-121.5738 cost:32.05
# epoch [8/50000] s_loss:266.7888 d_loss:-137.8416 val_s_loss:311.2092 val_d_loss:-155.0956 cost:31.16
# epoch [9/50000] s_loss:215.7909 d_loss:-132.3809 val_s_loss:101.2340 val_d_loss:43.0123 cost:30.12
# epoch [10/50000] s_loss:215.1358 d_loss:-75.6725 val_s_loss:154.8294 val_d_loss:-20.8239 cost:30.86
# epoch [11/50000] s_loss:157.0362 d_loss:-96.6667 val_s_loss:84.8834 val_d_loss:10.1488 cost:31.90
# epoch [12/50000] s_loss:149.5034 d_loss:-6.5837 val_s_loss:64.7793 val_d_loss:15.2712 cost:33.09
# epoch [13/50000] s_loss:105.6096 d_loss:-38.1268 val_s_loss:164.4133 val_d_loss:-29.4835 cost:31.03
# epoch [14/50000] s_loss:118.0136 d_loss:-49.6889 val_s_loss:96.4442 val_d_loss:19.9279 cost:31.33
# epoch [15/50000] s_loss:170.8259 d_loss:-33.5370 val_s_loss:86.8558 val_d_loss:3.2829 cost:31.45
# epoch [16/50000] s_loss:140.9614 d_loss:-55.5179 val_s_loss:1646.1453 val_d_loss:-1172.5161 cost:32.21
# epoch [17/50000] s_loss:77.8637 d_loss:-47.9415 val_s_loss:420.0847 val_d_loss:-305.2875 cost:29.98
# epoch [18/50000] s_loss:17.1359 d_loss:-15.1407 val_s_loss:4.4513 val_d_loss:-3.5381 cost:31.40
# epoch [19/50000] s_loss:61.6606 d_loss:-29.8681 val_s_loss:87.9127 val_d_loss:-53.4512 cost:32.88
# epoch [20/50000] s_loss:60.2449 d_loss:-24.5317 val_s_loss:35.6319 val_d_loss:-2.3079 cost:32.75
# epoch [21/50000] s_loss:50.5064 d_loss:-28.3973 val_s_loss:29.1988 val_d_loss:-4.4078 cost:33.23
# epoch [22/50000] s_loss:49.5292 d_loss:-25.9050 val_s_loss:154.7236 val_d_loss:-114.8351 cost:31.45
# epoch [23/50000] s_loss:37.0737 d_loss:-22.7715 val_s_loss:25.2723 val_d_loss:-9.5325 cost:33.83
# epoch [24/50000] s_loss:44.2449 d_loss:-35.8574 val_s_loss:182.7877 val_d_loss:-157.1599 cost:31.68
# epoch [25/50000] s_loss:46.2120 d_loss:-56.0423 val_s_loss:32.1356 val_d_loss:-39.1088 cost:31.44
# epoch [26/50000] s_loss:10.0496 d_loss:-57.2895 val_s_loss:53.4015 val_d_loss:-92.4392 cost:31.12
# epoch [27/50000] s_loss:14.6383 d_loss:-68.2372 val_s_loss:36.1409 val_d_loss:-75.2047 cost:33.50
# epoch [28/50000] s_loss:21.5217 d_loss:-49.0956 val_s_loss:41.8250 val_d_loss:-72.0863 cost:32.46
# epoch [29/50000] s_loss:19.0365 d_loss:-63.2148 val_s_loss:12.8034 val_d_loss:-56.2046 cost:33.28
# epoch [30/50000] s_loss:180.6029 d_loss:-69.9049 val_s_loss:170.9662 val_d_loss:-44.7859 cost:31.90
# epoch [31/50000] s_loss:43.3029 d_loss:-64.5418 val_s_loss:26.8483 val_d_loss:-54.0153 cost:33.97
# epoch [32/50000] s_loss:21.6259 d_loss:-66.5513 val_s_loss:0.8939 val_d_loss:-60.8178 cost:32.13
# epoch [33/50000] s_loss:105.7095 d_loss:-47.9211 val_s_loss:95.3740 val_d_loss:-47.3817 cost:33.42
# epoch [34/50000] s_loss:1.1774 d_loss:-68.6485 val_s_loss:38.1408 val_d_loss:-100.9201 cost:34.69
# epoch [35/50000] s_loss:8.3581 d_loss:-66.8869 val_s_loss:-3.2310 val_d_loss:-54.2322 cost:33.77
# epoch [36/50000] s_loss:85.1250 d_loss:-52.9431 val_s_loss:68.7732 val_d_loss:-31.3675 cost:32.66
# epoch [37/50000] s_loss:13.9178 d_loss:-68.8517 val_s_loss:11.8449 val_d_loss:-62.8996 cost:32.09
# epoch [38/50000] s_loss:18.9520 d_loss:-72.5166 val_s_loss:68.7446 val_d_loss:-115.6259 cost:33.40
# epoch [39/50000] s_loss:53.5881 d_loss:-61.9905 val_s_loss:41.5788 val_d_loss:-54.5029 cost:32.25
# epoch [40/50000] s_loss:16.5498 d_loss:-77.1067 val_s_loss:0.3979 val_d_loss:-50.8738 cost:33.22
# epoch [41/50000] s_loss:107.8604 d_loss:-74.0359 val_s_loss:93.8894 val_d_loss:-47.5647 cost:31.75
# epoch [42/50000] s_loss:1.1928 d_loss:-68.5100 val_s_loss:-8.3373 val_d_loss:-54.3823 cost:30.96
# epoch [43/50000] s_loss:37.5599 d_loss:-68.8867 val_s_loss:172.0734 val_d_loss:-186.4253 cost:33.48
# epoch [44/50000] s_loss:40.5922 d_loss:-67.2960 val_s_loss:43.7201 val_d_loss:-64.1520 cost:33.82
# epoch [45/50000] s_loss:56.3343 d_loss:-57.4585 val_s_loss:95.8024 val_d_loss:-89.6179 cost:30.05
# epoch [46/50000] s_loss:96.2544 d_loss:-47.3848 val_s_loss:88.9575 val_d_loss:-37.5651 cost:33.68
# epoch [47/50000] s_loss:-89.9126 d_loss:-72.5007 val_s_loss:-2.7779 val_d_loss:-60.4385 cost:31.49
# epoch [48/50000] s_loss:680.5325 d_loss:-382.2159 val_s_loss:2773.3267 val_d_loss:-1706.6016 cost:33.22
# epoch [49/50000] s_loss:-8.6698 d_loss:7.7539 val_s_loss:-7.9198 val_d_loss:7.4329 cost:33.78
# epoch [50/50000] s_loss:-6.2458 d_loss:-0.2016 val_s_loss:-4.9284 val_d_loss:-2.2474 cost:32.32
# epoch [51/50000] s_loss:-9.7617 d_loss:-9.7152 val_s_loss:-11.3571 val_d_loss:-7.7583 cost:34.10
# epoch [52/50000] s_loss:28.3041 d_loss:-12.5236 val_s_loss:29.3698 val_d_loss:-17.3279 cost:31.99
# epoch [53/50000] s_loss:190.4413 d_loss:-90.5453 val_s_loss:319.9333 val_d_loss:-162.1505 cost:35.05
# epoch [54/50000] s_loss:142.5899 d_loss:-84.4449 val_s_loss:335.8968 val_d_loss:-203.6752 cost:33.03
# epoch [55/50000] s_loss:242.5022 d_loss:-45.5193 val_s_loss:1152.6240 val_d_loss:-886.4996 cost:35.09
# epoch [56/50000] s_loss:246.2459 d_loss:-118.4391 val_s_loss:962.5004 val_d_loss:-459.8401 cost:30.54
# epoch [57/50000] s_loss:119.0737 d_loss:-78.2403 val_s_loss:46.9070 val_d_loss:5.6415 cost:34.30
# epoch [58/50000] s_loss:108.2526 d_loss:-51.5159 val_s_loss:82.6905 val_d_loss:17.4122 cost:32.51
# epoch [59/50000] s_loss:165.3981 d_loss:-70.9122 val_s_loss:2517.9858 val_d_loss:-1435.6250 cost:32.93
# epoch [60/50000] s_loss:163.6494 d_loss:-75.9392 val_s_loss:99.0854 val_d_loss:-48.3957 cost:33.05
# epoch [61/50000] s_loss:140.7681 d_loss:-75.5420 val_s_loss:106.5495 val_d_loss:-50.5083 cost:33.52
# epoch [62/50000] s_loss:160.8411 d_loss:-97.3499 val_s_loss:106.5182 val_d_loss:-58.5060 cost:33.03
# epoch [63/50000] s_loss:167.0598 d_loss:-74.3352 val_s_loss:107.0609 val_d_loss:-51.9570 cost:33.61
# epoch [64/50000] s_loss:152.3464 d_loss:-76.2720 val_s_loss:1687.7931 val_d_loss:-861.8855 cost:32.48
# epoch [65/50000] s_loss:159.7372 d_loss:-81.9908 val_s_loss:1021.5167 val_d_loss:-933.1488 cost:32.36
# epoch [66/50000] s_loss:137.0167 d_loss:-77.9840 val_s_loss:2809.4048 val_d_loss:-2210.5518 cost:32.40
# epoch [67/50000] s_loss:123.6699 d_loss:-88.9084 val_s_loss:178.1362 val_d_loss:-134.0119 cost:33.02
# epoch [68/50000] s_loss:124.6131 d_loss:-83.7510 val_s_loss:100.4707 val_d_loss:-59.3805 cost:30.50
# epoch [69/50000] s_loss:124.0035 d_loss:-72.9297 val_s_loss:362.8061 val_d_loss:-241.1640 cost:32.17
# epoch [70/50000] s_loss:93.9303 d_loss:-66.2283 val_s_loss:108.1095 val_d_loss:-61.5820 cost:32.89
# epoch [71/50000] s_loss:88.0929 d_loss:-76.0532 val_s_loss:106.5503 val_d_loss:-81.1345 cost:32.47
# epoch [72/50000] s_loss:45.0527 d_loss:-62.2229 val_s_loss:62.4579 val_d_loss:-58.4497 cost:32.66
# epoch [73/50000] s_loss:68.0054 d_loss:-56.7807 val_s_loss:55.3294 val_d_loss:-62.2117 cost:31.43
# epoch [74/50000] s_loss:44.8220 d_loss:-60.2470 val_s_loss:33.2142 val_d_loss:-54.7196 cost:32.48
# epoch [75/50000] s_loss:58.3726 d_loss:-68.8307 val_s_loss:11.3951 val_d_loss:-50.6761 cost:32.74
# epoch [76/50000] s_loss:154.7168 d_loss:-59.0826 val_s_loss:152.0893 val_d_loss:-62.3173 cost:32.79
# epoch [77/50000] s_loss:93.7182 d_loss:-59.4979 val_s_loss:75.6754 val_d_loss:-38.2164 cost:33.19
# epoch [78/50000] s_loss:62.5283 d_loss:-59.9226 val_s_loss:53.1936 val_d_loss:-46.2754 cost:32.08
# epoch [79/50000] s_loss:93.6429 d_loss:-50.2101 val_s_loss:82.9666 val_d_loss:-37.7882 cost:34.90
# epoch [80/50000] s_loss:79.8535 d_loss:-56.8335 val_s_loss:69.0149 val_d_loss:-50.2913 cost:32.05
# epoch [81/50000] s_loss:93.1154 d_loss:-55.6829 val_s_loss:78.5570 val_d_loss:-54.2011 cost:34.57
# epoch [82/50000] s_loss:58.9203 d_loss:-66.2868 val_s_loss:52.1599 val_d_loss:-50.3861 cost:33.13
# epoch [83/50000] s_loss:79.9678 d_loss:-52.6808 val_s_loss:72.7224 val_d_loss:-42.4893 cost:33.97
# epoch [84/50000] s_loss:66.6242 d_loss:-62.1417 val_s_loss:109.4125 val_d_loss:-99.3507 cost:32.52
# epoch [85/50000] s_loss:71.9124 d_loss:-60.1876 val_s_loss:61.2036 val_d_loss:-47.5276 cost:32.61
# epoch [86/50000] s_loss:63.3844 d_loss:-66.1419 val_s_loss:50.4193 val_d_loss:-63.4760 cost:33.10
# epoch [87/50000] s_loss:71.9842 d_loss:-59.8927 val_s_loss:60.4313 val_d_loss:-60.7825 cost:34.24
# epoch [88/50000] s_loss:82.8783 d_loss:-67.8583 val_s_loss:41.2635 val_d_loss:-54.6763 cost:31.80
# epoch [89/50000] s_loss:92.9609 d_loss:-55.3757 val_s_loss:86.4046 val_d_loss:-76.0183 cost:33.01
# epoch [90/50000] s_loss:36.8787 d_loss:-79.8513 val_s_loss:72.8464 val_d_loss:-96.8661 cost:33.01
# epoch [91/50000] s_loss:47.0865 d_loss:-75.9615 val_s_loss:35.6379 val_d_loss:-64.7104 cost:33.03
# epoch [92/50000] s_loss:72.2391 d_loss:-63.4373 val_s_loss:64.3282 val_d_loss:-53.1503 cost:32.22
# epoch [93/50000] s_loss:55.5105 d_loss:-72.5288 val_s_loss:52.7048 val_d_loss:-75.9631 cost:33.44
# epoch [94/50000] s_loss:39.8258 d_loss:-68.7303 val_s_loss:29.8066 val_d_loss:-54.1269 cost:33.48
# epoch [95/50000] s_loss:-6.2515 d_loss:-66.6748 val_s_loss:-9.6551 val_d_loss:-52.8343 cost:32.92
# epoch [96/50000] s_loss:54.3879 d_loss:-68.4307 val_s_loss:43.2475 val_d_loss:-65.9858 cost:33.53
# epoch [97/50000] s_loss:1.1961 d_loss:-71.2548 val_s_loss:1.9015 val_d_loss:-58.1254 cost:32.14
# epoch [98/50000] s_loss:38.5744 d_loss:-68.5523 val_s_loss:18.9664 val_d_loss:-74.2121 cost:33.70
# epoch [99/50000] s_loss:109.1011 d_loss:-69.5236 val_s_loss:95.3989 val_d_loss:-54.4335 cost:34.12
# epoch [100/50000] s_loss:18.3634 d_loss:-84.5199 val_s_loss:24.8913 val_d_loss:-97.6035 cost:32.27
# epoch [101/50000] s_loss:-55.9093 d_loss:-85.2971 val_s_loss:-44.1421 val_d_loss:-74.7619 cost:33.62
# epoch [102/50000] s_loss:110.0598 d_loss:-114.9997 val_s_loss:90.0084 val_d_loss:-67.9377 cost:32.64
# epoch [103/50000] s_loss:-6.9921 d_loss:-71.0346 val_s_loss:8.7903 val_d_loss:-75.6884 cost:32.76
# epoch [104/50000] s_loss:69.6473 d_loss:-83.0487 val_s_loss:57.1039 val_d_loss:-38.4247 cost:34.05
# epoch [105/50000] s_loss:32.6866 d_loss:-77.5440 val_s_loss:34.3590 val_d_loss:-93.7291 cost:31.92
# epoch [106/50000] s_loss:-7.1513 d_loss:-92.3124 val_s_loss:-12.2168 val_d_loss:-66.8928 cost:33.99
# epoch [107/50000] s_loss:-17.1867 d_loss:-76.7031 val_s_loss:16.3683 val_d_loss:-84.0571 cost:33.17
# epoch [108/50000] s_loss:83.0117 d_loss:-86.7354 val_s_loss:66.8879 val_d_loss:-60.8689 cost:35.05
# epoch [109/50000] s_loss:12.9968 d_loss:-78.6013 val_s_loss:6.7615 val_d_loss:-92.5852 cost:33.77
# epoch [110/50000] s_loss:-53.5579 d_loss:-82.1042 val_s_loss:-54.1026 val_d_loss:-73.0497 cost:33.03
# epoch [111/50000] s_loss:24.5797 d_loss:-75.2863 val_s_loss:3.4612 val_d_loss:-55.4889 cost:32.79
# epoch [112/50000] s_loss:73.4556 d_loss:-87.0714 val_s_loss:70.6454 val_d_loss:-53.4243 cost:33.18
# epoch [113/50000] s_loss:1.3971 d_loss:-83.2981 val_s_loss:10.5506 val_d_loss:-94.0052 cost:33.24
# epoch [114/50000] s_loss:-34.7543 d_loss:-92.9501 val_s_loss:-46.0076 val_d_loss:-71.7450 cost:32.50
# epoch [115/50000] s_loss:-58.0262 d_loss:-89.3381 val_s_loss:-59.7798 val_d_loss:-77.5271 cost:31.46
# epoch [116/50000] s_loss:-44.2012 d_loss:-82.4658 val_s_loss:-41.6669 val_d_loss:-73.4758 cost:31.99
# epoch [117/50000] s_loss:82.9977 d_loss:-71.2251 val_s_loss:97.0429 val_d_loss:-59.0636 cost:33.49
# epoch [118/50000] s_loss:37.9134 d_loss:-67.0701 val_s_loss:20.9564 val_d_loss:-55.2660 cost:33.28
# epoch [119/50000] s_loss:-82.7347 d_loss:-82.4865 val_s_loss:-80.1877 val_d_loss:-73.6464 cost:33.76
# epoch [120/50000] s_loss:-9.8259 d_loss:-68.9128 val_s_loss:-8.8693 val_d_loss:-74.1251 cost:33.56
# epoch [121/50000] s_loss:189.0945 d_loss:-108.6222 val_s_loss:186.9537 val_d_loss:0.2749 cost:33.53
# epoch [122/50000] s_loss:-4.6895 d_loss:-74.3745 val_s_loss:-1.7994 val_d_loss:-99.9359 cost:33.69
# epoch [123/50000] s_loss:-28.7155 d_loss:-86.3051 val_s_loss:-44.4126 val_d_loss:-71.4647 cost:33.98
# epoch [124/50000] s_loss:-41.9839 d_loss:-99.1766 val_s_loss:-55.8659 val_d_loss:-77.7225 cost:33.74
# epoch [125/50000] s_loss:-11.8543 d_loss:-98.2286 val_s_loss:-24.0538 val_d_loss:-74.4792 cost:31.98
# epoch [126/50000] s_loss:-45.1552 d_loss:-88.2963 val_s_loss:-24.0392 val_d_loss:-82.0924 cost:33.67
# epoch [127/50000] s_loss:616.7236 d_loss:-392.1274 val_s_loss:595.9231 val_d_loss:150.9898 cost:34.64
# epoch [128/50000] s_loss:96.6449 d_loss:-91.4380 val_s_loss:64.8652 val_d_loss:-64.6835 cost:31.81
# epoch [129/50000] s_loss:68.8044 d_loss:-106.6398 val_s_loss:29.0983 val_d_loss:-71.3295 cost:34.09
# epoch [130/50000] s_loss:30.6473 d_loss:-98.3327 val_s_loss:7.2982 val_d_loss:-68.7658 cost:32.21
# epoch [131/50000] s_loss:72.7808 d_loss:-89.3835 val_s_loss:67.2397 val_d_loss:-78.6402 cost:33.74
# epoch [132/50000] s_loss:90.9494 d_loss:-103.4632 val_s_loss:91.3118 val_d_loss:-94.6370 cost:31.57
# epoch [133/50000] s_loss:-33.6240 d_loss:-94.2498 val_s_loss:-13.4538 val_d_loss:-97.6540 cost:32.83
# epoch [134/50000] s_loss:140.5014 d_loss:-83.9421 val_s_loss:132.7290 val_d_loss:-54.8206 cost:33.40
# epoch [135/50000] s_loss:29.9323 d_loss:-81.2780 val_s_loss:18.2171 val_d_loss:-67.0336 cost:32.66
# epoch [136/50000] s_loss:15.4140 d_loss:-86.2289 val_s_loss:93.1636 val_d_loss:-150.9212 cost:33.76
# epoch [137/50000] s_loss:123.3176 d_loss:-83.9415 val_s_loss:118.5283 val_d_loss:-57.7673 cost:33.43
# epoch [138/50000] s_loss:16.2472 d_loss:-76.4509 val_s_loss:19.3798 val_d_loss:-79.5954 cost:33.36
# epoch [139/50000] s_loss:-47.3126 d_loss:-99.5787 val_s_loss:-52.1608 val_d_loss:-58.3638 cost:32.99
# epoch [140/50000] s_loss:45.4340 d_loss:-93.9713 val_s_loss:29.3403 val_d_loss:-52.9219 cost:32.96
# epoch [141/50000] s_loss:87.6021 d_loss:-71.8854 val_s_loss:197.7413 val_d_loss:-175.1483 cost:32.95
# epoch [142/50000] s_loss:0.2029 d_loss:-81.1495 val_s_loss:14.6210 val_d_loss:-72.9946 cost:33.00
# epoch [143/50000] s_loss:30.0845 d_loss:-80.3136 val_s_loss:91.3233 val_d_loss:-134.6566 cost:30.92
# epoch [144/50000] s_loss:60.3317 d_loss:-73.6947 val_s_loss:48.2964 val_d_loss:-68.2981 cost:33.10
# epoch [145/50000] s_loss:11.1081 d_loss:-81.2655 val_s_loss:4.8525 val_d_loss:-64.1667 cost:33.87
# epoch [146/50000] s_loss:10.3259 d_loss:-68.9588 val_s_loss:7.9042 val_d_loss:-70.7388 cost:32.34
# epoch [147/50000] s_loss:58.9723 d_loss:-67.5699 val_s_loss:49.3914 val_d_loss:-66.9787 cost:33.92
# epoch [148/50000] s_loss:38.6929 d_loss:-72.6437 val_s_loss:28.7409 val_d_loss:-63.6982 cost:33.29
# epoch [149/50000] s_loss:-9.6971 d_loss:-75.1271 val_s_loss:-19.2731 val_d_loss:-68.8814 cost:32.61
# epoch [150/50000] s_loss:56.0352 d_loss:-87.8095 val_s_loss:43.7356 val_d_loss:-75.0067 cost:34.01
# epoch [151/50000] s_loss:11.6477 d_loss:-70.9901 val_s_loss:19.8828 val_d_loss:-73.5869 cost:33.53
# epoch [152/50000] s_loss:-13.9052 d_loss:-79.9827 val_s_loss:-18.9480 val_d_loss:-71.0873 cost:29.93
# epoch [153/50000] s_loss:-54.4246 d_loss:-79.5589 val_s_loss:-54.8901 val_d_loss:-82.9244 cost:32.31
# epoch [154/50000] s_loss:42.4259 d_loss:-79.2885 val_s_loss:29.8378 val_d_loss:-60.2947 cost:33.66
# epoch [155/50000] s_loss:-0.9705 d_loss:-74.8658 val_s_loss:-19.3902 val_d_loss:-87.2160 cost:33.59
# epoch [156/50000] s_loss:-46.8829 d_loss:-79.9553 val_s_loss:-55.6680 val_d_loss:-77.1596 cost:31.25
# epoch [157/50000] s_loss:7.1670 d_loss:-76.3525 val_s_loss:46.0709 val_d_loss:-129.3448 cost:32.15
# epoch [158/50000] s_loss:51.0141 d_loss:-84.9817 val_s_loss:32.5405 val_d_loss:-57.0675 cost:32.43
# epoch [159/50000] s_loss:-0.7219 d_loss:-80.5475 val_s_loss:-12.3708 val_d_loss:-77.5827 cost:33.40
# epoch [160/50000] s_loss:-32.2686 d_loss:-79.1363 val_s_loss:1.5707 val_d_loss:-85.8531 cost:31.03
# epoch [161/50000] s_loss:38.1583 d_loss:-77.5177 val_s_loss:27.9562 val_d_loss:-72.8085 cost:33.05
# epoch [162/50000] s_loss:43.2880 d_loss:-67.3036 val_s_loss:32.0885 val_d_loss:-59.9739 cost:32.56
# epoch [163/50000] s_loss:-5.2627 d_loss:-76.1048 val_s_loss:11.2121 val_d_loss:-81.8653 cost:32.46
# epoch [164/50000] s_loss:41.8169 d_loss:-65.3312 val_s_loss:41.2659 val_d_loss:-76.7164 cost:33.36
# epoch [165/50000] s_loss:19.2516 d_loss:-69.2482 val_s_loss:11.1888 val_d_loss:-83.5148 cost:31.63
# epoch [166/50000] s_loss:-16.5888 d_loss:-70.9709 val_s_loss:-16.8380 val_d_loss:-78.2857 cost:33.71
# epoch [167/50000] s_loss:1.3792 d_loss:-72.3783 val_s_loss:-8.4976 val_d_loss:-70.7522 cost:31.64
# epoch [168/50000] s_loss:12.7187 d_loss:-69.7610 val_s_loss:9.3829 val_d_loss:-67.5520 cost:32.17
# epoch [169/50000] s_loss:4.6469 d_loss:-69.4622 val_s_loss:-1.9003 val_d_loss:-78.8301 cost:32.44
# epoch [170/50000] s_loss:-22.2850 d_loss:-71.8647 val_s_loss:37.8617 val_d_loss:-109.3914 cost:33.80
# epoch [171/50000] s_loss:9.4886 d_loss:-76.7342 val_s_loss:1.4988 val_d_loss:-64.6345 cost:32.83
# epoch [172/50000] s_loss:9.7692 d_loss:-74.1914 val_s_loss:1.2647 val_d_loss:-69.7052 cost:31.90
# epoch [173/50000] s_loss:-16.0790 d_loss:-76.2597 val_s_loss:-18.6221 val_d_loss:-65.2142 cost:33.71
# epoch [174/50000] s_loss:-13.7576 d_loss:-70.6469 val_s_loss:2.0894 val_d_loss:-81.4975 cost:32.07
# epoch [175/50000] s_loss:18.9974 d_loss:-72.7637 val_s_loss:18.5608 val_d_loss:-71.0550 cost:33.44
# epoch [176/50000] s_loss:12.3051 d_loss:-72.8715 val_s_loss:5.8741 val_d_loss:-64.1646 cost:29.97
# epoch [177/50000] s_loss:-23.0025 d_loss:-71.2549 val_s_loss:-18.5001 val_d_loss:-75.1706 cost:33.44
# epoch [178/50000] s_loss:35.2890 d_loss:-85.9293 val_s_loss:22.7276 val_d_loss:-56.2740 cost:32.72
# epoch [179/50000] s_loss:-4.8791 d_loss:-79.6149 val_s_loss:-11.3970 val_d_loss:-69.4378 cost:33.51
# epoch [180/50000] s_loss:-40.8195 d_loss:-86.6387 val_s_loss:-40.6988 val_d_loss:-88.4519 cost:32.04
# epoch [181/50000] s_loss:-78.4120 d_loss:-74.9597 val_s_loss:-25.4788 val_d_loss:-92.2179 cost:33.26
# epoch [182/50000] s_loss:60.2888 d_loss:-112.0383 val_s_loss:83.3411 val_d_loss:-71.8135 cost:32.68
# epoch [183/50000] s_loss:29.9547 d_loss:-70.7371 val_s_loss:26.4638 val_d_loss:-61.1350 cost:33.10
# epoch [184/50000] s_loss:-18.3083 d_loss:-81.1516 val_s_loss:-24.1346 val_d_loss:-77.3469 cost:32.38
# epoch [185/50000] s_loss:-62.6041 d_loss:-81.1456 val_s_loss:-58.0346 val_d_loss:-77.4604 cost:32.17
# epoch [186/50000] s_loss:-8.1475 d_loss:-75.5398 val_s_loss:34.7187 val_d_loss:-131.0181 cost:32.05
# epoch [187/50000] s_loss:69.9149 d_loss:-89.8843 val_s_loss:120.1412 val_d_loss:-124.6352 cost:32.81
# epoch [188/50000] s_loss:9.7023 d_loss:-74.1957 val_s_loss:6.6154 val_d_loss:-75.8308 cost:32.76
# epoch [189/50000] s_loss:-33.2796 d_loss:-80.6565 val_s_loss:-29.2668 val_d_loss:-87.9652 cost:33.07
# epoch [190/50000] s_loss:-14.8666 d_loss:-76.6879 val_s_loss:-20.2719 val_d_loss:-76.6201 cost:32.49
# epoch [191/50000] s_loss:35.9639 d_loss:-84.1475 val_s_loss:34.9273 val_d_loss:-77.1583 cost:31.85
# epoch [192/50000] s_loss:20.6018 d_loss:-75.2943 val_s_loss:18.6533 val_d_loss:-89.3021 cost:31.92
# epoch [193/50000] s_loss:-35.1463 d_loss:-82.1151 val_s_loss:-20.9664 val_d_loss:-97.3400 cost:31.53
# epoch [194/50000] s_loss:5.9988 d_loss:-79.2880 val_s_loss:-10.5904 val_d_loss:-82.7239 cost:32.20
# epoch [195/50000] s_loss:52.7434 d_loss:-83.5933 val_s_loss:38.2447 val_d_loss:-73.5048 cost:33.53
# epoch [196/50000] s_loss:8.5770 d_loss:-73.4948 val_s_loss:1.1334 val_d_loss:-76.7875 cost:30.77
# epoch [197/50000] s_loss:-25.3701 d_loss:-77.4104 val_s_loss:-19.5176 val_d_loss:-65.7111 cost:32.58
# epoch [198/50000] s_loss:4.3180 d_loss:-69.8537 val_s_loss:3.1845 val_d_loss:-73.1225 cost:32.20
# epoch [199/50000] s_loss:26.0907 d_loss:-83.8330 val_s_loss:25.7570 val_d_loss:-78.0305 cost:32.90
# epoch [200/50000] s_loss:-6.7789 d_loss:-69.3020 val_s_loss:-1.5724 val_d_loss:-92.0065 cost:33.82
# epoch [201/50000] s_loss:-35.4039 d_loss:-75.3429 val_s_loss:-29.4761 val_d_loss:-71.1534 cost:33.04
# epoch [202/50000] s_loss:24.3168 d_loss:-79.5790 val_s_loss:18.1728 val_d_loss:-74.9106 cost:33.47
# epoch [203/50000] s_loss:29.4316 d_loss:-75.7768 val_s_loss:24.6180 val_d_loss:-67.4719 cost:32.83
# epoch [204/50000] s_loss:7.4825 d_loss:-77.6950 val_s_loss:5.3312 val_d_loss:-81.8431 cost:30.25
# epoch [205/50000] s_loss:-22.8193 d_loss:-80.5476 val_s_loss:-8.2332 val_d_loss:-79.1970 cost:33.96
# epoch [206/50000] s_loss:-0.5599 d_loss:-74.7039 val_s_loss:-5.5431 val_d_loss:-66.7018 cost:33.33
# epoch [207/50000] s_loss:38.0493 d_loss:-72.5193 val_s_loss:30.3294 val_d_loss:-65.8837 cost:32.58
# epoch [208/50000] s_loss:6.6300 d_loss:-74.1450 val_s_loss:0.5097 val_d_loss:-62.2489 cost:31.52
# epoch [209/50000] s_loss:-25.3019 d_loss:-75.9885 val_s_loss:-21.9732 val_d_loss:-65.8537 cost:33.58
# epoch [210/50000] s_loss:37.6021 d_loss:-99.7505 val_s_loss:30.0177 val_d_loss:-53.6060 cost:31.30
# epoch [211/50000] s_loss:3.6011 d_loss:-73.0622 val_s_loss:1.3867 val_d_loss:-71.0464 cost:33.17
# epoch [212/50000] s_loss:-19.7751 d_loss:-76.0883 val_s_loss:-24.9948 val_d_loss:-61.8262 cost:32.02
# epoch [213/50000] s_loss:4.6951 d_loss:-70.4833 val_s_loss:3.3880 val_d_loss:-73.8384 cost:32.00
# epoch [214/50000] s_loss:53.9141 d_loss:-85.0374 val_s_loss:118.5304 val_d_loss:-127.9546 cost:34.69
# epoch [215/50000] s_loss:2.2322 d_loss:-71.9578 val_s_loss:6.6941 val_d_loss:-93.8098 cost:30.39
# epoch [216/50000] s_loss:-31.2990 d_loss:-76.5956 val_s_loss:-21.1163 val_d_loss:-74.8556 cost:33.42
# epoch [217/50000] s_loss:47.4270 d_loss:-79.9132 val_s_loss:346.2009 val_d_loss:-390.1507 cost:32.76
# epoch [218/50000] s_loss:17.6204 d_loss:-74.5092 val_s_loss:14.1393 val_d_loss:-66.1968 cost:33.64
# epoch [219/50000] s_loss:6.4955 d_loss:-75.4938 val_s_loss:300.3732 val_d_loss:-359.0125 cost:32.31
# epoch [220/50000] s_loss:3.7042 d_loss:-71.8125 val_s_loss:188.3727 val_d_loss:-249.7989 cost:32.60
# epoch [221/50000] s_loss:30.3637 d_loss:-72.6774 val_s_loss:23.0324 val_d_loss:-71.4788 cost:30.62
# epoch [222/50000] s_loss:40.3542 d_loss:-66.8524 val_s_loss:36.5283 val_d_loss:-97.0285 cost:32.32
# epoch [223/50000] s_loss:-0.0230 d_loss:-71.6438 val_s_loss:14.5457 val_d_loss:-85.5654 cost:33.31
# epoch [224/50000] s_loss:-2.5783 d_loss:-74.2097 val_s_loss:-4.7263 val_d_loss:-59.9139 cost:33.14
# epoch [225/50000] s_loss:27.9919 d_loss:-70.3856 val_s_loss:21.7214 val_d_loss:-75.2418 cost:34.27
# epoch [226/50000] s_loss:51.0218 d_loss:-72.4242 val_s_loss:57.3393 val_d_loss:-69.7663 cost:35.22
# epoch [227/50000] s_loss:17.1304 d_loss:-70.4049 val_s_loss:15.7670 val_d_loss:-64.5278 cost:34.38
# epoch [228/50000] s_loss:-29.6900 d_loss:-74.7244 val_s_loss:-30.9033 val_d_loss:-80.2532 cost:33.46
# epoch [229/50000] s_loss:25.7653 d_loss:-67.2601 val_s_loss:23.4552 val_d_loss:-68.6183 cost:30.95
# epoch [230/50000] s_loss:47.2336 d_loss:-80.0715 val_s_loss:44.7312 val_d_loss:-58.7019 cost:34.14
# epoch [231/50000] s_loss:-2.9233 d_loss:-75.3348 val_s_loss:-4.5653 val_d_loss:-65.7759 cost:34.15
# epoch [232/50000] s_loss:-18.1012 d_loss:-78.5202 val_s_loss:20.9067 val_d_loss:-109.1601 cost:33.59
# epoch [233/50000] s_loss:35.2845 d_loss:-77.5894 val_s_loss:25.3134 val_d_loss:-74.9279 cost:33.69
# epoch [234/50000] s_loss:65.3854 d_loss:-70.2416 val_s_loss:61.0744 val_d_loss:-79.2433 cost:33.93
# epoch [235/50000] s_loss:-0.1955 d_loss:-70.7204 val_s_loss:-3.3281 val_d_loss:-64.5178 cost:32.78
# epoch [236/50000] s_loss:-27.8708 d_loss:-72.4467 val_s_loss:-26.3971 val_d_loss:-80.1681 cost:32.51
# epoch [237/50000] s_loss:15.6529 d_loss:-71.0456 val_s_loss:24.0164 val_d_loss:-80.1883 cost:33.49
# epoch [238/50000] s_loss:107.6598 d_loss:-73.7107 val_s_loss:105.6959 val_d_loss:-55.1182 cost:34.00
# epoch [239/50000] s_loss:-17.1563 d_loss:-74.5186 val_s_loss:-20.9282 val_d_loss:-80.7416 cost:32.40
# epoch [240/50000] s_loss:-63.1681 d_loss:-82.4214 val_s_loss:-65.6155 val_d_loss:-69.6597 cost:33.33
# epoch [241/50000] s_loss:-72.2797 d_loss:-73.3538 val_s_loss:-60.0412 val_d_loss:-61.4608 cost:31.93
# epoch [242/50000] s_loss:119.7548 d_loss:-129.6026 val_s_loss:144.1841 val_d_loss:-25.1064 cost:31.02
# epoch [243/50000] s_loss:-2.4210 d_loss:-77.9183 val_s_loss:3.3526 val_d_loss:-102.3703 cost:32.46
# epoch [244/50000] s_loss:-22.1357 d_loss:-87.8989 val_s_loss:-29.8507 val_d_loss:-98.3630 cost:32.58
# epoch [245/50000] s_loss:-55.7723 d_loss:-89.9710 val_s_loss:-46.9192 val_d_loss:-100.4939 cost:32.68
# epoch [246/50000] s_loss:-53.3955 d_loss:-93.8096 val_s_loss:-69.5597 val_d_loss:-76.0726 cost:32.20
# epoch [247/50000] s_loss:-1.9588 d_loss:-84.5131 val_s_loss:432.5926 val_d_loss:-512.5794 cost:31.29
# epoch [248/50000] s_loss:-29.1122 d_loss:-92.8074 val_s_loss:-24.2432 val_d_loss:-87.1101 cost:31.78
# epoch [249/50000] s_loss:19.9752 d_loss:-91.9698 val_s_loss:128.5159 val_d_loss:-202.2728 cost:32.94
# epoch [250/50000] s_loss:-42.2432 d_loss:-84.3709 val_s_loss:-43.9773 val_d_loss:-81.4891 cost:31.47
# epoch [251/50000] s_loss:-35.0280 d_loss:-98.4065 val_s_loss:-47.6114 val_d_loss:-81.0662 cost:31.63
# epoch [252/50000] s_loss:-32.0898 d_loss:-80.2628 val_s_loss:45.1733 val_d_loss:-152.2572 cost:31.15
# epoch [253/50000] s_loss:324.9360 d_loss:-406.7310 val_s_loss:304.8250 val_d_loss:93.2132 cost:33.14
# epoch [254/50000] s_loss:-32.0815 d_loss:-84.5264 val_s_loss:-33.6088 val_d_loss:-86.0044 cost:31.87
# epoch [255/50000] s_loss:-40.7776 d_loss:-113.0167 val_s_loss:-42.1383 val_d_loss:-85.5536 cost:30.97
# epoch [256/50000] s_loss:-8.0250 d_loss:-103.1193 val_s_loss:-19.1876 val_d_loss:-100.0451 cost:30.32
# epoch [257/50000] s_loss:-35.6585 d_loss:-105.9059 val_s_loss:-22.7876 val_d_loss:-111.6246 cost:32.27
# epoch [258/50000] s_loss:-37.6856 d_loss:-103.2349 val_s_loss:-42.4163 val_d_loss:-97.3636 cost:32.65
# epoch [259/50000] s_loss:-32.0241 d_loss:-117.1610 val_s_loss:-64.2724 val_d_loss:-87.8210 cost:31.34
# epoch [260/50000] s_loss:-53.6351 d_loss:-103.1966 val_s_loss:-11.8566 val_d_loss:-111.8615 cost:33.37
# epoch [261/50000] s_loss:-55.5668 d_loss:-97.0906 val_s_loss:-72.3714 val_d_loss:-82.2174 cost:32.06
# epoch [262/50000] s_loss:-59.1211 d_loss:-100.5205 val_s_loss:-77.3245 val_d_loss:-83.1828 cost:30.62
# epoch [263/50000] s_loss:-42.9938 d_loss:-89.7027 val_s_loss:-49.2342 val_d_loss:-74.2849 cost:32.96
# epoch [264/50000] s_loss:-62.9177 d_loss:-87.7187 val_s_loss:-78.5985 val_d_loss:-68.3188 cost:31.80
# epoch [265/50000] s_loss:-47.4701 d_loss:-68.9154 val_s_loss:-50.4003 val_d_loss:-62.8614 cost:31.01
# epoch [266/50000] s_loss:210.2828 d_loss:-137.9200 val_s_loss:205.1596 val_d_loss:-3.7467 cost:33.23
# epoch [267/50000] s_loss:-12.5527 d_loss:-85.7512 val_s_loss:-19.2492 val_d_loss:-84.9986 cost:33.27
# epoch [268/50000] s_loss:-53.9793 d_loss:-95.6768 val_s_loss:-51.2184 val_d_loss:-93.2968 cost:31.93
# epoch [269/50000] s_loss:-58.7992 d_loss:-96.9351 val_s_loss:-60.2687 val_d_loss:-89.5229 cost:34.24
# epoch [270/50000] s_loss:-59.7160 d_loss:-96.3962 val_s_loss:-69.2206 val_d_loss:-99.8446 cost:32.33
# epoch [271/50000] s_loss:-63.2237 d_loss:-92.5909 val_s_loss:-38.3046 val_d_loss:-102.1938 cost:32.82
# epoch [272/50000] s_loss:-59.0895 d_loss:-94.4087 val_s_loss:-68.2576 val_d_loss:-82.7976 cost:32.16
# epoch [273/50000] s_loss:-53.5229 d_loss:-92.7251 val_s_loss:-62.9021 val_d_loss:-82.3394 cost:33.33
# epoch [274/50000] s_loss:-53.0953 d_loss:-94.3411 val_s_loss:-62.3585 val_d_loss:-79.7959 cost:31.52
# epoch [275/50000] s_loss:-73.3142 d_loss:-90.5845 val_s_loss:-77.6050 val_d_loss:-81.2466 cost:33.38
# epoch [276/50000] s_loss:-57.7215 d_loss:-87.4998 val_s_loss:-35.0033 val_d_loss:-97.4101 cost:32.94
# epoch [277/50000] s_loss:-36.0056 d_loss:-80.9662 val_s_loss:-16.3904 val_d_loss:-80.0730 cost:33.11
# epoch [278/50000] s_loss:136.2764 d_loss:-87.3748 val_s_loss:124.6858 val_d_loss:-13.9143 cost:31.89
# epoch [279/50000] s_loss:41.8078 d_loss:-83.9293 val_s_loss:35.0955 val_d_loss:-85.3498 cost:33.46
# epoch [280/50000] s_loss:-34.6604 d_loss:-95.8436 val_s_loss:-15.6980 val_d_loss:-111.6118 cost:32.17
# epoch [281/50000] s_loss:-42.9552 d_loss:-91.0325 val_s_loss:-58.5674 val_d_loss:-82.8048 cost:33.43
# epoch [282/50000] s_loss:-40.8804 d_loss:-95.6909 val_s_loss:-49.4050 val_d_loss:-93.3745 cost:33.70
# epoch [283/50000] s_loss:-50.1065 d_loss:-100.2392 val_s_loss:-58.9474 val_d_loss:-82.3578 cost:33.18
# epoch [284/50000] s_loss:-60.7348 d_loss:-90.4614 val_s_loss:-41.0560 val_d_loss:-98.1702 cost:32.97
# epoch [285/50000] s_loss:-3.4257 d_loss:-79.5846 val_s_loss:22.6334 val_d_loss:-80.9238 cost:32.00
# epoch [286/50000] s_loss:83.1095 d_loss:-82.4127 val_s_loss:94.2394 val_d_loss:-91.3566 cost:33.39
# epoch [287/50000] s_loss:36.8925 d_loss:-76.1135 val_s_loss:29.8518 val_d_loss:-72.2172 cost:32.37
# epoch [288/50000] s_loss:-6.5476 d_loss:-86.9328 val_s_loss:-5.9211 val_d_loss:-86.8757 cost:32.58
# epoch [289/50000] s_loss:3.3877 d_loss:-80.5170 val_s_loss:8.7233 val_d_loss:-78.2191 cost:33.27
# epoch [290/50000] s_loss:65.9673 d_loss:-113.5793 val_s_loss:59.9274 val_d_loss:-48.4155 cost:30.90
# epoch [291/50000] s_loss:34.7282 d_loss:-74.3793 val_s_loss:30.2131 val_d_loss:-72.0748 cost:32.82
# epoch [292/50000] s_loss:-27.3637 d_loss:-82.4020 val_s_loss:-29.3575 val_d_loss:-72.2474 cost:32.65
# epoch [293/50000] s_loss:-27.7990 d_loss:-77.4711 val_s_loss:-31.6835 val_d_loss:-64.6203 cost:32.24
# epoch [294/50000] s_loss:23.3250 d_loss:-75.5146 val_s_loss:24.4063 val_d_loss:-80.6702 cost:33.48
# epoch [295/50000] s_loss:52.6325 d_loss:-76.7502 val_s_loss:50.5752 val_d_loss:-84.4162 cost:32.16
# epoch [296/50000] s_loss:39.2048 d_loss:-76.1622 val_s_loss:30.3716 val_d_loss:-61.8196 cost:33.14
# epoch [297/50000] s_loss:10.3022 d_loss:-71.5093 val_s_loss:8.1166 val_d_loss:-65.1304 cost:32.91
# epoch [298/50000] s_loss:5.6073 d_loss:-71.9797 val_s_loss:5.6711 val_d_loss:-72.7590 cost:32.29
# epoch [299/50000] s_loss:20.7798 d_loss:-73.9387 val_s_loss:21.7841 val_d_loss:-67.3661 cost:33.13
# epoch [300/50000] s_loss:38.6280 d_loss:-75.7543 val_s_loss:35.2791 val_d_loss:-78.6558 cost:31.75
# epoch [301/50000] s_loss:39.4434 d_loss:-74.8182 val_s_loss:34.9761 val_d_loss:-64.8363 cost:32.59
# epoch [302/50000] s_loss:17.8803 d_loss:-78.1822 val_s_loss:14.3784 val_d_loss:-64.5728 cost:31.99
# epoch [303/50000] s_loss:14.5527 d_loss:-78.2004 val_s_loss:18.1227 val_d_loss:-82.0499 cost:33.99
# epoch [304/50000] s_loss:25.8689 d_loss:-73.6578 val_s_loss:21.5498 val_d_loss:-63.6686 cost:32.46
# epoch [305/50000] s_loss:39.8765 d_loss:-73.3391 val_s_loss:35.3279 val_d_loss:-68.1993 cost:33.99
# epoch [306/50000] s_loss:32.0412 d_loss:-70.7200 val_s_loss:30.9364 val_d_loss:-71.8831 cost:33.16
# epoch [307/50000] s_loss:21.0136 d_loss:-76.6268 val_s_loss:18.2669 val_d_loss:-60.6628 cost:33.18
# epoch [308/50000] s_loss:29.3172 d_loss:-75.2487 val_s_loss:25.4807 val_d_loss:-70.3014 cost:33.37
# epoch [309/50000] s_loss:37.3688 d_loss:-70.3665 val_s_loss:34.0054 val_d_loss:-85.5527 cost:33.12
# epoch [310/50000] s_loss:31.5205 d_loss:-73.1813 val_s_loss:28.0886 val_d_loss:-71.6694 cost:32.25
# epoch [311/50000] s_loss:22.2180 d_loss:-72.0547 val_s_loss:19.1223 val_d_loss:-74.0123 cost:34.83
# epoch [312/50000] s_loss:24.5156 d_loss:-70.2617 val_s_loss:20.3719 val_d_loss:-71.4595 cost:30.23
# epoch [313/50000] s_loss:32.7575 d_loss:-73.4348 val_s_loss:38.0756 val_d_loss:-66.7621 cost:34.10
# epoch [314/50000] s_loss:37.3537 d_loss:-74.0601 val_s_loss:33.8929 val_d_loss:-63.1619 cost:31.76
# epoch [315/50000] s_loss:14.0167 d_loss:-69.4334 val_s_loss:12.8941 val_d_loss:-79.3325 cost:33.87
# epoch [316/50000] s_loss:8.3346 d_loss:-68.9061 val_s_loss:6.5840 val_d_loss:-68.3812 cost:31.97
# epoch [317/50000] s_loss:49.3073 d_loss:-71.0429 val_s_loss:48.5011 val_d_loss:-80.4798 cost:32.15
# epoch [318/50000] s_loss:14.9612 d_loss:-73.7678 val_s_loss:13.1361 val_d_loss:-60.1082 cost:32.66
# epoch [319/50000] s_loss:-3.4706 d_loss:-68.1469 val_s_loss:1.0044 val_d_loss:-71.1178 cost:33.31
# epoch [320/50000] s_loss:18.7273 d_loss:-68.2052 val_s_loss:14.1785 val_d_loss:-78.7978 cost:31.32
# epoch [321/50000] s_loss:74.3133 d_loss:-85.4843 val_s_loss:71.6819 val_d_loss:-59.0117 cost:32.02
# epoch [322/50000] s_loss:2.0955 d_loss:-70.7519 val_s_loss:-1.1299 val_d_loss:-74.9110 cost:32.57
# epoch [323/50000] s_loss:-28.3719 d_loss:-69.9049 val_s_loss:-23.2372 val_d_loss:-72.0223 cost:33.72
# epoch [324/50000] s_loss:-27.1547 d_loss:-70.9158 val_s_loss:-25.7841 val_d_loss:-83.7821 cost:34.04
# epoch [325/50000] s_loss:63.0860 d_loss:-83.2778 val_s_loss:65.3030 val_d_loss:-76.1948 cost:30.52
# epoch [326/50000] s_loss:53.4903 d_loss:-76.2638 val_s_loss:51.6617 val_d_loss:-60.5852 cost:33.31
# epoch [327/50000] s_loss:-19.6862 d_loss:-75.0369 val_s_loss:-19.0810 val_d_loss:-63.2230 cost:32.54
# epoch [328/50000] s_loss:-24.3200 d_loss:-68.0195 val_s_loss:-20.5294 val_d_loss:-60.8572 cost:33.48
# epoch [329/50000] s_loss:167.5612 d_loss:-158.8179 val_s_loss:693.0711 val_d_loss:-570.1188 cost:33.45
# epoch [330/50000] s_loss:-59.7046 d_loss:-76.1747 val_s_loss:-62.5086 val_d_loss:-80.2992 cost:32.83
# epoch [331/50000] s_loss:-59.2315 d_loss:-80.3882 val_s_loss:-69.2611 val_d_loss:-76.0752 cost:31.76
# epoch [332/50000] s_loss:-62.3096 d_loss:-78.0851 val_s_loss:-64.4994 val_d_loss:-75.9762 cost:33.31
# epoch [333/50000] s_loss:63.9574 d_loss:-92.8940 val_s_loss:77.5074 val_d_loss:-63.2582 cost:31.38
# epoch [334/50000] s_loss:15.1512 d_loss:-87.0156 val_s_loss:6.7069 val_d_loss:-99.3514 cost:33.48
# epoch [335/50000] s_loss:4.6640 d_loss:-89.9763 val_s_loss:-17.5156 val_d_loss:-88.5219 cost:32.92
# epoch [336/50000] s_loss:-26.6302 d_loss:-93.6487 val_s_loss:-38.8714 val_d_loss:-85.3938 cost:33.45
# epoch [337/50000] s_loss:-43.6378 d_loss:-92.4777 val_s_loss:-54.8448 val_d_loss:-89.0445 cost:32.76
# epoch [338/50000] s_loss:-50.1263 d_loss:-85.9450 val_s_loss:-55.1112 val_d_loss:-64.3703 cost:33.39
# epoch [339/50000] s_loss:69.1634 d_loss:-96.0613 val_s_loss:84.2496 val_d_loss:-68.6880 cost:33.95
# epoch [340/50000] s_loss:12.1428 d_loss:-80.6207 val_s_loss:6.4491 val_d_loss:-78.8235 cost:30.99
# epoch [341/50000] s_loss:-48.7770 d_loss:-90.4248 val_s_loss:-58.9854 val_d_loss:-86.4159 cost:33.10
# epoch [342/50000] s_loss:-68.1843 d_loss:-90.7958 val_s_loss:-77.9550 val_d_loss:-97.2228 cost:31.05
# epoch [343/50000] s_loss:-58.7034 d_loss:-82.8025 val_s_loss:-57.6872 val_d_loss:-91.2011 cost:34.26
# epoch [344/50000] s_loss:-50.7173 d_loss:-73.7857 val_s_loss:-47.5168 val_d_loss:-66.9073 cost:32.13
# epoch [345/50000] s_loss:43.5690 d_loss:-78.0546 val_s_loss:33.8791 val_d_loss:-73.5625 cost:34.29
# epoch [346/50000] s_loss:80.3203 d_loss:-82.3207 val_s_loss:147.2184 val_d_loss:-132.5246 cost:34.80
# epoch [347/50000] s_loss:-12.7032 d_loss:-72.9517 val_s_loss:-13.3565 val_d_loss:-67.0453 cost:35.03
# epoch [348/50000] s_loss:-39.2892 d_loss:-76.4132 val_s_loss:-43.3227 val_d_loss:-105.0278 cost:30.48
# epoch [349/50000] s_loss:-31.6882 d_loss:-76.1817 val_s_loss:-18.5773 val_d_loss:-98.8182 cost:34.44
# epoch [350/50000] s_loss:54.3568 d_loss:-73.3928 val_s_loss:51.7850 val_d_loss:-72.7780 cost:33.80
# epoch [351/50000] s_loss:57.4654 d_loss:-71.1205 val_s_loss:54.8310 val_d_loss:-73.6316 cost:34.61
# epoch [352/50000] s_loss:-2.8042 d_loss:-70.6567 val_s_loss:-0.0819 val_d_loss:-62.0881 cost:30.84
# epoch [353/50000] s_loss:-13.2699 d_loss:-70.8134 val_s_loss:-1.3470 val_d_loss:-75.8961 cost:33.00
# epoch [354/50000] s_loss:23.1600 d_loss:-70.5655 val_s_loss:17.3108 val_d_loss:-74.7756 cost:30.55
# epoch [355/50000] s_loss:74.4049 d_loss:-71.6042 val_s_loss:164.9650 val_d_loss:-153.2885 cost:32.65
# epoch [356/50000] s_loss:-0.6689 d_loss:-72.5092 val_s_loss:-0.8713 val_d_loss:-71.4012 cost:33.06
# epoch [357/50000] s_loss:-16.9655 d_loss:-74.4579 val_s_loss:-14.4236 val_d_loss:-66.6925 cost:33.30
# epoch [358/50000] s_loss:-0.1381 d_loss:-69.9775 val_s_loss:-1.3374 val_d_loss:-68.8168 cost:34.89
# epoch [359/50000] s_loss:101.6253 d_loss:-75.4414 val_s_loss:99.8260 val_d_loss:-87.2472 cost:33.78
# epoch [360/50000] s_loss:27.5028 d_loss:-72.1186 val_s_loss:25.7283 val_d_loss:-82.0490 cost:34.12
# epoch [361/50000] s_loss:-16.3605 d_loss:-73.1342 val_s_loss:-17.8595 val_d_loss:-63.1648 cost:34.56
# epoch [362/50000] s_loss:-39.0071 d_loss:-72.8774 val_s_loss:-30.7042 val_d_loss:-67.7422 cost:32.01
# epoch [363/50000] s_loss:72.0502 d_loss:-70.6692 val_s_loss:62.3553 val_d_loss:-58.4113 cost:33.15
# epoch [364/50000] s_loss:47.5570 d_loss:-69.1849 val_s_loss:43.9438 val_d_loss:-57.7730 cost:33.97
# epoch [365/50000] s_loss:0.2160 d_loss:-68.5113 val_s_loss:-2.4047 val_d_loss:-76.8422 cost:32.94
# epoch [366/50000] s_loss:-20.6840 d_loss:-66.2703 val_s_loss:-10.5678 val_d_loss:-57.8457 cost:33.14
# epoch [367/50000] s_loss:55.3403 d_loss:-74.5779 val_s_loss:49.0858 val_d_loss:-64.4957 cost:31.96
# epoch [368/50000] s_loss:67.7618 d_loss:-67.2261 val_s_loss:64.1105 val_d_loss:-74.9602 cost:30.78
# epoch [369/50000] s_loss:9.2540 d_loss:-68.4691 val_s_loss:8.3017 val_d_loss:-71.3137 cost:33.72
# epoch [370/50000] s_loss:-12.2483 d_loss:-62.4859 val_s_loss:-12.2280 val_d_loss:-76.8791 cost:34.39
# epoch [371/50000] s_loss:114.8922 d_loss:-63.8771 val_s_loss:93.5309 val_d_loss:-30.9855 cost:34.73
# epoch [372/50000] s_loss:2.3137 d_loss:-64.9629 val_s_loss:0.7777 val_d_loss:-66.5757 cost:33.01
# epoch [373/50000] s_loss:-36.0293 d_loss:-71.4023 val_s_loss:-38.6200 val_d_loss:-74.8981 cost:33.04
# epoch [374/50000] s_loss:-58.1862 d_loss:-75.8358 val_s_loss:-58.8865 val_d_loss:-60.2326 cost:31.12
# epoch [375/50000] s_loss:96.7388 d_loss:-81.0335 val_s_loss:85.7528 val_d_loss:-44.0957 cost:33.44
# epoch [376/50000] s_loss:27.7394 d_loss:-62.7610 val_s_loss:22.2745 val_d_loss:-76.5761 cost:34.89
# epoch [377/50000] s_loss:-14.9335 d_loss:-71.9291 val_s_loss:-16.7324 val_d_loss:-63.8169 cost:33.08
# epoch [378/50000] s_loss:5.3408 d_loss:-65.7516 val_s_loss:1.4559 val_d_loss:-58.3642 cost:33.11
# epoch [379/50000] s_loss:114.3138 d_loss:-74.2066 val_s_loss:112.6742 val_d_loss:-49.3691 cost:33.99
# epoch [380/50000] s_loss:22.1389 d_loss:-63.1760 val_s_loss:41.9156 val_d_loss:-88.8444 cost:33.94
# epoch [381/50000] s_loss:-23.6010 d_loss:-65.7731 val_s_loss:-27.2475 val_d_loss:-53.9286 cost:33.61
# epoch [382/50000] s_loss:-22.8256 d_loss:-63.4854 val_s_loss:-21.9734 val_d_loss:-63.3601 cost:33.11
# epoch [383/50000] s_loss:143.9341 d_loss:-79.3168 val_s_loss:128.3221 val_d_loss:-33.4653 cost:34.26
# epoch [384/50000] s_loss:17.5054 d_loss:-60.3507 val_s_loss:13.7974 val_d_loss:-71.7046 cost:34.79
# epoch [385/50000] s_loss:-39.5250 d_loss:-67.4183 val_s_loss:-40.5874 val_d_loss:-53.2396 cost:32.23
# epoch [386/50000] s_loss:-41.0665 d_loss:-64.4062 val_s_loss:-33.0714 val_d_loss:-57.4062 cost:33.29
# epoch [387/50000] s_loss:89.2446 d_loss:-69.8386 val_s_loss:78.6888 val_d_loss:-35.4962 cost:35.18
# epoch [388/50000] s_loss:24.3474 d_loss:-65.4129 val_s_loss:18.1459 val_d_loss:-58.1928 cost:33.60
# epoch [389/50000] s_loss:-2.9761 d_loss:-63.6783 val_s_loss:-5.6173 val_d_loss:-45.8482 cost:33.82
# epoch [390/50000] s_loss:9.4953 d_loss:-59.6344 val_s_loss:10.7152 val_d_loss:-47.2961 cost:33.58
# epoch [391/50000] s_loss:82.1940 d_loss:-66.2934 val_s_loss:73.5239 val_d_loss:-53.5900 cost:33.59
# epoch [392/50000] s_loss:47.1601 d_loss:-54.4483 val_s_loss:43.1754 val_d_loss:-48.0788 cost:34.80
# epoch [393/50000] s_loss:19.2878 d_loss:-54.2974 val_s_loss:14.4358 val_d_loss:-45.0999 cost:33.87
# epoch [394/50000] s_loss:31.4198 d_loss:-55.4856 val_s_loss:26.9395 val_d_loss:-50.8300 cost:34.27
# epoch [395/50000] s_loss:90.4663 d_loss:-55.4700 val_s_loss:95.8293 val_d_loss:-53.8207 cost:34.60
# epoch [396/50000] s_loss:19.3096 d_loss:-52.6892 val_s_loss:13.3360 val_d_loss:-49.9167 cost:30.99
# epoch [397/50000] s_loss:-7.8820 d_loss:-52.5235 val_s_loss:-6.6428 val_d_loss:-44.2704 cost:31.34
# epoch [398/50000] s_loss:59.4381 d_loss:-52.4050 val_s_loss:56.7593 val_d_loss:-52.4395 cost:34.96
# epoch [399/50000] s_loss:81.1365 d_loss:-53.6634 val_s_loss:77.4050 val_d_loss:-44.8015 cost:34.52
# epoch [400/50000] s_loss:11.1080 d_loss:-53.2778 val_s_loss:7.8366 val_d_loss:-57.2289 cost:33.30
# epoch [401/50000] s_loss:-10.0835 d_loss:-52.4917 val_s_loss:-7.6314 val_d_loss:-49.1443 cost:33.29
# epoch [402/50000] s_loss:91.9764 d_loss:-59.1576 val_s_loss:82.2037 val_d_loss:-40.3030 cost:30.97
# epoch [403/50000] s_loss:38.6679 d_loss:-51.5374 val_s_loss:34.5025 val_d_loss:-51.5535 cost:32.93
# epoch [404/50000] s_loss:-4.9911 d_loss:-54.4426 val_s_loss:-4.0772 val_d_loss:-45.9962 cost:33.09
# epoch [405/50000] s_loss:15.2871 d_loss:-49.9513 val_s_loss:12.5735 val_d_loss:-46.2355 cost:34.00
# epoch [406/50000] s_loss:109.7828 d_loss:-59.7493 val_s_loss:111.8936 val_d_loss:-53.1184 cost:34.14
# epoch [407/50000] s_loss:19.3767 d_loss:-54.3121 val_s_loss:16.3900 val_d_loss:-60.3911 cost:35.22
# epoch [408/50000] s_loss:-13.7857 d_loss:-59.8797 val_s_loss:-3.3252 val_d_loss:-53.9104 cost:33.19
# epoch [409/50000] s_loss:2.5509 d_loss:-55.4936 val_s_loss:0.3911 val_d_loss:-43.8781 cost:33.28
# epoch [410/50000] s_loss:97.3465 d_loss:-56.9558 val_s_loss:156.5218 val_d_loss:-105.1238 cost:34.63
# epoch [411/50000] s_loss:37.4408 d_loss:-51.3537 val_s_loss:36.3671 val_d_loss:-52.4972 cost:31.71
# epoch [412/50000] s_loss:-7.3233 d_loss:-57.9291 val_s_loss:-3.7542 val_d_loss:-50.8728 cost:33.99
# epoch [413/50000] s_loss:-3.7244 d_loss:-52.0035 val_s_loss:-5.0878 val_d_loss:-52.6282 cost:32.62
# epoch [414/50000] s_loss:69.8202 d_loss:-54.9793 val_s_loss:66.2954 val_d_loss:-43.7288 cost:32.68
# epoch [415/50000] s_loss:40.1070 d_loss:-49.9745 val_s_loss:39.4516 val_d_loss:-58.0445 cost:35.01
# epoch [416/50000] s_loss:5.4909 d_loss:-51.7127 val_s_loss:4.5918 val_d_loss:-53.7753 cost:34.37
# epoch [417/50000] s_loss:8.0933 d_loss:-50.7106 val_s_loss:16.7060 val_d_loss:-54.8571 cost:33.97
# epoch [418/50000] s_loss:59.3459 d_loss:-52.9752 val_s_loss:79.2623 val_d_loss:-71.3134 cost:33.95
# epoch [419/50000] s_loss:39.4069 d_loss:-51.0077 val_s_loss:34.8789 val_d_loss:-43.3945 cost:32.88
# epoch [420/50000] s_loss:5.5929 d_loss:-53.0666 val_s_loss:2.6650 val_d_loss:-42.2997 cost:34.05
# epoch [421/50000] s_loss:25.9122 d_loss:-48.7413 val_s_loss:23.7152 val_d_loss:-49.2302 cost:33.77
# epoch [422/50000] s_loss:53.7270 d_loss:-52.3790 val_s_loss:106.3040 val_d_loss:-96.7075 cost:32.88
# epoch [423/50000] s_loss:21.8077 d_loss:-49.3338 val_s_loss:19.3700 val_d_loss:-43.5111 cost:33.98
# epoch [424/50000] s_loss:0.8154 d_loss:-51.4104 val_s_loss:-3.6482 val_d_loss:-50.2288 cost:33.05
# epoch [425/50000] s_loss:51.7346 d_loss:-54.9391 val_s_loss:44.5900 val_d_loss:-40.9394 cost:33.65
# epoch [426/50000] s_loss:45.8402 d_loss:-52.5886 val_s_loss:44.2580 val_d_loss:-45.8262 cost:31.64
# epoch [427/50000] s_loss:-1.1658 d_loss:-49.5372 val_s_loss:-1.6703 val_d_loss:-45.2955 cost:32.67
# epoch [428/50000] s_loss:5.6799 d_loss:-53.7058 val_s_loss:3.8600 val_d_loss:-44.9575 cost:32.82
# epoch [429/50000] s_loss:75.3181 d_loss:-56.3947 val_s_loss:73.5875 val_d_loss:-53.5574 cost:33.70
# epoch [430/50000] s_loss:22.5394 d_loss:-50.4428 val_s_loss:17.9365 val_d_loss:-52.1440 cost:34.16
# epoch [431/50000] s_loss:-12.7903 d_loss:-49.9799 val_s_loss:-13.7940 val_d_loss:-49.0147 cost:32.16
# epoch [432/50000] s_loss:22.6957 d_loss:-51.5994 val_s_loss:16.8333 val_d_loss:-48.3069 cost:33.89
# epoch [433/50000] s_loss:58.9372 d_loss:-54.8697 val_s_loss:56.3288 val_d_loss:-48.1137 cost:34.63
# epoch [434/50000] s_loss:17.8426 d_loss:-52.0396 val_s_loss:17.1190 val_d_loss:-52.0549 cost:32.12
# epoch [435/50000] s_loss:-9.4037 d_loss:-54.6418 val_s_loss:-9.0228 val_d_loss:-52.7482 cost:33.38
# epoch [436/50000] s_loss:31.4196 d_loss:-55.2785 val_s_loss:26.1701 val_d_loss:-51.7418 cost:32.99
# epoch [437/50000] s_loss:39.0441 d_loss:-54.6038 val_s_loss:37.3131 val_d_loss:-51.5956 cost:32.77
# epoch [438/50000] s_loss:11.6016 d_loss:-48.1120 val_s_loss:7.5342 val_d_loss:-48.7619 cost:32.77
# epoch [439/50000] s_loss:12.3126 d_loss:-51.3301 val_s_loss:9.6992 val_d_loss:-43.1094 cost:33.80
# epoch [440/50000] s_loss:41.7380 d_loss:-50.8273 val_s_loss:39.8541 val_d_loss:-51.1144 cost:32.78
# epoch [441/50000] s_loss:21.7534 d_loss:-51.4276 val_s_loss:19.4001 val_d_loss:-51.8572 cost:31.65
# epoch [442/50000] s_loss:-2.8606 d_loss:-48.9299 val_s_loss:-0.8151 val_d_loss:-44.6903 cost:32.24
# epoch [443/50000] s_loss:37.3239 d_loss:-55.7139 val_s_loss:38.2963 val_d_loss:-43.6278 cost:32.87
# epoch [444/50000] s_loss:29.4058 d_loss:-48.4887 val_s_loss:26.0930 val_d_loss:-58.4886 cost:33.62
# epoch [445/50000] s_loss:-10.3876 d_loss:-54.8525 val_s_loss:-5.3381 val_d_loss:-42.6637 cost:32.80
# epoch [446/50000] s_loss:16.0956 d_loss:-49.8604 val_s_loss:12.0627 val_d_loss:-40.4239 cost:32.57
# epoch [447/50000] s_loss:62.0610 d_loss:-54.7101 val_s_loss:64.1251 val_d_loss:-47.2576 cost:33.17
# epoch [448/50000] s_loss:7.0530 d_loss:-51.5245 val_s_loss:2.9055 val_d_loss:-53.2112 cost:33.02
# epoch [449/50000] s_loss:-22.5146 d_loss:-55.5723 val_s_loss:-12.2064 val_d_loss:-56.2274 cost:32.89
# epoch [450/50000] s_loss:34.3266 d_loss:-50.3800 val_s_loss:29.4840 val_d_loss:-40.0965 cost:32.30
# epoch [451/50000] s_loss:48.3250 d_loss:-54.7904 val_s_loss:44.0622 val_d_loss:-39.2574 cost:32.80
# epoch [452/50000] s_loss:3.5236 d_loss:-55.5738 val_s_loss:1.5906 val_d_loss:-43.5929 cost:32.04
# epoch [453/50000] s_loss:7.6868 d_loss:-50.7719 val_s_loss:7.6976 val_d_loss:-54.4431 cost:32.17
# epoch [454/50000] s_loss:50.0630 d_loss:-52.4737 val_s_loss:45.4339 val_d_loss:-46.0783 cost:32.42
# epoch [455/50000] s_loss:35.4590 d_loss:-49.7416 val_s_loss:32.0788 val_d_loss:-42.2394 cost:32.59
# epoch [456/50000] s_loss:-2.9676 d_loss:-51.1990 val_s_loss:-5.9176 val_d_loss:-40.9465 cost:32.55
# epoch [457/50000] s_loss:7.9884 d_loss:-48.5408 val_s_loss:4.9187 val_d_loss:-49.8050 cost:32.25
# epoch [458/50000] s_loss:55.4793 d_loss:-57.9357 val_s_loss:51.8371 val_d_loss:-48.6240 cost:33.72
# epoch [459/50000] s_loss:29.3731 d_loss:-48.0651 val_s_loss:26.0625 val_d_loss:-46.3109 cost:33.12
# epoch [460/50000] s_loss:-2.3806 d_loss:-52.1137 val_s_loss:-4.5389 val_d_loss:-52.1551 cost:31.78
# epoch [461/50000] s_loss:26.9099 d_loss:-47.6781 val_s_loss:25.3179 val_d_loss:-53.5962 cost:32.35
# epoch [462/50000] s_loss:52.7346 d_loss:-51.3202 val_s_loss:53.4869 val_d_loss:-45.3558 cost:32.14
# epoch [463/50000] s_loss:9.6782 d_loss:-49.9131 val_s_loss:8.6734 val_d_loss:-52.5506 cost:32.47
# epoch [464/50000] s_loss:4.4486 d_loss:-47.4337 val_s_loss:2.8641 val_d_loss:-49.7186 cost:32.84
# epoch [465/50000] s_loss:38.8554 d_loss:-51.9941 val_s_loss:35.9733 val_d_loss:-42.1265 cost:33.31
# epoch [466/50000] s_loss:35.6106 d_loss:-47.8794 val_s_loss:33.6104 val_d_loss:-41.2449 cost:33.89
# epoch [467/50000] s_loss:8.9738 d_loss:-49.6321 val_s_loss:7.5215 val_d_loss:-38.1784 cost:33.09
# epoch [468/50000] s_loss:26.7699 d_loss:-50.9035 val_s_loss:24.2809 val_d_loss:-44.5238 cost:33.33
# epoch [469/50000] s_loss:50.2455 d_loss:-48.8203 val_s_loss:49.5674 val_d_loss:-50.3665 cost:33.13
# epoch [470/50000] s_loss:12.9096 d_loss:-51.8290 val_s_loss:13.2076 val_d_loss:-58.2875 cost:32.99
# epoch [471/50000] s_loss:16.2958 d_loss:-51.0112 val_s_loss:14.9184 val_d_loss:-47.1385 cost:32.18
# epoch [472/50000] s_loss:46.0218 d_loss:-51.3572 val_s_loss:42.6194 val_d_loss:-41.6369 cost:32.81
# epoch [473/50000] s_loss:22.8088 d_loss:-45.3902 val_s_loss:19.2228 val_d_loss:-49.2754 cost:32.56
# epoch [474/50000] s_loss:6.1999 d_loss:-47.2696 val_s_loss:5.5434 val_d_loss:-45.1416 cost:33.01
# epoch [475/50000] s_loss:27.3720 d_loss:-51.2587 val_s_loss:35.8529 val_d_loss:-52.6293 cost:33.07
# epoch [476/50000] s_loss:39.8674 d_loss:-49.4049 val_s_loss:37.3221 val_d_loss:-43.3066 cost:33.57
# epoch [477/50000] s_loss:20.1736 d_loss:-49.4109 val_s_loss:18.0382 val_d_loss:-46.2310 cost:33.00
# epoch [478/50000] s_loss:7.5571 d_loss:-46.5838 val_s_loss:4.7305 val_d_loss:-39.5274 cost:32.19
# epoch [479/50000] s_loss:37.1113 d_loss:-48.6790 val_s_loss:36.9264 val_d_loss:-37.5083 cost:33.70
# epoch [480/50000] s_loss:43.9513 d_loss:-50.3795 val_s_loss:42.2356 val_d_loss:-42.3232 cost:33.05
# epoch [481/50000] s_loss:-4.6247 d_loss:-52.2567 val_s_loss:-2.5779 val_d_loss:-50.3038 cost:32.62
# epoch [482/50000] s_loss:25.0405 d_loss:-49.1990 val_s_loss:25.4609 val_d_loss:-49.5920 cost:31.90
# ...
# epoch [6952/50000] s_loss:3.6074 d_loss:-34.7765 val_s_loss:5.3944 val_d_loss:-28.6245 cost:34.69
# epoch [6953/50000] s_loss:10.7372 d_loss:-34.2533 val_s_loss:11.5336 val_d_loss:-33.2254 cost:34.38
# epoch [6954/50000] s_loss:-2.8495 d_loss:-35.4605 val_s_loss:-1.7084 val_d_loss:-33.8698 cost:35.07
# epoch [6955/50000] s_loss:-10.3452 d_loss:-34.6063 val_s_loss:-9.9232 val_d_loss:-42.3718 cost:35.33
# epoch [6956/50000] s_loss:3.9736 d_loss:-35.3830 val_s_loss:4.4305 val_d_loss:-39.6739 cost:36.55
# epoch [6957/50000] s_loss:11.3079 d_loss:-34.0147 val_s_loss:10.3054 val_d_loss:-36.0093 cost:35.38
# epoch [6958/50000] s_loss:-0.0617 d_loss:-36.3763 val_s_loss:2.2032 val_d_loss:-30.6061 cost:35.97
# epoch [6959/50000] s_loss:-7.0460 d_loss:-34.3960 val_s_loss:-7.5768 val_d_loss:-37.5325 cost:34.75
# epoch [6960/50000] s_loss:-8.4972 d_loss:-33.0957 val_s_loss:-5.9386 val_d_loss:-34.8218 cost:35.88
# epoch [6961/50000] s_loss:-5.7480 d_loss:-36.6590 val_s_loss:-4.5008 val_d_loss:-34.8422 cost:36.07
# epoch [6962/50000] s_loss:5.1667 d_loss:-33.8855 val_s_loss:3.7502 val_d_loss:-37.4026 cost:34.79
# epoch [6963/50000] s_loss:-1.1374 d_loss:-35.3705 val_s_loss:-0.0880 val_d_loss:-34.0835 cost:29.66
# epoch [6964/50000] s_loss:-3.0822 d_loss:-35.7639 val_s_loss:-1.8893 val_d_loss:-28.5184 cost:31.51
# epoch [6965/50000] s_loss:-6.7371 d_loss:-36.9705 val_s_loss:-7.7499 val_d_loss:-31.8355 cost:30.46
# epoch [6966/50000] s_loss:1.0905 d_loss:-34.1712 val_s_loss:1.8599 val_d_loss:-35.3873 cost:31.13
# epoch [6967/50000] s_loss:5.7505 d_loss:-34.9221 val_s_loss:6.0972 val_d_loss:-30.9411 cost:31.32
# epoch [6968/50000] s_loss:3.0726 d_loss:-35.0707 val_s_loss:1.2413 val_d_loss:-38.6986 cost:32.05
# epoch [6969/50000] s_loss:-2.4385 d_loss:-34.0368 val_s_loss:-4.2114 val_d_loss:-28.7730 cost:30.17
# epoch [6970/50000] s_loss:0.0503 d_loss:-36.5724 val_s_loss:1.3735 val_d_loss:-43.4448 cost:29.24
# epoch [6971/50000] s_loss:0.3525 d_loss:-34.0568 val_s_loss:-0.4189 val_d_loss:-34.1543 cost:31.47
# epoch [6972/50000] s_loss:5.4881 d_loss:-34.6165 val_s_loss:5.9822 val_d_loss:-33.0101 cost:30.20
# epoch [6973/50000] s_loss:0.3253 d_loss:-35.6552 val_s_loss:-2.5781 val_d_loss:-32.9464 cost:31.41
# epoch [6974/50000] s_loss:-0.8917 d_loss:-35.7442 val_s_loss:-0.4190 val_d_loss:-37.6343 cost:31.33
# epoch [6975/50000] s_loss:6.9927 d_loss:-35.5000 val_s_loss:6.1830 val_d_loss:-34.3465 cost:29.75
# epoch [6976/50000] s_loss:2.1108 d_loss:-38.9939 val_s_loss:0.5004 val_d_loss:-31.8777 cost:30.64
# epoch [6977/50000] s_loss:-3.0300 d_loss:-35.8013 val_s_loss:3.2468 val_d_loss:-38.1083 cost:29.85
# epoch [6978/50000] s_loss:3.8286 d_loss:-37.0615 val_s_loss:3.7832 val_d_loss:-38.8577 cost:30.87
# epoch [6979/50000] s_loss:5.0499 d_loss:-35.8969 val_s_loss:8.0780 val_d_loss:-35.8056 cost:30.44
# epoch [6980/50000] s_loss:-2.4961 d_loss:-32.9582 val_s_loss:-1.7068 val_d_loss:-36.2338 cost:31.23
# epoch [6981/50000] s_loss:-12.6415 d_loss:-37.1072 val_s_loss:-13.6812 val_d_loss:-34.4719 cost:30.09
# epoch [6982/50000] s_loss:5.5133 d_loss:-34.1935 val_s_loss:7.1251 val_d_loss:-38.6815 cost:30.18
# epoch [6983/50000] s_loss:13.1643 d_loss:-36.8056 val_s_loss:12.1592 val_d_loss:-31.7073 cost:33.17
# epoch [6984/50000] s_loss:0.4330 d_loss:-36.9645 val_s_loss:0.7549 val_d_loss:-37.8353 cost:33.90
# epoch [6985/50000] s_loss:-18.2450 d_loss:-35.0421 val_s_loss:-17.3508 val_d_loss:-36.3604 cost:31.97
# epoch [6986/50000] s_loss:-6.5229 d_loss:-37.4760 val_s_loss:-6.2829 val_d_loss:-38.3002 cost:30.37
# epoch [6987/50000] s_loss:7.7246 d_loss:-32.9485 val_s_loss:7.4206 val_d_loss:-38.6449 cost:30.38
# epoch [6988/50000] s_loss:3.9754 d_loss:-33.9229 val_s_loss:3.6729 val_d_loss:-42.2018 cost:30.71
# epoch [6989/50000] s_loss:-8.9204 d_loss:-36.7008 val_s_loss:-10.0721 val_d_loss:-26.2870 cost:29.59
# epoch [6990/50000] s_loss:-9.0396 d_loss:-33.8517 val_s_loss:-7.9490 val_d_loss:-47.5678 cost:31.40
# epoch [6991/50000] s_loss:2.3434 d_loss:-35.8739 val_s_loss:3.5375 val_d_loss:-31.3554 cost:30.54
# epoch [6992/50000] s_loss:4.2133 d_loss:-36.6901 val_s_loss:5.0161 val_d_loss:-42.4493 cost:30.90
# epoch [6993/50000] s_loss:-3.8081 d_loss:-35.3984 val_s_loss:-3.5150 val_d_loss:-33.1681 cost:30.58
# epoch [6994/50000] s_loss:-8.6779 d_loss:-37.0250 val_s_loss:-8.2622 val_d_loss:-33.3068 cost:31.23
# epoch [6995/50000] s_loss:5.7629 d_loss:-33.9504 val_s_loss:6.3420 val_d_loss:-32.5674 cost:31.68
# epoch [6996/50000] s_loss:4.4280 d_loss:-34.2768 val_s_loss:4.0903 val_d_loss:-34.0516 cost:30.80
# epoch [6997/50000] s_loss:-4.4449 d_loss:-36.3019 val_s_loss:-3.4007 val_d_loss:-44.3790 cost:30.39
# epoch [6998/50000] s_loss:-7.6098 d_loss:-33.3200 val_s_loss:-7.0627 val_d_loss:-33.9879 cost:29.46
# epoch [6999/50000] s_loss:-0.9404 d_loss:-34.1351 val_s_loss:0.7932 val_d_loss:-35.2540 cost:29.50
# epoch [7000/50000] s_loss:4.1160 d_loss:-35.0270 val_s_loss:4.3558 val_d_loss:-45.4208 cost:31.40
# epoch [7001/50000] s_loss:-4.6737 d_loss:-33.5203 val_s_loss:-2.7693 val_d_loss:-43.8640 cost:34.62
# epoch [7002/50000] s_loss:-2.9532 d_loss:-36.0339 val_s_loss:-2.6377 val_d_loss:-37.2831 cost:34.14
# epoch [7003/50000] s_loss:1.8961 d_loss:-31.7726 val_s_loss:2.1800 val_d_loss:-32.7206 cost:36.27
# epoch [7004/50000] s_loss:-2.5495 d_loss:-36.2389 val_s_loss:-4.1396 val_d_loss:-28.6297 cost:34.90
# epoch [7005/50000] s_loss:-1.3940 d_loss:-35.4492 val_s_loss:-0.6548 val_d_loss:-36.7357 cost:35.09
# epoch [7006/50000] s_loss:0.1291 d_loss:-34.4883 val_s_loss:1.1566 val_d_loss:-38.7344 cost:33.03
# epoch [7007/50000] s_loss:4.2070 d_loss:-35.6711 val_s_loss:4.6222 val_d_loss:-31.2759 cost:35.20
# epoch [7008/50000] s_loss:6.8491 d_loss:-33.7047 val_s_loss:6.0732 val_d_loss:-30.2418 cost:35.10
# epoch [7009/50000] s_loss:2.8265 d_loss:-33.5292 val_s_loss:2.5562 val_d_loss:-27.5961 cost:34.99
# epoch [7010/50000] s_loss:-4.8911 d_loss:-34.3285 val_s_loss:-5.1128 val_d_loss:-40.4393 cost:34.04
# epoch [7011/50000] s_loss:1.9699 d_loss:-34.2278 val_s_loss:3.8872 val_d_loss:-36.7029 cost:35.15
# epoch [7012/50000] s_loss:2.6750 d_loss:-33.6039 val_s_loss:2.5458 val_d_loss:-34.1737 cost:30.50
# epoch [7013/50000] s_loss:-1.9171 d_loss:-35.3486 val_s_loss:-0.1633 val_d_loss:-35.5255 cost:30.92
# epoch [7014/50000] s_loss:-0.0419 d_loss:-34.0166 val_s_loss:1.0165 val_d_loss:-30.2716 cost:30.25
# epoch [7015/50000] s_loss:1.6440 d_loss:-38.3442 val_s_loss:1.6101 val_d_loss:-38.7729 cost:35.31
# epoch [7016/50000] s_loss:2.9228 d_loss:-33.2692 val_s_loss:3.8216 val_d_loss:-32.5194 cost:34.78
# epoch [7017/50000] s_loss:-1.9628 d_loss:-35.1590 val_s_loss:-1.0713 val_d_loss:-29.6924 cost:35.68
# epoch [7018/50000] s_loss:6.2468 d_loss:-36.3343 val_s_loss:6.1171 val_d_loss:-33.8766 cost:33.24
# epoch [7019/50000] s_loss:2.8127 d_loss:-34.9812 val_s_loss:2.1040 val_d_loss:-33.1232 cost:35.24
# epoch [7020/50000] s_loss:-5.2663 d_loss:-33.1274 val_s_loss:-7.4052 val_d_loss:-35.0911 cost:35.99
# epoch [7021/50000] s_loss:-4.4844 d_loss:-35.8269 val_s_loss:-2.0803 val_d_loss:-36.4871 cost:34.69
# epoch [7022/50000] s_loss:8.0304 d_loss:-34.4182 val_s_loss:9.9496 val_d_loss:-37.6937 cost:34.80
# epoch [7023/50000] s_loss:4.2669 d_loss:-34.1412 val_s_loss:3.9002 val_d_loss:-32.6128 cost:35.17
# epoch [7024/50000] s_loss:-7.5093 d_loss:-35.6831 val_s_loss:-6.3711 val_d_loss:-32.0433 cost:33.61
# epoch [7025/50000] s_loss:1.8762 d_loss:-32.8656 val_s_loss:2.8418 val_d_loss:-39.4778 cost:35.60
# epoch [7026/50000] s_loss:5.2968 d_loss:-34.0266 val_s_loss:4.7168 val_d_loss:-37.2574 cost:33.06
# epoch [7027/50000] s_loss:-9.1266 d_loss:-33.8790 val_s_loss:-8.8532 val_d_loss:-31.8204 cost:30.97
# epoch [7028/50000] s_loss:-6.4992 d_loss:-36.3065 val_s_loss:-0.8346 val_d_loss:-46.3153 cost:30.46
# epoch [7029/50000] s_loss:11.3730 d_loss:-34.2033 val_s_loss:12.2445 val_d_loss:-33.7375 cost:31.15
# epoch [7030/50000] s_loss:5.5838 d_loss:-36.4315 val_s_loss:8.5905 val_d_loss:-43.0761 cost:31.07
# epoch [7031/50000] s_loss:-6.3730 d_loss:-33.9794 val_s_loss:-5.4633 val_d_loss:-42.3220 cost:31.05
# epoch [7032/50000] s_loss:-8.6424 d_loss:-35.2497 val_s_loss:-1.3418 val_d_loss:-42.4021 cost:30.43
# epoch [7033/50000] s_loss:4.0340 d_loss:-37.6599 val_s_loss:5.7629 val_d_loss:-34.7791 cost:31.95
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-17-ce8cca5cd907>", line 167, in <module>
#     AUC2 = roc_auc_score(true_mask, pred_mask2.cpu().detach().numpy())
#   File "/opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py", line 73, in inner_f
#     return f(**kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/sklearn/metrics/_ranking.py", line 370, in roc_auc_score
#     y_type = type_of_target(y_true)
#   File "/opt/conda/lib/python3.7/site-packages/sklearn/utils/multiclass.py", line 290, in type_of_target
#     if (len(np.unique(y)) > 2) or (y.ndim >= 2 and len(y[0]) > 1):
#   File "<__array_function__ internals>", line 6, in unique
#   File "/opt/conda/lib/python3.7/site-packages/numpy/lib/arraysetops.py", line 263, in unique
#     ret = _unique1d(ar, return_index, return_inverse, return_counts)
#   File "/opt/conda/lib/python3.7/site-packages/numpy/lib/arraysetops.py", line 311, in _unique1d
#     ar.sort()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/opt/conda/lib/python3.7/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/opt/conda/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/opt/conda/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/opt/conda/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/opt/conda/lib/python3.7/inspect.py", line 742, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/opt/conda/lib/python3.7/posixpath.py", line 395, in realpath
#     path, ok = _joinrealpath(filename[:0], filename, {})
#   File "/opt/conda/lib/python3.7/posixpath.py", line 429, in _joinrealpath
#     if not islink(newpath):
#   File "/opt/conda/lib/python3.7/posixpath.py", line 171, in islink
#     st = os.lstat(path)
# KeyboardInterrupt
# KeyboardInterruptTraceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-17-ce8cca5cd907> in <module>
#     166         AUC = roc_auc_score(true_mask, pred_mask.cpu().detach().numpy())
# --> 167         AUC2 = roc_auc_score(true_mask, pred_mask2.cpu().detach().numpy())
#     168
#
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_ranking.py in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     369
# --> 370     y_type = type_of_target(y_true)
#     371     y_true = check_array(y_true, ensure_2d=False, dtype=None)
#
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/multiclass.py in type_of_target(y)
#     289
# --> 290     if (len(np.unique(y)) > 2) or (y.ndim >= 2 and len(y[0]) > 1):
#     291         return 'multiclass' + suffix  # [1, 2, 3] or [[1., 2., 3]] or [[1, 2]]
#
# <__array_function__ internals> in unique(*args, **kwargs)
#
# /opt/conda/lib/python3.7/site-packages/numpy/lib/arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     262     if axis is None:
# --> 263         ret = _unique1d(ar, return_index, return_inverse, return_counts)
#     264         return _unpack_tuple(ret)
#
# /opt/conda/lib/python3.7/site-packages/numpy/lib/arraysetops.py in _unique1d(ar, return_index, return_inverse, return_counts)
#     310     else:
# --> 311         ar.sort()
#     312         aux = ar
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeErrorTraceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2043                         # in the engines. This should return a list of strings.
# -> 2044                         stb = value._render_traceback_()
#    2045                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeErrorTraceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2045                     except Exception:
#    2046                         stb = self.InteractiveTB.structured_traceback(etype,
# -> 2047                                             value, tb, tb_offset=tb_offset)
#    2048
#    2049                     self._showtraceback(etype, value, stb)
#
# /opt/conda/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1434             self.tb = tb
#    1435         return FormattedTB.structured_traceback(
# -> 1436             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1437
#    1438
#
# /opt/conda/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1334             # Verbose modes need a full traceback
#    1335             return VerboseTB.structured_traceback(
# -> 1336                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1337             )
#    1338         elif mode == 'Minimal':
#
# /opt/conda/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1191
#    1192         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
# -> 1193                                                                tb_offset)
#    1194
#    1195         colors = self.Colors  # just a shorthand + quicker name lookup
#
# /opt/conda/lib/python3.7/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1148
#    1149
# -> 1150         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1151
#    1152         frames = self.format_records(records, last_unique, recursion_repeat)
#
# /opt/conda/lib/python3.7/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     449     # first frame (from in to out) that looks different.
#     450     if not is_recursion_error(etype, value, records):
# --> 451         return len(records), 0
#     452
#     453     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %%
AE.eval()
S.eval()
for index, img in enumerate(test_loader):
    test_img = Variable(img[0]).cuda()

    # ======AE======
    blur_image = AE(test_img)
    
    noise = torch.zeros(blur_image.shape[0], 1, blur_image.shape[2], blur_image.shape[3] )
    noise = noise + (0.01**0.5)*torch.randn(blur_image.shape[0], 1, blur_image.shape[2], blur_image.shape[3])
    noise = noise.cuda()
    blur_image_with_noise = torch.cat([blur_image, noise], 1)
    fake_image = S(blur_image_with_noise)
    
    
    vutils.save_image(fake_image[0], './test_result/{}_simulated.png'.format(index))
    vutils.save_image(blur_image[0], './test_result/{}_blur.png'.format(index))
    vutils.save_image(test_img, './test_result/{}_origin.png'.format(index))
