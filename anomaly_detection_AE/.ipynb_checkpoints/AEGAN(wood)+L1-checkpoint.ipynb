# %%
import sys
sys.path.append('../')

import os
import time
import numpy as np

from torch.utils.data import DataLoader
from torch.autograd import Variable
from torch import autograd

import torch
import torch.nn as nn


from utils.tools import get_config, default_loader, is_image_file, normalize
from tensorboardX import SummaryWriter
import matplotlib.pyplot as plt
import torchvision.utils as vutils

from sklearn.metrics import roc_auc_score
sys.path.append('../PerceptualSimilarity')
import models as PerceptualSimilarity

# personal library
from networks import autoencoder, simulator, discriminator
from dataloader import MVTecDataset

# %%
# 限制可以使用的 GPU
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0,1"

# %%
# HYPER parameters
num_epochs = 50000
batch_size = 32
val_batch_size = 4
ae_lr = 1e-4
s_lr = 5e-4
d_lr = 5e-4
weight_decay = 1e-5
UPSET=True
expName = 'AEGAN-exp(capsule + L1)'
writer = SummaryWriter('checkpoints/'+expName)
TYPE='capsule'

# %%
trainDatset = MVTecDataset.MVTecDataset(TYPE=TYPE, isTrain='train')
testDatset = MVTecDataset.MVTecDataset(TYPE=TYPE, isTrain='test')
valDataset = MVTecDataset.MVTecDataset(TYPE=TYPE, isTrain='val')

val_loader = DataLoader(
    dataset=valDataset,
    batch_size=val_batch_size, 
    shuffle=True,
    num_workers=4
)
train_loader = DataLoader(
    dataset=trainDatset,
    batch_size=batch_size, 
    shuffle=True,
    num_workers=4
)
test_loader = DataLoader(
    dataset=testDatset,
    batch_size=1,
    shuffle=True,
    num_workers=4
)

# %%
# Model
AE = autoencoder.Autoencoder().cuda()
S = nn.DataParallel(simulator.Simulator(3, 8)).cuda()
D = nn.DataParallel(discriminator.Discriminator(6, 16)).cuda()

# Loss
L1_loss = nn.L1Loss()
L2_loss = nn.MSELoss(reduction='none')
perceptual_loss = PerceptualSimilarity.PerceptualLoss(model='net-lin', net='alex', use_gpu=True, gpu_ids=[0])

# Optimizer
optimizer_AE = torch.optim.Adam(
    AE.parameters(), 
    lr=ae_lr,
    weight_decay=weight_decay
)
optimizer_S = torch.optim.Adam(
    S.parameters(), 
    lr=s_lr,
    weight_decay=weight_decay
)
optimizer_D = torch.optim.Adam(
    D.parameters(), 
    lr=d_lr,
    weight_decay=weight_decay
)


Tensor = torch.cuda.FloatTensor
# Out:
# Setting up Perceptual loss...
# Loading model from: /workspace/PerceptualSimilarity/models/weights/v0.1/alex.pth
# ...[net-lin [alex]] initialized
# ...Done

# %%
AE.load_state_dict(torch.load('./save_weight/AE-capsule-z-2x2-exp2/AE_5500.npy', map_location="cuda:0"), False)

AE = nn.DataParallel(AE)

# %%
# To Solve: RuntimeError: cuDNN error: CUDNN_STATUS_EXECUTION_FAILED
torch.backends.cudnn.enabled = False 

# 拿掉煩人的 warning
import warnings
warnings.filterwarnings("ignore")

# %%
LAMBDA = 10

def calc_gradient_penalty(netD, real_data, fake_data):
    # print "real_data: ", real_data.size(), fake_data.size()
    BATCH_SIZE = real_data.size(0)
    alpha = torch.rand(BATCH_SIZE, 1)
    alpha = alpha.expand(BATCH_SIZE, real_data.nelement()//BATCH_SIZE).contiguous().view(BATCH_SIZE, 6, 256, 256)
    alpha = alpha.cuda()

    interpolates = alpha * real_data + ((1 - alpha) * fake_data)

    interpolates = interpolates.cuda()
    interpolates = autograd.Variable(interpolates, requires_grad=True)

    disc_interpolates = netD(interpolates)

    gradients = autograd.grad(
        outputs=disc_interpolates, 
        inputs=interpolates,
        grad_outputs=torch.ones(disc_interpolates.size()).cuda(),
        create_graph=True, 
        retain_graph=True, 
        only_inputs=True
    )[0]
    gradients = gradients.view(gradients.size(0), -1)

    gradient_penalty = ((gradients.norm(2, dim=1) - 1) ** 2).mean() * LAMBDA
    return gradient_penalty

def difNormalize(input_matrix, threshold=None):
    _min = torch.min(input_matrix)
    _max = torch.max(input_matrix)
    
    input_matrix = (input_matrix - _min) / (_max - _min)
    
    if threshold != None:
        input_matrix[input_matrix < threshold] = 0
        input_matrix[input_matrix >= threshold] = 1
        
    return input_matrix

# %%
for epoch in range(num_epochs): 
    start = time.time()
    ######## GAN ################
    one = torch.FloatTensor([1])
    mone = one * -1
    
    one = one.cuda()
    mone = mone.cuda()
    
    one = one.mean()
    mone = mone.mean()
    ## ==== GAN --> D =====
    for i in range(3):
        for index, img in enumerate(train_loader):
            AE.eval(), S.train(), D.train()

            img = Variable(img).cuda()

            # ====== AE ======
            blur_image = AE(img)

            _bs, _c, _w, _h = blur_image.shape
            noise = torch.zeros(_bs, 1, _w, _h )
            noise = noise + (0.01**0.5)*torch.randn(_bs, 1, _w, _h)
            noise = noise.cuda()

            blur_image_with_noise = torch.cat([blur_image, noise], 1)
            fake_image = S(blur_image_with_noise) # 當成是 residual
            
            fake_image = fake_image + blur_image # blur image + residual
            
            fake_pair = torch.cat([img, fake_image], 1)
            real_pair = torch.cat([img, img[torch.randperm(img.size(0)), :, :, :]], 1) if UPSET else torch.cat([img, img], 1)
            # ====== Train D ======
            for p in D.parameters():
                p.requires_grad = True

            optimizer_AE.zero_grad()
            optimizer_S.zero_grad()
            optimizer_D.zero_grad()


            real_D = D(real_pair)
            real_D = real_D.mean()
            real_D.backward(mone)


            fake_D = D(fake_pair)
            fake_D = fake_D.mean()
            fake_D.backward(one)

            gradient_penalty = calc_gradient_penalty(D, real_pair, fake_pair)
            gradient_penalty.backward()

            cost_D = fake_D - real_D + gradient_penalty
            Wasserstein_D = real_D - fake_D
            optimizer_D.step()
    
    ## ==== GAN --> G =====
    for index, img in enumerate(train_loader):
        AE.eval(), S.train(), D.train()

        img = Variable(img).cuda()
        # ======AE======
        blur_image = AE(img)

        _bs, _c, _w, _h = blur_image.shape
        noise = torch.zeros(_bs, 1, _w, _h )
        noise = noise + (0.01**0.5)*torch.randn(_bs, 1, _w, _h)
        noise = noise.cuda()

        blur_image_with_noise = torch.cat([blur_image, noise], 1)
        fake_image = S(blur_image_with_noise)
        
        fake_image = fake_image + blur_image
        
        fake_pair = torch.cat([img, fake_image], 1)
        # ====== Train G ======
        for p in D.parameters():
            p.requires_grad = False
        
        G_L1 = L1_loss(img, fake_image)
        G = D(fake_pair)
        G = G.mean()
        G = G + G_L1 * ( G / G_L1)
        
        optimizer_AE.zero_grad()
        optimizer_S.zero_grad()
        optimizer_D.zero_grad()
        
        G.backward(mone)
        
        cost_G = -G
        optimizer_S.step()
        
    
    # validation set
    for index, val_img in enumerate(val_loader):
        AE.eval(), S.eval(), D.eval()

        val_img = Variable(val_img).cuda()
        # ======AE======
        val_blur_image = AE(val_img)

        _bs, _c, _w, _h = val_blur_image.shape
        noise = torch.zeros(_bs, 1, _w, _h )
        noise = noise + (0.01**0.5)*torch.randn(_bs, 1, _w, _h)
        noise = noise.cuda()

        val_blur_image_with_noise = torch.cat([val_blur_image, noise], 1)

        val_fake_image = S(val_blur_image_with_noise)       
        val_fake_image = val_fake_image + val_blur_image
        
        
        val_fake_pair = torch.cat([val_img, val_fake_image], 1)
        val_real_pair = torch.cat([val_img, val_img[torch.randperm(val_img.size(0)), :, :, :]], 1) if UPSET else torch.cat([val_img, val_img], 1)
        
        val_real_D = D(val_real_pair)
        val_real_D = val_real_D.mean()
        
        val_fake_D = D(val_fake_pair)
        val_fake_D = val_fake_D.mean()
        
        val_gradient_penalty = calc_gradient_penalty(D, val_real_pair, val_fake_pair)
        
        val_G_L1 = L1_loss(val_img, val_fake_image)
        # =========== Losses =========
        val_Wasserstein_D = val_real_D - val_fake_D
        
        val_cost_G = -val_fake_D
        val_cost_D = val_fake_D - val_real_D + val_gradient_penalty
    
    # evaluate
    test_total_AUC = 0
    test_total_AUC2 = 0
    test_total_image = 0

    for index, (test_img, mask) in enumerate(test_loader):
        AE.eval(), S.eval(), D.eval()
        test_img = Variable(test_img).cuda()
        test_blur_image = AE(test_img)

        _bs, _c, _w, _h = test_blur_image.shape
        noise = torch.zeros(_bs, 1, _w, _h )
        noise = noise + (0.01**0.5)*torch.randn(_bs, 1, _w, _h)
        noise = noise.cuda()

        test_blur_image_with_noise = torch.cat([test_blur_image, noise], 1)

        test_fake_image = S(test_blur_image_with_noise)       
        test_fake_image = test_fake_image + test_blur_image

        # 計算 dif (相似度以及 L2)
        dif, _ = perceptual_loss.forward(test_fake_image, test_img)
        l2Dif = L2_loss(test_fake_image, test_img)
        l2Dif = torch.mean(l2Dif, 1, True)
        
        pred_mask2 = difNormalize(dif)
        pred_mask2 = torch.flatten(pred_mask2[0])
        
        pred_mask = difNormalize(dif[0] * l2Dif[0])
        pred_mask = torch.flatten(pred_mask)
        
        mask = torch.mean(mask, 1, True)
        true_mask = mask[0].cpu().detach().numpy().flatten()
        true_mask = true_mask.astype(int)

        AUC = roc_auc_score(true_mask, pred_mask.cpu().detach().numpy())
        AUC2 = roc_auc_score(true_mask, pred_mask2.cpu().detach().numpy())

        test_total_AUC += AUC
        test_total_AUC2 += AUC2
        test_total_image += 1
    
    # =================== GAN log========================
    end = time.time()
    print('epoch [{}/{}] s_loss:{:.4f} d_loss:{:.4f} val_s_loss:{:.4f} val_d_loss:{:.4f} cost:{:.2f}'.format(epoch+1, num_epochs, cost_G.item(), cost_D.item(), val_cost_G.item(), val_cost_D.item(), end-start ))
    writer.add_scalars('eval', {
        "auc_roc_score": test_total_AUC / test_total_image,
        "auc_roc_score(w/o L2)": test_total_AUC2 / test_total_image,
    }, epoch)
    
    writer.add_scalars('loss', {
        "Wasserstein Distance": Wasserstein_D.item(),
        "Val Wasserstein Distance": val_Wasserstein_D.item(),
        "gradient penalty": gradient_penalty,
        "val gradient penalty": val_gradient_penalty
    }, epoch)
    
    writer.add_scalars('gan loss', {
        "l1_loss": G_L1.item(),
        "g_loss": cost_G.item(),
        "d_loss": cost_D.item(),
        "val_l1_loss": val_G_L1.item(),
        "val_g_loss": val_cost_G.item(),
        "val_d_loss": val_cost_D.item()
    }, epoch)

    writer.add_images('Blur', blur_image, epoch)
    writer.add_images('Reconstruct', fake_image, epoch)
    writer.add_images('Origin', img, epoch)

    writer.add_images('Val Blur', val_blur_image, epoch)
    writer.add_images('Val Reconstruct', val_fake_image, epoch)
    writer.add_images('Val Origin', val_img, epoch)


        
    if epoch % 10 == 0:
        if not os.path.exists('./save_weight/{}'.format(expName)):
            os.makedirs('./save_weight/{}'.format(expName))
        torch.save(S.state_dict(), './save_weight/{}/S_{}.npy'.format(expName, epoch))
        torch.save(D.state_dict(), './save_weight/{}/D_{}.npy'.format(expName, epoch))
# Out:
# epoch [1/50000] s_loss:2132.9373 d_loss:-414.1952 val_s_loss:1159.5438 val_d_loss:294.2867 cost:35.86
# epoch [2/50000] s_loss:3708.6060 d_loss:-666.6209 val_s_loss:1939.3433 val_d_loss:-237.6073 cost:32.47
# epoch [3/50000] s_loss:4390.6406 d_loss:-597.4175 val_s_loss:2074.4292 val_d_loss:-271.5964 cost:32.09
# epoch [4/50000] s_loss:5383.2476 d_loss:-677.2370 val_s_loss:2771.7095 val_d_loss:-501.7083 cost:33.37
# epoch [5/50000] s_loss:4237.4233 d_loss:-717.3707 val_s_loss:2733.7478 val_d_loss:-705.0012 cost:31.89
# epoch [6/50000] s_loss:3606.2744 d_loss:-583.1256 val_s_loss:2099.3201 val_d_loss:-771.3479 cost:32.60
# epoch [7/50000] s_loss:1813.9099 d_loss:-622.9460 val_s_loss:654.7411 val_d_loss:43.2257 cost:33.24
# epoch [8/50000] s_loss:3428.5017 d_loss:-528.9409 val_s_loss:1366.8123 val_d_loss:-144.0901 cost:32.48
# epoch [9/50000] s_loss:3246.4988 d_loss:-518.7096 val_s_loss:1706.5587 val_d_loss:-295.2633 cost:31.68
# epoch [10/50000] s_loss:1799.4111 d_loss:-292.0072 val_s_loss:800.1934 val_d_loss:-240.8741 cost:32.56
# epoch [11/50000] s_loss:2143.7380 d_loss:-354.0616 val_s_loss:899.9268 val_d_loss:-100.6771 cost:32.24
# epoch [12/50000] s_loss:723.1555 d_loss:-311.9912 val_s_loss:223.4454 val_d_loss:116.9530 cost:30.84
# epoch [13/50000] s_loss:965.5078 d_loss:-216.4085 val_s_loss:655.5582 val_d_loss:-363.6373 cost:32.03
# epoch [14/50000] s_loss:1453.1636 d_loss:-288.2854 val_s_loss:1113.6350 val_d_loss:-568.7542 cost:32.92
# epoch [15/50000] s_loss:1006.9449 d_loss:-251.8758 val_s_loss:1180.6921 val_d_loss:-641.8090 cost:33.02
# epoch [16/50000] s_loss:1268.5939 d_loss:-162.1119 val_s_loss:871.8869 val_d_loss:-447.5657 cost:32.47
# epoch [17/50000] s_loss:1959.4158 d_loss:-298.8856 val_s_loss:634.0735 val_d_loss:-60.2701 cost:32.54
# epoch [18/50000] s_loss:1181.4194 d_loss:-187.1390 val_s_loss:538.3883 val_d_loss:-36.9114 cost:32.46
# epoch [19/50000] s_loss:1470.5381 d_loss:-211.1893 val_s_loss:1054.5082 val_d_loss:-472.2344 cost:33.52
# epoch [20/50000] s_loss:2283.5127 d_loss:-317.1534 val_s_loss:1647.7395 val_d_loss:-761.2050 cost:32.57
# epoch [21/50000] s_loss:2799.5322 d_loss:-368.2508 val_s_loss:1529.9597 val_d_loss:-476.5227 cost:32.49
# epoch [22/50000] s_loss:2188.8813 d_loss:-303.8831 val_s_loss:949.1503 val_d_loss:-119.5165 cost:32.23
# epoch [23/50000] s_loss:1427.1826 d_loss:-334.9800 val_s_loss:757.9863 val_d_loss:-194.1053 cost:31.22
# epoch [24/50000] s_loss:1144.1257 d_loss:-235.2095 val_s_loss:610.3029 val_d_loss:-220.6288 cost:32.71
# epoch [25/50000] s_loss:1099.3105 d_loss:-222.7935 val_s_loss:521.4167 val_d_loss:-189.7615 cost:32.63
# epoch [26/50000] s_loss:999.9123 d_loss:-211.5742 val_s_loss:478.1898 val_d_loss:-181.4980 cost:31.90
# epoch [27/50000] s_loss:957.0329 d_loss:-208.7724 val_s_loss:469.6105 val_d_loss:-196.4873 cost:33.38
# epoch [28/50000] s_loss:920.8054 d_loss:-211.1909 val_s_loss:464.0555 val_d_loss:-217.7798 cost:32.56
# epoch [29/50000] s_loss:881.6263 d_loss:-211.7601 val_s_loss:419.5318 val_d_loss:-176.8584 cost:33.00
# epoch [30/50000] s_loss:867.2247 d_loss:-201.3154 val_s_loss:420.8793 val_d_loss:-216.9915 cost:31.59
# epoch [31/50000] s_loss:745.6566 d_loss:-196.6221 val_s_loss:356.4794 val_d_loss:-170.5567 cost:32.87
# epoch [32/50000] s_loss:655.2377 d_loss:-175.5285 val_s_loss:312.9930 val_d_loss:-163.4534 cost:32.59
# epoch [33/50000] s_loss:669.0527 d_loss:-168.9201 val_s_loss:338.6449 val_d_loss:-147.3957 cost:34.87
# epoch [34/50000] s_loss:585.1073 d_loss:-151.8131 val_s_loss:274.5133 val_d_loss:-100.6313 cost:32.19
# epoch [35/50000] s_loss:682.3890 d_loss:-140.3727 val_s_loss:363.0923 val_d_loss:-141.5579 cost:32.04
# epoch [36/50000] s_loss:519.2083 d_loss:-130.0979 val_s_loss:248.4622 val_d_loss:-103.7942 cost:31.86
# epoch [37/50000] s_loss:747.1591 d_loss:-141.3185 val_s_loss:391.8962 val_d_loss:-138.1748 cost:32.54
# epoch [38/50000] s_loss:314.4656 d_loss:-130.0330 val_s_loss:85.8732 val_d_loss:-41.9067 cost:31.37
# epoch [39/50000] s_loss:576.6288 d_loss:-155.2113 val_s_loss:320.3074 val_d_loss:-143.2937 cost:31.45
# epoch [40/50000] s_loss:455.8547 d_loss:-122.3769 val_s_loss:199.9904 val_d_loss:-78.4570 cost:33.92
# epoch [41/50000] s_loss:181.5339 d_loss:-115.6278 val_s_loss:117.9378 val_d_loss:-115.6052 cost:33.23
# epoch [42/50000] s_loss:256.7459 d_loss:-102.4858 val_s_loss:127.1933 val_d_loss:-96.8135 cost:33.29
# epoch [43/50000] s_loss:161.9905 d_loss:-99.0325 val_s_loss:87.3618 val_d_loss:-92.5767 cost:32.59
# epoch [44/50000] s_loss:92.5761 d_loss:-97.1888 val_s_loss:50.2519 val_d_loss:-95.2799 cost:33.30
# epoch [45/50000] s_loss:7.6023 d_loss:-97.7369 val_s_loss:-28.9047 val_d_loss:-70.9021 cost:33.33
# epoch [46/50000] s_loss:45.8791 d_loss:-89.5620 val_s_loss:30.5167 val_d_loss:-90.5191 cost:33.06
# epoch [47/50000] s_loss:51.6882 d_loss:-86.7689 val_s_loss:11.2860 val_d_loss:-72.5738 cost:32.82
# epoch [48/50000] s_loss:141.1482 d_loss:-91.9531 val_s_loss:79.4140 val_d_loss:-90.3534 cost:31.67
# epoch [49/50000] s_loss:11.9169 d_loss:-81.5246 val_s_loss:32.3896 val_d_loss:-90.2064 cost:33.64
# epoch [50/50000] s_loss:573.5040 d_loss:-115.1300 val_s_loss:311.6626 val_d_loss:-93.5052 cost:32.15
# epoch [51/50000] s_loss:395.2243 d_loss:-106.3825 val_s_loss:196.5237 val_d_loss:-87.9373 cost:31.63
# epoch [52/50000] s_loss:29.7327 d_loss:-93.6233 val_s_loss:16.0407 val_d_loss:-90.7723 cost:32.85
# epoch [53/50000] s_loss:158.5419 d_loss:-103.7603 val_s_loss:79.3879 val_d_loss:-88.3880 cost:32.93
# epoch [54/50000] s_loss:24.3015 d_loss:-92.5756 val_s_loss:11.3144 val_d_loss:-80.4634 cost:33.06
# epoch [55/50000] s_loss:-18.5572 d_loss:-88.4486 val_s_loss:-10.1659 val_d_loss:-88.5172 cost:34.16
# epoch [56/50000] s_loss:-69.4498 d_loss:-89.1366 val_s_loss:-41.1964 val_d_loss:-83.9142 cost:32.04
# epoch [57/50000] s_loss:-123.8517 d_loss:-81.8914 val_s_loss:-60.5549 val_d_loss:-82.6880 cost:32.41
# epoch [58/50000] s_loss:-101.7754 d_loss:-83.1734 val_s_loss:-57.2581 val_d_loss:-67.7240 cost:32.69
# epoch [59/50000] s_loss:-25.1567 d_loss:-82.2175 val_s_loss:-6.2527 val_d_loss:-77.5847 cost:33.21
# epoch [60/50000] s_loss:56.9050 d_loss:-80.0776 val_s_loss:25.0232 val_d_loss:-81.9346 cost:32.76
# epoch [61/50000] s_loss:-26.7393 d_loss:-76.5778 val_s_loss:-99.9485 val_d_loss:-8.6886 cost:32.79
# epoch [62/50000] s_loss:355.5223 d_loss:-92.5479 val_s_loss:171.9228 val_d_loss:-67.9479 cost:32.40
# epoch [63/50000] s_loss:194.8899 d_loss:-75.6689 val_s_loss:94.5334 val_d_loss:-77.0729 cost:33.38
# epoch [64/50000] s_loss:9.8053 d_loss:-77.8975 val_s_loss:-43.5783 val_d_loss:-41.5999 cost:33.60
# epoch [65/50000] s_loss:-92.9155 d_loss:-77.2829 val_s_loss:-70.2265 val_d_loss:-46.6489 cost:33.87
# epoch [66/50000] s_loss:68.9933 d_loss:-78.1686 val_s_loss:37.2920 val_d_loss:-73.2933 cost:32.75
# epoch [67/50000] s_loss:198.7475 d_loss:-84.6878 val_s_loss:102.0556 val_d_loss:-66.7668 cost:32.18
# epoch [68/50000] s_loss:-33.2540 d_loss:-67.1608 val_s_loss:-93.5796 val_d_loss:-9.5885 cost:32.83
# epoch [69/50000] s_loss:82.6419 d_loss:-55.1345 val_s_loss:-9.4083 val_d_loss:-25.0532 cost:32.29
# epoch [70/50000] s_loss:161.3535 d_loss:-74.8071 val_s_loss:57.3847 val_d_loss:-62.4600 cost:33.24
# epoch [71/50000] s_loss:17.3624 d_loss:-57.5094 val_s_loss:-28.5121 val_d_loss:-24.5729 cost:31.89
# epoch [72/50000] s_loss:-84.4731 d_loss:-61.2542 val_s_loss:-35.2789 val_d_loss:-64.1178 cost:33.28
# epoch [73/50000] s_loss:396.9410 d_loss:-113.9072 val_s_loss:193.6842 val_d_loss:-59.5873 cost:32.79
# epoch [74/50000] s_loss:-105.1914 d_loss:-69.0712 val_s_loss:-87.0387 val_d_loss:-6.1650 cost:33.39
# epoch [75/50000] s_loss:450.0869 d_loss:-136.1709 val_s_loss:329.0861 val_d_loss:-179.8299 cost:32.21
# epoch [76/50000] s_loss:344.7783 d_loss:-50.0230 val_s_loss:113.2974 val_d_loss:-27.1474 cost:32.75
# epoch [77/50000] s_loss:162.0744 d_loss:-56.7052 val_s_loss:87.3930 val_d_loss:-63.2734 cost:32.55
# epoch [78/50000] s_loss:68.0533 d_loss:-64.1340 val_s_loss:21.4498 val_d_loss:-49.7860 cost:31.79
# epoch [79/50000] s_loss:5.1432 d_loss:-59.3625 val_s_loss:-22.6904 val_d_loss:-32.7031 cost:31.38
# epoch [80/50000] s_loss:-40.1919 d_loss:-58.0292 val_s_loss:49.5181 val_d_loss:-102.6196 cost:33.48
# epoch [81/50000] s_loss:21.0287 d_loss:-51.8385 val_s_loss:-39.4963 val_d_loss:-43.7667 cost:32.29
# epoch [82/50000] s_loss:-3.9314 d_loss:-98.9097 val_s_loss:-52.7887 val_d_loss:-43.9967 cost:32.09
# epoch [83/50000] s_loss:34.1849 d_loss:-50.2784 val_s_loss:-81.8669 val_d_loss:-4.4943 cost:33.85
# epoch [84/50000] s_loss:284.2185 d_loss:-164.6661 val_s_loss:176.0581 val_d_loss:-58.1813 cost:33.64
# epoch [85/50000] s_loss:210.9306 d_loss:-53.1069 val_s_loss:44.9333 val_d_loss:-35.4017 cost:33.83
# epoch [86/50000] s_loss:305.9703 d_loss:-222.9412 val_s_loss:236.8875 val_d_loss:-98.3855 cost:33.98
# epoch [87/50000] s_loss:388.2274 d_loss:-50.1573 val_s_loss:56.5021 val_d_loss:-7.7454 cost:32.84
# epoch [88/50000] s_loss:456.7739 d_loss:-192.4237 val_s_loss:106.9492 val_d_loss:8.6872 cost:32.54
# epoch [89/50000] s_loss:575.1522 d_loss:-105.5624 val_s_loss:410.0549 val_d_loss:-160.7282 cost:32.06
# epoch [90/50000] s_loss:248.9886 d_loss:-96.8044 val_s_loss:156.7641 val_d_loss:-104.5493 cost:32.47
# epoch [91/50000] s_loss:63.1017 d_loss:-56.2922 val_s_loss:-2.6779 val_d_loss:-6.7789 cost:32.70
# epoch [92/50000] s_loss:321.1640 d_loss:-34.1042 val_s_loss:-24.4528 val_d_loss:-8.5832 cost:32.01
# epoch [93/50000] s_loss:-14.1074 d_loss:-44.6384 val_s_loss:4.4594 val_d_loss:-53.2413 cost:32.98
# epoch [94/50000] s_loss:-61.3215 d_loss:-35.8703 val_s_loss:-93.5867 val_d_loss:-11.2154 cost:32.94
# epoch [95/50000] s_loss:71.4074 d_loss:-158.2273 val_s_loss:42.3168 val_d_loss:-42.5178 cost:31.38
# epoch [96/50000] s_loss:425.4487 d_loss:-68.7611 val_s_loss:29.8524 val_d_loss:-5.7221 cost:32.93
# epoch [97/50000] s_loss:24.8999 d_loss:-32.6428 val_s_loss:56.3673 val_d_loss:-74.7581 cost:33.98
# epoch [98/50000] s_loss:79.6140 d_loss:-38.1921 val_s_loss:-79.9543 val_d_loss:-8.0893 cost:33.45
# epoch [99/50000] s_loss:-113.6859 d_loss:-39.6357 val_s_loss:-119.0872 val_d_loss:-8.8949 cost:33.20
# epoch [100/50000] s_loss:-119.7262 d_loss:-46.6952 val_s_loss:-127.3273 val_d_loss:-24.5159 cost:33.62
# epoch [101/50000] s_loss:-140.3249 d_loss:-52.9697 val_s_loss:-105.5812 val_d_loss:-33.7076 cost:32.54
# epoch [102/50000] s_loss:-131.3028 d_loss:-49.7018 val_s_loss:-90.7678 val_d_loss:-15.1764 cost:33.24
# epoch [103/50000] s_loss:-218.3852 d_loss:-47.4923 val_s_loss:-148.5833 val_d_loss:-6.1531 cost:33.72
# epoch [104/50000] s_loss:-93.4776 d_loss:-45.9936 val_s_loss:-29.4351 val_d_loss:-103.9884 cost:31.48
# epoch [105/50000] s_loss:-259.5274 d_loss:-43.6221 val_s_loss:-153.2080 val_d_loss:-25.1340 cost:32.56
# epoch [106/50000] s_loss:-292.9604 d_loss:-49.5373 val_s_loss:-179.0632 val_d_loss:-6.2877 cost:32.53
# epoch [107/50000] s_loss:-205.8696 d_loss:-65.8088 val_s_loss:-133.6061 val_d_loss:-5.7973 cost:33.76
# epoch [108/50000] s_loss:18.8061 d_loss:-54.3337 val_s_loss:24.1393 val_d_loss:-42.9674 cost:31.74
# epoch [109/50000] s_loss:-190.8103 d_loss:-26.6308 val_s_loss:-116.4329 val_d_loss:-4.0368 cost:31.79
# epoch [110/50000] s_loss:-17.7528 d_loss:-34.2564 val_s_loss:-73.2752 val_d_loss:-5.5118 cost:31.93
# epoch [111/50000] s_loss:-1.6523 d_loss:-23.1401 val_s_loss:-32.5194 val_d_loss:1.8182 cost:33.33
# epoch [112/50000] s_loss:-17.0038 d_loss:-47.5156 val_s_loss:-57.4996 val_d_loss:-8.4136 cost:32.63
# epoch [113/50000] s_loss:-1.4991 d_loss:-77.2992 val_s_loss:21.4209 val_d_loss:-55.9399 cost:32.59
# epoch [114/50000] s_loss:-21.1554 d_loss:-48.7107 val_s_loss:-6.6702 val_d_loss:-42.3706 cost:32.51
# epoch [115/50000] s_loss:-64.5121 d_loss:-36.2091 val_s_loss:27.3128 val_d_loss:-97.1715 cost:31.18
# epoch [116/50000] s_loss:-114.8871 d_loss:-33.3272 val_s_loss:-29.9045 val_d_loss:-52.8911 cost:32.31
# epoch [117/50000] s_loss:-228.0593 d_loss:-36.2908 val_s_loss:-147.4861 val_d_loss:-9.2860 cost:33.75
# epoch [118/50000] s_loss:-141.5475 d_loss:-42.8276 val_s_loss:-118.1955 val_d_loss:-3.5127 cost:33.84
# epoch [119/50000] s_loss:-227.1781 d_loss:-28.0824 val_s_loss:-138.9757 val_d_loss:-9.2112 cost:32.93
# epoch [120/50000] s_loss:-62.5184 d_loss:-45.9846 val_s_loss:-82.2349 val_d_loss:-8.7728 cost:34.11
# epoch [121/50000] s_loss:-93.5623 d_loss:-57.0280 val_s_loss:-91.6270 val_d_loss:-6.9617 cost:34.69
# epoch [122/50000] s_loss:-116.5987 d_loss:-52.0568 val_s_loss:-131.2457 val_d_loss:-6.5950 cost:31.45
# epoch [123/50000] s_loss:247.9919 d_loss:-84.6691 val_s_loss:18.1953 val_d_loss:-18.4024 cost:32.19
# epoch [124/50000] s_loss:-41.8504 d_loss:-40.0147 val_s_loss:-46.7355 val_d_loss:-27.4429 cost:31.81
# epoch [125/50000] s_loss:-60.1321 d_loss:-62.2909 val_s_loss:49.1379 val_d_loss:-103.0064 cost:32.17
# epoch [126/50000] s_loss:-127.6407 d_loss:-87.3534 val_s_loss:-101.9450 val_d_loss:-11.8031 cost:32.21
# epoch [127/50000] s_loss:-94.8918 d_loss:-35.7907 val_s_loss:-122.0363 val_d_loss:-10.6234 cost:30.51
# epoch [128/50000] s_loss:177.1272 d_loss:-158.7547 val_s_loss:-54.2490 val_d_loss:-8.5594 cost:32.53
# epoch [129/50000] s_loss:-23.6366 d_loss:-32.3967 val_s_loss:14.7859 val_d_loss:-75.4733 cost:32.05
# epoch [130/50000] s_loss:-115.3660 d_loss:-57.1239 val_s_loss:-61.7145 val_d_loss:-62.4012 cost:32.22
# epoch [131/50000] s_loss:-218.0137 d_loss:-49.7872 val_s_loss:-159.5400 val_d_loss:-9.9682 cost:32.94
# epoch [132/50000] s_loss:-117.1906 d_loss:-52.5806 val_s_loss:-83.2645 val_d_loss:-9.7258 cost:31.92
# epoch [133/50000] s_loss:2.6519 d_loss:-56.0372 val_s_loss:-86.4388 val_d_loss:-7.5071 cost:33.17
# epoch [134/50000] s_loss:-106.3050 d_loss:-91.8305 val_s_loss:45.8691 val_d_loss:-107.2211 cost:33.91
# epoch [135/50000] s_loss:-141.9289 d_loss:-31.3407 val_s_loss:-101.3574 val_d_loss:-5.9102 cost:32.81
# epoch [136/50000] s_loss:-294.3291 d_loss:-28.1740 val_s_loss:-175.6513 val_d_loss:-7.7975 cost:32.23
# epoch [137/50000] s_loss:-186.3539 d_loss:-29.4006 val_s_loss:-133.6416 val_d_loss:-5.5482 cost:32.39
# epoch [138/50000] s_loss:-155.4791 d_loss:-48.6780 val_s_loss:-134.2676 val_d_loss:-7.9845 cost:33.31
# epoch [139/50000] s_loss:-178.3411 d_loss:-49.8288 val_s_loss:-83.9137 val_d_loss:-42.3852 cost:32.58
# epoch [140/50000] s_loss:-172.5107 d_loss:-26.7087 val_s_loss:-164.0074 val_d_loss:-4.9564 cost:31.96
# epoch [141/50000] s_loss:-235.8541 d_loss:-28.2930 val_s_loss:-173.5203 val_d_loss:-2.6120 cost:33.43
# epoch [142/50000] s_loss:-261.4512 d_loss:-35.2870 val_s_loss:-180.3071 val_d_loss:-3.5793 cost:33.24
# epoch [143/50000] s_loss:-208.3668 d_loss:-25.5923 val_s_loss:-169.5913 val_d_loss:-8.7631 cost:33.44
# epoch [144/50000] s_loss:-193.1250 d_loss:-29.0202 val_s_loss:-86.7685 val_d_loss:-41.4663 cost:33.92
# epoch [145/50000] s_loss:-265.6046 d_loss:-46.4079 val_s_loss:-167.1468 val_d_loss:-6.6065 cost:33.62
# epoch [146/50000] s_loss:-193.5916 d_loss:-33.9160 val_s_loss:-131.6385 val_d_loss:-6.2191 cost:33.02
# epoch [147/50000] s_loss:-147.0576 d_loss:-30.4313 val_s_loss:-134.3389 val_d_loss:-3.9948 cost:33.28
# epoch [148/50000] s_loss:-272.5594 d_loss:-33.9716 val_s_loss:-164.2569 val_d_loss:-4.2756 cost:32.92
# epoch [149/50000] s_loss:-302.2822 d_loss:-29.6798 val_s_loss:-180.9310 val_d_loss:-6.0690 cost:34.37
# epoch [150/50000] s_loss:-245.7706 d_loss:-37.4457 val_s_loss:-170.0204 val_d_loss:-5.0334 cost:33.71
# epoch [151/50000] s_loss:-176.5648 d_loss:-92.5393 val_s_loss:-118.3175 val_d_loss:-6.6438 cost:33.58
# epoch [152/50000] s_loss:-113.3000 d_loss:-31.4288 val_s_loss:-111.7579 val_d_loss:-5.5966 cost:32.38
# epoch [153/50000] s_loss:-211.2262 d_loss:-76.9783 val_s_loss:-143.0154 val_d_loss:-4.8420 cost:34.06
# epoch [154/50000] s_loss:-176.7830 d_loss:-35.9978 val_s_loss:-117.1822 val_d_loss:-5.8713 cost:31.80
# epoch [155/50000] s_loss:-171.0686 d_loss:-32.9922 val_s_loss:-116.1341 val_d_loss:-6.3085 cost:31.77
# epoch [156/50000] s_loss:-217.5761 d_loss:-24.5670 val_s_loss:-140.3461 val_d_loss:-6.3041 cost:32.60
# epoch [157/50000] s_loss:-311.6597 d_loss:-38.8054 val_s_loss:-190.8346 val_d_loss:-6.4791 cost:33.00
# epoch [158/50000] s_loss:-339.7974 d_loss:-22.3139 val_s_loss:-202.1224 val_d_loss:-8.1105 cost:32.22
# epoch [159/50000] s_loss:-186.8512 d_loss:-32.5786 val_s_loss:-132.8736 val_d_loss:-4.5439 cost:33.22
# epoch [160/50000] s_loss:-141.6438 d_loss:-24.8513 val_s_loss:4.6069 val_d_loss:-86.7757 cost:33.25
# epoch [161/50000] s_loss:-115.8586 d_loss:-27.9784 val_s_loss:-112.5659 val_d_loss:-3.8114 cost:32.46
# epoch [162/50000] s_loss:-117.8610 d_loss:-90.3368 val_s_loss:19.8092 val_d_loss:-100.1547 cost:32.75
# epoch [163/50000] s_loss:-83.0521 d_loss:-24.1127 val_s_loss:-91.5230 val_d_loss:-4.8435 cost:32.47
# epoch [164/50000] s_loss:-206.6580 d_loss:-42.1064 val_s_loss:-134.9088 val_d_loss:-8.3894 cost:33.74
# epoch [165/50000] s_loss:-263.5554 d_loss:-30.1774 val_s_loss:-159.5506 val_d_loss:-2.4036 cost:31.99
# epoch [166/50000] s_loss:-310.1360 d_loss:-24.1419 val_s_loss:-189.5328 val_d_loss:1.2230 cost:33.24
# epoch [167/50000] s_loss:-106.2656 d_loss:-26.0036 val_s_loss:-79.0408 val_d_loss:-0.2194 cost:32.25
# epoch [168/50000] s_loss:-32.3010 d_loss:-32.3387 val_s_loss:-58.6262 val_d_loss:-6.8538 cost:32.82
# epoch [169/50000] s_loss:-70.3828 d_loss:-33.8574 val_s_loss:-59.5753 val_d_loss:-24.4972 cost:31.41
# epoch [170/50000] s_loss:-168.1214 d_loss:-23.7749 val_s_loss:-124.5536 val_d_loss:-1.0676 cost:32.32
# epoch [171/50000] s_loss:-254.1052 d_loss:-25.7084 val_s_loss:-155.4255 val_d_loss:-3.5848 cost:32.49
# epoch [172/50000] s_loss:-222.6736 d_loss:-37.3940 val_s_loss:-138.8593 val_d_loss:-7.4382 cost:32.62
# epoch [173/50000] s_loss:-93.9592 d_loss:-39.4418 val_s_loss:-103.3268 val_d_loss:-1.4046 cost:33.35
# epoch [174/50000] s_loss:-111.0259 d_loss:-27.1600 val_s_loss:-93.4563 val_d_loss:-4.9624 cost:32.94
# epoch [175/50000] s_loss:-207.8320 d_loss:-23.3228 val_s_loss:-132.7506 val_d_loss:-7.0886 cost:33.26
# epoch [176/50000] s_loss:-172.1537 d_loss:-52.6180 val_s_loss:-196.9542 val_d_loss:-6.5487 cost:33.32
# epoch [177/50000] s_loss:-103.3672 d_loss:-30.0523 val_s_loss:-105.9109 val_d_loss:-4.1516 cost:33.12
# epoch [178/50000] s_loss:-109.2398 d_loss:-20.7798 val_s_loss:-17.5206 val_d_loss:-67.1634 cost:32.49
# epoch [179/50000] s_loss:-182.2943 d_loss:-38.3208 val_s_loss:-17.4721 val_d_loss:-82.6946 cost:31.68
# epoch [180/50000] s_loss:-167.2739 d_loss:-35.2652 val_s_loss:-126.9392 val_d_loss:-4.4289 cost:32.37
# epoch [181/50000] s_loss:-160.0480 d_loss:-62.6828 val_s_loss:-107.7178 val_d_loss:-6.1269 cost:33.20
# epoch [182/50000] s_loss:-39.6890 d_loss:-41.9198 val_s_loss:-93.3238 val_d_loss:-12.2761 cost:32.37
# epoch [183/50000] s_loss:-7.8131 d_loss:-103.3055 val_s_loss:-64.3913 val_d_loss:-17.6289 cost:33.26
# epoch [184/50000] s_loss:2.2134 d_loss:-117.7354 val_s_loss:-19.3258 val_d_loss:-0.5814 cost:31.94
# epoch [185/50000] s_loss:-41.9554 d_loss:-30.0666 val_s_loss:-51.6941 val_d_loss:-4.0090 cost:32.55
# epoch [186/50000] s_loss:-41.7554 d_loss:-81.1256 val_s_loss:-48.9469 val_d_loss:-3.1510 cost:32.59
# epoch [187/50000] s_loss:-6.8423 d_loss:-25.0415 val_s_loss:-35.8490 val_d_loss:-3.6023 cost:32.53
# epoch [188/50000] s_loss:-126.9459 d_loss:-35.6339 val_s_loss:-92.4032 val_d_loss:-4.3498 cost:33.76
# epoch [189/50000] s_loss:37.6430 d_loss:-138.2141 val_s_loss:-22.1339 val_d_loss:-3.7299 cost:32.11
# epoch [190/50000] s_loss:39.8042 d_loss:-27.9802 val_s_loss:9.5365 val_d_loss:-24.9444 cost:33.08
# epoch [191/50000] s_loss:-55.7771 d_loss:-31.2888 val_s_loss:-69.0372 val_d_loss:-5.2013 cost:32.83
# epoch [192/50000] s_loss:-185.9236 d_loss:-23.7025 val_s_loss:-10.6942 val_d_loss:-84.3399 cost:31.82
# epoch [193/50000] s_loss:-156.9721 d_loss:-38.8028 val_s_loss:-130.9813 val_d_loss:-6.5519 cost:31.45
# epoch [194/50000] s_loss:-138.2413 d_loss:-36.3452 val_s_loss:-97.3257 val_d_loss:-5.5774 cost:33.06
# epoch [195/50000] s_loss:-97.4816 d_loss:-32.6715 val_s_loss:13.5787 val_d_loss:-84.8719 cost:32.77
# epoch [196/50000] s_loss:-80.9239 d_loss:-70.1081 val_s_loss:-44.0706 val_d_loss:-17.6283 cost:31.19
# epoch [197/50000] s_loss:66.3125 d_loss:-109.0738 val_s_loss:21.7930 val_d_loss:-21.2767 cost:32.20
# epoch [198/50000] s_loss:58.2778 d_loss:-25.0972 val_s_loss:-5.9517 val_d_loss:-3.4221 cost:32.73
# epoch [199/50000] s_loss:-27.6165 d_loss:-33.3420 val_s_loss:-48.6993 val_d_loss:-4.9500 cost:32.49
# epoch [200/50000] s_loss:-150.7765 d_loss:-25.6389 val_s_loss:-110.9757 val_d_loss:-6.0480 cost:32.48
# epoch [201/50000] s_loss:-216.5585 d_loss:-27.5235 val_s_loss:-147.3377 val_d_loss:-6.7630 cost:32.36
# epoch [202/50000] s_loss:-251.0795 d_loss:-29.4316 val_s_loss:-155.9420 val_d_loss:-5.6693 cost:34.73
# epoch [203/50000] s_loss:-194.5439 d_loss:-28.3272 val_s_loss:-128.4760 val_d_loss:-5.6982 cost:31.40
# epoch [204/50000] s_loss:-87.1632 d_loss:-41.0295 val_s_loss:-82.4237 val_d_loss:-3.4693 cost:33.18
# epoch [205/50000] s_loss:-24.3670 d_loss:-51.9592 val_s_loss:-20.3486 val_d_loss:-22.9576 cost:32.29
# epoch [206/50000] s_loss:-60.3950 d_loss:-48.1962 val_s_loss:-11.4122 val_d_loss:-40.1051 cost:32.58
# epoch [207/50000] s_loss:-58.5052 d_loss:-56.2249 val_s_loss:-85.1790 val_d_loss:-6.4163 cost:32.92
# epoch [208/50000] s_loss:-130.6123 d_loss:-28.0346 val_s_loss:-89.2028 val_d_loss:-6.0573 cost:32.84
# epoch [209/50000] s_loss:-15.5876 d_loss:-53.0254 val_s_loss:4.5096 val_d_loss:-66.6152 cost:31.74
# epoch [210/50000] s_loss:-118.1711 d_loss:-60.4029 val_s_loss:9.6049 val_d_loss:-95.0998 cost:32.47
# epoch [211/50000] s_loss:-127.3097 d_loss:-24.8270 val_s_loss:-95.6928 val_d_loss:-3.7344 cost:32.83
# epoch [212/50000] s_loss:-162.6808 d_loss:-23.1502 val_s_loss:-37.2388 val_d_loss:-56.6713 cost:32.54
# epoch [213/50000] s_loss:-34.7308 d_loss:-54.2111 val_s_loss:-81.9440 val_d_loss:-6.2884 cost:32.65
# epoch [214/50000] s_loss:-61.2242 d_loss:-24.6185 val_s_loss:-69.0535 val_d_loss:-6.6043 cost:31.86
# epoch [215/50000] s_loss:-119.2338 d_loss:-37.3991 val_s_loss:6.0478 val_d_loss:-69.9779 cost:32.70
# epoch [216/50000] s_loss:13.6765 d_loss:-29.3462 val_s_loss:-61.7186 val_d_loss:-4.1860 cost:33.55
# epoch [217/50000] s_loss:-53.1776 d_loss:-33.6411 val_s_loss:-55.5692 val_d_loss:-6.6920 cost:34.09
# epoch [218/50000] s_loss:-20.4978 d_loss:-39.7111 val_s_loss:-46.7813 val_d_loss:-1.2249 cost:33.50
# epoch [219/50000] s_loss:-54.2863 d_loss:-29.4499 val_s_loss:31.1279 val_d_loss:-78.1904 cost:32.91
# epoch [220/50000] s_loss:-115.3461 d_loss:-24.7232 val_s_loss:-83.3628 val_d_loss:-3.4796 cost:33.10
# epoch [221/50000] s_loss:215.6577 d_loss:-31.0793 val_s_loss:-62.3236 val_d_loss:-4.4308 cost:33.57
# epoch [222/50000] s_loss:-76.7966 d_loss:-24.2250 val_s_loss:-62.8174 val_d_loss:-4.6455 cost:31.26
# epoch [223/50000] s_loss:-22.2543 d_loss:-62.6692 val_s_loss:-41.8821 val_d_loss:-2.1753 cost:33.03
# epoch [224/50000] s_loss:14.6681 d_loss:-30.4273 val_s_loss:-71.7977 val_d_loss:-3.6446 cost:32.07
# epoch [225/50000] s_loss:-125.0841 d_loss:-31.4459 val_s_loss:-111.5079 val_d_loss:-6.3509 cost:32.15
# epoch [226/50000] s_loss:-60.8727 d_loss:-23.9863 val_s_loss:-68.8412 val_d_loss:-5.6063 cost:33.07
# epoch [227/50000] s_loss:-72.7096 d_loss:-36.5619 val_s_loss:-78.6771 val_d_loss:-8.3795 cost:33.62
# epoch [228/50000] s_loss:-74.0104 d_loss:-46.9550 val_s_loss:15.4651 val_d_loss:-82.4371 cost:34.01
# epoch [229/50000] s_loss:-94.3880 d_loss:-37.2260 val_s_loss:-85.0321 val_d_loss:-5.0381 cost:32.42
# epoch [230/50000] s_loss:-16.0623 d_loss:-66.0464 val_s_loss:-49.8922 val_d_loss:-2.2579 cost:31.25
# epoch [231/50000] s_loss:288.3376 d_loss:-24.6972 val_s_loss:1.0689 val_d_loss:-7.6221 cost:31.27
# epoch [232/50000] s_loss:21.7836 d_loss:-92.0239 val_s_loss:38.5655 val_d_loss:-32.9096 cost:31.05
# epoch [233/50000] s_loss:8.2023 d_loss:-105.1021 val_s_loss:-22.7627 val_d_loss:-3.8661 cost:33.65
# epoch [234/50000] s_loss:-48.2898 d_loss:-26.3573 val_s_loss:-46.0112 val_d_loss:-3.4226 cost:33.25
# epoch [235/50000] s_loss:-97.5742 d_loss:-34.3199 val_s_loss:-12.5261 val_d_loss:-39.9124 cost:33.08
# epoch [236/50000] s_loss:-37.2953 d_loss:-63.7919 val_s_loss:46.1792 val_d_loss:-90.9583 cost:32.62
# epoch [237/50000] s_loss:18.4675 d_loss:-28.3962 val_s_loss:-18.0489 val_d_loss:-3.1309 cost:33.09
# epoch [238/50000] s_loss:37.9992 d_loss:-26.9144 val_s_loss:-27.0655 val_d_loss:-4.8055 cost:33.47
# epoch [239/50000] s_loss:-124.5988 d_loss:-29.6731 val_s_loss:-90.9794 val_d_loss:-2.3253 cost:32.41
# epoch [240/50000] s_loss:-41.6647 d_loss:-55.1920 val_s_loss:-78.3714 val_d_loss:-8.2658 cost:32.48
# epoch [241/50000] s_loss:-64.9360 d_loss:-32.4066 val_s_loss:-39.3626 val_d_loss:-24.2866 cost:32.79
# epoch [242/50000] s_loss:-53.6490 d_loss:-28.6338 val_s_loss:-56.3307 val_d_loss:-5.9167 cost:33.24
# epoch [243/50000] s_loss:-113.6140 d_loss:-42.1199 val_s_loss:-92.3764 val_d_loss:-7.2647 cost:32.53
# epoch [244/50000] s_loss:-71.9669 d_loss:-108.7749 val_s_loss:-93.3498 val_d_loss:-7.4579 cost:31.27
# epoch [245/50000] s_loss:-67.7643 d_loss:-22.5193 val_s_loss:-65.2611 val_d_loss:-2.2287 cost:32.53
# epoch [246/50000] s_loss:-94.5215 d_loss:-32.6983 val_s_loss:-11.8602 val_d_loss:-57.1374 cost:32.10
# epoch [247/50000] s_loss:-62.2502 d_loss:-27.4099 val_s_loss:-68.5605 val_d_loss:-5.7910 cost:31.93
# epoch [248/50000] s_loss:130.6832 d_loss:-114.8777 val_s_loss:-33.3681 val_d_loss:-5.3118 cost:33.30
# epoch [249/50000] s_loss:56.4236 d_loss:-20.7996 val_s_loss:6.6035 val_d_loss:-4.5378 cost:33.24
# epoch [250/50000] s_loss:184.9906 d_loss:-125.6599 val_s_loss:25.0286 val_d_loss:-1.7578 cost:33.27
# epoch [251/50000] s_loss:143.2173 d_loss:-21.3423 val_s_loss:95.5362 val_d_loss:-65.3526 cost:33.94
# epoch [252/50000] s_loss:25.2286 d_loss:-32.5118 val_s_loss:-20.3262 val_d_loss:-3.4723 cost:32.90
# epoch [253/50000] s_loss:-44.6143 d_loss:-31.0138 val_s_loss:-4.4849 val_d_loss:-41.6609 cost:32.25
# epoch [254/50000] s_loss:-51.3138 d_loss:-31.0457 val_s_loss:-91.6160 val_d_loss:-4.8478 cost:32.59
# epoch [255/50000] s_loss:-40.3946 d_loss:-33.5581 val_s_loss:-59.5089 val_d_loss:-4.2729 cost:32.36
# epoch [256/50000] s_loss:-20.0500 d_loss:-35.2891 val_s_loss:47.7558 val_d_loss:-83.9516 cost:32.97
# epoch [257/50000] s_loss:-59.6157 d_loss:-36.1697 val_s_loss:-66.0241 val_d_loss:-3.6022 cost:32.66
# epoch [258/50000] s_loss:-49.3158 d_loss:-30.0818 val_s_loss:-58.8664 val_d_loss:-3.2264 cost:32.59
# epoch [259/50000] s_loss:20.1329 d_loss:-102.1759 val_s_loss:-34.6480 val_d_loss:-1.5718 cost:33.60
# epoch [260/50000] s_loss:25.3656 d_loss:-30.4241 val_s_loss:-32.2273 val_d_loss:-3.0874 cost:32.92
# epoch [261/50000] s_loss:5.1787 d_loss:-35.0422 val_s_loss:14.0320 val_d_loss:-45.5472 cost:33.19
# epoch [262/50000] s_loss:-96.0326 d_loss:-26.9785 val_s_loss:-68.9593 val_d_loss:-6.8618 cost:31.83
# epoch [263/50000] s_loss:-103.8753 d_loss:-24.6714 val_s_loss:-78.5932 val_d_loss:-5.1781 cost:32.04
# epoch [264/50000] s_loss:-42.7091 d_loss:-50.3314 val_s_loss:-46.2674 val_d_loss:-3.5995 cost:33.98
# epoch [265/50000] s_loss:66.0112 d_loss:-34.4949 val_s_loss:-27.2530 val_d_loss:-3.7344 cost:32.28
# epoch [266/50000] s_loss:-19.1863 d_loss:-28.4919 val_s_loss:-34.2559 val_d_loss:-7.3671 cost:32.98
# epoch [267/50000] s_loss:-60.1930 d_loss:-21.2684 val_s_loss:-5.8623 val_d_loss:-31.0925 cost:34.12
# epoch [268/50000] s_loss:-4.7594 d_loss:-49.2750 val_s_loss:-57.9944 val_d_loss:-6.2954 cost:32.98
# epoch [269/50000] s_loss:-6.8027 d_loss:-30.9271 val_s_loss:59.7879 val_d_loss:-76.8488 cost:32.91
# epoch [270/50000] s_loss:-15.0025 d_loss:-24.3496 val_s_loss:-42.0378 val_d_loss:-3.9349 cost:31.80
# epoch [271/50000] s_loss:-64.6581 d_loss:-37.6702 val_s_loss:-59.6029 val_d_loss:-8.9168 cost:33.78
# epoch [272/50000] s_loss:115.7290 d_loss:-77.0967 val_s_loss:-30.3337 val_d_loss:-6.4387 cost:32.90
# epoch [273/50000] s_loss:50.5009 d_loss:-45.1809 val_s_loss:-21.4371 val_d_loss:-7.9766 cost:32.65
# epoch [274/50000] s_loss:38.1452 d_loss:-49.5731 val_s_loss:-25.0998 val_d_loss:-5.0799 cost:32.35
# epoch [275/50000] s_loss:73.6570 d_loss:-33.6536 val_s_loss:-20.8662 val_d_loss:-5.9987 cost:32.43
# epoch [276/50000] s_loss:40.3718 d_loss:-36.5129 val_s_loss:19.9558 val_d_loss:-36.0886 cost:32.41
# epoch [277/50000] s_loss:4.1065 d_loss:-27.1803 val_s_loss:-36.8263 val_d_loss:-5.2358 cost:32.60
# epoch [278/50000] s_loss:52.4395 d_loss:-30.3579 val_s_loss:-47.3701 val_d_loss:-6.1405 cost:32.68
# epoch [279/50000] s_loss:58.9149 d_loss:-63.4236 val_s_loss:-15.5067 val_d_loss:-4.2753 cost:32.84
# epoch [280/50000] s_loss:-0.6250 d_loss:-29.7919 val_s_loss:-25.7625 val_d_loss:-2.5673 cost:30.47
# epoch [281/50000] s_loss:60.4911 d_loss:-32.9638 val_s_loss:-1.3474 val_d_loss:-2.4920 cost:31.54
# epoch [282/50000] s_loss:-3.0387 d_loss:-30.3436 val_s_loss:-25.4553 val_d_loss:-6.1953 cost:30.80
# epoch [283/50000] s_loss:20.9063 d_loss:-32.6855 val_s_loss:-14.6857 val_d_loss:-2.3467 cost:31.57
# epoch [284/50000] s_loss:54.5925 d_loss:-25.6192 val_s_loss:-12.6006 val_d_loss:-4.3599 cost:31.87
# epoch [285/50000] s_loss:-21.3252 d_loss:-34.4303 val_s_loss:-42.3187 val_d_loss:-5.8306 cost:32.07
# epoch [286/50000] s_loss:-12.1435 d_loss:-21.6896 val_s_loss:-55.9423 val_d_loss:-6.0819 cost:32.08
# epoch [287/50000] s_loss:-43.4874 d_loss:-23.3643 val_s_loss:-46.1491 val_d_loss:-6.6339 cost:32.79
# epoch [288/50000] s_loss:-12.4370 d_loss:-31.1653 val_s_loss:-2.9908 val_d_loss:-42.1525 cost:33.09
# epoch [289/50000] s_loss:-27.7500 d_loss:-36.7791 val_s_loss:-43.4431 val_d_loss:-2.4436 cost:31.21
# epoch [290/50000] s_loss:-47.9584 d_loss:-43.5428 val_s_loss:-44.6823 val_d_loss:-3.2140 cost:32.45
# epoch [291/50000] s_loss:0.9849 d_loss:-28.1174 val_s_loss:-30.1664 val_d_loss:-6.3252 cost:33.05
# epoch [292/50000] s_loss:-28.3555 d_loss:-21.9391 val_s_loss:-37.5050 val_d_loss:-6.4232 cost:32.46
# epoch [293/50000] s_loss:-42.5892 d_loss:-27.7491 val_s_loss:-45.9591 val_d_loss:-5.9180 cost:33.26
# epoch [294/50000] s_loss:-21.8844 d_loss:-26.4980 val_s_loss:-37.4372 val_d_loss:-8.3252 cost:31.68
# epoch [295/50000] s_loss:-30.9785 d_loss:-30.4507 val_s_loss:-47.2511 val_d_loss:-6.8504 cost:32.54
# epoch [296/50000] s_loss:-53.3915 d_loss:-25.3271 val_s_loss:-55.6936 val_d_loss:-5.4107 cost:32.86
# epoch [297/50000] s_loss:-58.3422 d_loss:-31.3828 val_s_loss:14.4439 val_d_loss:-54.6785 cost:32.72
# epoch [298/50000] s_loss:-81.3234 d_loss:-31.7011 val_s_loss:-66.5046 val_d_loss:-3.8094 cost:32.50
# epoch [299/50000] s_loss:-50.3115 d_loss:-24.8140 val_s_loss:-47.7781 val_d_loss:-8.1114 cost:33.32
# epoch [300/50000] s_loss:-0.8195 d_loss:-26.4474 val_s_loss:74.0408 val_d_loss:-78.8785 cost:33.07
# epoch [301/50000] s_loss:70.1242 d_loss:-26.0891 val_s_loss:-20.4316 val_d_loss:-5.8982 cost:33.12
# epoch [302/50000] s_loss:9.3987 d_loss:-32.4734 val_s_loss:10.0388 val_d_loss:-27.9565 cost:33.72
# epoch [303/50000] s_loss:-29.9490 d_loss:-26.3944 val_s_loss:-48.0077 val_d_loss:-6.2555 cost:32.81
# epoch [304/50000] s_loss:-13.7803 d_loss:-56.1100 val_s_loss:-29.2651 val_d_loss:-4.0934 cost:32.86
# epoch [305/50000] s_loss:31.9942 d_loss:-22.3247 val_s_loss:-22.6009 val_d_loss:-4.6951 cost:31.68
# epoch [306/50000] s_loss:20.3244 d_loss:-31.2872 val_s_loss:-25.0313 val_d_loss:-6.7070 cost:32.59
# epoch [307/50000] s_loss:-6.0666 d_loss:-28.1462 val_s_loss:-34.2423 val_d_loss:-3.3973 cost:32.25
# epoch [308/50000] s_loss:-2.5588 d_loss:-26.8344 val_s_loss:-32.4224 val_d_loss:0.3907 cost:32.67
# epoch [309/50000] s_loss:17.6179 d_loss:-33.8315 val_s_loss:21.2670 val_d_loss:-34.3310 cost:31.55
# epoch [310/50000] s_loss:25.3290 d_loss:-28.2450 val_s_loss:-23.5200 val_d_loss:-3.5300 cost:31.81
# epoch [311/50000] s_loss:33.5818 d_loss:-22.1762 val_s_loss:-18.9901 val_d_loss:-4.4604 cost:32.90
# epoch [312/50000] s_loss:10.3959 d_loss:-19.6683 val_s_loss:-17.5177 val_d_loss:-6.6781 cost:33.78
# epoch [313/50000] s_loss:52.7360 d_loss:-27.6073 val_s_loss:48.7058 val_d_loss:-51.0114 cost:33.22
# epoch [314/50000] s_loss:-10.1718 d_loss:-51.0272 val_s_loss:-35.7493 val_d_loss:-6.5150 cost:33.90
# epoch [315/50000] s_loss:-14.7271 d_loss:-28.9602 val_s_loss:-31.5775 val_d_loss:-5.9088 cost:32.80
# epoch [316/50000] s_loss:94.9691 d_loss:-27.1281 val_s_loss:-39.7046 val_d_loss:-2.3227 cost:32.22
# epoch [317/50000] s_loss:39.3197 d_loss:-40.4887 val_s_loss:-28.6847 val_d_loss:-5.1330 cost:33.18
# epoch [318/50000] s_loss:2.3799 d_loss:-27.4204 val_s_loss:-30.1308 val_d_loss:-7.4974 cost:31.45
# epoch [319/50000] s_loss:-3.6789 d_loss:-24.8348 val_s_loss:-31.2584 val_d_loss:-3.8647 cost:32.53
# epoch [320/50000] s_loss:-4.1887 d_loss:-34.5645 val_s_loss:-24.2788 val_d_loss:0.7854 cost:33.33
# epoch [321/50000] s_loss:28.7988 d_loss:-23.3048 val_s_loss:51.4845 val_d_loss:-56.6127 cost:33.12
# epoch [322/50000] s_loss:81.9031 d_loss:-37.4996 val_s_loss:-16.5575 val_d_loss:-5.8157 cost:34.06
# epoch [323/50000] s_loss:-4.4146 d_loss:-24.4814 val_s_loss:-12.6898 val_d_loss:-15.6931 cost:31.00
# epoch [324/50000] s_loss:-16.6731 d_loss:-30.4923 val_s_loss:40.2869 val_d_loss:-68.8326 cost:32.29
# epoch [325/50000] s_loss:-26.8385 d_loss:-21.1019 val_s_loss:-60.3126 val_d_loss:-10.1133 cost:31.63
# epoch [326/50000] s_loss:-66.8437 d_loss:-22.2152 val_s_loss:-71.1704 val_d_loss:-7.2750 cost:32.46
# epoch [327/50000] s_loss:-88.6376 d_loss:-26.8682 val_s_loss:-73.0781 val_d_loss:-1.6433 cost:31.42
# epoch [328/50000] s_loss:-72.5429 d_loss:-31.2530 val_s_loss:-32.6819 val_d_loss:-20.7625 cost:31.64
# epoch [329/50000] s_loss:-49.0686 d_loss:-36.4356 val_s_loss:29.5372 val_d_loss:-61.6445 cost:31.92
# epoch [330/50000] s_loss:32.8482 d_loss:-27.3224 val_s_loss:90.5065 val_d_loss:-80.1014 cost:33.20
# epoch [331/50000] s_loss:0.5124 d_loss:-29.3876 val_s_loss:-20.3569 val_d_loss:-5.6943 cost:33.22
# epoch [332/50000] s_loss:-24.2773 d_loss:-21.5786 val_s_loss:-31.9662 val_d_loss:-6.9652 cost:32.75
# epoch [333/50000] s_loss:-46.4645 d_loss:-43.0009 val_s_loss:-45.3308 val_d_loss:0.6611 cost:32.28
# epoch [334/50000] s_loss:-21.8483 d_loss:-26.8262 val_s_loss:-38.6957 val_d_loss:-3.7307 cost:34.09
# epoch [335/50000] s_loss:-40.0071 d_loss:-26.5011 val_s_loss:51.5443 val_d_loss:-70.0032 cost:32.69
# epoch [336/50000] s_loss:11.1151 d_loss:-23.7768 val_s_loss:-58.8658 val_d_loss:-7.7071 cost:32.31
# epoch [337/50000] s_loss:-84.3607 d_loss:-25.0905 val_s_loss:30.1800 val_d_loss:-78.0082 cost:31.42
# epoch [338/50000] s_loss:11.5661 d_loss:-44.7486 val_s_loss:-61.6888 val_d_loss:-3.5652 cost:32.49
# epoch [339/50000] s_loss:-54.3144 d_loss:-31.4889 val_s_loss:-48.7664 val_d_loss:-5.6127 cost:33.69
# epoch [340/50000] s_loss:-9.5504 d_loss:-39.3105 val_s_loss:-39.4400 val_d_loss:-3.5816 cost:33.76
# epoch [341/50000] s_loss:-65.1966 d_loss:-32.9007 val_s_loss:-63.9827 val_d_loss:-6.3880 cost:33.44
# epoch [342/50000] s_loss:-124.8962 d_loss:-32.5681 val_s_loss:-88.1905 val_d_loss:-10.1001 cost:33.46
# epoch [343/50000] s_loss:-36.3696 d_loss:-28.4263 val_s_loss:-69.5929 val_d_loss:-8.9187 cost:33.46
# epoch [344/50000] s_loss:-8.6188 d_loss:-63.3916 val_s_loss:-35.0813 val_d_loss:-0.3301 cost:32.78
# epoch [345/50000] s_loss:4.3116 d_loss:-25.2499 val_s_loss:-19.9432 val_d_loss:-4.1871 cost:33.32
# epoch [346/50000] s_loss:-2.9146 d_loss:-20.7925 val_s_loss:-43.8587 val_d_loss:-2.8618 cost:33.01
# epoch [347/50000] s_loss:-49.4487 d_loss:-39.8100 val_s_loss:-44.5450 val_d_loss:-7.1860 cost:32.52
# epoch [348/50000] s_loss:-57.8230 d_loss:-21.7277 val_s_loss:47.9089 val_d_loss:-76.1656 cost:32.89
# epoch [349/50000] s_loss:-104.7644 d_loss:-21.0112 val_s_loss:-69.5839 val_d_loss:-9.5441 cost:32.09
# epoch [350/50000] s_loss:-134.5160 d_loss:-25.7202 val_s_loss:-24.5400 val_d_loss:-44.4660 cost:32.36
# epoch [351/50000] s_loss:-84.4151 d_loss:-22.3431 val_s_loss:-96.4662 val_d_loss:-4.7132 cost:32.49
# epoch [352/50000] s_loss:-77.0896 d_loss:-29.9153 val_s_loss:-64.9299 val_d_loss:-6.0471 cost:33.52
# epoch [353/50000] s_loss:-91.6532 d_loss:-48.4244 val_s_loss:19.1435 val_d_loss:-67.8798 cost:32.17
# epoch [354/50000] s_loss:-107.0085 d_loss:-25.8723 val_s_loss:-85.1218 val_d_loss:-5.3993 cost:31.79
# epoch [355/50000] s_loss:-137.4099 d_loss:-26.4990 val_s_loss:-104.8387 val_d_loss:4.3954 cost:31.45
# epoch [356/50000] s_loss:-28.6223 d_loss:-38.1103 val_s_loss:-45.6573 val_d_loss:-1.3634 cost:32.28
# epoch [357/50000] s_loss:-18.0697 d_loss:-33.0813 val_s_loss:30.3809 val_d_loss:-42.9025 cost:31.99
# epoch [358/50000] s_loss:47.8712 d_loss:-31.7269 val_s_loss:-33.7158 val_d_loss:-5.9921 cost:32.68
# epoch [359/50000] s_loss:-31.8911 d_loss:-26.0554 val_s_loss:-6.5436 val_d_loss:-34.7039 cost:32.42
# epoch [360/50000] s_loss:53.2046 d_loss:-123.8032 val_s_loss:-29.7243 val_d_loss:-0.8934 cost:32.38
# epoch [361/50000] s_loss:-20.0618 d_loss:-20.0279 val_s_loss:-29.1631 val_d_loss:-5.7250 cost:30.97
# epoch [362/50000] s_loss:3.2153 d_loss:-24.6561 val_s_loss:-23.2365 val_d_loss:-4.7478 cost:31.90
# epoch [363/50000] s_loss:130.9413 d_loss:-65.9803 val_s_loss:-22.6094 val_d_loss:-6.7092 cost:31.91
# epoch [364/50000] s_loss:153.8200 d_loss:-283.1902 val_s_loss:50.1027 val_d_loss:1.8989 cost:32.37
# epoch [365/50000] s_loss:-79.5443 d_loss:-22.9938 val_s_loss:-57.7484 val_d_loss:-9.3632 cost:31.16
# epoch [366/50000] s_loss:-125.5652 d_loss:-67.1466 val_s_loss:-83.3718 val_d_loss:-6.3336 cost:33.57
# epoch [367/50000] s_loss:-29.7819 d_loss:-58.9456 val_s_loss:24.1119 val_d_loss:-39.1744 cost:32.36
# epoch [368/50000] s_loss:107.5412 d_loss:-25.9253 val_s_loss:-19.3695 val_d_loss:-6.7742 cost:31.55
# epoch [369/50000] s_loss:29.1556 d_loss:-23.0877 val_s_loss:43.9981 val_d_loss:-60.3061 cost:32.68
# epoch [370/50000] s_loss:51.8696 d_loss:-52.8953 val_s_loss:-47.0405 val_d_loss:-6.6352 cost:32.76
# epoch [371/50000] s_loss:-44.2856 d_loss:-41.4257 val_s_loss:-43.6360 val_d_loss:-16.4008 cost:32.46
# epoch [372/50000] s_loss:54.5452 d_loss:-34.5951 val_s_loss:-58.7707 val_d_loss:-5.3521 cost:32.52
# epoch [373/50000] s_loss:-52.2780 d_loss:-30.9572 val_s_loss:-2.1471 val_d_loss:-45.4061 cost:33.21
# epoch [374/50000] s_loss:5.1643 d_loss:-43.9802 val_s_loss:-56.0547 val_d_loss:-3.3799 cost:31.62
# epoch [375/50000] s_loss:18.2106 d_loss:-27.1450 val_s_loss:20.3619 val_d_loss:-38.7994 cost:33.21
# epoch [376/50000] s_loss:94.9217 d_loss:-36.2093 val_s_loss:30.9986 val_d_loss:-15.5918 cost:33.70
# epoch [377/50000] s_loss:62.6864 d_loss:-35.9438 val_s_loss:32.4531 val_d_loss:-22.6337 cost:31.78
# epoch [378/50000] s_loss:4.4794 d_loss:-23.0174 val_s_loss:-23.6273 val_d_loss:-3.8533 cost:32.61
# epoch [379/50000] s_loss:-3.9794 d_loss:-33.7612 val_s_loss:-32.9581 val_d_loss:-6.5114 cost:34.27
# epoch [380/50000] s_loss:-57.4328 d_loss:-26.1559 val_s_loss:-50.8798 val_d_loss:-6.5959 cost:31.41
# epoch [381/50000] s_loss:-113.1216 d_loss:-34.0571 val_s_loss:-81.2486 val_d_loss:-6.6261 cost:33.30
# epoch [382/50000] s_loss:61.6695 d_loss:-19.5189 val_s_loss:-33.5724 val_d_loss:-7.4554 cost:32.62
# epoch [383/50000] s_loss:-8.2474 d_loss:-28.4649 val_s_loss:-37.4872 val_d_loss:-5.4942 cost:33.67
# epoch [384/50000] s_loss:0.3253 d_loss:-33.8957 val_s_loss:-56.1253 val_d_loss:-5.4451 cost:31.26
# epoch [385/50000] s_loss:-74.2774 d_loss:-42.3876 val_s_loss:-39.6521 val_d_loss:-29.2803 cost:33.54
# epoch [386/50000] s_loss:-60.7344 d_loss:-23.0088 val_s_loss:-80.5858 val_d_loss:-4.3631 cost:32.34
# epoch [387/50000] s_loss:91.7292 d_loss:-73.8941 val_s_loss:37.6073 val_d_loss:-19.3665 cost:32.59
# epoch [388/50000] s_loss:82.6937 d_loss:-28.4765 val_s_loss:10.6241 val_d_loss:-4.5950 cost:33.66
# epoch [389/50000] s_loss:28.5593 d_loss:-35.4604 val_s_loss:-16.2701 val_d_loss:-3.7069 cost:33.90
# epoch [390/50000] s_loss:63.1236 d_loss:-34.9674 val_s_loss:-39.2340 val_d_loss:-5.5375 cost:34.15
# epoch [391/50000] s_loss:9.8048 d_loss:-30.3017 val_s_loss:-31.6238 val_d_loss:-9.3783 cost:33.02
# epoch [392/50000] s_loss:0.5667 d_loss:-34.0431 val_s_loss:48.3993 val_d_loss:-65.9746 cost:32.25
# epoch [393/50000] s_loss:-32.7296 d_loss:-30.0524 val_s_loss:-34.8486 val_d_loss:-9.2373 cost:32.41
# epoch [394/50000] s_loss:-29.4765 d_loss:-33.9408 val_s_loss:-45.1484 val_d_loss:-5.8209 cost:32.37
# epoch [395/50000] s_loss:-44.3447 d_loss:-24.1951 val_s_loss:-41.3173 val_d_loss:-3.8432 cost:32.58
# epoch [396/50000] s_loss:-10.2621 d_loss:-34.4239 val_s_loss:-27.8212 val_d_loss:-7.2924 cost:32.47
# epoch [397/50000] s_loss:43.6000 d_loss:-36.9859 val_s_loss:-11.8780 val_d_loss:-6.4350 cost:33.87
# epoch [398/50000] s_loss:29.9522 d_loss:-25.7806 val_s_loss:81.0575 val_d_loss:-75.4922 cost:32.65
# epoch [399/50000] s_loss:8.9038 d_loss:-26.7046 val_s_loss:1.0216 val_d_loss:-8.2041 cost:33.16
# epoch [400/50000] s_loss:-13.7133 d_loss:-24.6557 val_s_loss:-27.0637 val_d_loss:-8.5075 cost:31.53
# epoch [401/50000] s_loss:73.6271 d_loss:-20.4858 val_s_loss:-27.6771 val_d_loss:-5.8654 cost:32.56
# epoch [402/50000] s_loss:4.1626 d_loss:-20.9859 val_s_loss:-23.5393 val_d_loss:-4.3833 cost:31.53
# epoch [403/50000] s_loss:16.4800 d_loss:-33.4458 val_s_loss:-26.6111 val_d_loss:-5.5963 cost:32.84
# epoch [404/50000] s_loss:-43.7162 d_loss:-36.9063 val_s_loss:-42.8620 val_d_loss:-5.0375 cost:33.41
# epoch [405/50000] s_loss:-62.8245 d_loss:-30.3751 val_s_loss:-51.0378 val_d_loss:-4.7055 cost:32.93
# epoch [406/50000] s_loss:-44.0286 d_loss:-31.9442 val_s_loss:-53.5357 val_d_loss:-5.3854 cost:32.09
# epoch [407/50000] s_loss:7.1575 d_loss:-64.2715 val_s_loss:-36.4187 val_d_loss:-7.3271 cost:33.17
# epoch [408/50000] s_loss:19.8257 d_loss:-21.5339 val_s_loss:-17.8825 val_d_loss:-3.7684 cost:33.18
# epoch [409/50000] s_loss:11.9265 d_loss:-32.4200 val_s_loss:54.0284 val_d_loss:-62.5795 cost:33.85
# epoch [410/50000] s_loss:-57.6800 d_loss:-34.8393 val_s_loss:34.4588 val_d_loss:-68.1526 cost:32.26
# epoch [411/50000] s_loss:-71.8703 d_loss:-28.9394 val_s_loss:-59.7293 val_d_loss:-5.0089 cost:32.28
# epoch [412/50000] s_loss:-74.4496 d_loss:-20.6274 val_s_loss:-54.0735 val_d_loss:-5.8493 cost:31.70
# epoch [413/50000] s_loss:-11.6345 d_loss:-53.6105 val_s_loss:-14.9465 val_d_loss:-10.5775 cost:33.34
# epoch [414/50000] s_loss:19.8350 d_loss:-33.6188 val_s_loss:-11.7515 val_d_loss:-2.3568 cost:30.98
# epoch [415/50000] s_loss:47.2813 d_loss:-24.7044 val_s_loss:-4.4740 val_d_loss:-6.8569 cost:31.71
# epoch [416/50000] s_loss:50.1867 d_loss:-24.0646 val_s_loss:9.2205 val_d_loss:1.2023 cost:31.02
# epoch [417/50000] s_loss:91.9209 d_loss:-24.2181 val_s_loss:22.5993 val_d_loss:-4.8046 cost:32.14
# epoch [418/50000] s_loss:40.5150 d_loss:-22.3868 val_s_loss:0.5841 val_d_loss:-6.0649 cost:32.64
# epoch [419/50000] s_loss:67.9725 d_loss:-25.4768 val_s_loss:10.0083 val_d_loss:-7.7018 cost:32.69
# epoch [420/50000] s_loss:94.8885 d_loss:-34.8587 val_s_loss:-14.5865 val_d_loss:-6.8896 cost:32.44
# epoch [421/50000] s_loss:27.4529 d_loss:-17.3200 val_s_loss:-4.3617 val_d_loss:-7.2811 cost:32.92
# epoch [422/50000] s_loss:-11.3787 d_loss:-28.1097 val_s_loss:-4.2021 val_d_loss:-17.0670 cost:32.87
# epoch [423/50000] s_loss:-23.7516 d_loss:-22.7970 val_s_loss:27.4260 val_d_loss:-52.2955 cost:33.60
# epoch [424/50000] s_loss:70.3046 d_loss:-64.0789 val_s_loss:-17.0413 val_d_loss:-5.8938 cost:32.78
# epoch [425/50000] s_loss:19.0734 d_loss:-24.1792 val_s_loss:4.2674 val_d_loss:-23.0405 cost:32.73
# epoch [426/50000] s_loss:22.2631 d_loss:-35.3142 val_s_loss:-18.2281 val_d_loss:-11.0679 cost:31.05
# epoch [427/50000] s_loss:-44.6918 d_loss:-33.2859 val_s_loss:-39.7083 val_d_loss:-9.7132 cost:32.34
# epoch [428/50000] s_loss:-75.4861 d_loss:-30.0446 val_s_loss:-58.4607 val_d_loss:-8.8748 cost:31.46
# epoch [429/50000] s_loss:-73.7595 d_loss:-24.0972 val_s_loss:-61.1912 val_d_loss:-3.4934 cost:32.73
# epoch [430/50000] s_loss:-56.5710 d_loss:-25.0643 val_s_loss:-39.9202 val_d_loss:-8.5621 cost:33.30
# epoch [431/50000] s_loss:-8.8313 d_loss:-24.8074 val_s_loss:-23.0036 val_d_loss:-5.8450 cost:32.58
# epoch [432/50000] s_loss:23.8137 d_loss:-25.8067 val_s_loss:-19.6601 val_d_loss:-9.1984 cost:33.45
# epoch [433/50000] s_loss:-13.9817 d_loss:-23.3216 val_s_loss:-34.6938 val_d_loss:-4.2095 cost:32.30
# epoch [434/50000] s_loss:-40.8991 d_loss:-21.7803 val_s_loss:-37.0351 val_d_loss:-6.2875 cost:33.65
# epoch [435/50000] s_loss:-54.6444 d_loss:-25.4909 val_s_loss:43.7186 val_d_loss:-72.0637 cost:31.13
# epoch [436/50000] s_loss:12.4171 d_loss:-93.9186 val_s_loss:-38.4248 val_d_loss:-5.0230 cost:32.87
# epoch [437/50000] s_loss:30.1933 d_loss:-19.2687 val_s_loss:7.3310 val_d_loss:-13.3699 cost:32.52
# epoch [438/50000] s_loss:38.6068 d_loss:-25.5896 val_s_loss:-4.2588 val_d_loss:-6.4125 cost:32.72
# epoch [439/50000] s_loss:4.9751 d_loss:-31.0382 val_s_loss:-6.4023 val_d_loss:-8.1319 cost:33.07
# epoch [440/50000] s_loss:-1.8301 d_loss:-30.2830 val_s_loss:-25.6249 val_d_loss:-5.9773 cost:34.38
# epoch [441/50000] s_loss:-37.0705 d_loss:-28.6650 val_s_loss:-34.4699 val_d_loss:-4.5355 cost:33.48
# epoch [442/50000] s_loss:3.1262 d_loss:-23.2315 val_s_loss:-24.2235 val_d_loss:-0.8568 cost:32.28
# epoch [443/50000] s_loss:-9.5611 d_loss:-31.2319 val_s_loss:-22.0528 val_d_loss:1.6371 cost:33.14
# epoch [444/50000] s_loss:72.2076 d_loss:-33.0213 val_s_loss:15.8861 val_d_loss:-3.3263 cost:32.45
# epoch [445/50000] s_loss:52.9174 d_loss:-29.0478 val_s_loss:8.2979 val_d_loss:-3.7839 cost:33.22
# epoch [446/50000] s_loss:99.3931 d_loss:-26.1519 val_s_loss:32.7677 val_d_loss:-7.2469 cost:29.81
# epoch [447/50000] s_loss:242.0429 d_loss:-17.9124 val_s_loss:87.8336 val_d_loss:-33.8902 cost:33.36
# epoch [448/50000] s_loss:180.4655 d_loss:-48.3431 val_s_loss:15.9290 val_d_loss:-5.7962 cost:33.01
# epoch [449/50000] s_loss:105.9586 d_loss:-23.5845 val_s_loss:18.5870 val_d_loss:-8.8533 cost:31.67
# epoch [450/50000] s_loss:122.8844 d_loss:-33.8952 val_s_loss:27.1748 val_d_loss:-8.6115 cost:34.22
# epoch [451/50000] s_loss:82.3699 d_loss:-26.4713 val_s_loss:13.9058 val_d_loss:-7.4688 cost:32.99
# epoch [452/50000] s_loss:47.2794 d_loss:-26.2474 val_s_loss:-4.7690 val_d_loss:-2.9878 cost:32.70
# epoch [453/50000] s_loss:6.9680 d_loss:-24.6804 val_s_loss:-16.4762 val_d_loss:-4.8995 cost:31.61
# epoch [454/50000] s_loss:77.5005 d_loss:-21.1635 val_s_loss:58.3861 val_d_loss:-78.8652 cost:34.04
# epoch [455/50000] s_loss:18.8738 d_loss:-28.0269 val_s_loss:-5.6148 val_d_loss:-6.8500 cost:32.97
# epoch [456/50000] s_loss:45.1613 d_loss:-24.2720 val_s_loss:2.3999 val_d_loss:-5.6733 cost:32.59
# epoch [457/50000] s_loss:33.2876 d_loss:-22.4784 val_s_loss:-4.0723 val_d_loss:-8.7208 cost:34.03
# epoch [458/50000] s_loss:20.2838 d_loss:-25.1702 val_s_loss:-12.0186 val_d_loss:-4.7316 cost:33.61
# epoch [459/50000] s_loss:14.3371 d_loss:-50.0811 val_s_loss:-24.4538 val_d_loss:-2.6380 cost:31.93
# epoch [460/50000] s_loss:13.8741 d_loss:-23.5414 val_s_loss:86.1111 val_d_loss:-85.6025 cost:32.72
# epoch [461/50000] s_loss:-3.3778 d_loss:-21.9828 val_s_loss:73.8848 val_d_loss:-77.7744 cost:32.76
# epoch [462/50000] s_loss:-15.1439 d_loss:-28.0397 val_s_loss:-28.1094 val_d_loss:-7.1632 cost:31.20
# epoch [463/50000] s_loss:-47.6828 d_loss:-18.5799 val_s_loss:-37.3622 val_d_loss:-9.0415 cost:33.17
# epoch [464/50000] s_loss:14.4537 d_loss:-28.8224 val_s_loss:-43.9181 val_d_loss:-5.5231 cost:34.08
# epoch [465/50000] s_loss:13.0643 d_loss:-19.9809 val_s_loss:53.2994 val_d_loss:-61.3320 cost:32.07
# epoch [466/50000] s_loss:-12.5142 d_loss:-28.0273 val_s_loss:-28.5284 val_d_loss:-7.9606 cost:32.43
# epoch [467/50000] s_loss:-59.3341 d_loss:-29.9182 val_s_loss:-52.5692 val_d_loss:-8.1273 cost:31.39
# epoch [468/50000] s_loss:-94.0262 d_loss:-31.5746 val_s_loss:-70.8023 val_d_loss:-8.7700 cost:31.91
# epoch [469/50000] s_loss:-104.2327 d_loss:-26.7627 val_s_loss:-104.3730 val_d_loss:-5.4277 cost:31.44
# epoch [470/50000] s_loss:-137.2983 d_loss:-40.2869 val_s_loss:-104.9042 val_d_loss:-8.2139 cost:30.45
# epoch [471/50000] s_loss:-177.5150 d_loss:-29.0264 val_s_loss:-107.0880 val_d_loss:-7.6057 cost:32.40
# epoch [472/50000] s_loss:-124.7689 d_loss:-20.4691 val_s_loss:-93.1641 val_d_loss:-8.2949 cost:32.93
# epoch [473/50000] s_loss:-123.0413 d_loss:-18.5455 val_s_loss:-78.5451 val_d_loss:-6.9941 cost:32.48
# epoch [474/50000] s_loss:-69.1901 d_loss:-25.2101 val_s_loss:-64.2144 val_d_loss:-4.1745 cost:32.71
# epoch [475/50000] s_loss:-46.4251 d_loss:-23.3472 val_s_loss:20.4394 val_d_loss:-54.8962 cost:31.78
# epoch [476/50000] s_loss:7.4297 d_loss:-24.4698 val_s_loss:-27.1070 val_d_loss:-6.8697 cost:32.21
# epoch [477/50000] s_loss:32.6464 d_loss:-23.3541 val_s_loss:-9.7336 val_d_loss:-4.2296 cost:30.73
# epoch [478/50000] s_loss:15.2464 d_loss:-24.8898 val_s_loss:-16.5213 val_d_loss:-4.8248 cost:31.71
# epoch [479/50000] s_loss:18.4766 d_loss:-28.1105 val_s_loss:-13.1867 val_d_loss:-5.7825 cost:34.06
# ...
# epoch [9157/50000] s_loss:-11.7390 d_loss:-3.6175 val_s_loss:-4.5498 val_d_loss:-3.2172 cost:26.24
# epoch [9158/50000] s_loss:-10.0317 d_loss:-3.7703 val_s_loss:-5.3095 val_d_loss:-2.6277 cost:25.80
# epoch [9159/50000] s_loss:-10.0639 d_loss:-5.5343 val_s_loss:-4.8882 val_d_loss:-2.9491 cost:24.04
# epoch [9160/50000] s_loss:-8.1341 d_loss:-4.5886 val_s_loss:-6.3438 val_d_loss:0.6792 cost:25.70
# epoch [9161/50000] s_loss:-5.1923 d_loss:-4.1895 val_s_loss:-5.9484 val_d_loss:2.1396 cost:24.45
# epoch [9162/50000] s_loss:1.1730 d_loss:-4.8101 val_s_loss:-0.1392 val_d_loss:-3.4058 cost:25.51
# epoch [9163/50000] s_loss:-5.7295 d_loss:-4.3688 val_s_loss:-4.1037 val_d_loss:-2.1635 cost:25.67
# epoch [9164/50000] s_loss:-14.6048 d_loss:-3.4900 val_s_loss:-7.9393 val_d_loss:-3.3952 cost:24.56
# epoch [9165/50000] s_loss:-18.6755 d_loss:-2.6454 val_s_loss:-8.7738 val_d_loss:-2.6080 cost:23.84
# epoch [9166/50000] s_loss:-10.1442 d_loss:-3.3320 val_s_loss:-4.7321 val_d_loss:-5.9896 cost:25.98
# epoch [9167/50000] s_loss:-6.4139 d_loss:-4.8930 val_s_loss:-1.5137 val_d_loss:-5.7297 cost:23.62
# epoch [9168/50000] s_loss:-4.7800 d_loss:-5.1344 val_s_loss:-4.7079 val_d_loss:-1.3194 cost:23.77
# epoch [9169/50000] s_loss:-10.9830 d_loss:-4.2335 val_s_loss:-9.3375 val_d_loss:2.6824 cost:25.17
# epoch [9170/50000] s_loss:-11.7579 d_loss:-3.7519 val_s_loss:-5.9289 val_d_loss:-3.3288 cost:24.78
# epoch [9171/50000] s_loss:-14.2202 d_loss:-3.7938 val_s_loss:-7.5641 val_d_loss:-3.2183 cost:25.01
# epoch [9172/50000] s_loss:-8.7396 d_loss:-4.3930 val_s_loss:-7.4112 val_d_loss:-2.1996 cost:25.73
# epoch [9173/50000] s_loss:-7.8537 d_loss:-4.4063 val_s_loss:-2.9599 val_d_loss:-5.7018 cost:25.24
# epoch [9174/50000] s_loss:-4.7291 d_loss:-3.9496 val_s_loss:-3.7597 val_d_loss:-0.7701 cost:25.43
# epoch [9175/50000] s_loss:-8.6390 d_loss:-4.6518 val_s_loss:-4.0074 val_d_loss:-3.0265 cost:25.46
# epoch [9176/50000] s_loss:-11.7795 d_loss:-3.0602 val_s_loss:-7.5916 val_d_loss:-0.9790 cost:25.96
# epoch [9177/50000] s_loss:-8.6715 d_loss:-4.8188 val_s_loss:-5.0073 val_d_loss:-2.1384 cost:25.48
# epoch [9178/50000] s_loss:-9.9478 d_loss:-6.3367 val_s_loss:-2.5816 val_d_loss:-2.9952 cost:25.51
# epoch [9179/50000] s_loss:-7.2130 d_loss:-4.0060 val_s_loss:-5.9257 val_d_loss:-1.1368 cost:24.80
# epoch [9180/50000] s_loss:-11.9916 d_loss:-4.4060 val_s_loss:-5.2998 val_d_loss:-4.1438 cost:25.28
# epoch [9181/50000] s_loss:-12.3802 d_loss:-3.6917 val_s_loss:-9.5825 val_d_loss:0.9518 cost:25.77
# epoch [9182/50000] s_loss:-9.8589 d_loss:-4.4857 val_s_loss:-6.1836 val_d_loss:-2.0612 cost:25.28
# epoch [9183/50000] s_loss:-5.4398 d_loss:-4.7129 val_s_loss:-2.2687 val_d_loss:-2.5987 cost:25.96
# epoch [9184/50000] s_loss:-6.9313 d_loss:-4.3657 val_s_loss:-4.3135 val_d_loss:-1.8683 cost:25.73
# epoch [9185/50000] s_loss:-6.6605 d_loss:-4.5758 val_s_loss:-3.5888 val_d_loss:-3.1610 cost:24.68
# epoch [9186/50000] s_loss:-13.4470 d_loss:-4.9280 val_s_loss:-7.4154 val_d_loss:-4.4554 cost:25.90
# epoch [9187/50000] s_loss:-13.8238 d_loss:-4.2971 val_s_loss:-4.1059 val_d_loss:-4.8092 cost:25.90
# epoch [9188/50000] s_loss:-10.9162 d_loss:-3.2272 val_s_loss:-3.9492 val_d_loss:-4.0648 cost:23.64
# epoch [9189/50000] s_loss:-7.6566 d_loss:-3.8067 val_s_loss:-3.2747 val_d_loss:-4.4465 cost:23.29
# epoch [9190/50000] s_loss:0.7619 d_loss:-3.5264 val_s_loss:3.7438 val_d_loss:-6.4892 cost:22.67
# epoch [9191/50000] s_loss:-3.6041 d_loss:-4.5983 val_s_loss:1.6742 val_d_loss:-6.4003 cost:24.23
# epoch [9192/50000] s_loss:-4.1793 d_loss:-4.2435 val_s_loss:-3.1895 val_d_loss:-3.1074 cost:24.70
# epoch [9193/50000] s_loss:-8.1508 d_loss:-3.7186 val_s_loss:-4.0152 val_d_loss:-3.1494 cost:25.16
# epoch [9194/50000] s_loss:-2.2792 d_loss:-3.7674 val_s_loss:-1.1951 val_d_loss:-3.0929 cost:25.79
# epoch [9195/50000] s_loss:-3.5032 d_loss:-3.4074 val_s_loss:-2.7189 val_d_loss:-2.1555 cost:25.56
# epoch [9196/50000] s_loss:-6.2055 d_loss:-4.6414 val_s_loss:-5.0855 val_d_loss:0.3064 cost:25.51
# epoch [9197/50000] s_loss:-2.3855 d_loss:-5.6519 val_s_loss:0.4922 val_d_loss:-5.9635 cost:25.75
# epoch [9198/50000] s_loss:-3.2524 d_loss:-4.5722 val_s_loss:-1.0280 val_d_loss:-4.7656 cost:24.98
# epoch [9199/50000] s_loss:-6.3846 d_loss:-3.3760 val_s_loss:-3.1190 val_d_loss:-4.1315 cost:24.57
# epoch [9200/50000] s_loss:-5.9296 d_loss:-4.4404 val_s_loss:-3.4826 val_d_loss:-2.4471 cost:25.05
# epoch [9201/50000] s_loss:-2.4626 d_loss:-4.9176 val_s_loss:-2.1897 val_d_loss:-2.6742 cost:25.69
# epoch [9202/50000] s_loss:-8.4672 d_loss:-2.7147 val_s_loss:-5.9403 val_d_loss:-1.1917 cost:25.57
# epoch [9203/50000] s_loss:-6.6699 d_loss:-4.8525 val_s_loss:-5.4472 val_d_loss:-2.4480 cost:26.48
# epoch [9204/50000] s_loss:-6.9444 d_loss:-4.6309 val_s_loss:-5.3561 val_d_loss:-2.2055 cost:24.39
# epoch [9205/50000] s_loss:-8.6964 d_loss:-3.3072 val_s_loss:-5.6438 val_d_loss:-1.8803 cost:25.41
# epoch [9206/50000] s_loss:-5.8894 d_loss:-4.2600 val_s_loss:-2.8134 val_d_loss:-1.9875 cost:25.06
# epoch [9207/50000] s_loss:-7.7713 d_loss:-4.2033 val_s_loss:-2.8814 val_d_loss:-5.0782 cost:23.11
# epoch [9208/50000] s_loss:-10.6267 d_loss:-4.1145 val_s_loss:-3.3357 val_d_loss:-5.4091 cost:23.54
# epoch [9209/50000] s_loss:-8.5291 d_loss:-3.4376 val_s_loss:-2.2365 val_d_loss:-5.0458 cost:25.94
# epoch [9210/50000] s_loss:-7.0953 d_loss:-5.1748 val_s_loss:-4.4075 val_d_loss:-3.0688 cost:23.60
# epoch [9211/50000] s_loss:-5.2670 d_loss:-4.0798 val_s_loss:-3.4079 val_d_loss:-2.9852 cost:25.53
# epoch [9212/50000] s_loss:-1.8962 d_loss:-3.4386 val_s_loss:-3.7317 val_d_loss:-1.5833 cost:24.59
# epoch [9213/50000] s_loss:-3.3803 d_loss:-4.2403 val_s_loss:-1.2917 val_d_loss:-3.3566 cost:25.25
# epoch [9214/50000] s_loss:-4.8640 d_loss:-4.2717 val_s_loss:-2.5113 val_d_loss:-2.6566 cost:25.83
# epoch [9215/50000] s_loss:-3.6340 d_loss:-4.7191 val_s_loss:-1.8017 val_d_loss:-2.7623 cost:25.33
# epoch [9216/50000] s_loss:-8.6338 d_loss:-3.5466 val_s_loss:-5.3316 val_d_loss:-1.9898 cost:24.95
# epoch [9217/50000] s_loss:-4.7925 d_loss:-4.2892 val_s_loss:-2.6437 val_d_loss:-2.7518 cost:25.30
# epoch [9218/50000] s_loss:-0.6340 d_loss:-4.1686 val_s_loss:0.4869 val_d_loss:-4.3948 cost:25.53
# epoch [9219/50000] s_loss:-2.7562 d_loss:-3.6119 val_s_loss:-0.9990 val_d_loss:-3.1766 cost:25.09
# epoch [9220/50000] s_loss:-9.5127 d_loss:-3.6338 val_s_loss:-3.9315 val_d_loss:-3.7151 cost:25.52
# epoch [9221/50000] s_loss:-14.2097 d_loss:-4.5664 val_s_loss:-6.2519 val_d_loss:-2.9006 cost:25.09
# epoch [9222/50000] s_loss:-9.7667 d_loss:-3.7878 val_s_loss:-4.7697 val_d_loss:-3.0488 cost:25.49
# epoch [9223/50000] s_loss:-4.1181 d_loss:-4.6548 val_s_loss:-2.2378 val_d_loss:-6.8091 cost:24.17
# epoch [9224/50000] s_loss:-0.8165 d_loss:-3.3930 val_s_loss:0.3565 val_d_loss:-4.0493 cost:25.83
# epoch [9225/50000] s_loss:-1.4908 d_loss:-3.2834 val_s_loss:-1.1768 val_d_loss:-3.2272 cost:25.73
# epoch [9226/50000] s_loss:-5.2443 d_loss:-3.3865 val_s_loss:-3.2479 val_d_loss:-1.6176 cost:24.53
# epoch [9227/50000] s_loss:-6.5589 d_loss:-5.1456 val_s_loss:-4.2825 val_d_loss:-2.3941 cost:25.08
# epoch [9228/50000] s_loss:-10.2159 d_loss:-5.2836 val_s_loss:-4.6015 val_d_loss:-3.2037 cost:24.88
# epoch [9229/50000] s_loss:-8.5547 d_loss:-4.6914 val_s_loss:-4.0670 val_d_loss:-2.1306 cost:24.04
# epoch [9230/50000] s_loss:-3.8832 d_loss:-3.7441 val_s_loss:-2.1449 val_d_loss:-4.0001 cost:23.38
# epoch [9231/50000] s_loss:-9.4772 d_loss:-4.6499 val_s_loss:-4.2930 val_d_loss:-5.0752 cost:22.42
# epoch [9232/50000] s_loss:-14.1070 d_loss:-3.8793 val_s_loss:-6.2046 val_d_loss:-4.1031 cost:23.85
# epoch [9233/50000] s_loss:-15.4038 d_loss:-5.0359 val_s_loss:-6.9867 val_d_loss:-5.0265 cost:25.00
# epoch [9234/50000] s_loss:-12.7098 d_loss:-3.2764 val_s_loss:-6.1496 val_d_loss:-2.8227 cost:25.63
# epoch [9235/50000] s_loss:-7.7210 d_loss:-4.2534 val_s_loss:-4.4345 val_d_loss:-3.3500 cost:25.65
# epoch [9236/50000] s_loss:-3.3422 d_loss:-4.6195 val_s_loss:-0.7633 val_d_loss:-3.5138 cost:25.70
# epoch [9237/50000] s_loss:-1.4372 d_loss:-4.0437 val_s_loss:-1.0313 val_d_loss:-3.1134 cost:26.00
# epoch [9238/50000] s_loss:-4.3723 d_loss:-3.9092 val_s_loss:-1.7271 val_d_loss:-3.3303 cost:25.67
# epoch [9239/50000] s_loss:-8.2102 d_loss:-3.7532 val_s_loss:-4.2382 val_d_loss:-1.9540 cost:25.41
# epoch [9240/50000] s_loss:-10.1512 d_loss:-2.8207 val_s_loss:-5.7630 val_d_loss:-2.4647 cost:25.92
# epoch [9241/50000] s_loss:-9.2172 d_loss:-4.4457 val_s_loss:-4.0760 val_d_loss:-1.5388 cost:25.81
# epoch [9242/50000] s_loss:-8.0685 d_loss:-4.4571 val_s_loss:-2.5914 val_d_loss:-4.3309 cost:24.45
# epoch [9243/50000] s_loss:-13.1077 d_loss:-3.6796 val_s_loss:-6.1885 val_d_loss:-3.0754 cost:25.46
# epoch [9244/50000] s_loss:-12.8246 d_loss:-3.3563 val_s_loss:-5.3460 val_d_loss:-2.3195 cost:25.90
# epoch [9245/50000] s_loss:-12.7847 d_loss:-3.7417 val_s_loss:-4.0962 val_d_loss:-6.3448 cost:25.51
# epoch [9246/50000] s_loss:-5.3371 d_loss:-3.3482 val_s_loss:-2.1335 val_d_loss:-4.3689 cost:25.74
# epoch [9247/50000] s_loss:-0.1439 d_loss:-4.4484 val_s_loss:0.3701 val_d_loss:-5.6608 cost:25.63
# epoch [9248/50000] s_loss:-2.1847 d_loss:-6.0868 val_s_loss:-1.8295 val_d_loss:-3.6510 cost:24.33
# epoch [9249/50000] s_loss:-9.9907 d_loss:-5.1002 val_s_loss:-4.7325 val_d_loss:-1.0080 cost:25.17
# epoch [9250/50000] s_loss:-5.8088 d_loss:-4.8976 val_s_loss:-4.5948 val_d_loss:-0.2189 cost:25.80
# epoch [9251/50000] s_loss:-10.2126 d_loss:-3.5194 val_s_loss:-3.4892 val_d_loss:-4.1536 cost:24.46
# epoch [9252/50000] s_loss:-14.7601 d_loss:-3.9101 val_s_loss:-6.0328 val_d_loss:-3.1299 cost:24.45
# epoch [9253/50000] s_loss:-12.5002 d_loss:-3.9624 val_s_loss:-5.8913 val_d_loss:-4.7826 cost:23.77
# epoch [9254/50000] s_loss:-6.2129 d_loss:-2.7741 val_s_loss:-4.2228 val_d_loss:-2.5311 cost:24.39
# epoch [9255/50000] s_loss:-7.0122 d_loss:-3.7348 val_s_loss:-4.1686 val_d_loss:-2.4692 cost:26.25
# epoch [9256/50000] s_loss:-1.8099 d_loss:-5.4136 val_s_loss:-1.7960 val_d_loss:-2.2235 cost:25.16
# epoch [9257/50000] s_loss:-4.4680 d_loss:-6.4014 val_s_loss:-4.3903 val_d_loss:-2.9500 cost:23.27
# epoch [9258/50000] s_loss:-10.5072 d_loss:-4.7842 val_s_loss:-9.1854 val_d_loss:2.4997 cost:26.55
# epoch [9259/50000] s_loss:-10.3382 d_loss:-3.2669 val_s_loss:-6.3289 val_d_loss:-3.1646 cost:23.88
# epoch [9260/50000] s_loss:-5.6937 d_loss:-5.1554 val_s_loss:-3.7910 val_d_loss:-3.7067 cost:26.35
# epoch [9261/50000] s_loss:-7.2711 d_loss:-4.2713 val_s_loss:-4.3825 val_d_loss:-3.2361 cost:25.07
# epoch [9262/50000] s_loss:-5.7391 d_loss:-3.7775 val_s_loss:-3.6559 val_d_loss:-3.9573 cost:25.17
# epoch [9263/50000] s_loss:-5.8407 d_loss:-3.6815 val_s_loss:-1.7594 val_d_loss:-5.6550 cost:23.76
# epoch [9264/50000] s_loss:-7.3711 d_loss:-3.3230 val_s_loss:-1.4058 val_d_loss:-3.0845 cost:25.42
# epoch [9265/50000] s_loss:-12.4314 d_loss:-4.2283 val_s_loss:-7.9631 val_d_loss:0.6568 cost:25.88
# epoch [9266/50000] s_loss:-8.7214 d_loss:-4.3370 val_s_loss:-4.3291 val_d_loss:-3.0968 cost:24.12
# epoch [9267/50000] s_loss:-7.9271 d_loss:-4.5800 val_s_loss:-6.6948 val_d_loss:-1.6998 cost:25.21
# epoch [9268/50000] s_loss:-7.5287 d_loss:-4.6391 val_s_loss:-5.1330 val_d_loss:-4.1893 cost:24.91
# epoch [9269/50000] s_loss:-3.8674 d_loss:-4.9936 val_s_loss:-2.1966 val_d_loss:-2.8508 cost:25.79
# epoch [9270/50000] s_loss:-5.5054 d_loss:-5.0277 val_s_loss:-3.3065 val_d_loss:-3.6691 cost:25.61
# epoch [9271/50000] s_loss:-2.7166 d_loss:-3.6409 val_s_loss:-3.5930 val_d_loss:-2.0097 cost:25.94
# epoch [9272/50000] s_loss:-9.4477 d_loss:-3.1833 val_s_loss:-6.0733 val_d_loss:-1.3605 cost:25.66
# epoch [9273/50000] s_loss:-8.6825 d_loss:-3.5829 val_s_loss:-5.0557 val_d_loss:-2.6547 cost:25.47
# epoch [9274/50000] s_loss:-7.4328 d_loss:-3.7516 val_s_loss:-3.7052 val_d_loss:-2.1235 cost:25.05
# epoch [9275/50000] s_loss:-5.8273 d_loss:-4.4596 val_s_loss:-2.7364 val_d_loss:-3.6321 cost:23.67
# epoch [9276/50000] s_loss:-0.9691 d_loss:-3.2388 val_s_loss:0.9322 val_d_loss:-3.3606 cost:23.76
# epoch [9277/50000] s_loss:0.9302 d_loss:-3.5266 val_s_loss:-1.4099 val_d_loss:-0.7212 cost:24.53
# epoch [9278/50000] s_loss:-2.7420 d_loss:-3.9194 val_s_loss:-3.4855 val_d_loss:-0.3628 cost:23.25
# epoch [9279/50000] s_loss:-5.7752 d_loss:-4.9555 val_s_loss:-4.2640 val_d_loss:-2.1427 cost:23.94
# epoch [9280/50000] s_loss:-6.7889 d_loss:-4.4759 val_s_loss:-5.7430 val_d_loss:-2.3254 cost:24.47
# epoch [9281/50000] s_loss:-6.8275 d_loss:-4.2280 val_s_loss:-5.0928 val_d_loss:-0.1275 cost:24.89
# epoch [9282/50000] s_loss:-4.8596 d_loss:-4.0415 val_s_loss:-2.9165 val_d_loss:-3.7446 cost:23.89
# epoch [9283/50000] s_loss:-6.7931 d_loss:-4.7227 val_s_loss:-3.7408 val_d_loss:-2.1754 cost:20.52
# epoch [9284/50000] s_loss:-4.5129 d_loss:-3.5608 val_s_loss:-1.7703 val_d_loss:-2.3803 cost:20.04
# epoch [9285/50000] s_loss:-9.8085 d_loss:-3.3066 val_s_loss:-4.2612 val_d_loss:-3.9739 cost:20.26
# epoch [9286/50000] s_loss:-9.7360 d_loss:-4.1107 val_s_loss:-2.5191 val_d_loss:-5.1246 cost:21.23
# epoch [9287/50000] s_loss:-3.8911 d_loss:-3.6048 val_s_loss:-3.1725 val_d_loss:-2.7228 cost:20.59
# epoch [9288/50000] s_loss:1.0898 d_loss:-3.3785 val_s_loss:-2.5765 val_d_loss:-0.8965 cost:20.83
# epoch [9289/50000] s_loss:-2.2407 d_loss:-2.8777 val_s_loss:-5.7622 val_d_loss:2.0047 cost:21.99
# epoch [9290/50000] s_loss:-8.0730 d_loss:-4.2151 val_s_loss:-4.3697 val_d_loss:-1.9675 cost:21.09
# epoch [9291/50000] s_loss:-11.6740 d_loss:-4.1658 val_s_loss:-4.2404 val_d_loss:-5.2222 cost:20.42
# epoch [9292/50000] s_loss:-8.9605 d_loss:-3.9420 val_s_loss:-3.9267 val_d_loss:-4.0366 cost:20.08
# epoch [9293/50000] s_loss:-6.7170 d_loss:-4.0646 val_s_loss:-2.0517 val_d_loss:-4.7700 cost:21.22
# epoch [9294/50000] s_loss:-5.4480 d_loss:-4.6552 val_s_loss:-2.9085 val_d_loss:-3.8614 cost:20.81
# epoch [9295/50000] s_loss:-8.9113 d_loss:-3.9517 val_s_loss:-2.6066 val_d_loss:-4.3002 cost:20.17
# epoch [9296/50000] s_loss:-14.0989 d_loss:-4.6872 val_s_loss:-5.6313 val_d_loss:-4.3477 cost:20.72
# epoch [9297/50000] s_loss:-14.4160 d_loss:-4.8557 val_s_loss:-7.4483 val_d_loss:-3.2508 cost:20.77
# epoch [9298/50000] s_loss:-10.9870 d_loss:-3.7496 val_s_loss:-7.1238 val_d_loss:-2.5347 cost:20.52
# epoch [9299/50000] s_loss:-0.6128 d_loss:-4.0634 val_s_loss:-0.6025 val_d_loss:-4.1740 cost:20.39
# epoch [9300/50000] s_loss:3.3410 d_loss:-4.3894 val_s_loss:0.5105 val_d_loss:-1.8275 cost:20.71
# epoch [9301/50000] s_loss:-4.6272 d_loss:-3.7208 val_s_loss:-2.9409 val_d_loss:-1.1641 cost:20.26
# epoch [9302/50000] s_loss:-7.6361 d_loss:-3.8227 val_s_loss:-5.5660 val_d_loss:-1.1372 cost:20.15
# epoch [9303/50000] s_loss:-9.0110 d_loss:-5.6304 val_s_loss:-3.9775 val_d_loss:-4.2027 cost:20.82
# epoch [9304/50000] s_loss:-6.3555 d_loss:-4.9577 val_s_loss:-4.0288 val_d_loss:-2.2036 cost:21.07
# epoch [9305/50000] s_loss:-6.1202 d_loss:-3.6881 val_s_loss:-4.4371 val_d_loss:-1.6039 cost:33.10
# epoch [9306/50000] s_loss:-6.7076 d_loss:-3.9377 val_s_loss:-3.4782 val_d_loss:-2.2809 cost:32.55
# epoch [9307/50000] s_loss:-10.9835 d_loss:-2.8014 val_s_loss:-3.0319 val_d_loss:-5.2265 cost:32.19
# epoch [9308/50000] s_loss:-12.7351 d_loss:-2.5631 val_s_loss:-6.6506 val_d_loss:-1.1753 cost:31.94
# epoch [9309/50000] s_loss:-13.5753 d_loss:-3.2081 val_s_loss:-4.7735 val_d_loss:-4.5855 cost:32.87
# epoch [9310/50000] s_loss:-2.2456 d_loss:-4.6726 val_s_loss:-4.6029 val_d_loss:0.7369 cost:33.11
# epoch [9311/50000] s_loss:0.9069 d_loss:-4.4245 val_s_loss:-2.8787 val_d_loss:-1.9099 cost:34.91
# epoch [9312/50000] s_loss:-4.0404 d_loss:-4.7224 val_s_loss:-3.8892 val_d_loss:-1.4390 cost:33.89
# epoch [9313/50000] s_loss:-6.8179 d_loss:-3.5126 val_s_loss:-2.3591 val_d_loss:-4.3457 cost:33.33
# epoch [9314/50000] s_loss:-10.4835 d_loss:-3.7745 val_s_loss:-3.3808 val_d_loss:-3.3837 cost:33.35
# epoch [9315/50000] s_loss:-7.8717 d_loss:-4.4814 val_s_loss:-4.9881 val_d_loss:-1.8991 cost:31.95
# epoch [9316/50000] s_loss:-3.7097 d_loss:-4.6928 val_s_loss:-3.9128 val_d_loss:-3.7444 cost:34.29
# epoch [9317/50000] s_loss:-1.0251 d_loss:-4.9039 val_s_loss:-1.5150 val_d_loss:-2.4670 cost:34.44
# epoch [9318/50000] s_loss:1.4042 d_loss:-3.8884 val_s_loss:0.2308 val_d_loss:-3.7444 cost:33.63
# epoch [9319/50000] s_loss:-5.4635 d_loss:-4.7560 val_s_loss:-6.7147 val_d_loss:1.5048 cost:34.52

# %%
AE.eval()
S.eval()
for index, img in enumerate(test_loader):
    test_img = Variable(img[0]).cuda()

    # ======AE======
    blur_image = AE(test_img)
    
    noise = torch.zeros(blur_image.shape[0], 1, blur_image.shape[2], blur_image.shape[3] )
    noise = noise + (0.01**0.5)*torch.randn(blur_image.shape[0], 1, blur_image.shape[2], blur_image.shape[3])
    noise = noise.cuda()
    blur_image_with_noise = torch.cat([blur_image, noise], 1)
    fake_image = S(blur_image_with_noise)
    
    
    vutils.save_image(fake_image[0], './test_result/{}_simulated.png'.format(index))
    vutils.save_image(blur_image[0], './test_result/{}_blur.png'.format(index))
    vutils.save_image(test_img, './test_result/{}_origin.png'.format(index))
