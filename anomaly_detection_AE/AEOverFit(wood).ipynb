# %%
import sys
sys.path.append('../')

import os
import numpy as np

from torch.utils.data import DataLoader
from torch.autograd import Variable
from torch import autograd

import torch
import torch.nn as nn


from utils.tools import get_config, default_loader, is_image_file, normalize
from tensorboardX import SummaryWriter
import matplotlib.pyplot as plt
import torchvision.utils as vutils

# personal library
from networks import autoencoder, simulator, discriminator
from dataloader import MVTecDataset

# %%
# HYPER parameters
device_id = 1
num_epochs = 50000
batch_size = 32
val_batch_size = 4
ae_lr = 1e-4
weight_decay = 1e-5
expName = 'AE-wood-z-2x2-exp2'
writer = SummaryWriter('checkpoints/'+expName)

# %%
trainDatset = MVTecDataset.MVTecDataset(TYPE='wood', isTrain='train')
testDatset = MVTecDataset.MVTecDataset(TYPE='wood', isTrain='test')
valDataset = MVTecDataset.MVTecDataset(TYPE='wood', isTrain='val')

val_loader = DataLoader(
    dataset=valDataset,
    batch_size=val_batch_size, 
    shuffle=True,
    num_workers=4
)
train_loader = DataLoader(
    dataset=trainDatset,
    batch_size=batch_size, 
    shuffle=True,
    num_workers=4
)
test_loader = DataLoader(
    dataset=testDatset,
    batch_size=1,
    shuffle=True,
    num_workers=4
)

# %%
AE = autoencoder.Autoencoder().cuda(device_id)
L1_loss = torch.nn.L1Loss()

optimizer_AE = torch.optim.Adam(
    AE.parameters(), 
    lr=ae_lr,
    weight_decay=weight_decay
)

Tensor = torch.cuda.FloatTensor

# %%
# To Solve: RuntimeError: cuDNN error: CUDNN_STATUS_EXECUTION_FAILED
torch.backends.cudnn.enabled = False

# %%
for epoch in range(num_epochs):
    ## ===== AE ======= 
    for img in train_loader:
        AE.train()

        img = Variable(img).cuda(device_id)    
        # ======AE======
        blur_image = AE(img)
        ae_loss = L1_loss(blur_image, img)

        optimizer_AE.zero_grad()
        ae_loss.backward()
        optimizer_AE.step()
    
    # Validation set
    for val_img in val_loader:
        AE.eval()

        val_img = Variable(val_img).cuda(device_id)    
        # ======AE======
        val_blur_image = AE(val_img)
        val_ae_loss = L1_loss(val_blur_image, val_img)
    
    for (test_img, mask) in test_loader:
        AE.eval()

        test_img = Variable(test_img).cuda(device_id)    
        # ======AE======
        test_blur_image = AE(test_img)
        test_ae_loss = L1_loss(test_blur_image, test_img)

    # =================== AE log========================
    print('epoch [{}/{}] ae_loss:{:.4f} val_ae_loss:{:.4f} test_ae_loss:{:.4f}'.format(epoch+1, num_epochs, ae_loss.item(), val_ae_loss.item(), test_ae_loss.item()))
    writer.add_scalars('ae_loss', {
        'train': ae_loss.item(),
        'test': test_ae_loss.item(),
        'val': val_ae_loss.item()
    }, epoch)
    
    writer.add_images('Blur', blur_image, epoch)
    writer.add_images('Val Blur', val_blur_image, epoch)
    writer.add_images('Test Blur', test_blur_image, epoch)
    writer.add_images('Origin', img, epoch)
    writer.add_images('Val Origin', val_img, epoch)
    writer.add_images('Test Origin', test_img, epoch)
    
    if epoch % 10 == 0:
        if not os.path.exists('./save_weight/{}'.format(expName)):
            os.makedirs('./save_weight/{}'.format(expName))
        torch.save(AE.state_dict(), './save_weight/{}/AE_{}.npy'.format(expName, epoch))
# Out:
# epoch [1/50000] ae_loss:0.1578 val_ae_loss:0.1346 test_ae_loss:0.1508
# epoch [2/50000] ae_loss:0.1530 val_ae_loss:0.1346 test_ae_loss:0.1268
# epoch [3/50000] ae_loss:0.1459 val_ae_loss:0.1326 test_ae_loss:0.1356
# epoch [4/50000] ae_loss:0.1447 val_ae_loss:0.1339 test_ae_loss:0.1365
# epoch [5/50000] ae_loss:0.1422 val_ae_loss:0.1245 test_ae_loss:0.1271
# epoch [6/50000] ae_loss:0.1416 val_ae_loss:0.1263 test_ae_loss:0.1280
# epoch [7/50000] ae_loss:0.1390 val_ae_loss:0.1292 test_ae_loss:0.1317
# epoch [8/50000] ae_loss:0.1379 val_ae_loss:0.1269 test_ae_loss:0.1408
# epoch [9/50000] ae_loss:0.1370 val_ae_loss:0.1216 test_ae_loss:0.1326
# epoch [10/50000] ae_loss:0.1348 val_ae_loss:0.1228 test_ae_loss:0.1219
# epoch [11/50000] ae_loss:0.1341 val_ae_loss:0.1287 test_ae_loss:0.1905
# epoch [12/50000] ae_loss:0.1360 val_ae_loss:0.1356 test_ae_loss:0.1219
# epoch [13/50000] ae_loss:0.1324 val_ae_loss:0.1199 test_ae_loss:0.1212
# epoch [14/50000] ae_loss:0.1319 val_ae_loss:0.1195 test_ae_loss:0.1441
# epoch [15/50000] ae_loss:0.1290 val_ae_loss:0.1240 test_ae_loss:0.1271
# epoch [16/50000] ae_loss:0.1316 val_ae_loss:0.1227 test_ae_loss:0.1198
# epoch [17/50000] ae_loss:0.1298 val_ae_loss:0.1202 test_ae_loss:0.1385
# epoch [18/50000] ae_loss:0.1275 val_ae_loss:0.1218 test_ae_loss:0.1192
# epoch [19/50000] ae_loss:0.1279 val_ae_loss:0.1213 test_ae_loss:0.1349
# epoch [20/50000] ae_loss:0.1244 val_ae_loss:0.1304 test_ae_loss:0.1247
# epoch [21/50000] ae_loss:0.1264 val_ae_loss:0.1079 test_ae_loss:0.1064
# epoch [22/50000] ae_loss:0.1249 val_ae_loss:0.1184 test_ae_loss:0.1397
# epoch [23/50000] ae_loss:0.1249 val_ae_loss:0.1065 test_ae_loss:0.1231
# epoch [24/50000] ae_loss:0.1226 val_ae_loss:0.1056 test_ae_loss:0.1355
# epoch [25/50000] ae_loss:0.1232 val_ae_loss:0.1187 test_ae_loss:0.1315
# epoch [26/50000] ae_loss:0.1218 val_ae_loss:0.1236 test_ae_loss:0.1106
# epoch [27/50000] ae_loss:0.1199 val_ae_loss:0.1284 test_ae_loss:0.1420
# epoch [28/50000] ae_loss:0.1211 val_ae_loss:0.1185 test_ae_loss:0.1175
# epoch [29/50000] ae_loss:0.1196 val_ae_loss:0.1153 test_ae_loss:0.1344
# epoch [30/50000] ae_loss:0.1166 val_ae_loss:0.1020 test_ae_loss:0.1823
# epoch [31/50000] ae_loss:0.1166 val_ae_loss:0.1119 test_ae_loss:0.1215
# epoch [32/50000] ae_loss:0.1162 val_ae_loss:0.1046 test_ae_loss:0.1026
# epoch [33/50000] ae_loss:0.1167 val_ae_loss:0.1060 test_ae_loss:0.1434
# epoch [34/50000] ae_loss:0.1114 val_ae_loss:0.1116 test_ae_loss:0.1484
# epoch [35/50000] ae_loss:0.1135 val_ae_loss:0.1009 test_ae_loss:0.1120
# epoch [36/50000] ae_loss:0.1128 val_ae_loss:0.1100 test_ae_loss:0.0979
# epoch [37/50000] ae_loss:0.1096 val_ae_loss:0.1084 test_ae_loss:0.1231
# epoch [38/50000] ae_loss:0.1103 val_ae_loss:0.1225 test_ae_loss:0.1366
# epoch [39/50000] ae_loss:0.1077 val_ae_loss:0.1095 test_ae_loss:0.1218
# epoch [40/50000] ae_loss:0.1081 val_ae_loss:0.1021 test_ae_loss:0.1070
# epoch [41/50000] ae_loss:0.1061 val_ae_loss:0.0977 test_ae_loss:0.1511
# epoch [42/50000] ae_loss:0.1054 val_ae_loss:0.1074 test_ae_loss:0.0917
# epoch [43/50000] ae_loss:0.1028 val_ae_loss:0.1154 test_ae_loss:0.1324
# epoch [44/50000] ae_loss:0.1009 val_ae_loss:0.0919 test_ae_loss:0.0611
# epoch [45/50000] ae_loss:0.0997 val_ae_loss:0.1006 test_ae_loss:0.1344
# epoch [46/50000] ae_loss:0.0982 val_ae_loss:0.1003 test_ae_loss:0.0988
# epoch [47/50000] ae_loss:0.0959 val_ae_loss:0.0735 test_ae_loss:0.0935
# epoch [48/50000] ae_loss:0.0921 val_ae_loss:0.0778 test_ae_loss:0.0690
# epoch [49/50000] ae_loss:0.0919 val_ae_loss:0.0903 test_ae_loss:0.0700
# epoch [50/50000] ae_loss:0.0912 val_ae_loss:0.1048 test_ae_loss:0.0864
# epoch [51/50000] ae_loss:0.0930 val_ae_loss:0.0731 test_ae_loss:0.1535
# epoch [52/50000] ae_loss:0.0902 val_ae_loss:0.0758 test_ae_loss:0.0647
# epoch [53/50000] ae_loss:0.0884 val_ae_loss:0.1000 test_ae_loss:0.1058
# epoch [54/50000] ae_loss:0.0862 val_ae_loss:0.0654 test_ae_loss:0.0843
# epoch [55/50000] ae_loss:0.0828 val_ae_loss:0.0895 test_ae_loss:0.0903
# epoch [56/50000] ae_loss:0.0814 val_ae_loss:0.0821 test_ae_loss:0.0730
# epoch [57/50000] ae_loss:0.0783 val_ae_loss:0.0849 test_ae_loss:0.1065
# epoch [58/50000] ae_loss:0.0749 val_ae_loss:0.0892 test_ae_loss:0.0779
# epoch [59/50000] ae_loss:0.0730 val_ae_loss:0.0492 test_ae_loss:0.1064
# epoch [60/50000] ae_loss:0.0719 val_ae_loss:0.0855 test_ae_loss:0.0693
# epoch [61/50000] ae_loss:0.0702 val_ae_loss:0.0713 test_ae_loss:0.0903
# epoch [62/50000] ae_loss:0.0662 val_ae_loss:0.0548 test_ae_loss:0.1083
# epoch [63/50000] ae_loss:0.0668 val_ae_loss:0.0756 test_ae_loss:0.0425
# epoch [64/50000] ae_loss:0.0655 val_ae_loss:0.0562 test_ae_loss:0.0969
# epoch [65/50000] ae_loss:0.0650 val_ae_loss:0.0630 test_ae_loss:0.0928
# epoch [66/50000] ae_loss:0.0603 val_ae_loss:0.0488 test_ae_loss:0.0536
# epoch [67/50000] ae_loss:0.0602 val_ae_loss:0.0556 test_ae_loss:0.0706
# epoch [68/50000] ae_loss:0.0582 val_ae_loss:0.0585 test_ae_loss:0.0867
# epoch [69/50000] ae_loss:0.0577 val_ae_loss:0.0593 test_ae_loss:0.0702
# epoch [70/50000] ae_loss:0.0550 val_ae_loss:0.0542 test_ae_loss:0.0821
# epoch [71/50000] ae_loss:0.0568 val_ae_loss:0.0481 test_ae_loss:0.0652
# epoch [72/50000] ae_loss:0.0550 val_ae_loss:0.0578 test_ae_loss:0.0509
# epoch [73/50000] ae_loss:0.0529 val_ae_loss:0.0474 test_ae_loss:0.0794
# epoch [74/50000] ae_loss:0.0498 val_ae_loss:0.0435 test_ae_loss:0.0475
# epoch [75/50000] ae_loss:0.0494 val_ae_loss:0.0481 test_ae_loss:0.0621
# epoch [76/50000] ae_loss:0.0484 val_ae_loss:0.0482 test_ae_loss:0.0579
# epoch [77/50000] ae_loss:0.0468 val_ae_loss:0.0447 test_ae_loss:0.0534
# epoch [78/50000] ae_loss:0.0490 val_ae_loss:0.0385 test_ae_loss:0.0398
# epoch [79/50000] ae_loss:0.0469 val_ae_loss:0.0481 test_ae_loss:0.0627
# epoch [80/50000] ae_loss:0.0450 val_ae_loss:0.0484 test_ae_loss:0.0440
# epoch [81/50000] ae_loss:0.0470 val_ae_loss:0.0485 test_ae_loss:0.0562
# epoch [82/50000] ae_loss:0.0460 val_ae_loss:0.0404 test_ae_loss:0.0478
# epoch [83/50000] ae_loss:0.0453 val_ae_loss:0.0399 test_ae_loss:0.0690
# epoch [84/50000] ae_loss:0.0426 val_ae_loss:0.0436 test_ae_loss:0.0541
# epoch [85/50000] ae_loss:0.0455 val_ae_loss:0.0471 test_ae_loss:0.0686
# epoch [86/50000] ae_loss:0.0447 val_ae_loss:0.0392 test_ae_loss:0.0581
# epoch [87/50000] ae_loss:0.0417 val_ae_loss:0.0437 test_ae_loss:0.0441
# epoch [88/50000] ae_loss:0.0442 val_ae_loss:0.0376 test_ae_loss:0.0394
# epoch [89/50000] ae_loss:0.0430 val_ae_loss:0.0483 test_ae_loss:0.0540
# epoch [90/50000] ae_loss:0.0421 val_ae_loss:0.0418 test_ae_loss:0.0449
# epoch [91/50000] ae_loss:0.0419 val_ae_loss:0.0429 test_ae_loss:0.0381
# epoch [92/50000] ae_loss:0.0417 val_ae_loss:0.0373 test_ae_loss:0.0489
# epoch [93/50000] ae_loss:0.0403 val_ae_loss:0.0380 test_ae_loss:0.0514
# epoch [94/50000] ae_loss:0.0426 val_ae_loss:0.0427 test_ae_loss:0.0420
# epoch [95/50000] ae_loss:0.0425 val_ae_loss:0.0360 test_ae_loss:0.0523
# epoch [96/50000] ae_loss:0.0401 val_ae_loss:0.0443 test_ae_loss:0.0412
# epoch [97/50000] ae_loss:0.0398 val_ae_loss:0.0375 test_ae_loss:0.0376
# epoch [98/50000] ae_loss:0.0429 val_ae_loss:0.0452 test_ae_loss:0.0557
# epoch [99/50000] ae_loss:0.0418 val_ae_loss:0.0371 test_ae_loss:0.0562
# epoch [100/50000] ae_loss:0.0409 val_ae_loss:0.0364 test_ae_loss:0.0517
# epoch [101/50000] ae_loss:0.0393 val_ae_loss:0.0422 test_ae_loss:0.0538
# epoch [102/50000] ae_loss:0.0396 val_ae_loss:0.0397 test_ae_loss:0.0678
# epoch [103/50000] ae_loss:0.0396 val_ae_loss:0.0341 test_ae_loss:0.0437
# epoch [104/50000] ae_loss:0.0402 val_ae_loss:0.0462 test_ae_loss:0.0664
# epoch [105/50000] ae_loss:0.0399 val_ae_loss:0.0416 test_ae_loss:0.0405
# epoch [106/50000] ae_loss:0.0396 val_ae_loss:0.0387 test_ae_loss:0.0505
# epoch [107/50000] ae_loss:0.0397 val_ae_loss:0.0369 test_ae_loss:0.0446
# epoch [108/50000] ae_loss:0.0412 val_ae_loss:0.0373 test_ae_loss:0.0471
# epoch [109/50000] ae_loss:0.0384 val_ae_loss:0.0423 test_ae_loss:0.0491
# epoch [110/50000] ae_loss:0.0394 val_ae_loss:0.0386 test_ae_loss:0.0460
# epoch [111/50000] ae_loss:0.0406 val_ae_loss:0.0441 test_ae_loss:0.0458
# epoch [112/50000] ae_loss:0.0401 val_ae_loss:0.0456 test_ae_loss:0.0442
# epoch [113/50000] ae_loss:0.0390 val_ae_loss:0.0443 test_ae_loss:0.0453
# epoch [114/50000] ae_loss:0.0410 val_ae_loss:0.0404 test_ae_loss:0.0572
# epoch [115/50000] ae_loss:0.0393 val_ae_loss:0.0368 test_ae_loss:0.0442
# epoch [116/50000] ae_loss:0.0402 val_ae_loss:0.0336 test_ae_loss:0.0557
# epoch [117/50000] ae_loss:0.0389 val_ae_loss:0.0404 test_ae_loss:0.0497
# epoch [118/50000] ae_loss:0.0406 val_ae_loss:0.0346 test_ae_loss:0.0500
# epoch [119/50000] ae_loss:0.0387 val_ae_loss:0.0405 test_ae_loss:0.0540
# epoch [120/50000] ae_loss:0.0401 val_ae_loss:0.0371 test_ae_loss:0.0379
# epoch [121/50000] ae_loss:0.0410 val_ae_loss:0.0347 test_ae_loss:0.0573
# epoch [122/50000] ae_loss:0.0380 val_ae_loss:0.0424 test_ae_loss:0.0451
# epoch [123/50000] ae_loss:0.0420 val_ae_loss:0.0386 test_ae_loss:0.0495
# epoch [124/50000] ae_loss:0.0391 val_ae_loss:0.0436 test_ae_loss:0.0457
# epoch [125/50000] ae_loss:0.0380 val_ae_loss:0.0333 test_ae_loss:0.0596
# epoch [126/50000] ae_loss:0.0391 val_ae_loss:0.0386 test_ae_loss:0.0439
# epoch [127/50000] ae_loss:0.0420 val_ae_loss:0.0342 test_ae_loss:0.0560
# epoch [128/50000] ae_loss:0.0373 val_ae_loss:0.0346 test_ae_loss:0.0596
# epoch [129/50000] ae_loss:0.0393 val_ae_loss:0.0350 test_ae_loss:0.0564
# epoch [130/50000] ae_loss:0.0403 val_ae_loss:0.0342 test_ae_loss:0.0400
# epoch [131/50000] ae_loss:0.0405 val_ae_loss:0.0404 test_ae_loss:0.0455
# epoch [132/50000] ae_loss:0.0392 val_ae_loss:0.0417 test_ae_loss:0.0568
# epoch [133/50000] ae_loss:0.0396 val_ae_loss:0.0358 test_ae_loss:0.0377
# epoch [134/50000] ae_loss:0.0388 val_ae_loss:0.0433 test_ae_loss:0.0439
# epoch [135/50000] ae_loss:0.0399 val_ae_loss:0.0329 test_ae_loss:0.0439
# epoch [136/50000] ae_loss:0.0379 val_ae_loss:0.0366 test_ae_loss:0.0390
# epoch [137/50000] ae_loss:0.0404 val_ae_loss:0.0377 test_ae_loss:0.0401
# epoch [138/50000] ae_loss:0.0388 val_ae_loss:0.0342 test_ae_loss:0.0521
# epoch [139/50000] ae_loss:0.0389 val_ae_loss:0.0374 test_ae_loss:0.0375
# epoch [140/50000] ae_loss:0.0385 val_ae_loss:0.0441 test_ae_loss:0.0443
# epoch [141/50000] ae_loss:0.0402 val_ae_loss:0.0372 test_ae_loss:0.0441
# epoch [142/50000] ae_loss:0.0380 val_ae_loss:0.0447 test_ae_loss:0.0415
# epoch [143/50000] ae_loss:0.0391 val_ae_loss:0.0392 test_ae_loss:0.0459
# epoch [144/50000] ae_loss:0.0374 val_ae_loss:0.0401 test_ae_loss:0.0410
# epoch [145/50000] ae_loss:0.0402 val_ae_loss:0.0356 test_ae_loss:0.0531
# epoch [146/50000] ae_loss:0.0393 val_ae_loss:0.0359 test_ae_loss:0.0570
# epoch [147/50000] ae_loss:0.0394 val_ae_loss:0.0416 test_ae_loss:0.0597
# epoch [148/50000] ae_loss:0.0400 val_ae_loss:0.0405 test_ae_loss:0.0363
# epoch [149/50000] ae_loss:0.0391 val_ae_loss:0.0344 test_ae_loss:0.0672
# epoch [150/50000] ae_loss:0.0396 val_ae_loss:0.0469 test_ae_loss:0.0563
# epoch [151/50000] ae_loss:0.0399 val_ae_loss:0.0430 test_ae_loss:0.0449
# epoch [152/50000] ae_loss:0.0409 val_ae_loss:0.0408 test_ae_loss:0.0589
# epoch [153/50000] ae_loss:0.0388 val_ae_loss:0.0380 test_ae_loss:0.0559
# epoch [154/50000] ae_loss:0.0391 val_ae_loss:0.0347 test_ae_loss:0.0506
# epoch [155/50000] ae_loss:0.0389 val_ae_loss:0.0329 test_ae_loss:0.0452
# epoch [156/50000] ae_loss:0.0395 val_ae_loss:0.0417 test_ae_loss:0.0427
# epoch [157/50000] ae_loss:0.0371 val_ae_loss:0.0397 test_ae_loss:0.0660
# epoch [158/50000] ae_loss:0.0378 val_ae_loss:0.0354 test_ae_loss:0.0529
# epoch [159/50000] ae_loss:0.0366 val_ae_loss:0.0480 test_ae_loss:0.0608
# epoch [160/50000] ae_loss:0.0377 val_ae_loss:0.0401 test_ae_loss:0.0419
# epoch [161/50000] ae_loss:0.0369 val_ae_loss:0.0414 test_ae_loss:0.0455
# epoch [162/50000] ae_loss:0.0402 val_ae_loss:0.0418 test_ae_loss:0.0510
# epoch [163/50000] ae_loss:0.0383 val_ae_loss:0.0317 test_ae_loss:0.0445
# epoch [164/50000] ae_loss:0.0378 val_ae_loss:0.0408 test_ae_loss:0.0553
# epoch [165/50000] ae_loss:0.0386 val_ae_loss:0.0351 test_ae_loss:0.0416
# epoch [166/50000] ae_loss:0.0371 val_ae_loss:0.0409 test_ae_loss:0.0467
# epoch [167/50000] ae_loss:0.0382 val_ae_loss:0.0405 test_ae_loss:0.0550
# epoch [168/50000] ae_loss:0.0380 val_ae_loss:0.0315 test_ae_loss:0.0566
# epoch [169/50000] ae_loss:0.0381 val_ae_loss:0.0396 test_ae_loss:0.0467
# epoch [170/50000] ae_loss:0.0383 val_ae_loss:0.0334 test_ae_loss:0.0529
# epoch [171/50000] ae_loss:0.0400 val_ae_loss:0.0377 test_ae_loss:0.0542
# epoch [172/50000] ae_loss:0.0390 val_ae_loss:0.0375 test_ae_loss:0.0517
# epoch [173/50000] ae_loss:0.0396 val_ae_loss:0.0368 test_ae_loss:0.0596
# epoch [174/50000] ae_loss:0.0355 val_ae_loss:0.0378 test_ae_loss:0.0486
# epoch [175/50000] ae_loss:0.0383 val_ae_loss:0.0393 test_ae_loss:0.0578
# epoch [176/50000] ae_loss:0.0387 val_ae_loss:0.0385 test_ae_loss:0.0445
# epoch [177/50000] ae_loss:0.0377 val_ae_loss:0.0373 test_ae_loss:0.0457
# epoch [178/50000] ae_loss:0.0411 val_ae_loss:0.0376 test_ae_loss:0.0448
# epoch [179/50000] ae_loss:0.0365 val_ae_loss:0.0419 test_ae_loss:0.0402
# epoch [180/50000] ae_loss:0.0410 val_ae_loss:0.0368 test_ae_loss:0.0597
# epoch [181/50000] ae_loss:0.0399 val_ae_loss:0.0333 test_ae_loss:0.0385
# epoch [182/50000] ae_loss:0.0388 val_ae_loss:0.0360 test_ae_loss:0.0537
# epoch [183/50000] ae_loss:0.0381 val_ae_loss:0.0362 test_ae_loss:0.0436
# epoch [184/50000] ae_loss:0.0376 val_ae_loss:0.0424 test_ae_loss:0.0436
# epoch [185/50000] ae_loss:0.0398 val_ae_loss:0.0383 test_ae_loss:0.0496
# epoch [186/50000] ae_loss:0.0388 val_ae_loss:0.0396 test_ae_loss:0.0420
# epoch [187/50000] ae_loss:0.0387 val_ae_loss:0.0424 test_ae_loss:0.0593
# epoch [188/50000] ae_loss:0.0381 val_ae_loss:0.0388 test_ae_loss:0.0476
# epoch [189/50000] ae_loss:0.0380 val_ae_loss:0.0406 test_ae_loss:0.0471
# epoch [190/50000] ae_loss:0.0392 val_ae_loss:0.0359 test_ae_loss:0.0512
# epoch [191/50000] ae_loss:0.0388 val_ae_loss:0.0412 test_ae_loss:0.0307
# epoch [192/50000] ae_loss:0.0383 val_ae_loss:0.0423 test_ae_loss:0.0598
# epoch [193/50000] ae_loss:0.0411 val_ae_loss:0.0364 test_ae_loss:0.0518
# epoch [194/50000] ae_loss:0.0375 val_ae_loss:0.0461 test_ae_loss:0.0567
# epoch [195/50000] ae_loss:0.0393 val_ae_loss:0.0432 test_ae_loss:0.0380
# epoch [196/50000] ae_loss:0.0380 val_ae_loss:0.0399 test_ae_loss:0.0418
# epoch [197/50000] ae_loss:0.0368 val_ae_loss:0.0397 test_ae_loss:0.0599
# epoch [198/50000] ae_loss:0.0376 val_ae_loss:0.0435 test_ae_loss:0.0468
# epoch [199/50000] ae_loss:0.0373 val_ae_loss:0.0378 test_ae_loss:0.0394
# epoch [200/50000] ae_loss:0.0395 val_ae_loss:0.0452 test_ae_loss:0.0451
# epoch [201/50000] ae_loss:0.0387 val_ae_loss:0.0342 test_ae_loss:0.0461
# epoch [202/50000] ae_loss:0.0386 val_ae_loss:0.0412 test_ae_loss:0.0488
# epoch [203/50000] ae_loss:0.0374 val_ae_loss:0.0434 test_ae_loss:0.0606
# epoch [204/50000] ae_loss:0.0390 val_ae_loss:0.0414 test_ae_loss:0.0483
# epoch [205/50000] ae_loss:0.0389 val_ae_loss:0.0423 test_ae_loss:0.0558
# epoch [206/50000] ae_loss:0.0372 val_ae_loss:0.0426 test_ae_loss:0.0421
# epoch [207/50000] ae_loss:0.0367 val_ae_loss:0.0397 test_ae_loss:0.0384
# epoch [208/50000] ae_loss:0.0386 val_ae_loss:0.0412 test_ae_loss:0.0391
# epoch [209/50000] ae_loss:0.0407 val_ae_loss:0.0496 test_ae_loss:0.0450
# epoch [210/50000] ae_loss:0.0383 val_ae_loss:0.0387 test_ae_loss:0.0425
# epoch [211/50000] ae_loss:0.0377 val_ae_loss:0.0361 test_ae_loss:0.0443
# epoch [212/50000] ae_loss:0.0383 val_ae_loss:0.0397 test_ae_loss:0.0459
# epoch [213/50000] ae_loss:0.0404 val_ae_loss:0.0439 test_ae_loss:0.0305
# epoch [214/50000] ae_loss:0.0360 val_ae_loss:0.0428 test_ae_loss:0.0448
# epoch [215/50000] ae_loss:0.0373 val_ae_loss:0.0421 test_ae_loss:0.0447
# epoch [216/50000] ae_loss:0.0387 val_ae_loss:0.0449 test_ae_loss:0.0438
# epoch [217/50000] ae_loss:0.0361 val_ae_loss:0.0368 test_ae_loss:0.0646
# epoch [218/50000] ae_loss:0.0380 val_ae_loss:0.0413 test_ae_loss:0.0645
# epoch [219/50000] ae_loss:0.0377 val_ae_loss:0.0385 test_ae_loss:0.0396
# epoch [220/50000] ae_loss:0.0371 val_ae_loss:0.0354 test_ae_loss:0.0553
# epoch [221/50000] ae_loss:0.0368 val_ae_loss:0.0518 test_ae_loss:0.0575
# epoch [222/50000] ae_loss:0.0366 val_ae_loss:0.0372 test_ae_loss:0.0474
# epoch [223/50000] ae_loss:0.0378 val_ae_loss:0.0371 test_ae_loss:0.0477
# epoch [224/50000] ae_loss:0.0380 val_ae_loss:0.0420 test_ae_loss:0.0397
# epoch [225/50000] ae_loss:0.0373 val_ae_loss:0.0385 test_ae_loss:0.0425
# epoch [226/50000] ae_loss:0.0353 val_ae_loss:0.0394 test_ae_loss:0.0461
# epoch [227/50000] ae_loss:0.0367 val_ae_loss:0.0409 test_ae_loss:0.0458
# epoch [228/50000] ae_loss:0.0389 val_ae_loss:0.0361 test_ae_loss:0.0428
# epoch [229/50000] ae_loss:0.0385 val_ae_loss:0.0424 test_ae_loss:0.0435
# epoch [230/50000] ae_loss:0.0384 val_ae_loss:0.0350 test_ae_loss:0.0446
# epoch [231/50000] ae_loss:0.0383 val_ae_loss:0.0379 test_ae_loss:0.0396
# epoch [232/50000] ae_loss:0.0384 val_ae_loss:0.0381 test_ae_loss:0.0419
# epoch [233/50000] ae_loss:0.0382 val_ae_loss:0.0388 test_ae_loss:0.0465
# epoch [234/50000] ae_loss:0.0378 val_ae_loss:0.0398 test_ae_loss:0.0638
# epoch [235/50000] ae_loss:0.0365 val_ae_loss:0.0385 test_ae_loss:0.0596
# epoch [236/50000] ae_loss:0.0385 val_ae_loss:0.0331 test_ae_loss:0.0596
# epoch [237/50000] ae_loss:0.0387 val_ae_loss:0.0412 test_ae_loss:0.0459
# epoch [238/50000] ae_loss:0.0361 val_ae_loss:0.0426 test_ae_loss:0.0395
# epoch [239/50000] ae_loss:0.0366 val_ae_loss:0.0360 test_ae_loss:0.0586
# epoch [240/50000] ae_loss:0.0388 val_ae_loss:0.0390 test_ae_loss:0.0550
# epoch [241/50000] ae_loss:0.0400 val_ae_loss:0.0420 test_ae_loss:0.0452
# epoch [242/50000] ae_loss:0.0373 val_ae_loss:0.0386 test_ae_loss:0.0560
# epoch [243/50000] ae_loss:0.0372 val_ae_loss:0.0404 test_ae_loss:0.0459
# epoch [244/50000] ae_loss:0.0385 val_ae_loss:0.0365 test_ae_loss:0.0568
# epoch [245/50000] ae_loss:0.0374 val_ae_loss:0.0388 test_ae_loss:0.0441
# epoch [246/50000] ae_loss:0.0352 val_ae_loss:0.0432 test_ae_loss:0.0420
# epoch [247/50000] ae_loss:0.0378 val_ae_loss:0.0396 test_ae_loss:0.0424
# epoch [248/50000] ae_loss:0.0374 val_ae_loss:0.0426 test_ae_loss:0.0441
# epoch [249/50000] ae_loss:0.0360 val_ae_loss:0.0416 test_ae_loss:0.0365
# epoch [250/50000] ae_loss:0.0379 val_ae_loss:0.0357 test_ae_loss:0.0307
# epoch [251/50000] ae_loss:0.0385 val_ae_loss:0.0377 test_ae_loss:0.0308
# epoch [252/50000] ae_loss:0.0365 val_ae_loss:0.0435 test_ae_loss:0.0533
# epoch [253/50000] ae_loss:0.0387 val_ae_loss:0.0400 test_ae_loss:0.0423
# epoch [254/50000] ae_loss:0.0356 val_ae_loss:0.0406 test_ae_loss:0.0404
# epoch [255/50000] ae_loss:0.0387 val_ae_loss:0.0375 test_ae_loss:0.0515
# epoch [256/50000] ae_loss:0.0374 val_ae_loss:0.0408 test_ae_loss:0.0478
# epoch [257/50000] ae_loss:0.0397 val_ae_loss:0.0482 test_ae_loss:0.0433
# epoch [258/50000] ae_loss:0.0372 val_ae_loss:0.0369 test_ae_loss:0.0579
# epoch [259/50000] ae_loss:0.0402 val_ae_loss:0.0490 test_ae_loss:0.0423
# epoch [260/50000] ae_loss:0.0372 val_ae_loss:0.0413 test_ae_loss:0.0378
# epoch [261/50000] ae_loss:0.0385 val_ae_loss:0.0367 test_ae_loss:0.0388
# epoch [262/50000] ae_loss:0.0370 val_ae_loss:0.0412 test_ae_loss:0.0395
# epoch [263/50000] ae_loss:0.0385 val_ae_loss:0.0498 test_ae_loss:0.0421
# epoch [264/50000] ae_loss:0.0396 val_ae_loss:0.0376 test_ae_loss:0.0449
# epoch [265/50000] ae_loss:0.0381 val_ae_loss:0.0376 test_ae_loss:0.0497
# epoch [266/50000] ae_loss:0.0385 val_ae_loss:0.0392 test_ae_loss:0.0539
# epoch [267/50000] ae_loss:0.0370 val_ae_loss:0.0383 test_ae_loss:0.0386
# epoch [268/50000] ae_loss:0.0388 val_ae_loss:0.0479 test_ae_loss:0.0491
# epoch [269/50000] ae_loss:0.0393 val_ae_loss:0.0417 test_ae_loss:0.0442
# epoch [270/50000] ae_loss:0.0386 val_ae_loss:0.0412 test_ae_loss:0.0402
# epoch [271/50000] ae_loss:0.0374 val_ae_loss:0.0432 test_ae_loss:0.0482
# epoch [272/50000] ae_loss:0.0390 val_ae_loss:0.0453 test_ae_loss:0.0568
# epoch [273/50000] ae_loss:0.0371 val_ae_loss:0.0396 test_ae_loss:0.0416
# epoch [274/50000] ae_loss:0.0358 val_ae_loss:0.0420 test_ae_loss:0.0399
# epoch [275/50000] ae_loss:0.0388 val_ae_loss:0.0416 test_ae_loss:0.0557
# epoch [276/50000] ae_loss:0.0388 val_ae_loss:0.0384 test_ae_loss:0.0553
# epoch [277/50000] ae_loss:0.0376 val_ae_loss:0.0415 test_ae_loss:0.0396
# epoch [278/50000] ae_loss:0.0378 val_ae_loss:0.0403 test_ae_loss:0.0549
# epoch [279/50000] ae_loss:0.0373 val_ae_loss:0.0367 test_ae_loss:0.0680
# epoch [280/50000] ae_loss:0.0380 val_ae_loss:0.0378 test_ae_loss:0.0396
# epoch [281/50000] ae_loss:0.0386 val_ae_loss:0.0323 test_ae_loss:0.0438
# epoch [282/50000] ae_loss:0.0370 val_ae_loss:0.0486 test_ae_loss:0.0412
# epoch [283/50000] ae_loss:0.0371 val_ae_loss:0.0388 test_ae_loss:0.0402
# epoch [284/50000] ae_loss:0.0393 val_ae_loss:0.0496 test_ae_loss:0.0546
# epoch [285/50000] ae_loss:0.0364 val_ae_loss:0.0386 test_ae_loss:0.0472
# epoch [286/50000] ae_loss:0.0390 val_ae_loss:0.0435 test_ae_loss:0.0386
# epoch [287/50000] ae_loss:0.0395 val_ae_loss:0.0381 test_ae_loss:0.0669
# epoch [288/50000] ae_loss:0.0379 val_ae_loss:0.0341 test_ae_loss:0.0439
# epoch [289/50000] ae_loss:0.0380 val_ae_loss:0.0319 test_ae_loss:0.0553
# epoch [290/50000] ae_loss:0.0379 val_ae_loss:0.0379 test_ae_loss:0.0436
# epoch [291/50000] ae_loss:0.0373 val_ae_loss:0.0418 test_ae_loss:0.0555
# epoch [292/50000] ae_loss:0.0387 val_ae_loss:0.0417 test_ae_loss:0.0393
# epoch [293/50000] ae_loss:0.0394 val_ae_loss:0.0387 test_ae_loss:0.0517
# epoch [294/50000] ae_loss:0.0382 val_ae_loss:0.0426 test_ae_loss:0.0586
# epoch [295/50000] ae_loss:0.0385 val_ae_loss:0.0410 test_ae_loss:0.0503
# epoch [296/50000] ae_loss:0.0365 val_ae_loss:0.0410 test_ae_loss:0.0414
# epoch [297/50000] ae_loss:0.0382 val_ae_loss:0.0483 test_ae_loss:0.0567
# epoch [298/50000] ae_loss:0.0354 val_ae_loss:0.0415 test_ae_loss:0.0441
# epoch [299/50000] ae_loss:0.0383 val_ae_loss:0.0389 test_ae_loss:0.0653
# epoch [300/50000] ae_loss:0.0373 val_ae_loss:0.0428 test_ae_loss:0.0563
# epoch [301/50000] ae_loss:0.0376 val_ae_loss:0.0380 test_ae_loss:0.0609
# epoch [302/50000] ae_loss:0.0383 val_ae_loss:0.0361 test_ae_loss:0.0552
# epoch [303/50000] ae_loss:0.0384 val_ae_loss:0.0393 test_ae_loss:0.0307
# epoch [304/50000] ae_loss:0.0379 val_ae_loss:0.0382 test_ae_loss:0.0593
# epoch [305/50000] ae_loss:0.0388 val_ae_loss:0.0460 test_ae_loss:0.0354
# epoch [306/50000] ae_loss:0.0387 val_ae_loss:0.0387 test_ae_loss:0.0370
# epoch [307/50000] ae_loss:0.0381 val_ae_loss:0.0426 test_ae_loss:0.0460
# epoch [308/50000] ae_loss:0.0377 val_ae_loss:0.0369 test_ae_loss:0.0394
# epoch [309/50000] ae_loss:0.0371 val_ae_loss:0.0415 test_ae_loss:0.0551
# epoch [310/50000] ae_loss:0.0384 val_ae_loss:0.0389 test_ae_loss:0.0672
# epoch [311/50000] ae_loss:0.0370 val_ae_loss:0.0406 test_ae_loss:0.0590
# epoch [312/50000] ae_loss:0.0366 val_ae_loss:0.0403 test_ae_loss:0.0481
# epoch [313/50000] ae_loss:0.0363 val_ae_loss:0.0349 test_ae_loss:0.0392
# epoch [314/50000] ae_loss:0.0371 val_ae_loss:0.0394 test_ae_loss:0.0596
# epoch [315/50000] ae_loss:0.0387 val_ae_loss:0.0396 test_ae_loss:0.0456
# epoch [316/50000] ae_loss:0.0372 val_ae_loss:0.0472 test_ae_loss:0.0526
# epoch [317/50000] ae_loss:0.0359 val_ae_loss:0.0345 test_ae_loss:0.0464
# epoch [318/50000] ae_loss:0.0375 val_ae_loss:0.0425 test_ae_loss:0.0499
# epoch [319/50000] ae_loss:0.0382 val_ae_loss:0.0399 test_ae_loss:0.0498
# epoch [320/50000] ae_loss:0.0380 val_ae_loss:0.0379 test_ae_loss:0.0351
# epoch [321/50000] ae_loss:0.0358 val_ae_loss:0.0331 test_ae_loss:0.0415
# epoch [322/50000] ae_loss:0.0380 val_ae_loss:0.0486 test_ae_loss:0.0458
# epoch [323/50000] ae_loss:0.0375 val_ae_loss:0.0415 test_ae_loss:0.0463
# epoch [324/50000] ae_loss:0.0371 val_ae_loss:0.0379 test_ae_loss:0.0669
# epoch [325/50000] ae_loss:0.0362 val_ae_loss:0.0377 test_ae_loss:0.0442
# epoch [326/50000] ae_loss:0.0397 val_ae_loss:0.0427 test_ae_loss:0.0653
# epoch [327/50000] ae_loss:0.0396 val_ae_loss:0.0334 test_ae_loss:0.0553
# epoch [328/50000] ae_loss:0.0364 val_ae_loss:0.0377 test_ae_loss:0.0473
# epoch [329/50000] ae_loss:0.0382 val_ae_loss:0.0458 test_ae_loss:0.0459
# epoch [330/50000] ae_loss:0.0367 val_ae_loss:0.0358 test_ae_loss:0.0494
# epoch [331/50000] ae_loss:0.0378 val_ae_loss:0.0373 test_ae_loss:0.0588
# epoch [332/50000] ae_loss:0.0399 val_ae_loss:0.0366 test_ae_loss:0.0557
# epoch [333/50000] ae_loss:0.0389 val_ae_loss:0.0346 test_ae_loss:0.0566
# epoch [334/50000] ae_loss:0.0403 val_ae_loss:0.0447 test_ae_loss:0.0546
# epoch [335/50000] ae_loss:0.0375 val_ae_loss:0.0398 test_ae_loss:0.0540
# epoch [336/50000] ae_loss:0.0391 val_ae_loss:0.0409 test_ae_loss:0.0386
# epoch [337/50000] ae_loss:0.0367 val_ae_loss:0.0360 test_ae_loss:0.0386
# epoch [338/50000] ae_loss:0.0372 val_ae_loss:0.0342 test_ae_loss:0.0421
# epoch [339/50000] ae_loss:0.0365 val_ae_loss:0.0362 test_ae_loss:0.0498
# epoch [340/50000] ae_loss:0.0378 val_ae_loss:0.0405 test_ae_loss:0.0516
# epoch [341/50000] ae_loss:0.0370 val_ae_loss:0.0417 test_ae_loss:0.0450
# epoch [342/50000] ae_loss:0.0398 val_ae_loss:0.0400 test_ae_loss:0.0563
# epoch [343/50000] ae_loss:0.0385 val_ae_loss:0.0369 test_ae_loss:0.0605
# epoch [344/50000] ae_loss:0.0378 val_ae_loss:0.0490 test_ae_loss:0.0477
# epoch [345/50000] ae_loss:0.0373 val_ae_loss:0.0350 test_ae_loss:0.0448
# epoch [346/50000] ae_loss:0.0387 val_ae_loss:0.0363 test_ae_loss:0.0387
# epoch [347/50000] ae_loss:0.0369 val_ae_loss:0.0412 test_ae_loss:0.0400
# epoch [348/50000] ae_loss:0.0408 val_ae_loss:0.0406 test_ae_loss:0.0660
# epoch [349/50000] ae_loss:0.0385 val_ae_loss:0.0423 test_ae_loss:0.0436
# epoch [350/50000] ae_loss:0.0375 val_ae_loss:0.0366 test_ae_loss:0.0493
# epoch [351/50000] ae_loss:0.0389 val_ae_loss:0.0431 test_ae_loss:0.0449
# epoch [352/50000] ae_loss:0.0383 val_ae_loss:0.0379 test_ae_loss:0.0460
# epoch [353/50000] ae_loss:0.0369 val_ae_loss:0.0468 test_ae_loss:0.0617
# epoch [354/50000] ae_loss:0.0365 val_ae_loss:0.0482 test_ae_loss:0.0437
# epoch [355/50000] ae_loss:0.0375 val_ae_loss:0.0356 test_ae_loss:0.0489
# epoch [356/50000] ae_loss:0.0380 val_ae_loss:0.0422 test_ae_loss:0.0418
# epoch [357/50000] ae_loss:0.0378 val_ae_loss:0.0365 test_ae_loss:0.0579
# epoch [358/50000] ae_loss:0.0353 val_ae_loss:0.0355 test_ae_loss:0.0578
# epoch [359/50000] ae_loss:0.0386 val_ae_loss:0.0339 test_ae_loss:0.0588
# epoch [360/50000] ae_loss:0.0380 val_ae_loss:0.0353 test_ae_loss:0.0656
# epoch [361/50000] ae_loss:0.0371 val_ae_loss:0.0400 test_ae_loss:0.0415
# epoch [362/50000] ae_loss:0.0367 val_ae_loss:0.0342 test_ae_loss:0.0309
# epoch [363/50000] ae_loss:0.0363 val_ae_loss:0.0454 test_ae_loss:0.0488
# epoch [364/50000] ae_loss:0.0357 val_ae_loss:0.0333 test_ae_loss:0.0527
# epoch [365/50000] ae_loss:0.0364 val_ae_loss:0.0379 test_ae_loss:0.0385
# epoch [366/50000] ae_loss:0.0358 val_ae_loss:0.0409 test_ae_loss:0.0453
# epoch [367/50000] ae_loss:0.0376 val_ae_loss:0.0418 test_ae_loss:0.0497
# epoch [368/50000] ae_loss:0.0401 val_ae_loss:0.0407 test_ae_loss:0.0420
# epoch [369/50000] ae_loss:0.0370 val_ae_loss:0.0397 test_ae_loss:0.0469
# epoch [370/50000] ae_loss:0.0363 val_ae_loss:0.0416 test_ae_loss:0.0425
# epoch [371/50000] ae_loss:0.0373 val_ae_loss:0.0413 test_ae_loss:0.0496
# epoch [372/50000] ae_loss:0.0371 val_ae_loss:0.0393 test_ae_loss:0.0478
# epoch [373/50000] ae_loss:0.0389 val_ae_loss:0.0425 test_ae_loss:0.0535
# epoch [374/50000] ae_loss:0.0395 val_ae_loss:0.0445 test_ae_loss:0.0423
# epoch [375/50000] ae_loss:0.0360 val_ae_loss:0.0367 test_ae_loss:0.0479
# epoch [376/50000] ae_loss:0.0389 val_ae_loss:0.0415 test_ae_loss:0.0467
# epoch [377/50000] ae_loss:0.0360 val_ae_loss:0.0396 test_ae_loss:0.0625
# epoch [378/50000] ae_loss:0.0375 val_ae_loss:0.0382 test_ae_loss:0.0577
# epoch [379/50000] ae_loss:0.0360 val_ae_loss:0.0416 test_ae_loss:0.0388
# epoch [380/50000] ae_loss:0.0382 val_ae_loss:0.0350 test_ae_loss:0.0383
# epoch [381/50000] ae_loss:0.0379 val_ae_loss:0.0370 test_ae_loss:0.0494
# epoch [382/50000] ae_loss:0.0363 val_ae_loss:0.0433 test_ae_loss:0.0590
# epoch [383/50000] ae_loss:0.0366 val_ae_loss:0.0400 test_ae_loss:0.0640
# epoch [384/50000] ae_loss:0.0385 val_ae_loss:0.0362 test_ae_loss:0.0395
# epoch [385/50000] ae_loss:0.0395 val_ae_loss:0.0356 test_ae_loss:0.0597
# epoch [386/50000] ae_loss:0.0369 val_ae_loss:0.0426 test_ae_loss:0.0435
# epoch [387/50000] ae_loss:0.0375 val_ae_loss:0.0369 test_ae_loss:0.0397
# epoch [388/50000] ae_loss:0.0371 val_ae_loss:0.0442 test_ae_loss:0.0519
# epoch [389/50000] ae_loss:0.0390 val_ae_loss:0.0434 test_ae_loss:0.0440
# epoch [390/50000] ae_loss:0.0378 val_ae_loss:0.0466 test_ae_loss:0.0562
# epoch [391/50000] ae_loss:0.0373 val_ae_loss:0.0379 test_ae_loss:0.0558
# epoch [392/50000] ae_loss:0.0366 val_ae_loss:0.0435 test_ae_loss:0.0467
# epoch [393/50000] ae_loss:0.0373 val_ae_loss:0.0442 test_ae_loss:0.0605
# epoch [394/50000] ae_loss:0.0387 val_ae_loss:0.0365 test_ae_loss:0.0387
# epoch [395/50000] ae_loss:0.0361 val_ae_loss:0.0475 test_ae_loss:0.0474
# epoch [396/50000] ae_loss:0.0368 val_ae_loss:0.0376 test_ae_loss:0.0454
# epoch [397/50000] ae_loss:0.0365 val_ae_loss:0.0424 test_ae_loss:0.0425
# epoch [398/50000] ae_loss:0.0362 val_ae_loss:0.0428 test_ae_loss:0.0417
# epoch [399/50000] ae_loss:0.0370 val_ae_loss:0.0475 test_ae_loss:0.0595
# epoch [400/50000] ae_loss:0.0387 val_ae_loss:0.0465 test_ae_loss:0.0396
# epoch [401/50000] ae_loss:0.0368 val_ae_loss:0.0379 test_ae_loss:0.0397
# epoch [402/50000] ae_loss:0.0381 val_ae_loss:0.0356 test_ae_loss:0.0595
# epoch [403/50000] ae_loss:0.0365 val_ae_loss:0.0421 test_ae_loss:0.0434
# epoch [404/50000] ae_loss:0.0378 val_ae_loss:0.0455 test_ae_loss:0.0549
# epoch [405/50000] ae_loss:0.0396 val_ae_loss:0.0414 test_ae_loss:0.0405
# epoch [406/50000] ae_loss:0.0366 val_ae_loss:0.0350 test_ae_loss:0.0504
# epoch [407/50000] ae_loss:0.0360 val_ae_loss:0.0380 test_ae_loss:0.0583
# epoch [408/50000] ae_loss:0.0379 val_ae_loss:0.0438 test_ae_loss:0.0592
# epoch [409/50000] ae_loss:0.0362 val_ae_loss:0.0408 test_ae_loss:0.0530
# epoch [410/50000] ae_loss:0.0377 val_ae_loss:0.0326 test_ae_loss:0.0436
# epoch [411/50000] ae_loss:0.0369 val_ae_loss:0.0441 test_ae_loss:0.0574
# epoch [412/50000] ae_loss:0.0384 val_ae_loss:0.0460 test_ae_loss:0.0561
# epoch [413/50000] ae_loss:0.0383 val_ae_loss:0.0352 test_ae_loss:0.0468
# epoch [414/50000] ae_loss:0.0365 val_ae_loss:0.0409 test_ae_loss:0.0422
# epoch [415/50000] ae_loss:0.0388 val_ae_loss:0.0401 test_ae_loss:0.0310
# epoch [416/50000] ae_loss:0.0362 val_ae_loss:0.0376 test_ae_loss:0.0439
# epoch [417/50000] ae_loss:0.0375 val_ae_loss:0.0304 test_ae_loss:0.0382
# epoch [418/50000] ae_loss:0.0388 val_ae_loss:0.0370 test_ae_loss:0.0351
# epoch [419/50000] ae_loss:0.0379 val_ae_loss:0.0385 test_ae_loss:0.0481
# epoch [420/50000] ae_loss:0.0394 val_ae_loss:0.0428 test_ae_loss:0.0559
# epoch [421/50000] ae_loss:0.0374 val_ae_loss:0.0406 test_ae_loss:0.0424
# epoch [422/50000] ae_loss:0.0367 val_ae_loss:0.0367 test_ae_loss:0.0417
# epoch [423/50000] ae_loss:0.0386 val_ae_loss:0.0365 test_ae_loss:0.0553
# epoch [424/50000] ae_loss:0.0378 val_ae_loss:0.0444 test_ae_loss:0.0478
# epoch [425/50000] ae_loss:0.0385 val_ae_loss:0.0420 test_ae_loss:0.0441
# epoch [426/50000] ae_loss:0.0367 val_ae_loss:0.0478 test_ae_loss:0.0575
# epoch [427/50000] ae_loss:0.0385 val_ae_loss:0.0444 test_ae_loss:0.0461
# epoch [428/50000] ae_loss:0.0394 val_ae_loss:0.0376 test_ae_loss:0.0545
# epoch [429/50000] ae_loss:0.0386 val_ae_loss:0.0378 test_ae_loss:0.0601
# epoch [430/50000] ae_loss:0.0385 val_ae_loss:0.0468 test_ae_loss:0.0508
# epoch [431/50000] ae_loss:0.0367 val_ae_loss:0.0401 test_ae_loss:0.0662
# epoch [432/50000] ae_loss:0.0375 val_ae_loss:0.0421 test_ae_loss:0.0447
# epoch [433/50000] ae_loss:0.0357 val_ae_loss:0.0424 test_ae_loss:0.0439
# epoch [434/50000] ae_loss:0.0366 val_ae_loss:0.0361 test_ae_loss:0.0456
# epoch [435/50000] ae_loss:0.0369 val_ae_loss:0.0462 test_ae_loss:0.0399
# epoch [436/50000] ae_loss:0.0359 val_ae_loss:0.0432 test_ae_loss:0.0647
# epoch [437/50000] ae_loss:0.0382 val_ae_loss:0.0346 test_ae_loss:0.0402
# epoch [438/50000] ae_loss:0.0359 val_ae_loss:0.0450 test_ae_loss:0.0448
# epoch [439/50000] ae_loss:0.0381 val_ae_loss:0.0444 test_ae_loss:0.0552
# epoch [440/50000] ae_loss:0.0381 val_ae_loss:0.0421 test_ae_loss:0.0397
# epoch [441/50000] ae_loss:0.0371 val_ae_loss:0.0374 test_ae_loss:0.0388
# epoch [442/50000] ae_loss:0.0360 val_ae_loss:0.0355 test_ae_loss:0.0398
# epoch [443/50000] ae_loss:0.0379 val_ae_loss:0.0481 test_ae_loss:0.0380
# epoch [444/50000] ae_loss:0.0385 val_ae_loss:0.0377 test_ae_loss:0.0556
# epoch [445/50000] ae_loss:0.0378 val_ae_loss:0.0372 test_ae_loss:0.0563
# epoch [446/50000] ae_loss:0.0374 val_ae_loss:0.0426 test_ae_loss:0.0497
# epoch [447/50000] ae_loss:0.0370 val_ae_loss:0.0429 test_ae_loss:0.0646
# epoch [448/50000] ae_loss:0.0367 val_ae_loss:0.0380 test_ae_loss:0.0571
# epoch [449/50000] ae_loss:0.0383 val_ae_loss:0.0475 test_ae_loss:0.0538
# epoch [450/50000] ae_loss:0.0368 val_ae_loss:0.0454 test_ae_loss:0.0445
# epoch [451/50000] ae_loss:0.0395 val_ae_loss:0.0338 test_ae_loss:0.0475
# epoch [452/50000] ae_loss:0.0362 val_ae_loss:0.0401 test_ae_loss:0.0421
# epoch [453/50000] ae_loss:0.0399 val_ae_loss:0.0404 test_ae_loss:0.0309
# epoch [454/50000] ae_loss:0.0384 val_ae_loss:0.0412 test_ae_loss:0.0394
# epoch [455/50000] ae_loss:0.0370 val_ae_loss:0.0406 test_ae_loss:0.0510
# epoch [456/50000] ae_loss:0.0375 val_ae_loss:0.0373 test_ae_loss:0.0445
# epoch [457/50000] ae_loss:0.0388 val_ae_loss:0.0395 test_ae_loss:0.0499
# epoch [458/50000] ae_loss:0.0363 val_ae_loss:0.0436 test_ae_loss:0.0397
# epoch [459/50000] ae_loss:0.0363 val_ae_loss:0.0416 test_ae_loss:0.0390
# epoch [460/50000] ae_loss:0.0380 val_ae_loss:0.0402 test_ae_loss:0.0407
# epoch [461/50000] ae_loss:0.0390 val_ae_loss:0.0453 test_ae_loss:0.0567
# epoch [462/50000] ae_loss:0.0369 val_ae_loss:0.0368 test_ae_loss:0.0399
# epoch [463/50000] ae_loss:0.0389 val_ae_loss:0.0417 test_ae_loss:0.0465
# epoch [464/50000] ae_loss:0.0377 val_ae_loss:0.0392 test_ae_loss:0.0439
# epoch [465/50000] ae_loss:0.0387 val_ae_loss:0.0390 test_ae_loss:0.0443
# epoch [466/50000] ae_loss:0.0368 val_ae_loss:0.0449 test_ae_loss:0.0542
# epoch [467/50000] ae_loss:0.0378 val_ae_loss:0.0400 test_ae_loss:0.0588
# epoch [468/50000] ae_loss:0.0368 val_ae_loss:0.0421 test_ae_loss:0.0400
# epoch [469/50000] ae_loss:0.0362 val_ae_loss:0.0344 test_ae_loss:0.0590
# epoch [470/50000] ae_loss:0.0383 val_ae_loss:0.0376 test_ae_loss:0.0439
# epoch [471/50000] ae_loss:0.0385 val_ae_loss:0.0335 test_ae_loss:0.0585
# epoch [472/50000] ae_loss:0.0386 val_ae_loss:0.0426 test_ae_loss:0.0408
# epoch [473/50000] ae_loss:0.0380 val_ae_loss:0.0443 test_ae_loss:0.0465
# epoch [474/50000] ae_loss:0.0374 val_ae_loss:0.0411 test_ae_loss:0.0421
# epoch [475/50000] ae_loss:0.0360 val_ae_loss:0.0342 test_ae_loss:0.0495
# epoch [476/50000] ae_loss:0.0365 val_ae_loss:0.0469 test_ae_loss:0.0498
# epoch [477/50000] ae_loss:0.0374 val_ae_loss:0.0403 test_ae_loss:0.0395
# epoch [478/50000] ae_loss:0.0359 val_ae_loss:0.0447 test_ae_loss:0.0396
# epoch [479/50000] ae_loss:0.0370 val_ae_loss:0.0397 test_ae_loss:0.0469
# epoch [480/50000] ae_loss:0.0408 val_ae_loss:0.0425 test_ae_loss:0.0386
# epoch [481/50000] ae_loss:0.0362 val_ae_loss:0.0370 test_ae_loss:0.0588
# epoch [482/50000] ae_loss:0.0373 val_ae_loss:0.0379 test_ae_loss:0.0593
# epoch [483/50000] ae_loss:0.0380 val_ae_loss:0.0363 test_ae_loss:0.0439
# epoch [484/50000] ae_loss:0.0380 val_ae_loss:0.0361 test_ae_loss:0.0551
# epoch [485/50000] ae_loss:0.0387 val_ae_loss:0.0415 test_ae_loss:0.0389
# epoch [486/50000] ae_loss:0.0362 val_ae_loss:0.0466 test_ae_loss:0.0480
# epoch [487/50000] ae_loss:0.0396 val_ae_loss:0.0392 test_ae_loss:0.0550
# epoch [488/50000] ae_loss:0.0369 val_ae_loss:0.0390 test_ae_loss:0.0550
# epoch [489/50000] ae_loss:0.0366 val_ae_loss:0.0447 test_ae_loss:0.0437
# epoch [490/50000] ae_loss:0.0383 val_ae_loss:0.0402 test_ae_loss:0.0590
# epoch [491/50000] ae_loss:0.0393 val_ae_loss:0.0367 test_ae_loss:0.0409
# epoch [492/50000] ae_loss:0.0362 val_ae_loss:0.0360 test_ae_loss:0.0413
# epoch [493/50000] ae_loss:0.0373 val_ae_loss:0.0435 test_ae_loss:0.0590
# epoch [494/50000] ae_loss:0.0379 val_ae_loss:0.0369 test_ae_loss:0.0402
# epoch [495/50000] ae_loss:0.0369 val_ae_loss:0.0443 test_ae_loss:0.0503
# epoch [496/50000] ae_loss:0.0381 val_ae_loss:0.0367 test_ae_loss:0.0407
# epoch [497/50000] ae_loss:0.0366 val_ae_loss:0.0383 test_ae_loss:0.0433
# epoch [498/50000] ae_loss:0.0389 val_ae_loss:0.0386 test_ae_loss:0.0608
# epoch [499/50000] ae_loss:0.0367 val_ae_loss:0.0338 test_ae_loss:0.0488
# epoch [500/50000] ae_loss:0.0388 val_ae_loss:0.0429 test_ae_loss:0.0509
# epoch [501/50000] ae_loss:0.0369 val_ae_loss:0.0386 test_ae_loss:0.0505
# epoch [502/50000] ae_loss:0.0369 val_ae_loss:0.0402 test_ae_loss:0.0597
# epoch [503/50000] ae_loss:0.0369 val_ae_loss:0.0346 test_ae_loss:0.0380
# epoch [504/50000] ae_loss:0.0399 val_ae_loss:0.0434 test_ae_loss:0.0563
# epoch [505/50000] ae_loss:0.0360 val_ae_loss:0.0460 test_ae_loss:0.0429
# epoch [506/50000] ae_loss:0.0391 val_ae_loss:0.0382 test_ae_loss:0.0525
# epoch [507/50000] ae_loss:0.0379 val_ae_loss:0.0348 test_ae_loss:0.0495
# epoch [508/50000] ae_loss:0.0372 val_ae_loss:0.0408 test_ae_loss:0.0389
# epoch [509/50000] ae_loss:0.0364 val_ae_loss:0.0414 test_ae_loss:0.0550
# epoch [510/50000] ae_loss:0.0377 val_ae_loss:0.0423 test_ae_loss:0.0477
# epoch [511/50000] ae_loss:0.0381 val_ae_loss:0.0443 test_ae_loss:0.0403
# epoch [512/50000] ae_loss:0.0380 val_ae_loss:0.0395 test_ae_loss:0.0644
# epoch [513/50000] ae_loss:0.0358 val_ae_loss:0.0405 test_ae_loss:0.0389
# epoch [514/50000] ae_loss:0.0343 val_ae_loss:0.0342 test_ae_loss:0.0450
# epoch [515/50000] ae_loss:0.0375 val_ae_loss:0.0403 test_ae_loss:0.0632
# epoch [516/50000] ae_loss:0.0365 val_ae_loss:0.0399 test_ae_loss:0.0524
# epoch [517/50000] ae_loss:0.0382 val_ae_loss:0.0415 test_ae_loss:0.0673
# epoch [518/50000] ae_loss:0.0403 val_ae_loss:0.0442 test_ae_loss:0.0531
# epoch [519/50000] ae_loss:0.0362 val_ae_loss:0.0381 test_ae_loss:0.0663
# epoch [520/50000] ae_loss:0.0394 val_ae_loss:0.0378 test_ae_loss:0.0499
# epoch [521/50000] ae_loss:0.0385 val_ae_loss:0.0372 test_ae_loss:0.0360
# epoch [522/50000] ae_loss:0.0379 val_ae_loss:0.0464 test_ae_loss:0.0400
# epoch [523/50000] ae_loss:0.0379 val_ae_loss:0.0434 test_ae_loss:0.0463
# epoch [524/50000] ae_loss:0.0373 val_ae_loss:0.0417 test_ae_loss:0.0392
# epoch [525/50000] ae_loss:0.0350 val_ae_loss:0.0437 test_ae_loss:0.0540
# epoch [526/50000] ae_loss:0.0398 val_ae_loss:0.0369 test_ae_loss:0.0496
# epoch [527/50000] ae_loss:0.0372 val_ae_loss:0.0374 test_ae_loss:0.0314
# epoch [528/50000] ae_loss:0.0372 val_ae_loss:0.0393 test_ae_loss:0.0500
# epoch [529/50000] ae_loss:0.0387 val_ae_loss:0.0425 test_ae_loss:0.0433
# epoch [530/50000] ae_loss:0.0370 val_ae_loss:0.0400 test_ae_loss:0.0347
# epoch [531/50000] ae_loss:0.0378 val_ae_loss:0.0445 test_ae_loss:0.0584
# epoch [532/50000] ae_loss:0.0372 val_ae_loss:0.0410 test_ae_loss:0.0453
# epoch [533/50000] ae_loss:0.0378 val_ae_loss:0.0379 test_ae_loss:0.0498
# epoch [534/50000] ae_loss:0.0375 val_ae_loss:0.0456 test_ae_loss:0.0509
# epoch [535/50000] ae_loss:0.0376 val_ae_loss:0.0457 test_ae_loss:0.0472
# epoch [536/50000] ae_loss:0.0374 val_ae_loss:0.0375 test_ae_loss:0.0455
# epoch [537/50000] ae_loss:0.0370 val_ae_loss:0.0426 test_ae_loss:0.0554
# epoch [538/50000] ae_loss:0.0375 val_ae_loss:0.0379 test_ae_loss:0.0409
# epoch [539/50000] ae_loss:0.0357 val_ae_loss:0.0392 test_ae_loss:0.0438
# epoch [540/50000] ae_loss:0.0370 val_ae_loss:0.0327 test_ae_loss:0.0537
# epoch [541/50000] ae_loss:0.0367 val_ae_loss:0.0376 test_ae_loss:0.0359
# epoch [542/50000] ae_loss:0.0377 val_ae_loss:0.0390 test_ae_loss:0.0570
# epoch [543/50000] ae_loss:0.0369 val_ae_loss:0.0438 test_ae_loss:0.0398
# epoch [544/50000] ae_loss:0.0371 val_ae_loss:0.0364 test_ae_loss:0.0497
# epoch [545/50000] ae_loss:0.0392 val_ae_loss:0.0416 test_ae_loss:0.0475
# epoch [546/50000] ae_loss:0.0374 val_ae_loss:0.0428 test_ae_loss:0.0389
# epoch [547/50000] ae_loss:0.0375 val_ae_loss:0.0390 test_ae_loss:0.0556
# epoch [548/50000] ae_loss:0.0364 val_ae_loss:0.0376 test_ae_loss:0.0415
# epoch [549/50000] ae_loss:0.0382 val_ae_loss:0.0473 test_ae_loss:0.0450
# epoch [550/50000] ae_loss:0.0374 val_ae_loss:0.0412 test_ae_loss:0.0409
# epoch [551/50000] ae_loss:0.0372 val_ae_loss:0.0398 test_ae_loss:0.0500
# epoch [552/50000] ae_loss:0.0372 val_ae_loss:0.0344 test_ae_loss:0.0387
# epoch [553/50000] ae_loss:0.0380 val_ae_loss:0.0336 test_ae_loss:0.0474
# epoch [554/50000] ae_loss:0.0360 val_ae_loss:0.0377 test_ae_loss:0.0391
# epoch [555/50000] ae_loss:0.0352 val_ae_loss:0.0483 test_ae_loss:0.0502
# epoch [556/50000] ae_loss:0.0355 val_ae_loss:0.0369 test_ae_loss:0.0509
# epoch [557/50000] ae_loss:0.0380 val_ae_loss:0.0354 test_ae_loss:0.0505
# epoch [558/50000] ae_loss:0.0379 val_ae_loss:0.0402 test_ae_loss:0.0465
# epoch [559/50000] ae_loss:0.0341 val_ae_loss:0.0435 test_ae_loss:0.0423
# epoch [560/50000] ae_loss:0.0393 val_ae_loss:0.0404 test_ae_loss:0.0537
# epoch [561/50000] ae_loss:0.0369 val_ae_loss:0.0409 test_ae_loss:0.0438
# epoch [562/50000] ae_loss:0.0380 val_ae_loss:0.0459 test_ae_loss:0.0433
# epoch [563/50000] ae_loss:0.0365 val_ae_loss:0.0346 test_ae_loss:0.0539
# epoch [564/50000] ae_loss:0.0382 val_ae_loss:0.0367 test_ae_loss:0.0492
# epoch [565/50000] ae_loss:0.0384 val_ae_loss:0.0383 test_ae_loss:0.0539
# epoch [566/50000] ae_loss:0.0376 val_ae_loss:0.0401 test_ae_loss:0.0474
# epoch [567/50000] ae_loss:0.0388 val_ae_loss:0.0404 test_ae_loss:0.0552
# epoch [568/50000] ae_loss:0.0379 val_ae_loss:0.0420 test_ae_loss:0.0445
# epoch [569/50000] ae_loss:0.0371 val_ae_loss:0.0387 test_ae_loss:0.0397
# epoch [570/50000] ae_loss:0.0387 val_ae_loss:0.0395 test_ae_loss:0.0433
# epoch [571/50000] ae_loss:0.0360 val_ae_loss:0.0343 test_ae_loss:0.0404
# epoch [572/50000] ae_loss:0.0378 val_ae_loss:0.0376 test_ae_loss:0.0543
# epoch [573/50000] ae_loss:0.0379 val_ae_loss:0.0385 test_ae_loss:0.0379
# epoch [574/50000] ae_loss:0.0366 val_ae_loss:0.0312 test_ae_loss:0.0389
# epoch [575/50000] ae_loss:0.0388 val_ae_loss:0.0423 test_ae_loss:0.0547
# epoch [576/50000] ae_loss:0.0360 val_ae_loss:0.0409 test_ae_loss:0.0676
# epoch [577/50000] ae_loss:0.0387 val_ae_loss:0.0413 test_ae_loss:0.0387
# epoch [578/50000] ae_loss:0.0377 val_ae_loss:0.0349 test_ae_loss:0.0429
# epoch [579/50000] ae_loss:0.0371 val_ae_loss:0.0362 test_ae_loss:0.0511
# epoch [580/50000] ae_loss:0.0385 val_ae_loss:0.0407 test_ae_loss:0.0433
# epoch [581/50000] ae_loss:0.0383 val_ae_loss:0.0384 test_ae_loss:0.0535
# epoch [582/50000] ae_loss:0.0364 val_ae_loss:0.0344 test_ae_loss:0.0457
# epoch [583/50000] ae_loss:0.0372 val_ae_loss:0.0438 test_ae_loss:0.0422
# epoch [584/50000] ae_loss:0.0397 val_ae_loss:0.0344 test_ae_loss:0.0310
# epoch [585/50000] ae_loss:0.0363 val_ae_loss:0.0443 test_ae_loss:0.0465
# epoch [586/50000] ae_loss:0.0379 val_ae_loss:0.0379 test_ae_loss:0.0577
# epoch [587/50000] ae_loss:0.0365 val_ae_loss:0.0380 test_ae_loss:0.0376
# epoch [588/50000] ae_loss:0.0374 val_ae_loss:0.0359 test_ae_loss:0.0587
# epoch [589/50000] ae_loss:0.0364 val_ae_loss:0.0362 test_ae_loss:0.0594
# epoch [590/50000] ae_loss:0.0371 val_ae_loss:0.0463 test_ae_loss:0.0490
# epoch [591/50000] ae_loss:0.0370 val_ae_loss:0.0372 test_ae_loss:0.0441
# epoch [592/50000] ae_loss:0.0381 val_ae_loss:0.0371 test_ae_loss:0.0417
# epoch [593/50000] ae_loss:0.0373 val_ae_loss:0.0456 test_ae_loss:0.0444
# epoch [594/50000] ae_loss:0.0369 val_ae_loss:0.0457 test_ae_loss:0.0545
# epoch [595/50000] ae_loss:0.0370 val_ae_loss:0.0423 test_ae_loss:0.0416
# epoch [596/50000] ae_loss:0.0374 val_ae_loss:0.0435 test_ae_loss:0.0497
# epoch [597/50000] ae_loss:0.0379 val_ae_loss:0.0430 test_ae_loss:0.0418
# epoch [598/50000] ae_loss:0.0382 val_ae_loss:0.0404 test_ae_loss:0.0512
# epoch [599/50000] ae_loss:0.0383 val_ae_loss:0.0353 test_ae_loss:0.0588
# epoch [600/50000] ae_loss:0.0387 val_ae_loss:0.0375 test_ae_loss:0.0466
# epoch [601/50000] ae_loss:0.0367 val_ae_loss:0.0450 test_ae_loss:0.0600
# epoch [602/50000] ae_loss:0.0368 val_ae_loss:0.0467 test_ae_loss:0.0501
# epoch [603/50000] ae_loss:0.0379 val_ae_loss:0.0312 test_ae_loss:0.0311
# epoch [604/50000] ae_loss:0.0367 val_ae_loss:0.0467 test_ae_loss:0.0442
# epoch [605/50000] ae_loss:0.0393 val_ae_loss:0.0418 test_ae_loss:0.0353
# epoch [606/50000] ae_loss:0.0359 val_ae_loss:0.0383 test_ae_loss:0.0586
# epoch [607/50000] ae_loss:0.0374 val_ae_loss:0.0388 test_ae_loss:0.0707
# epoch [608/50000] ae_loss:0.0374 val_ae_loss:0.0438 test_ae_loss:0.0444
# epoch [609/50000] ae_loss:0.0369 val_ae_loss:0.0385 test_ae_loss:0.0310
# epoch [610/50000] ae_loss:0.0392 val_ae_loss:0.0328 test_ae_loss:0.0442
# epoch [611/50000] ae_loss:0.0377 val_ae_loss:0.0416 test_ae_loss:0.0432
# epoch [612/50000] ae_loss:0.0368 val_ae_loss:0.0423 test_ae_loss:0.0381
# epoch [613/50000] ae_loss:0.0370 val_ae_loss:0.0405 test_ae_loss:0.0615
# epoch [614/50000] ae_loss:0.0359 val_ae_loss:0.0418 test_ae_loss:0.0580
# epoch [615/50000] ae_loss:0.0346 val_ae_loss:0.0441 test_ae_loss:0.0448
# epoch [616/50000] ae_loss:0.0384 val_ae_loss:0.0387 test_ae_loss:0.0505
# epoch [617/50000] ae_loss:0.0364 val_ae_loss:0.0363 test_ae_loss:0.0447
# epoch [618/50000] ae_loss:0.0377 val_ae_loss:0.0391 test_ae_loss:0.0462
# epoch [619/50000] ae_loss:0.0378 val_ae_loss:0.0449 test_ae_loss:0.0591
# epoch [620/50000] ae_loss:0.0368 val_ae_loss:0.0361 test_ae_loss:0.0613
# epoch [621/50000] ae_loss:0.0367 val_ae_loss:0.0318 test_ae_loss:0.0493
# epoch [622/50000] ae_loss:0.0377 val_ae_loss:0.0402 test_ae_loss:0.0615
# epoch [623/50000] ae_loss:0.0367 val_ae_loss:0.0393 test_ae_loss:0.0488
# epoch [624/50000] ae_loss:0.0380 val_ae_loss:0.0436 test_ae_loss:0.0525
# epoch [625/50000] ae_loss:0.0390 val_ae_loss:0.0440 test_ae_loss:0.0575
# epoch [626/50000] ae_loss:0.0390 val_ae_loss:0.0407 test_ae_loss:0.0581
# epoch [627/50000] ae_loss:0.0369 val_ae_loss:0.0376 test_ae_loss:0.0445
# epoch [628/50000] ae_loss:0.0379 val_ae_loss:0.0347 test_ae_loss:0.0463
# epoch [629/50000] ae_loss:0.0380 val_ae_loss:0.0454 test_ae_loss:0.0511
# epoch [630/50000] ae_loss:0.0386 val_ae_loss:0.0368 test_ae_loss:0.0444
# epoch [631/50000] ae_loss:0.0372 val_ae_loss:0.0443 test_ae_loss:0.0576
# epoch [632/50000] ae_loss:0.0366 val_ae_loss:0.0375 test_ae_loss:0.0497
# epoch [633/50000] ae_loss:0.0370 val_ae_loss:0.0424 test_ae_loss:0.0398
# epoch [634/50000] ae_loss:0.0379 val_ae_loss:0.0443 test_ae_loss:0.0504
# epoch [635/50000] ae_loss:0.0369 val_ae_loss:0.0438 test_ae_loss:0.0436
# epoch [636/50000] ae_loss:0.0385 val_ae_loss:0.0346 test_ae_loss:0.0461
# epoch [637/50000] ae_loss:0.0381 val_ae_loss:0.0359 test_ae_loss:0.0470
# epoch [638/50000] ae_loss:0.0365 val_ae_loss:0.0450 test_ae_loss:0.0598
# epoch [639/50000] ae_loss:0.0367 val_ae_loss:0.0427 test_ae_loss:0.0513
# epoch [640/50000] ae_loss:0.0383 val_ae_loss:0.0415 test_ae_loss:0.0566
# epoch [641/50000] ae_loss:0.0374 val_ae_loss:0.0384 test_ae_loss:0.0443
# epoch [642/50000] ae_loss:0.0381 val_ae_loss:0.0370 test_ae_loss:0.0309
# epoch [643/50000] ae_loss:0.0380 val_ae_loss:0.0418 test_ae_loss:0.0456
# epoch [644/50000] ae_loss:0.0359 val_ae_loss:0.0438 test_ae_loss:0.0493
# epoch [645/50000] ae_loss:0.0390 val_ae_loss:0.0394 test_ae_loss:0.0492
# epoch [646/50000] ae_loss:0.0391 val_ae_loss:0.0427 test_ae_loss:0.0613
# epoch [647/50000] ae_loss:0.0373 val_ae_loss:0.0391 test_ae_loss:0.0414
# epoch [648/50000] ae_loss:0.0371 val_ae_loss:0.0424 test_ae_loss:0.0568
# epoch [649/50000] ae_loss:0.0383 val_ae_loss:0.0396 test_ae_loss:0.0480
# epoch [650/50000] ae_loss:0.0394 val_ae_loss:0.0414 test_ae_loss:0.0499
# epoch [651/50000] ae_loss:0.0388 val_ae_loss:0.0438 test_ae_loss:0.0504
# epoch [652/50000] ae_loss:0.0379 val_ae_loss:0.0431 test_ae_loss:0.0604
# epoch [653/50000] ae_loss:0.0361 val_ae_loss:0.0404 test_ae_loss:0.0459
# epoch [654/50000] ae_loss:0.0368 val_ae_loss:0.0384 test_ae_loss:0.0421
# epoch [655/50000] ae_loss:0.0367 val_ae_loss:0.0407 test_ae_loss:0.0542
# epoch [656/50000] ae_loss:0.0380 val_ae_loss:0.0395 test_ae_loss:0.0444
# epoch [657/50000] ae_loss:0.0366 val_ae_loss:0.0385 test_ae_loss:0.0498
# epoch [658/50000] ae_loss:0.0385 val_ae_loss:0.0461 test_ae_loss:0.0424
# epoch [659/50000] ae_loss:0.0362 val_ae_loss:0.0399 test_ae_loss:0.0359
# epoch [660/50000] ae_loss:0.0363 val_ae_loss:0.0437 test_ae_loss:0.0381
# epoch [661/50000] ae_loss:0.0371 val_ae_loss:0.0320 test_ae_loss:0.0442
# epoch [662/50000] ae_loss:0.0375 val_ae_loss:0.0345 test_ae_loss:0.0504
# epoch [663/50000] ae_loss:0.0364 val_ae_loss:0.0341 test_ae_loss:0.0483
# epoch [664/50000] ae_loss:0.0370 val_ae_loss:0.0417 test_ae_loss:0.0575
# epoch [665/50000] ae_loss:0.0379 val_ae_loss:0.0358 test_ae_loss:0.0605
# epoch [666/50000] ae_loss:0.0368 val_ae_loss:0.0389 test_ae_loss:0.0412
# epoch [667/50000] ae_loss:0.0364 val_ae_loss:0.0445 test_ae_loss:0.0571
# epoch [668/50000] ae_loss:0.0375 val_ae_loss:0.0409 test_ae_loss:0.0432
# ...
# epoch [744/50000] ae_loss:0.0378 val_ae_loss:0.0427 test_ae_loss:0.0506
# epoch [745/50000] ae_loss:0.0378 val_ae_loss:0.0401 test_ae_loss:0.0434
# epoch [746/50000] ae_loss:0.0359 val_ae_loss:0.0429 test_ae_loss:0.0430
# epoch [747/50000] ae_loss:0.0369 val_ae_loss:0.0391 test_ae_loss:0.0451
# epoch [748/50000] ae_loss:0.0378 val_ae_loss:0.0370 test_ae_loss:0.0495
# epoch [749/50000] ae_loss:0.0367 val_ae_loss:0.0386 test_ae_loss:0.0531
# epoch [750/50000] ae_loss:0.0382 val_ae_loss:0.0414 test_ae_loss:0.0506
# epoch [751/50000] ae_loss:0.0356 val_ae_loss:0.0434 test_ae_loss:0.0427
# epoch [752/50000] ae_loss:0.0372 val_ae_loss:0.0409 test_ae_loss:0.0331
# epoch [753/50000] ae_loss:0.0373 val_ae_loss:0.0438 test_ae_loss:0.0576
# epoch [754/50000] ae_loss:0.0375 val_ae_loss:0.0383 test_ae_loss:0.0424
# epoch [755/50000] ae_loss:0.0383 val_ae_loss:0.0428 test_ae_loss:0.0689
# epoch [756/50000] ae_loss:0.0381 val_ae_loss:0.0416 test_ae_loss:0.0575
# epoch [757/50000] ae_loss:0.0372 val_ae_loss:0.0337 test_ae_loss:0.0427
# epoch [758/50000] ae_loss:0.0370 val_ae_loss:0.0406 test_ae_loss:0.0433
# epoch [759/50000] ae_loss:0.0363 val_ae_loss:0.0386 test_ae_loss:0.0351
# epoch [760/50000] ae_loss:0.0385 val_ae_loss:0.0390 test_ae_loss:0.0351
# epoch [761/50000] ae_loss:0.0379 val_ae_loss:0.0358 test_ae_loss:0.0466
# epoch [762/50000] ae_loss:0.0365 val_ae_loss:0.0438 test_ae_loss:0.0515
# epoch [763/50000] ae_loss:0.0376 val_ae_loss:0.0290 test_ae_loss:0.0421
# epoch [764/50000] ae_loss:0.0390 val_ae_loss:0.0381 test_ae_loss:0.0565
# epoch [765/50000] ae_loss:0.0359 val_ae_loss:0.0383 test_ae_loss:0.0412
# epoch [766/50000] ae_loss:0.0360 val_ae_loss:0.0444 test_ae_loss:0.0394
# epoch [767/50000] ae_loss:0.0372 val_ae_loss:0.0329 test_ae_loss:0.0393
# epoch [768/50000] ae_loss:0.0378 val_ae_loss:0.0443 test_ae_loss:0.0545
# epoch [769/50000] ae_loss:0.0389 val_ae_loss:0.0459 test_ae_loss:0.0503
# epoch [770/50000] ae_loss:0.0372 val_ae_loss:0.0460 test_ae_loss:0.0611
# epoch [771/50000] ae_loss:0.0356 val_ae_loss:0.0409 test_ae_loss:0.0561
# epoch [772/50000] ae_loss:0.0375 val_ae_loss:0.0402 test_ae_loss:0.0436
# epoch [773/50000] ae_loss:0.0356 val_ae_loss:0.0376 test_ae_loss:0.0460
# epoch [774/50000] ae_loss:0.0362 val_ae_loss:0.0308 test_ae_loss:0.0394
# epoch [775/50000] ae_loss:0.0372 val_ae_loss:0.0400 test_ae_loss:0.0415
# epoch [776/50000] ae_loss:0.0368 val_ae_loss:0.0361 test_ae_loss:0.0357
# epoch [777/50000] ae_loss:0.0363 val_ae_loss:0.0414 test_ae_loss:0.0446
# epoch [778/50000] ae_loss:0.0380 val_ae_loss:0.0402 test_ae_loss:0.0419
# epoch [779/50000] ae_loss:0.0361 val_ae_loss:0.0382 test_ae_loss:0.0465
# epoch [780/50000] ae_loss:0.0390 val_ae_loss:0.0401 test_ae_loss:0.0431
# epoch [781/50000] ae_loss:0.0370 val_ae_loss:0.0368 test_ae_loss:0.0348
# epoch [782/50000] ae_loss:0.0372 val_ae_loss:0.0398 test_ae_loss:0.0540
# epoch [783/50000] ae_loss:0.0360 val_ae_loss:0.0420 test_ae_loss:0.0515
# epoch [784/50000] ae_loss:0.0374 val_ae_loss:0.0382 test_ae_loss:0.0448
# epoch [785/50000] ae_loss:0.0377 val_ae_loss:0.0432 test_ae_loss:0.0499
# epoch [786/50000] ae_loss:0.0380 val_ae_loss:0.0393 test_ae_loss:0.0488
# epoch [787/50000] ae_loss:0.0382 val_ae_loss:0.0341 test_ae_loss:0.0416
# epoch [788/50000] ae_loss:0.0367 val_ae_loss:0.0319 test_ae_loss:0.0396
# epoch [789/50000] ae_loss:0.0366 val_ae_loss:0.0384 test_ae_loss:0.0337
# epoch [790/50000] ae_loss:0.0353 val_ae_loss:0.0442 test_ae_loss:0.0566
# epoch [791/50000] ae_loss:0.0367 val_ae_loss:0.0390 test_ae_loss:0.0474
# epoch [792/50000] ae_loss:0.0360 val_ae_loss:0.0473 test_ae_loss:0.0358
# epoch [793/50000] ae_loss:0.0371 val_ae_loss:0.0321 test_ae_loss:0.0539
# epoch [794/50000] ae_loss:0.0378 val_ae_loss:0.0335 test_ae_loss:0.0428
# epoch [795/50000] ae_loss:0.0369 val_ae_loss:0.0348 test_ae_loss:0.0551
# epoch [796/50000] ae_loss:0.0371 val_ae_loss:0.0425 test_ae_loss:0.0356
# epoch [797/50000] ae_loss:0.0366 val_ae_loss:0.0501 test_ae_loss:0.0395
# epoch [798/50000] ae_loss:0.0384 val_ae_loss:0.0398 test_ae_loss:0.0500
# epoch [799/50000] ae_loss:0.0376 val_ae_loss:0.0387 test_ae_loss:0.0358
# epoch [800/50000] ae_loss:0.0358 val_ae_loss:0.0370 test_ae_loss:0.0513
# epoch [801/50000] ae_loss:0.0371 val_ae_loss:0.0375 test_ae_loss:0.0534
# epoch [802/50000] ae_loss:0.0362 val_ae_loss:0.0406 test_ae_loss:0.0477
# epoch [803/50000] ae_loss:0.0367 val_ae_loss:0.0453 test_ae_loss:0.0492
# epoch [804/50000] ae_loss:0.0370 val_ae_loss:0.0361 test_ae_loss:0.0307
# epoch [805/50000] ae_loss:0.0378 val_ae_loss:0.0450 test_ae_loss:0.0391
# epoch [806/50000] ae_loss:0.0354 val_ae_loss:0.0401 test_ae_loss:0.0380
# epoch [807/50000] ae_loss:0.0379 val_ae_loss:0.0361 test_ae_loss:0.0575
# epoch [808/50000] ae_loss:0.0377 val_ae_loss:0.0434 test_ae_loss:0.0492
# epoch [809/50000] ae_loss:0.0374 val_ae_loss:0.0360 test_ae_loss:0.0512
# epoch [810/50000] ae_loss:0.0394 val_ae_loss:0.0402 test_ae_loss:0.0499
# epoch [811/50000] ae_loss:0.0361 val_ae_loss:0.0368 test_ae_loss:0.0584
# epoch [812/50000] ae_loss:0.0384 val_ae_loss:0.0428 test_ae_loss:0.0511
# epoch [813/50000] ae_loss:0.0366 val_ae_loss:0.0299 test_ae_loss:0.0396
# epoch [814/50000] ae_loss:0.0357 val_ae_loss:0.0383 test_ae_loss:0.0491
# epoch [815/50000] ae_loss:0.0358 val_ae_loss:0.0385 test_ae_loss:0.0538
# epoch [816/50000] ae_loss:0.0375 val_ae_loss:0.0368 test_ae_loss:0.0524
# epoch [817/50000] ae_loss:0.0377 val_ae_loss:0.0405 test_ae_loss:0.0473
# epoch [818/50000] ae_loss:0.0368 val_ae_loss:0.0403 test_ae_loss:0.0569
# epoch [819/50000] ae_loss:0.0368 val_ae_loss:0.0428 test_ae_loss:0.0414
# epoch [820/50000] ae_loss:0.0368 val_ae_loss:0.0401 test_ae_loss:0.0428
# epoch [821/50000] ae_loss:0.0368 val_ae_loss:0.0442 test_ae_loss:0.0443
# epoch [822/50000] ae_loss:0.0364 val_ae_loss:0.0359 test_ae_loss:0.0568
# epoch [823/50000] ae_loss:0.0375 val_ae_loss:0.0412 test_ae_loss:0.0347
# epoch [824/50000] ae_loss:0.0364 val_ae_loss:0.0453 test_ae_loss:0.0519
# epoch [825/50000] ae_loss:0.0367 val_ae_loss:0.0442 test_ae_loss:0.0549
# epoch [826/50000] ae_loss:0.0373 val_ae_loss:0.0348 test_ae_loss:0.0567
# epoch [827/50000] ae_loss:0.0374 val_ae_loss:0.0392 test_ae_loss:0.0412
# epoch [828/50000] ae_loss:0.0363 val_ae_loss:0.0374 test_ae_loss:0.0426
# epoch [829/50000] ae_loss:0.0367 val_ae_loss:0.0394 test_ae_loss:0.0491
# epoch [830/50000] ae_loss:0.0360 val_ae_loss:0.0366 test_ae_loss:0.0477
# epoch [831/50000] ae_loss:0.0375 val_ae_loss:0.0348 test_ae_loss:0.0378
# epoch [832/50000] ae_loss:0.0371 val_ae_loss:0.0462 test_ae_loss:0.0424
# epoch [833/50000] ae_loss:0.0380 val_ae_loss:0.0466 test_ae_loss:0.0414
# epoch [834/50000] ae_loss:0.0370 val_ae_loss:0.0325 test_ae_loss:0.0445
# epoch [835/50000] ae_loss:0.0364 val_ae_loss:0.0422 test_ae_loss:0.0503
# epoch [836/50000] ae_loss:0.0366 val_ae_loss:0.0450 test_ae_loss:0.0355
# epoch [837/50000] ae_loss:0.0366 val_ae_loss:0.0352 test_ae_loss:0.0444
# epoch [838/50000] ae_loss:0.0378 val_ae_loss:0.0408 test_ae_loss:0.0400
# epoch [839/50000] ae_loss:0.0368 val_ae_loss:0.0392 test_ae_loss:0.0509
# epoch [840/50000] ae_loss:0.0377 val_ae_loss:0.0443 test_ae_loss:0.0443
# epoch [841/50000] ae_loss:0.0369 val_ae_loss:0.0400 test_ae_loss:0.0558
# epoch [842/50000] ae_loss:0.0384 val_ae_loss:0.0382 test_ae_loss:0.0561
# epoch [843/50000] ae_loss:0.0364 val_ae_loss:0.0412 test_ae_loss:0.0394
# epoch [844/50000] ae_loss:0.0359 val_ae_loss:0.0392 test_ae_loss:0.0448
# epoch [845/50000] ae_loss:0.0392 val_ae_loss:0.0335 test_ae_loss:0.0549
# epoch [846/50000] ae_loss:0.0364 val_ae_loss:0.0384 test_ae_loss:0.0407
# epoch [847/50000] ae_loss:0.0372 val_ae_loss:0.0398 test_ae_loss:0.0459
# epoch [848/50000] ae_loss:0.0365 val_ae_loss:0.0461 test_ae_loss:0.0612
# epoch [849/50000] ae_loss:0.0373 val_ae_loss:0.0397 test_ae_loss:0.0498
# epoch [850/50000] ae_loss:0.0374 val_ae_loss:0.0384 test_ae_loss:0.0382
# epoch [851/50000] ae_loss:0.0366 val_ae_loss:0.0330 test_ae_loss:0.0509
# epoch [852/50000] ae_loss:0.0371 val_ae_loss:0.0348 test_ae_loss:0.0496
# epoch [853/50000] ae_loss:0.0362 val_ae_loss:0.0385 test_ae_loss:0.0585
# epoch [854/50000] ae_loss:0.0364 val_ae_loss:0.0337 test_ae_loss:0.0496
# epoch [855/50000] ae_loss:0.0368 val_ae_loss:0.0319 test_ae_loss:0.0579
# epoch [856/50000] ae_loss:0.0376 val_ae_loss:0.0362 test_ae_loss:0.0473
# epoch [857/50000] ae_loss:0.0377 val_ae_loss:0.0356 test_ae_loss:0.0430
# epoch [858/50000] ae_loss:0.0374 val_ae_loss:0.0370 test_ae_loss:0.0307
# epoch [859/50000] ae_loss:0.0359 val_ae_loss:0.0403 test_ae_loss:0.0488
# epoch [860/50000] ae_loss:0.0352 val_ae_loss:0.0384 test_ae_loss:0.0305
# epoch [861/50000] ae_loss:0.0383 val_ae_loss:0.0365 test_ae_loss:0.0705
# epoch [862/50000] ae_loss:0.0379 val_ae_loss:0.0330 test_ae_loss:0.0392
# epoch [863/50000] ae_loss:0.0367 val_ae_loss:0.0425 test_ae_loss:0.0421
# epoch [864/50000] ae_loss:0.0366 val_ae_loss:0.0345 test_ae_loss:0.0569
# epoch [865/50000] ae_loss:0.0408 val_ae_loss:0.0359 test_ae_loss:0.0396
# epoch [866/50000] ae_loss:0.0347 val_ae_loss:0.0405 test_ae_loss:0.0448
# epoch [867/50000] ae_loss:0.0365 val_ae_loss:0.0409 test_ae_loss:0.0508
# epoch [868/50000] ae_loss:0.0375 val_ae_loss:0.0339 test_ae_loss:0.0450
# epoch [869/50000] ae_loss:0.0367 val_ae_loss:0.0321 test_ae_loss:0.0434
# epoch [870/50000] ae_loss:0.0354 val_ae_loss:0.0408 test_ae_loss:0.0494
# epoch [871/50000] ae_loss:0.0384 val_ae_loss:0.0465 test_ae_loss:0.0623
# epoch [872/50000] ae_loss:0.0370 val_ae_loss:0.0327 test_ae_loss:0.0336
# epoch [873/50000] ae_loss:0.0361 val_ae_loss:0.0435 test_ae_loss:0.0426
# epoch [874/50000] ae_loss:0.0364 val_ae_loss:0.0358 test_ae_loss:0.0428
# epoch [875/50000] ae_loss:0.0354 val_ae_loss:0.0401 test_ae_loss:0.0614
# epoch [876/50000] ae_loss:0.0386 val_ae_loss:0.0404 test_ae_loss:0.0355
# epoch [877/50000] ae_loss:0.0372 val_ae_loss:0.0421 test_ae_loss:0.0443
# epoch [878/50000] ae_loss:0.0361 val_ae_loss:0.0321 test_ae_loss:0.0378
# epoch [879/50000] ae_loss:0.0353 val_ae_loss:0.0399 test_ae_loss:0.0548
# epoch [880/50000] ae_loss:0.0389 val_ae_loss:0.0392 test_ae_loss:0.0561
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-6-942a09966249>", line 12, in <module>
#     ae_loss.backward()
#   File "/opt/conda/lib/python3.7/site-packages/torch/tensor.py", line 185, in backward
#     torch.autograd.backward(self, gradient, retain_graph, create_graph)
#   File "/opt/conda/lib/python3.7/site-packages/torch/autograd/__init__.py", line 127, in backward
#     allow_unreachable=True)  # allow_unreachable flag
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/opt/conda/lib/python3.7/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/opt/conda/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/opt/conda/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/opt/conda/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/opt/conda/lib/python3.7/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
# KeyboardInterrupt
# KeyboardInterruptTraceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-6-942a09966249> in <module>
#      11         optimizer_AE.zero_grad()
# ---> 12         ae_loss.backward()
#      13         optimizer_AE.step()
#
# /opt/conda/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     184         """
# --> 185         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     186
#
# /opt/conda/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     126         tensors, grad_tensors, retain_graph, create_graph,
# --> 127         allow_unreachable=True)  # allow_unreachable flag
#     128
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeErrorTraceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2043                         # in the engines. This should return a list of strings.
# -> 2044                         stb = value._render_traceback_()
#    2045                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeErrorTraceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2045                     except Exception:
#    2046                         stb = self.InteractiveTB.structured_traceback(etype,
# -> 2047                                             value, tb, tb_offset=tb_offset)
#    2048
#    2049                     self._showtraceback(etype, value, stb)
#
# /opt/conda/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1434             self.tb = tb
#    1435         return FormattedTB.structured_traceback(
# -> 1436             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1437
#    1438
#
# /opt/conda/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1334             # Verbose modes need a full traceback
#    1335             return VerboseTB.structured_traceback(
# -> 1336                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1337             )
#    1338         elif mode == 'Minimal':
#
# /opt/conda/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1191
#    1192         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
# -> 1193                                                                tb_offset)
#    1194
#    1195         colors = self.Colors  # just a shorthand + quicker name lookup
#
# /opt/conda/lib/python3.7/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1148
#    1149
# -> 1150         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1151
#    1152         frames = self.format_records(records, last_unique, recursion_repeat)
#
# /opt/conda/lib/python3.7/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     449     # first frame (from in to out) that looks different.
#     450     if not is_recursion_error(etype, value, records):
# --> 451         return len(records), 0
#     452
#     453     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %%
AE.eval()
S.eval()
for index, img in enumerate(test_loader):
    test_img = Variable(img[0]).cuda(device_id)

    # ======AE======
    blur_image = AE(test_img)
    
    noise = torch.zeros(blur_image.shape[0], 1, blur_image.shape[2], blur_image.shape[3] )
    noise = noise + (0.01**0.5)*torch.randn(blur_image.shape[0], 1, blur_image.shape[2], blur_image.shape[3])
    noise = noise.cuda(device_id)
    blur_image_with_noise = torch.cat([blur_image, noise], 1)
    fake_image = S(blur_image_with_noise)
    
    
    vutils.save_image(fake_image[0], './test_result/{}_simulated.png'.format(index))
    vutils.save_image(blur_image[0], './test_result/{}_blur.png'.format(index))
    vutils.save_image(test_img, './test_result/{}_origin.png'.format(index))
