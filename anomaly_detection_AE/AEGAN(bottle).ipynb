# %%
import sys
sys.path.append('../')

import os
import time
import numpy as np

from torch.utils.data import DataLoader
from torch.autograd import Variable
from torch import autograd

import torch
import torch.nn as nn
import torch.nn.functional as F


from utils.tools import get_config, default_loader, is_image_file, normalize
from tensorboardX import SummaryWriter
import matplotlib.pyplot as plt
import torchvision.utils as vutils

from sklearn.metrics import roc_auc_score
sys.path.append('../PerceptualSimilarity')
import models as PerceptualSimilarity

# personal library
from networks import autoencoder, simulator, discriminator
from dataloader import MVTecDataset

# %%
# 限制可以使用的 GPU
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0,1"

# %%
# HYPER parameters
num_epochs = 50000
batch_size = 32
val_batch_size = 4
ae_lr = 1e-4
s_lr = 5e-4
d_lr = 5e-4
weight_decay = 1e-5
UPSET=True
expName = 'AEGAN-exp(bottle + L1)'
writer = SummaryWriter('checkpoints/'+expName)
TYPE='bottle'

# %%
trainDatset = MVTecDataset.MVTecDataset(TYPE=TYPE, isTrain='train')
testDatset = MVTecDataset.MVTecDataset(TYPE=TYPE, isTrain='test')
valDataset = MVTecDataset.MVTecDataset(TYPE=TYPE, isTrain='val')

val_loader = DataLoader(
    dataset=valDataset,
    batch_size=val_batch_size, 
    shuffle=True,
    num_workers=4
)
train_loader = DataLoader(
    dataset=trainDatset,
    batch_size=batch_size, 
    shuffle=True,
    num_workers=4
)
test_loader = DataLoader(
    dataset=testDatset,
    batch_size=1,
    shuffle=True,
    num_workers=4
)

# %%
# Model
AE = autoencoder.Autoencoder().cuda()
S = nn.DataParallel(simulator.Simulator(3, 8)).cuda()
D = nn.DataParallel(discriminator.Discriminator(6, 16)).cuda()

# Loss
L1_loss = nn.L1Loss()
L2_loss = nn.MSELoss(reduction='none')
perceptual_loss = PerceptualSimilarity.PerceptualLoss(model='net-lin', net='alex', use_gpu=True, gpu_ids=[0])

# Optimizer
optimizer_AE = torch.optim.Adam(
    AE.parameters(), 
    lr=ae_lr,
    weight_decay=weight_decay
)
optimizer_S = torch.optim.Adam(
    S.parameters(), 
    lr=s_lr,
    weight_decay=weight_decay
)
optimizer_D = torch.optim.Adam(
    D.parameters(), 
    lr=d_lr,
    weight_decay=weight_decay
)


Tensor = torch.cuda.FloatTensor
# Out:
# Setting up Perceptual loss...
# Loading model from: /root/AFS/Corn/AEGAN/PerceptualSimilarity/models/weights/v0.1/alex.pth
# ...[net-lin [alex]] initialized
# ...Done

# %%
AE.load_state_dict(torch.load('./save_weight/AE-bottle-z-2x2-exp1/AE_11000.npy', map_location="cuda:0"), False)

AE = nn.DataParallel(AE)

# %%
# To Solve: RuntimeError: cuDNN error: CUDNN_STATUS_EXECUTION_FAILED
torch.backends.cudnn.enabled = False 

# 拿掉煩人的 warning
import warnings
warnings.filterwarnings("ignore")

# %%
LAMBDA = 10

def calc_gradient_penalty(netD, real_data, fake_data):
    # print "real_data: ", real_data.size(), fake_data.size()
    BATCH_SIZE = real_data.size(0)
    alpha = torch.rand(BATCH_SIZE, 1)
    alpha = alpha.expand(BATCH_SIZE, real_data.nelement()//BATCH_SIZE).contiguous().view(BATCH_SIZE, 6, 256, 256)
    alpha = alpha.cuda()

    interpolates = alpha * real_data + ((1 - alpha) * fake_data)

    interpolates = interpolates.cuda()
    interpolates = autograd.Variable(interpolates, requires_grad=True)

    disc_interpolates = netD(interpolates)

    gradients = autograd.grad(
        outputs=disc_interpolates, 
        inputs=interpolates,
        grad_outputs=torch.ones(disc_interpolates.size()).cuda(),
        create_graph=True, 
        retain_graph=True, 
        only_inputs=True
    )[0]
    gradients = gradients.view(gradients.size(0), -1)

    gradient_penalty = ((gradients.norm(2, dim=1) - 1) ** 2).mean() * LAMBDA
    return gradient_penalty

def difNormalize(input_matrix, threshold=None):
    _min = torch.min(input_matrix)
    _max = torch.max(input_matrix)
    
    input_matrix = (input_matrix - _min) / (_max - _min)
    
    if threshold != None:
        input_matrix[input_matrix < threshold] = 0
        input_matrix[input_matrix >= threshold] = 1
        
    return input_matrix

def gradient_loss(gen_frames, gt_frames, alpha=1):
    def gradient(x):
        h_x = x.size()[-2]
        w_x = x.size()[-1]
        # gradient step=1
        left = x
        right = F.pad(x, [0, 1, 0, 0])[:, :, :, 1:]
        top = x
        bottom = F.pad(x, [0, 0, 0, 1])[:, :, 1:, :]

        # dx, dy = torch.abs(right - left), torch.abs(bottom - top)
        dx, dy = right - left, bottom - top 
        # dx will always have zeros in the last column, right-left
        # dy will always have zeros in the last row,    bottom-top
        dx[:, :, :, -1] = 0
        dy[:, :, -1, :] = 0

        return dx, dy

    # gradient
    gen_dx, gen_dy = gradient(gen_frames)
    gt_dx, gt_dy = gradient(gt_frames)
    #
    grad_diff_x = torch.abs(gt_dx - gen_dx)
    grad_diff_y = torch.abs(gt_dy - gen_dy)

    # condense into one tensor and avg
    return torch.mean(grad_diff_x ** alpha + grad_diff_y ** alpha)

# %%
heightest_score = 0
for epoch in range(num_epochs): 
    start = time.time()
    ######## GAN ################
    one = torch.FloatTensor([1])
    mone = one * -1
    
    one = one.cuda()
    mone = mone.cuda()
    
    one = one.mean()
    mone = mone.mean()
    ## ==== GAN --> D =====
    for i in range(3):
        for index, img in enumerate(train_loader):
            AE.eval(), S.train(), D.train()

            img = Variable(img).cuda()

            # ====== AE ======
            blur_image = AE(img)

            _bs, _c, _w, _h = blur_image.shape
            noise = torch.zeros(_bs, 1, _w, _h )
            noise = noise + (0.01**0.5)*torch.randn(_bs, 1, _w, _h)
            noise = noise.cuda()

            blur_image_with_noise = torch.cat([blur_image, noise], 1)
            fake_image = S(blur_image_with_noise) # 當成是 residual
            
            fake_image = fake_image + blur_image # blur image + residual
            
            fake_pair = torch.cat([img, fake_image], 1)
            real_pair = torch.cat([img, img[torch.randperm(img.size(0)), :, :, :]], 1) if UPSET else torch.cat([img, img], 1)
            # ====== Train D ======
            for p in D.parameters():
                p.requires_grad = True

            optimizer_AE.zero_grad()
            optimizer_S.zero_grad()
            optimizer_D.zero_grad()


            real_D = D(real_pair)
            real_D = real_D.mean()
            real_D.backward(mone)


            fake_D = D(fake_pair)
            fake_D = fake_D.mean()
            fake_D.backward(one)

            gradient_penalty = calc_gradient_penalty(D, real_pair, fake_pair)
            gradient_penalty.backward()

            cost_D = fake_D - real_D + gradient_penalty
            Wasserstein_D = real_D - fake_D
            optimizer_D.step()
    
    ## ==== GAN --> G =====
    for index, img in enumerate(train_loader):
        AE.eval(), S.train(), D.train()

        img = Variable(img).cuda()
        # ======AE======
        blur_image = AE(img)

        _bs, _c, _w, _h = blur_image.shape
        noise = torch.zeros(_bs, 1, _w, _h )
        noise = noise + (0.01**0.5)*torch.randn(_bs, 1, _w, _h)
        noise = noise.cuda()

        blur_image_with_noise = torch.cat([blur_image, noise], 1)
        fake_image = S(blur_image_with_noise)
        
        fake_image = fake_image + blur_image
        
        fake_pair = torch.cat([img, fake_image], 1)
        # ====== Train G ======
        for p in D.parameters():
            p.requires_grad = False
            
        G_L1 = L1_loss(img, fake_image)
        G = D(fake_pair)
        G = G.mean()
        G = G + G_L1 * ( G / G_L1) * 100
        
        optimizer_AE.zero_grad()
        optimizer_S.zero_grad()
        optimizer_D.zero_grad()
        
        G.backward(mone)
        
        cost_G = -G
        optimizer_S.step()
        
    
    # validation set
    for index, val_img in enumerate(val_loader):
        AE.eval(), S.eval(), D.eval()

        val_img = Variable(val_img).cuda()
        # ======AE======
        val_blur_image = AE(val_img)

        _bs, _c, _w, _h = val_blur_image.shape
        noise = torch.zeros(_bs, 1, _w, _h )
        noise = noise + (0.01**0.5)*torch.randn(_bs, 1, _w, _h)
        noise = noise.cuda()

        val_blur_image_with_noise = torch.cat([val_blur_image, noise], 1)

        val_fake_image = S(val_blur_image_with_noise)       
        val_fake_image = val_fake_image + val_blur_image
        
        
        val_fake_pair = torch.cat([val_img, val_fake_image], 1)
        val_real_pair = torch.cat([val_img, val_img[torch.randperm(val_img.size(0)), :, :, :]], 1) if UPSET else torch.cat([val_img, val_img], 1)
        
        val_real_D = D(val_real_pair)
        val_real_D = val_real_D.mean()
        
        val_fake_D = D(val_fake_pair)
        val_fake_D = val_fake_D.mean()
        
        val_gradient_penalty = calc_gradient_penalty(D, val_real_pair, val_fake_pair)
        
        val_grad_loss = gradient_loss(val_fake_image, val_img)
        val_G_L1 = L1_loss(val_img, val_fake_image)
        # =========== Losses =========
        val_Wasserstein_D = val_real_D - val_fake_D
        
        val_cost_G = -val_fake_D
        val_cost_D = val_fake_D - val_real_D + val_gradient_penalty
    
    # evaluate
    test_total_AUC = 0
    test_total_AUC2 = 0
    test_total_image = 0

    for index, (test_img, mask) in enumerate(test_loader):
        AE.eval(), S.eval(), D.eval()
        test_img = Variable(test_img).cuda()
        test_blur_image = AE(test_img)

        _bs, _c, _w, _h = test_blur_image.shape
        noise = torch.zeros(_bs, 1, _w, _h )
        noise = noise + (0.01**0.5)*torch.randn(_bs, 1, _w, _h)
        noise = noise.cuda()

        test_blur_image_with_noise = torch.cat([test_blur_image, noise], 1)

        test_fake_image = S(test_blur_image_with_noise)       
        test_fake_image = test_fake_image + test_blur_image

        # 計算 dif (相似度以及 L2)
        dif, _ = perceptual_loss.forward(test_fake_image, test_img)
        l2Dif = L2_loss(test_fake_image, test_img)
        l2Dif = torch.mean(l2Dif, 1, True)
        
        pred_mask2 = difNormalize(dif)
        pred_mask2 = torch.flatten(pred_mask2[0])
        
        pred_mask = difNormalize(dif[0] * l2Dif[0])
        pred_mask = torch.flatten(pred_mask)
        
        mask = torch.mean(mask, 1, True)
        true_mask = mask[0].cpu().detach().numpy().flatten()
        true_mask = true_mask.astype(int)

        AUC = roc_auc_score(true_mask, pred_mask.cpu().detach().numpy())
        AUC2 = roc_auc_score(true_mask, pred_mask2.cpu().detach().numpy())

        test_total_AUC += AUC
        test_total_AUC2 += AUC2
        test_total_image += 1
    if heightest_score < (test_total_AUC / test_total_image) :
        heightest_score = (test_total_AUC / test_total_image)
    # =================== GAN log========================
    end = time.time()
    print('epoch [{}/{}] s_loss:{:.4f} d_loss:{:.4f} val_s_loss:{:.4f} val_d_loss:{:.4f} heightest auc:{:.2f} cost:{:.2f}'.format(epoch+1, num_epochs, cost_G.item(), cost_D.item(), val_cost_G.item(), val_cost_D.item(), heightest_score, end-start ))
    writer.add_scalars('eval', {
        "auc_roc_score": test_total_AUC / test_total_image,
        "auc_roc_score(w/o L2)": test_total_AUC2 / test_total_image,
        "heightest roc_score": heightest_score
    }, epoch)
    
    writer.add_scalars('loss', {
        "Wasserstein Distance": Wasserstein_D.item(),
        "Val Wasserstein Distance": val_Wasserstein_D.item(),
        "gradient penalty": gradient_penalty,
        "val gradient penalty": val_gradient_penalty
    }, epoch)
    
    writer.add_scalars('gan loss', {
        "l1_loss": G_L1.item(),
        "g_loss": cost_G.item(),
        "d_loss": cost_D.item(),
        "val_l1_loss": val_G_L1.item(),
        "val_g_loss": val_cost_G.item(),
        "val_d_loss": val_cost_D.item()
    }, epoch)

    writer.add_images('Blur', blur_image, epoch)
    writer.add_images('Reconstruct', fake_image, epoch)
    writer.add_images('Origin', img, epoch)

    writer.add_images('Val Blur', val_blur_image, epoch)
    writer.add_images('Val Reconstruct', val_fake_image, epoch)
    writer.add_images('Val Origin', val_img, epoch)


        
    if epoch % 10 == 0:
        if not os.path.exists('./save_weight/{}'.format(expName)):
            os.makedirs('./save_weight/{}'.format(expName))
        torch.save(S.state_dict(), './save_weight/{}/S_{}.npy'.format(expName, epoch))
        torch.save(D.state_dict(), './save_weight/{}/D_{}.npy'.format(expName, epoch))
# Out:
# epoch [1/50000] s_loss:-27732.9492 d_loss:-113.6210 val_s_loss:135.1258 val_d_loss:-24.1200 heightest auc:0.71 cost:22.07
# epoch [2/50000] s_loss:44280.3359 d_loss:-257.3133 val_s_loss:463.2817 val_d_loss:-178.1200 heightest auc:0.71 cost:16.64
# epoch [3/50000] s_loss:158321.8438 d_loss:-603.4503 val_s_loss:2010.5254 val_d_loss:-664.9491 heightest auc:0.71 cost:16.07
# epoch [4/50000] s_loss:94840.2812 d_loss:-415.7206 val_s_loss:547.6414 val_d_loss:455.0285 heightest auc:0.71 cost:16.06
# epoch [5/50000] s_loss:73793.9297 d_loss:-242.8197 val_s_loss:709.0756 val_d_loss:-117.1889 heightest auc:0.71 cost:15.38
# epoch [6/50000] s_loss:160388.0938 d_loss:-374.1095 val_s_loss:1537.0756 val_d_loss:-214.2070 heightest auc:0.71 cost:16.69
# epoch [7/50000] s_loss:175262.4688 d_loss:-480.8354 val_s_loss:1820.4497 val_d_loss:-409.8997 heightest auc:0.71 cost:17.02
# epoch [8/50000] s_loss:131604.7969 d_loss:-417.5418 val_s_loss:1511.8829 val_d_loss:-447.3179 heightest auc:0.71 cost:17.40
# epoch [9/50000] s_loss:89027.7812 d_loss:-308.6697 val_s_loss:1007.7612 val_d_loss:-358.3318 heightest auc:0.71 cost:16.63
# epoch [10/50000] s_loss:74613.7031 d_loss:-273.3103 val_s_loss:835.2427 val_d_loss:-315.9950 heightest auc:0.71 cost:16.75
# epoch [11/50000] s_loss:72263.6172 d_loss:-267.7918 val_s_loss:940.1633 val_d_loss:-428.4473 heightest auc:0.71 cost:17.43
# epoch [12/50000] s_loss:60755.9062 d_loss:-224.6751 val_s_loss:583.8240 val_d_loss:-171.0042 heightest auc:0.72 cost:17.15
# epoch [13/50000] s_loss:57533.3203 d_loss:-213.2984 val_s_loss:572.6940 val_d_loss:-173.0763 heightest auc:0.72 cost:17.23
# epoch [14/50000] s_loss:59904.3320 d_loss:-238.6483 val_s_loss:609.1760 val_d_loss:-206.3972 heightest auc:0.72 cost:17.47
# epoch [15/50000] s_loss:60515.6758 d_loss:-253.9743 val_s_loss:629.8625 val_d_loss:-269.3570 heightest auc:0.72 cost:17.99
# epoch [16/50000] s_loss:63652.4648 d_loss:-273.2197 val_s_loss:520.3569 val_d_loss:-85.4726 heightest auc:0.72 cost:17.93
# epoch [17/50000] s_loss:61878.2930 d_loss:-309.7029 val_s_loss:649.4348 val_d_loss:-156.8469 heightest auc:0.72 cost:18.07
# epoch [18/50000] s_loss:63784.7773 d_loss:-226.6748 val_s_loss:610.7603 val_d_loss:-189.2668 heightest auc:0.77 cost:17.69
# epoch [19/50000] s_loss:62890.1445 d_loss:-250.0535 val_s_loss:621.7557 val_d_loss:-233.7347 heightest auc:0.77 cost:17.08
# epoch [20/50000] s_loss:44220.0625 d_loss:-245.5979 val_s_loss:422.7770 val_d_loss:-169.1278 heightest auc:0.77 cost:18.33
# epoch [21/50000] s_loss:49625.4844 d_loss:-220.7269 val_s_loss:535.0546 val_d_loss:-218.0664 heightest auc:0.77 cost:17.77
# epoch [22/50000] s_loss:43695.5742 d_loss:-216.9889 val_s_loss:478.9805 val_d_loss:-252.5990 heightest auc:0.77 cost:17.61
# epoch [23/50000] s_loss:41433.5195 d_loss:-200.8954 val_s_loss:420.8021 val_d_loss:-182.1667 heightest auc:0.77 cost:16.88
# epoch [24/50000] s_loss:41552.5664 d_loss:-192.9470 val_s_loss:345.2933 val_d_loss:-116.6841 heightest auc:0.81 cost:17.39
# epoch [25/50000] s_loss:39760.5273 d_loss:-183.0220 val_s_loss:326.4417 val_d_loss:-93.8134 heightest auc:0.84 cost:16.48
# epoch [26/50000] s_loss:36548.0625 d_loss:-166.1586 val_s_loss:308.8188 val_d_loss:-99.0416 heightest auc:0.84 cost:17.04
# epoch [27/50000] s_loss:35876.5820 d_loss:-160.6289 val_s_loss:433.9328 val_d_loss:-216.9053 heightest auc:0.84 cost:17.01
# epoch [28/50000] s_loss:33506.2070 d_loss:-147.3596 val_s_loss:264.3709 val_d_loss:-68.2021 heightest auc:0.84 cost:17.10
# epoch [29/50000] s_loss:27827.0020 d_loss:-139.0487 val_s_loss:191.0222 val_d_loss:-45.6322 heightest auc:0.84 cost:18.20
# epoch [30/50000] s_loss:31655.2734 d_loss:-155.3445 val_s_loss:466.0817 val_d_loss:-265.7593 heightest auc:0.84 cost:17.72
# epoch [31/50000] s_loss:20841.0762 d_loss:-129.2712 val_s_loss:223.6096 val_d_loss:-133.2265 heightest auc:0.84 cost:17.93
# epoch [32/50000] s_loss:13900.3916 d_loss:-130.9193 val_s_loss:129.0242 val_d_loss:-113.3186 heightest auc:0.84 cost:17.87
# epoch [33/50000] s_loss:10248.5078 d_loss:-125.0698 val_s_loss:4.0615 val_d_loss:-10.6111 heightest auc:0.87 cost:17.73
# epoch [34/50000] s_loss:16380.0654 d_loss:-107.5398 val_s_loss:85.4796 val_d_loss:-3.5477 heightest auc:0.87 cost:17.50
# epoch [35/50000] s_loss:30057.8672 d_loss:-115.0538 val_s_loss:534.8101 val_d_loss:-314.6588 heightest auc:0.87 cost:17.31
# epoch [36/50000] s_loss:19266.2227 d_loss:-97.2899 val_s_loss:189.4877 val_d_loss:-87.8127 heightest auc:0.87 cost:17.08
# epoch [37/50000] s_loss:5914.6138 d_loss:-97.7207 val_s_loss:64.5214 val_d_loss:-89.7998 heightest auc:0.87 cost:17.08
# epoch [38/50000] s_loss:25275.1738 d_loss:-117.5510 val_s_loss:227.7705 val_d_loss:-60.9335 heightest auc:0.87 cost:18.19
# epoch [39/50000] s_loss:22291.5332 d_loss:-101.5190 val_s_loss:322.2852 val_d_loss:-182.4368 heightest auc:0.87 cost:18.37
# epoch [40/50000] s_loss:9295.3564 d_loss:-87.4980 val_s_loss:178.1162 val_d_loss:-164.9698 heightest auc:0.87 cost:17.49
# epoch [41/50000] s_loss:7228.4751 d_loss:-82.8699 val_s_loss:113.5707 val_d_loss:-114.4761 heightest auc:0.87 cost:17.22
# epoch [42/50000] s_loss:8259.4766 d_loss:-77.2764 val_s_loss:63.0437 val_d_loss:-56.7756 heightest auc:0.87 cost:17.05
# epoch [43/50000] s_loss:10126.0127 d_loss:-83.7916 val_s_loss:47.5686 val_d_loss:-16.7318 heightest auc:0.87 cost:16.92
# epoch [44/50000] s_loss:13655.3701 d_loss:-75.2331 val_s_loss:127.4973 val_d_loss:-53.9116 heightest auc:0.87 cost:17.57
# epoch [45/50000] s_loss:5032.6592 d_loss:-66.3875 val_s_loss:32.9832 val_d_loss:-40.2912 heightest auc:0.87 cost:18.02
# epoch [46/50000] s_loss:6971.1436 d_loss:-63.8738 val_s_loss:61.3286 val_d_loss:-46.8962 heightest auc:0.87 cost:17.86
# epoch [47/50000] s_loss:8757.7891 d_loss:-59.8865 val_s_loss:82.7166 val_d_loss:-46.4019 heightest auc:0.87 cost:18.28
# epoch [48/50000] s_loss:8940.4502 d_loss:-55.6362 val_s_loss:82.0862 val_d_loss:-40.6723 heightest auc:0.87 cost:17.31
# epoch [49/50000] s_loss:7599.5073 d_loss:-55.9994 val_s_loss:72.1180 val_d_loss:-47.0063 heightest auc:0.87 cost:17.43
# epoch [50/50000] s_loss:8486.8076 d_loss:-56.8885 val_s_loss:119.8461 val_d_loss:-82.3863 heightest auc:0.87 cost:17.47
# epoch [51/50000] s_loss:9193.3770 d_loss:-58.0482 val_s_loss:87.2585 val_d_loss:-49.6817 heightest auc:0.87 cost:16.82
# epoch [52/50000] s_loss:4567.9756 d_loss:-54.7701 val_s_loss:42.4521 val_d_loss:-52.8385 heightest auc:0.87 cost:16.41
# epoch [53/50000] s_loss:2233.7668 d_loss:-56.5839 val_s_loss:16.2165 val_d_loss:-46.4318 heightest auc:0.87 cost:16.83
# epoch [54/50000] s_loss:4611.8042 d_loss:-53.8620 val_s_loss:49.8478 val_d_loss:-48.0034 heightest auc:0.87 cost:17.09
# epoch [55/50000] s_loss:4686.8877 d_loss:-51.7609 val_s_loss:53.4874 val_d_loss:-53.7298 heightest auc:0.87 cost:16.88
# epoch [56/50000] s_loss:311.3465 d_loss:-48.4426 val_s_loss:26.3546 val_d_loss:-73.5995 heightest auc:0.87 cost:18.30
# epoch [57/50000] s_loss:3316.2788 d_loss:-50.9856 val_s_loss:35.1604 val_d_loss:-48.2017 heightest auc:0.87 cost:17.72
# epoch [58/50000] s_loss:-62.1205 d_loss:-48.9911 val_s_loss:1.9677 val_d_loss:-51.3284 heightest auc:0.87 cost:18.09
# epoch [59/50000] s_loss:463.6751 d_loss:-47.1447 val_s_loss:15.2358 val_d_loss:-53.9499 heightest auc:0.87 cost:17.65
# epoch [60/50000] s_loss:3380.5205 d_loss:-49.7614 val_s_loss:33.4644 val_d_loss:-45.1270 heightest auc:0.87 cost:17.63
# epoch [61/50000] s_loss:1285.7511 d_loss:-47.7218 val_s_loss:16.5273 val_d_loss:-51.5440 heightest auc:0.87 cost:17.97
# epoch [62/50000] s_loss:-446.6331 d_loss:-49.4789 val_s_loss:14.0032 val_d_loss:-59.3082 heightest auc:0.87 cost:17.63
# epoch [63/50000] s_loss:5569.4038 d_loss:-47.5483 val_s_loss:65.7878 val_d_loss:-54.0851 heightest auc:0.87 cost:17.50
# epoch [64/50000] s_loss:3811.4177 d_loss:-48.6287 val_s_loss:38.8318 val_d_loss:-46.6597 heightest auc:0.87 cost:18.04
# epoch [65/50000] s_loss:-595.5471 d_loss:-46.4907 val_s_loss:-11.8929 val_d_loss:-37.0429 heightest auc:0.87 cost:18.53
# epoch [66/50000] s_loss:-765.9259 d_loss:-45.2367 val_s_loss:-12.1369 val_d_loss:-40.2335 heightest auc:0.87 cost:17.70
# epoch [67/50000] s_loss:1497.3661 d_loss:-47.1143 val_s_loss:48.7659 val_d_loss:-77.0023 heightest auc:0.87 cost:17.11
# epoch [68/50000] s_loss:2267.6472 d_loss:-42.9120 val_s_loss:63.0102 val_d_loss:-79.3897 heightest auc:0.87 cost:16.87
# epoch [69/50000] s_loss:685.3517 d_loss:-43.8390 val_s_loss:18.8263 val_d_loss:-51.3610 heightest auc:0.87 cost:16.49
# epoch [70/50000] s_loss:241.3741 d_loss:-41.7356 val_s_loss:0.3385 val_d_loss:-38.5495 heightest auc:0.87 cost:17.10
# epoch [71/50000] s_loss:3775.2559 d_loss:-43.4023 val_s_loss:56.0468 val_d_loss:-58.0130 heightest auc:0.87 cost:16.94
# epoch [72/50000] s_loss:-3193.0881 d_loss:-41.0113 val_s_loss:-34.7156 val_d_loss:-35.6109 heightest auc:0.87 cost:16.83
# epoch [73/50000] s_loss:-2039.0898 d_loss:-46.8009 val_s_loss:-17.9818 val_d_loss:-40.6416 heightest auc:0.87 cost:16.97
# epoch [74/50000] s_loss:3807.1704 d_loss:-41.8484 val_s_loss:43.7172 val_d_loss:-42.3876 heightest auc:0.87 cost:18.43
# epoch [75/50000] s_loss:-800.3442 d_loss:-41.5743 val_s_loss:32.3174 val_d_loss:-81.9435 heightest auc:0.87 cost:18.40
# epoch [76/50000] s_loss:392.4718 d_loss:-42.4900 val_s_loss:6.3338 val_d_loss:-39.5176 heightest auc:0.87 cost:17.75
# epoch [77/50000] s_loss:6524.8081 d_loss:-40.1761 val_s_loss:70.6808 val_d_loss:-43.2671 heightest auc:0.87 cost:17.45
# epoch [78/50000] s_loss:-2048.6665 d_loss:-38.9990 val_s_loss:-19.1451 val_d_loss:-38.0333 heightest auc:0.87 cost:17.38
# epoch [79/50000] s_loss:-2160.2668 d_loss:-39.3080 val_s_loss:0.8738 val_d_loss:-53.4452 heightest auc:0.87 cost:17.59
# epoch [80/50000] s_loss:-1317.3801 d_loss:-38.0596 val_s_loss:-14.8796 val_d_loss:-34.9050 heightest auc:0.87 cost:17.21
# epoch [81/50000] s_loss:558.1086 d_loss:-39.4120 val_s_loss:43.3107 val_d_loss:-74.7975 heightest auc:0.87 cost:17.06
# epoch [82/50000] s_loss:-2152.5701 d_loss:-35.6503 val_s_loss:-22.8759 val_d_loss:-34.2602 heightest auc:0.87 cost:16.85
# epoch [83/50000] s_loss:-2367.7454 d_loss:-35.7564 val_s_loss:-24.8032 val_d_loss:-34.8563 heightest auc:0.87 cost:17.81
# epoch [84/50000] s_loss:679.0341 d_loss:-36.8024 val_s_loss:16.7007 val_d_loss:-42.0956 heightest auc:0.87 cost:17.13
# epoch [85/50000] s_loss:-3339.1838 d_loss:-34.4270 val_s_loss:-31.0449 val_d_loss:-33.5748 heightest auc:0.87 cost:16.97
# epoch [86/50000] s_loss:-1574.7430 d_loss:-34.3663 val_s_loss:-17.0364 val_d_loss:-32.6742 heightest auc:0.87 cost:16.96
# epoch [87/50000] s_loss:-2710.8147 d_loss:-33.4374 val_s_loss:-29.4457 val_d_loss:-29.2607 heightest auc:0.88 cost:16.98
# epoch [88/50000] s_loss:-4619.7964 d_loss:-33.4441 val_s_loss:-46.0538 val_d_loss:-29.3061 heightest auc:0.88 cost:16.82
# epoch [89/50000] s_loss:4178.6113 d_loss:-43.1553 val_s_loss:45.6833 val_d_loss:-32.0883 heightest auc:0.88 cost:17.03
# epoch [90/50000] s_loss:-3436.3438 d_loss:-33.7673 val_s_loss:-36.7747 val_d_loss:-31.5250 heightest auc:0.88 cost:17.95
# epoch [91/50000] s_loss:-5595.8755 d_loss:-35.2941 val_s_loss:-61.0838 val_d_loss:-27.7717 heightest auc:0.88 cost:18.21
# epoch [92/50000] s_loss:-2783.3547 d_loss:-33.7395 val_s_loss:-31.8925 val_d_loss:-25.7096 heightest auc:0.88 cost:18.13
# epoch [93/50000] s_loss:813.4280 d_loss:-36.2355 val_s_loss:46.2579 val_d_loss:-68.6832 heightest auc:0.88 cost:18.51
# epoch [94/50000] s_loss:-4456.1191 d_loss:-32.1716 val_s_loss:-39.6402 val_d_loss:-36.1386 heightest auc:0.88 cost:17.69
# epoch [95/50000] s_loss:-4642.0908 d_loss:-32.6590 val_s_loss:-43.1024 val_d_loss:-31.1536 heightest auc:0.88 cost:16.57
# epoch [96/50000] s_loss:-4255.2622 d_loss:-32.2072 val_s_loss:-42.2235 val_d_loss:-29.1982 heightest auc:0.88 cost:17.35
# epoch [97/50000] s_loss:-2865.5210 d_loss:-31.9146 val_s_loss:-17.6398 val_d_loss:-40.3153 heightest auc:0.88 cost:17.25
# epoch [98/50000] s_loss:-2486.0098 d_loss:-31.1630 val_s_loss:-26.7658 val_d_loss:-29.3571 heightest auc:0.88 cost:17.43
# epoch [99/50000] s_loss:-3494.1050 d_loss:-30.2743 val_s_loss:-16.8338 val_d_loss:-46.8114 heightest auc:0.88 cost:17.04
# epoch [100/50000] s_loss:-1470.9557 d_loss:-30.5875 val_s_loss:-14.4055 val_d_loss:-29.5929 heightest auc:0.88 cost:17.10
# epoch [101/50000] s_loss:-3972.5161 d_loss:-31.6369 val_s_loss:-38.0998 val_d_loss:-29.9720 heightest auc:0.88 cost:17.75
# epoch [102/50000] s_loss:-520.7606 d_loss:-33.1654 val_s_loss:-7.0681 val_d_loss:-28.1054 heightest auc:0.88 cost:16.88
# epoch [103/50000] s_loss:-6209.2212 d_loss:-30.8073 val_s_loss:-61.2962 val_d_loss:-29.4194 heightest auc:0.88 cost:16.96
# epoch [104/50000] s_loss:-4932.4780 d_loss:-29.9019 val_s_loss:-49.0836 val_d_loss:-28.0440 heightest auc:0.88 cost:17.18
# epoch [105/50000] s_loss:78.3945 d_loss:-32.5694 val_s_loss:-1.0165 val_d_loss:-26.4998 heightest auc:0.88 cost:17.95
# epoch [106/50000] s_loss:-5292.5073 d_loss:-29.2321 val_s_loss:-54.4887 val_d_loss:-25.2050 heightest auc:0.88 cost:17.67
# epoch [107/50000] s_loss:-2825.5476 d_loss:-32.5896 val_s_loss:-26.6132 val_d_loss:-29.3966 heightest auc:0.88 cost:17.64
# epoch [108/50000] s_loss:-4324.1274 d_loss:-30.6029 val_s_loss:-45.5981 val_d_loss:-26.8969 heightest auc:0.89 cost:17.39
# epoch [109/50000] s_loss:-3758.6799 d_loss:-30.4010 val_s_loss:-37.9197 val_d_loss:-27.5595 heightest auc:0.89 cost:17.05
# epoch [110/50000] s_loss:-2383.1663 d_loss:-29.5101 val_s_loss:-24.0032 val_d_loss:-26.7338 heightest auc:0.89 cost:18.30
# epoch [111/50000] s_loss:-2277.9602 d_loss:-29.0824 val_s_loss:-16.9257 val_d_loss:-31.8224 heightest auc:0.89 cost:18.13
# epoch [112/50000] s_loss:-5379.5923 d_loss:-28.5851 val_s_loss:-53.6788 val_d_loss:-25.5023 heightest auc:0.89 cost:17.37
# epoch [113/50000] s_loss:-6043.5122 d_loss:-28.3370 val_s_loss:-61.6485 val_d_loss:-24.8590 heightest auc:0.89 cost:17.13
# epoch [114/50000] s_loss:197.6003 d_loss:-31.1764 val_s_loss:16.6669 val_d_loss:-40.1815 heightest auc:0.89 cost:16.83
# epoch [115/50000] s_loss:-5059.6978 d_loss:-28.2374 val_s_loss:-49.2306 val_d_loss:-30.3726 heightest auc:0.89 cost:17.03
# epoch [116/50000] s_loss:-5469.0757 d_loss:-29.1918 val_s_loss:-57.6448 val_d_loss:-24.6899 heightest auc:0.89 cost:17.35
# epoch [117/50000] s_loss:2086.5518 d_loss:-32.2348 val_s_loss:22.9698 val_d_loss:-28.7205 heightest auc:0.89 cost:17.35
# epoch [118/50000] s_loss:-2683.1968 d_loss:-29.6297 val_s_loss:-27.2878 val_d_loss:-25.9363 heightest auc:0.89 cost:16.85
# epoch [119/50000] s_loss:-2440.6562 d_loss:-28.8662 val_s_loss:-11.7200 val_d_loss:-40.2205 heightest auc:0.89 cost:18.03
# epoch [120/50000] s_loss:-4593.4282 d_loss:-27.1896 val_s_loss:-41.6721 val_d_loss:-29.4764 heightest auc:0.89 cost:17.89
# epoch [121/50000] s_loss:-3133.2388 d_loss:-27.9409 val_s_loss:-33.2647 val_d_loss:-25.2340 heightest auc:0.89 cost:18.34
# epoch [122/50000] s_loss:-4690.4868 d_loss:-28.2857 val_s_loss:-48.7823 val_d_loss:-23.5564 heightest auc:0.89 cost:17.75
# epoch [123/50000] s_loss:-838.8537 d_loss:-29.3790 val_s_loss:-7.6248 val_d_loss:-26.8845 heightest auc:0.89 cost:17.24
# epoch [124/50000] s_loss:-4891.6812 d_loss:-26.9506 val_s_loss:-48.5555 val_d_loss:-24.8099 heightest auc:0.90 cost:17.49
# epoch [125/50000] s_loss:-4977.8267 d_loss:-28.0230 val_s_loss:-49.4613 val_d_loss:-25.3837 heightest auc:0.90 cost:17.34
# epoch [126/50000] s_loss:-2034.5217 d_loss:-28.9206 val_s_loss:-18.8071 val_d_loss:-25.8729 heightest auc:0.90 cost:17.22
# epoch [127/50000] s_loss:-2964.7158 d_loss:-27.4804 val_s_loss:-29.0550 val_d_loss:-23.9196 heightest auc:0.90 cost:17.23
# epoch [128/50000] s_loss:705.7912 d_loss:-40.6215 val_s_loss:9.8227 val_d_loss:-26.6244 heightest auc:0.90 cost:18.02
# epoch [129/50000] s_loss:-1988.1100 d_loss:-27.0343 val_s_loss:-20.9911 val_d_loss:-22.8476 heightest auc:0.90 cost:17.87
# epoch [130/50000] s_loss:4225.7915 d_loss:-36.4576 val_s_loss:86.8562 val_d_loss:-68.5073 heightest auc:0.90 cost:17.03
# epoch [131/50000] s_loss:-3592.5447 d_loss:-30.5696 val_s_loss:-37.7245 val_d_loss:-23.3028 heightest auc:0.90 cost:17.17
# epoch [132/50000] s_loss:-2014.8123 d_loss:-34.1083 val_s_loss:-9.1924 val_d_loss:-33.8200 heightest auc:0.90 cost:17.05
# epoch [133/50000] s_loss:-2046.9678 d_loss:-27.8749 val_s_loss:-23.5557 val_d_loss:-23.2496 heightest auc:0.90 cost:17.22
# epoch [134/50000] s_loss:-1698.7601 d_loss:-29.3243 val_s_loss:-19.2083 val_d_loss:-24.8325 heightest auc:0.90 cost:17.18
# epoch [135/50000] s_loss:-4288.3989 d_loss:-29.2264 val_s_loss:-46.7870 val_d_loss:-20.6510 heightest auc:0.90 cost:17.76
# epoch [136/50000] s_loss:-4621.7563 d_loss:-36.4704 val_s_loss:-44.2528 val_d_loss:-24.2920 heightest auc:0.90 cost:18.23
# epoch [137/50000] s_loss:3610.4912 d_loss:-31.5501 val_s_loss:38.0951 val_d_loss:-27.0319 heightest auc:0.90 cost:19.17
# epoch [138/50000] s_loss:-58.8376 d_loss:-30.7889 val_s_loss:0.4414 val_d_loss:-30.0367 heightest auc:0.90 cost:18.30
# epoch [139/50000] s_loss:-2672.2952 d_loss:-30.3044 val_s_loss:-29.6680 val_d_loss:-23.3178 heightest auc:0.90 cost:17.96
# epoch [140/50000] s_loss:2824.6475 d_loss:-35.1059 val_s_loss:29.4501 val_d_loss:-27.5316 heightest auc:0.90 cost:17.42
# epoch [141/50000] s_loss:-2705.5928 d_loss:-27.4976 val_s_loss:-30.1090 val_d_loss:-23.9048 heightest auc:0.90 cost:17.58
# epoch [142/50000] s_loss:-2884.9768 d_loss:-27.7052 val_s_loss:-29.9206 val_d_loss:-22.1124 heightest auc:0.91 cost:16.69
# epoch [143/50000] s_loss:3744.4727 d_loss:-32.3994 val_s_loss:148.1046 val_d_loss:-128.4637 heightest auc:0.91 cost:16.88
# epoch [144/50000] s_loss:-2375.1157 d_loss:-26.2027 val_s_loss:-24.0437 val_d_loss:-22.8771 heightest auc:0.91 cost:17.28
# epoch [145/50000] s_loss:-8375.2451 d_loss:-27.2404 val_s_loss:-85.8581 val_d_loss:-21.8708 heightest auc:0.91 cost:17.86
# epoch [146/50000] s_loss:-3690.3596 d_loss:-31.7575 val_s_loss:-32.5243 val_d_loss:-28.0469 heightest auc:0.91 cost:18.08
# epoch [147/50000] s_loss:-4340.5581 d_loss:-26.6501 val_s_loss:-45.7890 val_d_loss:-21.8661 heightest auc:0.91 cost:18.19
# epoch [148/50000] s_loss:-5048.2939 d_loss:-27.0841 val_s_loss:-48.9171 val_d_loss:-25.6376 heightest auc:0.91 cost:17.90
# epoch [149/50000] s_loss:-1456.9449 d_loss:-27.3184 val_s_loss:-13.2192 val_d_loss:-25.5124 heightest auc:0.91 cost:16.86
# epoch [150/50000] s_loss:-1364.4954 d_loss:-25.9364 val_s_loss:-4.4049 val_d_loss:-31.7904 heightest auc:0.91 cost:17.26
# epoch [151/50000] s_loss:-3269.7231 d_loss:-25.1218 val_s_loss:-33.6757 val_d_loss:-22.1087 heightest auc:0.91 cost:17.67
# epoch [152/50000] s_loss:-2876.3093 d_loss:-25.7235 val_s_loss:-29.7797 val_d_loss:-23.3867 heightest auc:0.91 cost:17.90
# epoch [153/50000] s_loss:-2037.8859 d_loss:-26.0756 val_s_loss:-18.1958 val_d_loss:-26.0803 heightest auc:0.91 cost:18.55
# epoch [154/50000] s_loss:-4838.5347 d_loss:-24.4368 val_s_loss:-50.3655 val_d_loss:-22.2836 heightest auc:0.91 cost:17.85
# epoch [155/50000] s_loss:-4983.5415 d_loss:-23.7224 val_s_loss:-49.6451 val_d_loss:-21.0256 heightest auc:0.91 cost:18.90
# epoch [156/50000] s_loss:-440.6793 d_loss:-29.6272 val_s_loss:0.0603 val_d_loss:-26.9335 heightest auc:0.91 cost:17.16
# epoch [157/50000] s_loss:-5588.9014 d_loss:-25.8926 val_s_loss:-56.6183 val_d_loss:-23.7986 heightest auc:0.91 cost:17.37
# epoch [158/50000] s_loss:-8542.8418 d_loss:-27.2077 val_s_loss:-86.4410 val_d_loss:-23.8241 heightest auc:0.91 cost:16.50
# epoch [159/50000] s_loss:-7189.9814 d_loss:-26.1337 val_s_loss:-71.1616 val_d_loss:-21.4434 heightest auc:0.91 cost:16.97
# epoch [160/50000] s_loss:389.5651 d_loss:-29.7858 val_s_loss:11.8329 val_d_loss:-26.8209 heightest auc:0.91 cost:16.30
# epoch [161/50000] s_loss:-1734.7402 d_loss:-22.6391 val_s_loss:-18.7234 val_d_loss:-20.8709 heightest auc:0.91 cost:16.40
# epoch [162/50000] s_loss:-4067.9609 d_loss:-25.0516 val_s_loss:-40.5532 val_d_loss:-23.1738 heightest auc:0.91 cost:16.53
# epoch [163/50000] s_loss:-3572.9065 d_loss:-27.9750 val_s_loss:-34.4528 val_d_loss:-24.3147 heightest auc:0.91 cost:17.98
# epoch [164/50000] s_loss:-2806.8896 d_loss:-24.7021 val_s_loss:-27.9897 val_d_loss:-23.5222 heightest auc:0.91 cost:18.61
# epoch [165/50000] s_loss:-421.1263 d_loss:-26.1810 val_s_loss:-4.8173 val_d_loss:-19.9653 heightest auc:0.91 cost:18.44
# epoch [166/50000] s_loss:-2047.1121 d_loss:-24.5139 val_s_loss:-25.8602 val_d_loss:-13.6500 heightest auc:0.91 cost:17.58
# epoch [167/50000] s_loss:-1742.9854 d_loss:-25.8307 val_s_loss:-15.3530 val_d_loss:-24.0689 heightest auc:0.91 cost:18.06
# epoch [168/50000] s_loss:-4221.9175 d_loss:-25.6475 val_s_loss:-32.5307 val_d_loss:-30.5003 heightest auc:0.91 cost:18.36
# epoch [169/50000] s_loss:-2702.9868 d_loss:-24.7916 val_s_loss:-23.6772 val_d_loss:-26.7379 heightest auc:0.91 cost:17.73
# epoch [170/50000] s_loss:-2995.4722 d_loss:-25.3571 val_s_loss:-29.0377 val_d_loss:-24.1718 heightest auc:0.91 cost:17.91
# epoch [171/50000] s_loss:-4388.0537 d_loss:-24.5727 val_s_loss:-46.4792 val_d_loss:-20.3410 heightest auc:0.91 cost:17.30
# epoch [172/50000] s_loss:257.3391 d_loss:-25.4954 val_s_loss:5.9828 val_d_loss:-23.5333 heightest auc:0.91 cost:17.13
# epoch [173/50000] s_loss:-5211.3213 d_loss:-23.1366 val_s_loss:-52.6870 val_d_loss:-22.8004 heightest auc:0.91 cost:17.63
# epoch [174/50000] s_loss:-8155.5088 d_loss:-25.0228 val_s_loss:-94.2765 val_d_loss:-8.9303 heightest auc:0.91 cost:17.25
# epoch [175/50000] s_loss:-3031.7861 d_loss:-24.8439 val_s_loss:-30.8870 val_d_loss:-19.7325 heightest auc:0.91 cost:16.85
# epoch [176/50000] s_loss:-1998.9032 d_loss:-23.6025 val_s_loss:-21.5825 val_d_loss:-21.1588 heightest auc:0.91 cost:16.94
# epoch [177/50000] s_loss:-3307.7107 d_loss:-24.7795 val_s_loss:-32.9996 val_d_loss:-16.8893 heightest auc:0.91 cost:16.72
# epoch [178/50000] s_loss:-2301.2576 d_loss:-23.6146 val_s_loss:-23.5164 val_d_loss:-19.1336 heightest auc:0.91 cost:16.93
# epoch [179/50000] s_loss:-1100.5654 d_loss:-23.7033 val_s_loss:-11.1699 val_d_loss:-21.5279 heightest auc:0.91 cost:16.46
# epoch [180/50000] s_loss:-3607.8518 d_loss:-23.9874 val_s_loss:-37.2875 val_d_loss:-18.7800 heightest auc:0.91 cost:16.80
# epoch [181/50000] s_loss:-7002.8940 d_loss:-25.9518 val_s_loss:-73.1289 val_d_loss:-17.0426 heightest auc:0.91 cost:17.25
# epoch [182/50000] s_loss:-7418.5024 d_loss:-22.8433 val_s_loss:-77.2608 val_d_loss:-14.5199 heightest auc:0.91 cost:19.16
# epoch [183/50000] s_loss:12766.6523 d_loss:-41.5706 val_s_loss:150.9820 val_d_loss:-34.1582 heightest auc:0.91 cost:18.43
# epoch [184/50000] s_loss:-2698.5022 d_loss:-22.4514 val_s_loss:-27.7595 val_d_loss:-20.3311 heightest auc:0.91 cost:19.19
# epoch [185/50000] s_loss:-3843.3123 d_loss:-34.7414 val_s_loss:-42.4799 val_d_loss:-20.6043 heightest auc:0.91 cost:18.20
# epoch [186/50000] s_loss:-11252.6631 d_loss:-29.9176 val_s_loss:-110.9662 val_d_loss:-23.6091 heightest auc:0.91 cost:17.84
# epoch [187/50000] s_loss:-1140.1403 d_loss:-31.0284 val_s_loss:-10.4268 val_d_loss:-24.2571 heightest auc:0.91 cost:17.46
# epoch [188/50000] s_loss:1088.2698 d_loss:-26.8882 val_s_loss:9.7654 val_d_loss:-21.3389 heightest auc:0.91 cost:16.92
# epoch [189/50000] s_loss:5797.9492 d_loss:-28.8220 val_s_loss:57.2502 val_d_loss:-22.1513 heightest auc:0.91 cost:17.25
# epoch [190/50000] s_loss:1133.6669 d_loss:-26.1927 val_s_loss:10.7784 val_d_loss:-21.2674 heightest auc:0.91 cost:16.93
# epoch [191/50000] s_loss:-2768.8384 d_loss:-26.7048 val_s_loss:-27.3056 val_d_loss:-24.9577 heightest auc:0.91 cost:17.80
# epoch [192/50000] s_loss:-4426.6670 d_loss:-25.1903 val_s_loss:-44.5809 val_d_loss:-21.7396 heightest auc:0.91 cost:17.30
# epoch [193/50000] s_loss:-5132.2446 d_loss:-23.8629 val_s_loss:-52.1792 val_d_loss:-19.0937 heightest auc:0.91 cost:16.97
# epoch [194/50000] s_loss:518.9465 d_loss:-27.2781 val_s_loss:11.2758 val_d_loss:-22.6871 heightest auc:0.91 cost:16.45
# epoch [195/50000] s_loss:-3502.2122 d_loss:-22.4471 val_s_loss:-35.8040 val_d_loss:-19.3949 heightest auc:0.91 cost:16.73
# epoch [196/50000] s_loss:-6366.7456 d_loss:-23.9200 val_s_loss:-65.4378 val_d_loss:-18.6915 heightest auc:0.91 cost:17.74
# epoch [197/50000] s_loss:-7548.6318 d_loss:-26.9328 val_s_loss:-75.1555 val_d_loss:-24.9133 heightest auc:0.91 cost:17.91
# epoch [198/50000] s_loss:-4857.9541 d_loss:-26.2265 val_s_loss:-50.1787 val_d_loss:-20.3923 heightest auc:0.91 cost:18.38
# epoch [199/50000] s_loss:-2876.4517 d_loss:-25.4508 val_s_loss:-30.6960 val_d_loss:-20.3356 heightest auc:0.91 cost:18.17
# epoch [200/50000] s_loss:-821.3500 d_loss:-24.9009 val_s_loss:-5.1890 val_d_loss:-21.6063 heightest auc:0.91 cost:18.37
# epoch [201/50000] s_loss:4075.7036 d_loss:-30.4416 val_s_loss:45.7645 val_d_loss:-20.9660 heightest auc:0.91 cost:18.27
# epoch [202/50000] s_loss:-627.5079 d_loss:-22.0969 val_s_loss:-5.5513 val_d_loss:-23.5167 heightest auc:0.91 cost:17.51
# epoch [203/50000] s_loss:-3812.7998 d_loss:-26.0544 val_s_loss:-36.0022 val_d_loss:-24.8454 heightest auc:0.91 cost:17.48
# epoch [204/50000] s_loss:-4941.0405 d_loss:-27.9040 val_s_loss:-49.5584 val_d_loss:-24.8350 heightest auc:0.91 cost:17.17
# epoch [205/50000] s_loss:-1867.0903 d_loss:-24.5384 val_s_loss:-19.5464 val_d_loss:-18.2160 heightest auc:0.91 cost:17.37
# epoch [206/50000] s_loss:9284.1533 d_loss:-37.1199 val_s_loss:97.0193 val_d_loss:-19.0376 heightest auc:0.91 cost:17.14
# epoch [207/50000] s_loss:-1042.3286 d_loss:-22.0082 val_s_loss:-9.8509 val_d_loss:-23.8343 heightest auc:0.91 cost:17.14
# epoch [208/50000] s_loss:-3851.3757 d_loss:-29.3355 val_s_loss:-33.1857 val_d_loss:-30.8562 heightest auc:0.91 cost:16.82
# epoch [209/50000] s_loss:-7359.7817 d_loss:-27.0013 val_s_loss:-72.2961 val_d_loss:-20.6952 heightest auc:0.91 cost:17.87
# epoch [210/50000] s_loss:6453.2080 d_loss:-48.8894 val_s_loss:76.3390 val_d_loss:-24.1125 heightest auc:0.91 cost:17.57
# epoch [211/50000] s_loss:-399.0200 d_loss:-25.4332 val_s_loss:-7.4190 val_d_loss:-16.4594 heightest auc:0.91 cost:17.56
# epoch [212/50000] s_loss:-8896.1572 d_loss:-22.8869 val_s_loss:-87.2204 val_d_loss:-20.5637 heightest auc:0.91 cost:17.91
# epoch [213/50000] s_loss:1070.0231 d_loss:-29.0203 val_s_loss:14.0460 val_d_loss:-23.3032 heightest auc:0.91 cost:17.39
# epoch [214/50000] s_loss:-862.6340 d_loss:-22.5844 val_s_loss:-7.4284 val_d_loss:-21.7239 heightest auc:0.91 cost:17.82
# epoch [215/50000] s_loss:2460.1204 d_loss:-26.4053 val_s_loss:23.0317 val_d_loss:-22.7255 heightest auc:0.91 cost:17.63
# epoch [216/50000] s_loss:-796.8824 d_loss:-25.3825 val_s_loss:-8.6546 val_d_loss:-22.5620 heightest auc:0.91 cost:17.26
# epoch [217/50000] s_loss:-3338.7996 d_loss:-23.5248 val_s_loss:-35.5375 val_d_loss:-18.0351 heightest auc:0.91 cost:17.66
# epoch [218/50000] s_loss:2528.0547 d_loss:-34.3393 val_s_loss:29.1025 val_d_loss:-19.2116 heightest auc:0.91 cost:18.13
# epoch [219/50000] s_loss:-1436.5420 d_loss:-21.8375 val_s_loss:-15.7900 val_d_loss:-19.4078 heightest auc:0.91 cost:18.35
# epoch [220/50000] s_loss:-4678.5225 d_loss:-24.1053 val_s_loss:-48.6928 val_d_loss:-23.8375 heightest auc:0.91 cost:17.01
# epoch [221/50000] s_loss:-7477.5039 d_loss:-25.4408 val_s_loss:-78.7262 val_d_loss:-15.3029 heightest auc:0.91 cost:17.16
# epoch [222/50000] s_loss:-5788.0278 d_loss:-24.2687 val_s_loss:-60.7174 val_d_loss:-15.3402 heightest auc:0.91 cost:17.38
# epoch [223/50000] s_loss:4377.3657 d_loss:-38.6052 val_s_loss:49.0697 val_d_loss:-19.9250 heightest auc:0.91 cost:17.20
# epoch [224/50000] s_loss:-1608.6266 d_loss:-21.0016 val_s_loss:-16.4431 val_d_loss:-21.4604 heightest auc:0.91 cost:17.55
# epoch [225/50000] s_loss:-3645.8652 d_loss:-26.5469 val_s_loss:-40.8396 val_d_loss:-18.2205 heightest auc:0.91 cost:17.71
# epoch [226/50000] s_loss:-5582.4258 d_loss:-24.8941 val_s_loss:-55.8675 val_d_loss:-17.4159 heightest auc:0.91 cost:17.82
# epoch [227/50000] s_loss:-1947.1510 d_loss:-23.7029 val_s_loss:-16.6231 val_d_loss:-18.7375 heightest auc:0.91 cost:18.36
# epoch [228/50000] s_loss:968.4316 d_loss:-26.8169 val_s_loss:12.3842 val_d_loss:-24.2332 heightest auc:0.91 cost:17.34
# epoch [229/50000] s_loss:-1527.7322 d_loss:-23.1027 val_s_loss:-12.8469 val_d_loss:-21.7572 heightest auc:0.91 cost:17.33
# epoch [230/50000] s_loss:-503.0139 d_loss:-22.7465 val_s_loss:-6.6591 val_d_loss:-20.0882 heightest auc:0.91 cost:17.12
# epoch [231/50000] s_loss:-265.8025 d_loss:-23.6036 val_s_loss:-2.4707 val_d_loss:-19.1235 heightest auc:0.91 cost:16.92
# epoch [232/50000] s_loss:322.0640 d_loss:-25.9176 val_s_loss:2.4540 val_d_loss:-17.4764 heightest auc:0.91 cost:16.88
# epoch [233/50000] s_loss:-3113.0757 d_loss:-23.3493 val_s_loss:-30.8135 val_d_loss:-18.2090 heightest auc:0.91 cost:16.65
# epoch [234/50000] s_loss:-3263.6836 d_loss:-22.6172 val_s_loss:-32.6168 val_d_loss:-19.1978 heightest auc:0.91 cost:16.62
# epoch [235/50000] s_loss:-158.9430 d_loss:-23.6236 val_s_loss:-2.0705 val_d_loss:-20.7503 heightest auc:0.91 cost:18.48
# epoch [236/50000] s_loss:-1049.8151 d_loss:-23.2130 val_s_loss:-11.5202 val_d_loss:-19.0823 heightest auc:0.91 cost:18.24
# epoch [237/50000] s_loss:-4109.3237 d_loss:-22.9471 val_s_loss:-41.5677 val_d_loss:-17.9845 heightest auc:0.91 cost:18.87
# epoch [238/50000] s_loss:-4408.3389 d_loss:-22.7689 val_s_loss:-46.7600 val_d_loss:-20.8471 heightest auc:0.91 cost:17.49
# epoch [239/50000] s_loss:-4068.2280 d_loss:-22.3643 val_s_loss:-40.9066 val_d_loss:-18.3871 heightest auc:0.91 cost:17.95
# epoch [240/50000] s_loss:-2396.5566 d_loss:-23.5910 val_s_loss:-21.4844 val_d_loss:-22.9372 heightest auc:0.91 cost:17.86
# epoch [241/50000] s_loss:-764.0402 d_loss:-22.5880 val_s_loss:-7.7342 val_d_loss:-17.3235 heightest auc:0.91 cost:17.55
# epoch [242/50000] s_loss:-730.2606 d_loss:-21.5878 val_s_loss:-7.5862 val_d_loss:-19.7907 heightest auc:0.91 cost:17.03
# epoch [243/50000] s_loss:-1175.9661 d_loss:-20.7032 val_s_loss:-12.3216 val_d_loss:-19.5772 heightest auc:0.91 cost:16.91
# epoch [244/50000] s_loss:-1980.7692 d_loss:-21.7251 val_s_loss:-23.5445 val_d_loss:-17.0751 heightest auc:0.91 cost:18.13
# epoch [245/50000] s_loss:-1840.7478 d_loss:-24.1508 val_s_loss:-19.5989 val_d_loss:-15.8213 heightest auc:0.91 cost:17.80
# epoch [246/50000] s_loss:-1050.9987 d_loss:-21.3467 val_s_loss:-9.4995 val_d_loss:-19.8395 heightest auc:0.91 cost:17.07
# epoch [247/50000] s_loss:-1015.0834 d_loss:-25.1789 val_s_loss:-9.2998 val_d_loss:-21.5531 heightest auc:0.91 cost:16.89
# epoch [248/50000] s_loss:-2792.5305 d_loss:-25.4564 val_s_loss:-29.0047 val_d_loss:-19.0274 heightest auc:0.91 cost:16.68
# epoch [249/50000] s_loss:-4604.2734 d_loss:-26.4518 val_s_loss:-48.4836 val_d_loss:-20.7399 heightest auc:0.91 cost:16.67
# epoch [250/50000] s_loss:-4948.2622 d_loss:-26.5381 val_s_loss:-50.6439 val_d_loss:-19.4624 heightest auc:0.91 cost:16.69
# epoch [251/50000] s_loss:-4287.2339 d_loss:-24.9959 val_s_loss:-45.3853 val_d_loss:-21.5506 heightest auc:0.91 cost:17.31
# epoch [252/50000] s_loss:-1226.7053 d_loss:-24.1935 val_s_loss:-12.5713 val_d_loss:-16.8331 heightest auc:0.91 cost:17.89
# epoch [253/50000] s_loss:649.9717 d_loss:-21.0403 val_s_loss:6.0397 val_d_loss:-17.2177 heightest auc:0.91 cost:19.30
# epoch [254/50000] s_loss:1673.4265 d_loss:-20.2646 val_s_loss:15.7848 val_d_loss:-18.9252 heightest auc:0.91 cost:19.27
# epoch [255/50000] s_loss:2025.4598 d_loss:-22.1845 val_s_loss:18.1034 val_d_loss:-18.6845 heightest auc:0.91 cost:18.33
# epoch [256/50000] s_loss:997.3369 d_loss:-22.3657 val_s_loss:8.0100 val_d_loss:-19.5838 heightest auc:0.91 cost:17.40
# epoch [257/50000] s_loss:-565.9451 d_loss:-23.2177 val_s_loss:-6.0344 val_d_loss:-15.9691 heightest auc:0.91 cost:17.41
# epoch [258/50000] s_loss:-1243.5992 d_loss:-21.0930 val_s_loss:-12.3170 val_d_loss:-20.5608 heightest auc:0.91 cost:16.91
# epoch [259/50000] s_loss:-1885.6389 d_loss:-22.8366 val_s_loss:-19.0753 val_d_loss:-21.0481 heightest auc:0.91 cost:17.37
# epoch [260/50000] s_loss:-1813.8472 d_loss:-22.9236 val_s_loss:-17.6371 val_d_loss:-18.5340 heightest auc:0.91 cost:17.13
# epoch [261/50000] s_loss:-2471.7053 d_loss:-22.2882 val_s_loss:-25.1824 val_d_loss:-21.7079 heightest auc:0.91 cost:16.98
# epoch [262/50000] s_loss:-3235.6321 d_loss:-21.7337 val_s_loss:-35.1405 val_d_loss:-17.2365 heightest auc:0.91 cost:17.44
# epoch [263/50000] s_loss:-3789.6653 d_loss:-22.4170 val_s_loss:-37.2254 val_d_loss:-17.9351 heightest auc:0.92 cost:17.28
# epoch [264/50000] s_loss:-3069.0515 d_loss:-23.0668 val_s_loss:-32.7121 val_d_loss:-19.6066 heightest auc:0.92 cost:16.61
# epoch [265/50000] s_loss:-1279.5254 d_loss:-23.5098 val_s_loss:-12.2859 val_d_loss:-18.1370 heightest auc:0.92 cost:17.30
# epoch [266/50000] s_loss:-552.3102 d_loss:-23.1743 val_s_loss:-8.1958 val_d_loss:-16.2905 heightest auc:0.92 cost:17.59
# epoch [267/50000] s_loss:-1694.6344 d_loss:-24.4396 val_s_loss:-20.3982 val_d_loss:-13.8510 heightest auc:0.92 cost:18.02
# epoch [268/50000] s_loss:-3638.3308 d_loss:-23.5001 val_s_loss:-35.4702 val_d_loss:-18.0461 heightest auc:0.92 cost:17.87
# epoch [269/50000] s_loss:-1743.6251 d_loss:-24.1354 val_s_loss:-19.3546 val_d_loss:-18.6917 heightest auc:0.92 cost:17.81
# epoch [270/50000] s_loss:2101.7412 d_loss:-22.0358 val_s_loss:20.2001 val_d_loss:-18.0852 heightest auc:0.92 cost:17.17
# epoch [271/50000] s_loss:2721.1138 d_loss:-20.5490 val_s_loss:26.0606 val_d_loss:-19.7384 heightest auc:0.92 cost:18.33
# epoch [272/50000] s_loss:1669.6416 d_loss:-22.7603 val_s_loss:16.9995 val_d_loss:-17.3299 heightest auc:0.92 cost:17.69
# epoch [273/50000] s_loss:1277.2750 d_loss:-20.0798 val_s_loss:11.2724 val_d_loss:-18.8854 heightest auc:0.92 cost:17.38
# epoch [274/50000] s_loss:1962.7002 d_loss:-23.4627 val_s_loss:19.1209 val_d_loss:-17.3619 heightest auc:0.92 cost:16.85
# epoch [275/50000] s_loss:230.0291 d_loss:-21.5059 val_s_loss:3.3691 val_d_loss:-20.8851 heightest auc:0.92 cost:17.16
# epoch [276/50000] s_loss:-1694.4203 d_loss:-22.4199 val_s_loss:-17.2654 val_d_loss:-18.3100 heightest auc:0.92 cost:16.91
# epoch [277/50000] s_loss:-3110.5193 d_loss:-21.8703 val_s_loss:-29.9649 val_d_loss:-22.3397 heightest auc:0.92 cost:17.28
# epoch [278/50000] s_loss:-4051.9182 d_loss:-25.9753 val_s_loss:-39.8453 val_d_loss:-20.2919 heightest auc:0.92 cost:17.40
# epoch [279/50000] s_loss:-4055.8848 d_loss:-23.6143 val_s_loss:-40.8258 val_d_loss:-17.8002 heightest auc:0.92 cost:17.39
# epoch [280/50000] s_loss:503.8005 d_loss:-26.7188 val_s_loss:1.9823 val_d_loss:-15.5178 heightest auc:0.92 cost:18.04
# epoch [281/50000] s_loss:1266.1790 d_loss:-22.8938 val_s_loss:11.8334 val_d_loss:-18.0000 heightest auc:0.92 cost:17.97
# epoch [282/50000] s_loss:1407.0636 d_loss:-20.3562 val_s_loss:13.1205 val_d_loss:-18.6580 heightest auc:0.92 cost:17.39
# epoch [283/50000] s_loss:1233.3241 d_loss:-21.8334 val_s_loss:11.5075 val_d_loss:-19.0108 heightest auc:0.92 cost:17.57
# epoch [284/50000] s_loss:-158.5736 d_loss:-23.8361 val_s_loss:-4.5120 val_d_loss:-17.6909 heightest auc:0.92 cost:17.38
# epoch [285/50000] s_loss:-1307.0646 d_loss:-25.1171 val_s_loss:-13.8151 val_d_loss:-21.8237 heightest auc:0.92 cost:16.68
# epoch [286/50000] s_loss:-1188.3639 d_loss:-23.6090 val_s_loss:-11.6054 val_d_loss:-20.4128 heightest auc:0.92 cost:16.95
# epoch [287/50000] s_loss:-3696.6667 d_loss:-21.7256 val_s_loss:-37.0205 val_d_loss:-15.1069 heightest auc:0.92 cost:16.98
# epoch [288/50000] s_loss:-3552.7939 d_loss:-24.2300 val_s_loss:-36.2005 val_d_loss:-18.8608 heightest auc:0.92 cost:16.90
# epoch [289/50000] s_loss:-3279.0952 d_loss:-24.1925 val_s_loss:-33.9879 val_d_loss:-20.4390 heightest auc:0.92 cost:18.29
# epoch [290/50000] s_loss:-5166.6660 d_loss:-23.9288 val_s_loss:-55.5124 val_d_loss:-16.4011 heightest auc:0.92 cost:17.79
# epoch [291/50000] s_loss:-2156.7358 d_loss:-30.4222 val_s_loss:-20.6918 val_d_loss:-13.6174 heightest auc:0.92 cost:17.43
# epoch [292/50000] s_loss:1645.9594 d_loss:-22.1269 val_s_loss:15.0874 val_d_loss:-20.0606 heightest auc:0.92 cost:17.77
# epoch [293/50000] s_loss:3512.9023 d_loss:-23.7590 val_s_loss:34.3358 val_d_loss:-21.4897 heightest auc:0.92 cost:17.42
# epoch [294/50000] s_loss:3257.2385 d_loss:-28.5133 val_s_loss:32.1294 val_d_loss:-20.0135 heightest auc:0.92 cost:18.15
# epoch [295/50000] s_loss:1600.1240 d_loss:-25.8733 val_s_loss:12.9192 val_d_loss:-21.8633 heightest auc:0.92 cost:18.48
# epoch [296/50000] s_loss:1317.6843 d_loss:-24.2617 val_s_loss:10.3260 val_d_loss:-16.6950 heightest auc:0.92 cost:17.61
# epoch [297/50000] s_loss:2682.7026 d_loss:-26.1070 val_s_loss:27.0975 val_d_loss:-20.7077 heightest auc:0.92 cost:18.03
# epoch [298/50000] s_loss:464.4104 d_loss:-21.4444 val_s_loss:2.8806 val_d_loss:-19.2122 heightest auc:0.92 cost:17.89
# epoch [299/50000] s_loss:-1395.8187 d_loss:-22.6863 val_s_loss:-15.2623 val_d_loss:-18.5461 heightest auc:0.92 cost:17.12
# epoch [300/50000] s_loss:-2433.7812 d_loss:-25.4470 val_s_loss:-25.1195 val_d_loss:-24.6492 heightest auc:0.92 cost:16.90
# epoch [301/50000] s_loss:-3776.3059 d_loss:-26.6022 val_s_loss:-37.7113 val_d_loss:-18.7013 heightest auc:0.92 cost:16.67
# epoch [302/50000] s_loss:-958.0482 d_loss:-22.6179 val_s_loss:-10.7522 val_d_loss:-17.8053 heightest auc:0.92 cost:16.89
# epoch [303/50000] s_loss:1699.2378 d_loss:-23.2623 val_s_loss:16.3647 val_d_loss:-20.7710 heightest auc:0.92 cost:16.66
# epoch [304/50000] s_loss:3699.5522 d_loss:-24.6600 val_s_loss:35.1366 val_d_loss:-19.0686 heightest auc:0.92 cost:16.97
# epoch [305/50000] s_loss:2452.4568 d_loss:-22.3580 val_s_loss:20.6819 val_d_loss:-11.4973 heightest auc:0.92 cost:16.76
# epoch [306/50000] s_loss:1482.5563 d_loss:-25.6819 val_s_loss:14.9493 val_d_loss:-15.9163 heightest auc:0.92 cost:17.96
# epoch [307/50000] s_loss:1366.6014 d_loss:-18.7615 val_s_loss:13.6519 val_d_loss:-18.6803 heightest auc:0.92 cost:18.60
# epoch [308/50000] s_loss:986.6786 d_loss:-22.8197 val_s_loss:6.3049 val_d_loss:-20.4145 heightest auc:0.92 cost:19.18
# epoch [309/50000] s_loss:628.7036 d_loss:-23.8982 val_s_loss:8.1123 val_d_loss:-20.4733 heightest auc:0.92 cost:18.25
# epoch [310/50000] s_loss:-668.4371 d_loss:-23.4154 val_s_loss:-5.8968 val_d_loss:-17.6246 heightest auc:0.92 cost:17.89
# epoch [311/50000] s_loss:-1394.8875 d_loss:-23.8223 val_s_loss:-14.2711 val_d_loss:-14.7790 heightest auc:0.92 cost:17.39
# epoch [312/50000] s_loss:-3316.1985 d_loss:-23.1345 val_s_loss:-35.1327 val_d_loss:-21.1929 heightest auc:0.92 cost:16.90
# epoch [313/50000] s_loss:-5015.7974 d_loss:-20.9151 val_s_loss:-45.5030 val_d_loss:-15.0652 heightest auc:0.92 cost:17.02
# epoch [314/50000] s_loss:766.5841 d_loss:-37.4813 val_s_loss:18.5855 val_d_loss:-16.7754 heightest auc:0.92 cost:17.08
# epoch [315/50000] s_loss:3216.6404 d_loss:-18.8847 val_s_loss:31.1363 val_d_loss:-14.9128 heightest auc:0.92 cost:17.51
# epoch [316/50000] s_loss:274.7409 d_loss:-25.9764 val_s_loss:2.4966 val_d_loss:-21.2493 heightest auc:0.92 cost:17.67
# epoch [317/50000] s_loss:288.2040 d_loss:-32.9986 val_s_loss:2.7798 val_d_loss:-25.7238 heightest auc:0.92 cost:16.84
# epoch [318/50000] s_loss:-4894.7729 d_loss:-27.8221 val_s_loss:-47.7979 val_d_loss:-26.7726 heightest auc:0.92 cost:16.93
# epoch [319/50000] s_loss:-6440.5166 d_loss:-26.7630 val_s_loss:-64.2307 val_d_loss:-18.2367 heightest auc:0.92 cost:17.16
# epoch [320/50000] s_loss:-2909.3513 d_loss:-30.5504 val_s_loss:-18.8377 val_d_loss:-21.0579 heightest auc:0.92 cost:17.97
# epoch [321/50000] s_loss:3831.9973 d_loss:-21.5729 val_s_loss:34.5284 val_d_loss:-19.2427 heightest auc:0.92 cost:17.41
# epoch [322/50000] s_loss:2137.1074 d_loss:-22.9961 val_s_loss:19.9769 val_d_loss:-20.4856 heightest auc:0.92 cost:17.96
# epoch [323/50000] s_loss:310.1623 d_loss:-25.5485 val_s_loss:2.5145 val_d_loss:-18.3895 heightest auc:0.92 cost:17.85
# epoch [324/50000] s_loss:-293.9016 d_loss:-25.0836 val_s_loss:-5.9298 val_d_loss:-17.3431 heightest auc:0.92 cost:18.75
# epoch [325/50000] s_loss:1779.5828 d_loss:-23.3181 val_s_loss:16.2281 val_d_loss:-18.2543 heightest auc:0.92 cost:18.31
# epoch [326/50000] s_loss:1705.0304 d_loss:-20.9214 val_s_loss:18.3051 val_d_loss:-19.6218 heightest auc:0.92 cost:17.92
# epoch [327/50000] s_loss:-317.2102 d_loss:-21.1248 val_s_loss:-4.1275 val_d_loss:-17.9299 heightest auc:0.92 cost:17.20
# epoch [328/50000] s_loss:-3903.5195 d_loss:-22.2742 val_s_loss:-38.4607 val_d_loss:-20.7339 heightest auc:0.92 cost:17.10
# epoch [329/50000] s_loss:-3981.6470 d_loss:-24.6452 val_s_loss:-40.9113 val_d_loss:-13.8225 heightest auc:0.92 cost:17.20
# epoch [330/50000] s_loss:1708.9187 d_loss:-20.0847 val_s_loss:16.9408 val_d_loss:-18.2456 heightest auc:0.92 cost:16.64
# epoch [331/50000] s_loss:2934.8086 d_loss:-21.1189 val_s_loss:28.5008 val_d_loss:-21.1792 heightest auc:0.92 cost:17.16
# epoch [332/50000] s_loss:3083.7095 d_loss:-22.7096 val_s_loss:29.1841 val_d_loss:-22.4116 heightest auc:0.92 cost:16.83
# epoch [333/50000] s_loss:2028.7120 d_loss:-24.4612 val_s_loss:17.8995 val_d_loss:-19.1977 heightest auc:0.92 cost:17.10
# epoch [334/50000] s_loss:240.3945 d_loss:-25.7535 val_s_loss:2.2025 val_d_loss:-20.8736 heightest auc:0.92 cost:18.87
# epoch [335/50000] s_loss:-1543.0273 d_loss:-22.5695 val_s_loss:-14.3065 val_d_loss:-17.0930 heightest auc:0.92 cost:17.69
# epoch [336/50000] s_loss:-421.9136 d_loss:-20.4373 val_s_loss:-6.4057 val_d_loss:-16.9373 heightest auc:0.92 cost:17.73
# epoch [337/50000] s_loss:1269.8960 d_loss:-27.9024 val_s_loss:16.0801 val_d_loss:-17.1214 heightest auc:0.92 cost:17.34
# epoch [338/50000] s_loss:2693.3596 d_loss:-20.3535 val_s_loss:27.3950 val_d_loss:-15.2033 heightest auc:0.92 cost:17.12
# epoch [339/50000] s_loss:1790.9972 d_loss:-23.9340 val_s_loss:18.5014 val_d_loss:-16.3809 heightest auc:0.92 cost:16.99
# epoch [340/50000] s_loss:1813.8824 d_loss:-27.1465 val_s_loss:19.4766 val_d_loss:-27.2139 heightest auc:0.92 cost:16.75
# epoch [341/50000] s_loss:334.0355 d_loss:-28.0560 val_s_loss:4.0279 val_d_loss:-24.7906 heightest auc:0.92 cost:16.91
# epoch [342/50000] s_loss:-2355.5864 d_loss:-27.8478 val_s_loss:-25.2439 val_d_loss:-21.8462 heightest auc:0.92 cost:17.61
# epoch [343/50000] s_loss:-5387.1104 d_loss:-24.8648 val_s_loss:-50.9793 val_d_loss:-19.2534 heightest auc:0.92 cost:18.44
# epoch [344/50000] s_loss:-1864.3628 d_loss:-18.5046 val_s_loss:-20.3171 val_d_loss:-14.3820 heightest auc:0.92 cost:18.44
# epoch [345/50000] s_loss:16891.9062 d_loss:-102.2621 val_s_loss:182.0805 val_d_loss:28.7453 heightest auc:0.92 cost:17.29
# epoch [346/50000] s_loss:29.3805 d_loss:-23.2038 val_s_loss:1.4813 val_d_loss:-14.4338 heightest auc:0.92 cost:17.51
# epoch [347/50000] s_loss:-371.9308 d_loss:-32.5048 val_s_loss:-3.0677 val_d_loss:-28.1867 heightest auc:0.92 cost:17.97
# epoch [348/50000] s_loss:644.4274 d_loss:-38.3773 val_s_loss:6.0989 val_d_loss:-28.1956 heightest auc:0.92 cost:18.21
# epoch [349/50000] s_loss:-3497.4543 d_loss:-32.1421 val_s_loss:-31.3777 val_d_loss:-29.7416 heightest auc:0.92 cost:17.98
# epoch [350/50000] s_loss:-3345.8569 d_loss:-32.4442 val_s_loss:-29.2166 val_d_loss:-28.9323 heightest auc:0.92 cost:17.44
# epoch [351/50000] s_loss:-4192.6631 d_loss:-30.7966 val_s_loss:-43.3278 val_d_loss:-25.6834 heightest auc:0.92 cost:17.57
# epoch [352/50000] s_loss:-370.4611 d_loss:-32.2755 val_s_loss:-6.2219 val_d_loss:-18.7340 heightest auc:0.92 cost:18.52
# epoch [353/50000] s_loss:-4050.3137 d_loss:-27.6842 val_s_loss:-39.2351 val_d_loss:-22.6142 heightest auc:0.92 cost:17.60
# epoch [354/50000] s_loss:-1580.5941 d_loss:-25.9455 val_s_loss:-19.0244 val_d_loss:-22.2338 heightest auc:0.92 cost:17.05
# epoch [355/50000] s_loss:6924.8892 d_loss:-29.1328 val_s_loss:67.5448 val_d_loss:-18.2753 heightest auc:0.92 cost:17.28
# epoch [356/50000] s_loss:-1692.9590 d_loss:-24.0887 val_s_loss:-18.3487 val_d_loss:-24.3511 heightest auc:0.92 cost:17.21
# epoch [357/50000] s_loss:-5704.8433 d_loss:-26.3942 val_s_loss:-61.6775 val_d_loss:-16.1970 heightest auc:0.92 cost:16.74
# epoch [358/50000] s_loss:-4811.6401 d_loss:-25.4375 val_s_loss:-51.5919 val_d_loss:-18.0251 heightest auc:0.92 cost:16.71
# epoch [359/50000] s_loss:-4516.1475 d_loss:-27.1746 val_s_loss:-45.7235 val_d_loss:-21.3957 heightest auc:0.92 cost:16.93
# epoch [360/50000] s_loss:-1519.2738 d_loss:-23.8900 val_s_loss:-16.4675 val_d_loss:-19.8632 heightest auc:0.92 cost:17.28
# epoch [361/50000] s_loss:3840.9851 d_loss:-23.4687 val_s_loss:35.8223 val_d_loss:-21.0906 heightest auc:0.92 cost:18.34
# epoch [362/50000] s_loss:4709.0879 d_loss:-23.6977 val_s_loss:45.1796 val_d_loss:-19.2715 heightest auc:0.92 cost:18.67
# epoch [363/50000] s_loss:-163.4305 d_loss:-23.6232 val_s_loss:-3.6350 val_d_loss:-19.7537 heightest auc:0.92 cost:19.02
# epoch [364/50000] s_loss:-3011.3486 d_loss:-23.3368 val_s_loss:-30.6230 val_d_loss:-18.4838 heightest auc:0.92 cost:18.34
# epoch [365/50000] s_loss:-3302.0415 d_loss:-23.1382 val_s_loss:-31.7885 val_d_loss:-18.6296 heightest auc:0.92 cost:17.61
# epoch [366/50000] s_loss:1972.1278 d_loss:-23.5390 val_s_loss:17.5700 val_d_loss:-17.6327 heightest auc:0.92 cost:17.68
# epoch [367/50000] s_loss:66.3969 d_loss:-20.9619 val_s_loss:-0.0807 val_d_loss:-17.1396 heightest auc:0.92 cost:16.86
# epoch [368/50000] s_loss:-2365.8584 d_loss:-22.3098 val_s_loss:-25.2893 val_d_loss:-17.5249 heightest auc:0.92 cost:16.98
# epoch [369/50000] s_loss:-2639.1980 d_loss:-22.8685 val_s_loss:-26.6096 val_d_loss:-15.9363 heightest auc:0.92 cost:17.03
# epoch [370/50000] s_loss:-709.8217 d_loss:-23.7591 val_s_loss:-7.0623 val_d_loss:-20.8944 heightest auc:0.92 cost:17.64
# epoch [371/50000] s_loss:1627.7278 d_loss:-28.3038 val_s_loss:18.6508 val_d_loss:-18.8288 heightest auc:0.92 cost:16.71
# epoch [372/50000] s_loss:2733.0645 d_loss:-21.9254 val_s_loss:26.6125 val_d_loss:-18.7663 heightest auc:0.92 cost:17.37
# epoch [373/50000] s_loss:1956.2527 d_loss:-22.4459 val_s_loss:19.6271 val_d_loss:-20.7233 heightest auc:0.92 cost:17.02
# epoch [374/50000] s_loss:-319.4581 d_loss:-23.9697 val_s_loss:-6.1536 val_d_loss:-21.2335 heightest auc:0.92 cost:17.20
# epoch [375/50000] s_loss:-1635.5638 d_loss:-24.2733 val_s_loss:-16.9613 val_d_loss:-22.1415 heightest auc:0.92 cost:17.39
# epoch [376/50000] s_loss:-716.7703 d_loss:-24.2776 val_s_loss:-5.0230 val_d_loss:-23.7867 heightest auc:0.92 cost:18.05
# epoch [377/50000] s_loss:3194.6675 d_loss:-23.3207 val_s_loss:32.2953 val_d_loss:-16.4354 heightest auc:0.92 cost:18.19
# epoch [378/50000] s_loss:6967.5776 d_loss:-23.5433 val_s_loss:69.8080 val_d_loss:-16.3074 heightest auc:0.92 cost:17.75
# epoch [379/50000] s_loss:3850.1646 d_loss:-21.2272 val_s_loss:38.3303 val_d_loss:-18.7819 heightest auc:0.92 cost:18.54
# epoch [380/50000] s_loss:1685.4512 d_loss:-22.3120 val_s_loss:17.3110 val_d_loss:-20.4421 heightest auc:0.92 cost:18.65
# epoch [381/50000] s_loss:27.4999 d_loss:-23.6244 val_s_loss:-0.3123 val_d_loss:-22.0558 heightest auc:0.92 cost:18.71
# epoch [382/50000] s_loss:-1084.9082 d_loss:-23.4797 val_s_loss:-10.6330 val_d_loss:-22.8424 heightest auc:0.92 cost:17.17
# epoch [383/50000] s_loss:-1889.3857 d_loss:-23.4351 val_s_loss:-19.8259 val_d_loss:-19.8874 heightest auc:0.92 cost:17.37
# epoch [384/50000] s_loss:-189.0126 d_loss:-21.6120 val_s_loss:-3.2066 val_d_loss:-14.8862 heightest auc:0.92 cost:17.78
# epoch [385/50000] s_loss:2096.6743 d_loss:-34.6880 val_s_loss:25.9000 val_d_loss:-16.9527 heightest auc:0.92 cost:16.85
# epoch [386/50000] s_loss:3273.3252 d_loss:-19.6265 val_s_loss:33.1580 val_d_loss:-21.4667 heightest auc:0.92 cost:17.02
# epoch [387/50000] s_loss:2456.8564 d_loss:-22.8820 val_s_loss:25.0288 val_d_loss:-21.0968 heightest auc:0.92 cost:16.76
# epoch [388/50000] s_loss:441.6364 d_loss:-25.9191 val_s_loss:4.0017 val_d_loss:-20.9051 heightest auc:0.92 cost:16.82
# epoch [389/50000] s_loss:-612.4732 d_loss:-25.6957 val_s_loss:-7.3030 val_d_loss:-28.3999 heightest auc:0.92 cost:17.82
# epoch [390/50000] s_loss:-2071.9001 d_loss:-29.9891 val_s_loss:-21.9823 val_d_loss:-27.8790 heightest auc:0.92 cost:18.24
# epoch [391/50000] s_loss:-4362.7871 d_loss:-28.1557 val_s_loss:-47.0678 val_d_loss:-24.3111 heightest auc:0.92 cost:17.98
# epoch [392/50000] s_loss:-5181.4775 d_loss:-27.0772 val_s_loss:-50.4555 val_d_loss:-23.3874 heightest auc:0.92 cost:17.88
# epoch [393/50000] s_loss:-3870.8337 d_loss:-21.8569 val_s_loss:-35.4662 val_d_loss:-18.5547 heightest auc:0.92 cost:17.40
# epoch [394/50000] s_loss:2416.4680 d_loss:-24.7263 val_s_loss:25.0767 val_d_loss:-19.1786 heightest auc:0.92 cost:17.75
# epoch [395/50000] s_loss:2683.2556 d_loss:-32.8825 val_s_loss:29.1669 val_d_loss:-9.6122 heightest auc:0.92 cost:17.20
# epoch [396/50000] s_loss:3747.3511 d_loss:-18.9000 val_s_loss:36.4888 val_d_loss:-18.4832 heightest auc:0.92 cost:17.28
# ...
# epoch [706/50000] s_loss:-5683.9390 d_loss:-24.0084 val_s_loss:-54.4188 val_d_loss:-16.5305 heightest auc:0.93 cost:18.54
# epoch [707/50000] s_loss:-7677.9990 d_loss:-22.1496 val_s_loss:-78.5674 val_d_loss:-14.3655 heightest auc:0.93 cost:18.23
# epoch [708/50000] s_loss:-7886.0522 d_loss:-17.1272 val_s_loss:-74.8930 val_d_loss:-6.7580 heightest auc:0.93 cost:17.99
# epoch [709/50000] s_loss:-8955.7041 d_loss:-35.1259 val_s_loss:-93.6733 val_d_loss:-7.1898 heightest auc:0.93 cost:17.51
# epoch [710/50000] s_loss:-2697.1548 d_loss:-16.3463 val_s_loss:-23.4017 val_d_loss:-14.3666 heightest auc:0.93 cost:17.45
# epoch [711/50000] s_loss:-648.8716 d_loss:-16.4711 val_s_loss:-7.0294 val_d_loss:-13.8979 heightest auc:0.93 cost:17.38
# epoch [712/50000] s_loss:2336.6316 d_loss:-18.9176 val_s_loss:16.4597 val_d_loss:-11.7958 heightest auc:0.93 cost:16.65
# epoch [713/50000] s_loss:3509.7151 d_loss:-18.0688 val_s_loss:29.7980 val_d_loss:-13.7905 heightest auc:0.93 cost:17.24
# epoch [714/50000] s_loss:2350.5408 d_loss:-20.2463 val_s_loss:22.1013 val_d_loss:-16.4911 heightest auc:0.93 cost:17.02
# epoch [715/50000] s_loss:1037.0814 d_loss:-18.6274 val_s_loss:11.8942 val_d_loss:-17.4369 heightest auc:0.93 cost:17.42
# epoch [716/50000] s_loss:-677.0956 d_loss:-17.6502 val_s_loss:-3.2980 val_d_loss:-13.2335 heightest auc:0.93 cost:18.02
# epoch [717/50000] s_loss:-3368.3296 d_loss:-17.9578 val_s_loss:-32.7777 val_d_loss:-13.0234 heightest auc:0.93 cost:17.71
# epoch [718/50000] s_loss:-7154.0293 d_loss:-16.6184 val_s_loss:-63.5191 val_d_loss:-4.3461 heightest auc:0.93 cost:18.09
# epoch [719/50000] s_loss:-811.6657 d_loss:-12.7546 val_s_loss:-8.3006 val_d_loss:-9.3444 heightest auc:0.93 cost:18.49
# epoch [720/50000] s_loss:3231.5010 d_loss:-14.7328 val_s_loss:30.6728 val_d_loss:-16.0238 heightest auc:0.93 cost:17.47
# epoch [721/50000] s_loss:3784.6809 d_loss:-17.9793 val_s_loss:33.4261 val_d_loss:-18.5953 heightest auc:0.93 cost:17.17
# epoch [722/50000] s_loss:1650.2764 d_loss:-20.0535 val_s_loss:16.2020 val_d_loss:-16.1797 heightest auc:0.93 cost:16.99
# epoch [723/50000] s_loss:-275.2336 d_loss:-19.5936 val_s_loss:-4.3706 val_d_loss:-14.2082 heightest auc:0.93 cost:16.52
# epoch [724/50000] s_loss:-3032.1079 d_loss:-16.9826 val_s_loss:-30.1268 val_d_loss:-14.9415 heightest auc:0.93 cost:17.59
# epoch [725/50000] s_loss:-5810.8721 d_loss:-17.4736 val_s_loss:-64.5031 val_d_loss:-8.1168 heightest auc:0.93 cost:18.20
# epoch [726/50000] s_loss:-5154.7495 d_loss:-15.5598 val_s_loss:-51.6719 val_d_loss:-8.0635 heightest auc:0.93 cost:18.01
# epoch [727/50000] s_loss:-2995.9685 d_loss:-13.9319 val_s_loss:-28.0379 val_d_loss:-15.9343 heightest auc:0.93 cost:17.75
# epoch [728/50000] s_loss:-61.7293 d_loss:-16.8662 val_s_loss:-2.7465 val_d_loss:-12.5898 heightest auc:0.93 cost:17.36
# epoch [729/50000] s_loss:713.0908 d_loss:-16.7276 val_s_loss:8.0514 val_d_loss:-17.2307 heightest auc:0.93 cost:17.19
# epoch [730/50000] s_loss:-1023.5413 d_loss:-14.2634 val_s_loss:-10.2975 val_d_loss:-9.1789 heightest auc:0.93 cost:17.73
# epoch [731/50000] s_loss:-2143.7219 d_loss:-16.1875 val_s_loss:-24.3368 val_d_loss:-9.7722 heightest auc:0.93 cost:17.90
# epoch [732/50000] s_loss:-4112.1533 d_loss:-15.0793 val_s_loss:-39.0522 val_d_loss:-10.3236 heightest auc:0.93 cost:18.72
# epoch [733/50000] s_loss:-1234.7434 d_loss:-14.0342 val_s_loss:-7.8758 val_d_loss:-12.2920 heightest auc:0.93 cost:17.99
# epoch [734/50000] s_loss:908.5233 d_loss:-18.0052 val_s_loss:10.2962 val_d_loss:-10.6613 heightest auc:0.93 cost:18.74
# epoch [735/50000] s_loss:1083.8411 d_loss:-17.5194 val_s_loss:7.7619 val_d_loss:-8.7966 heightest auc:0.93 cost:17.49
# epoch [736/50000] s_loss:-334.3821 d_loss:-19.6855 val_s_loss:-1.8101 val_d_loss:-19.1140 heightest auc:0.93 cost:17.30
# epoch [737/50000] s_loss:-2308.9077 d_loss:-19.8873 val_s_loss:-16.0579 val_d_loss:-21.8610 heightest auc:0.93 cost:17.10
# epoch [738/50000] s_loss:-4846.1211 d_loss:-19.0285 val_s_loss:-49.7337 val_d_loss:-15.3991 heightest auc:0.93 cost:16.83
# epoch [739/50000] s_loss:-6634.6030 d_loss:-17.1923 val_s_loss:-63.7354 val_d_loss:-19.1367 heightest auc:0.93 cost:17.15
# epoch [740/50000] s_loss:-7986.4160 d_loss:-32.3093 val_s_loss:-75.5394 val_d_loss:-11.2209 heightest auc:0.93 cost:16.95
# epoch [741/50000] s_loss:-5318.6699 d_loss:-18.9372 val_s_loss:-51.5115 val_d_loss:-7.8742 heightest auc:0.93 cost:16.99
# epoch [742/50000] s_loss:-1721.8419 d_loss:-13.1943 val_s_loss:-15.9477 val_d_loss:-10.7843 heightest auc:0.93 cost:16.86
# epoch [743/50000] s_loss:1378.0310 d_loss:-15.0045 val_s_loss:9.0960 val_d_loss:-12.5333 heightest auc:0.93 cost:18.30
# epoch [744/50000] s_loss:1070.8835 d_loss:-17.4497 val_s_loss:7.2530 val_d_loss:-13.8907 heightest auc:0.93 cost:18.82
# epoch [745/50000] s_loss:-875.4197 d_loss:-14.4216 val_s_loss:-10.6004 val_d_loss:-7.3990 heightest auc:0.93 cost:18.48
# epoch [746/50000] s_loss:-2011.8124 d_loss:-18.5186 val_s_loss:-23.4411 val_d_loss:-11.7606 heightest auc:0.93 cost:17.96
# epoch [747/50000] s_loss:-2483.8667 d_loss:-21.7009 val_s_loss:-27.2259 val_d_loss:-5.9539 heightest auc:0.93 cost:18.23
# epoch [748/50000] s_loss:-1344.4812 d_loss:-16.2574 val_s_loss:-12.2240 val_d_loss:-13.9715 heightest auc:0.93 cost:17.98
# epoch [749/50000] s_loss:-189.6703 d_loss:-17.1679 val_s_loss:-3.6238 val_d_loss:-14.4248 heightest auc:0.93 cost:17.85
# epoch [750/50000] s_loss:-467.8237 d_loss:-17.3123 val_s_loss:-2.6181 val_d_loss:-9.6596 heightest auc:0.93 cost:17.33
# epoch [751/50000] s_loss:-2043.2832 d_loss:-19.3882 val_s_loss:-22.1975 val_d_loss:-11.4416 heightest auc:0.93 cost:17.68
# epoch [752/50000] s_loss:-4684.8447 d_loss:-14.9863 val_s_loss:-47.3238 val_d_loss:-9.6582 heightest auc:0.93 cost:18.16
# epoch [753/50000] s_loss:-6341.9351 d_loss:-18.4649 val_s_loss:-66.1260 val_d_loss:-9.5193 heightest auc:0.93 cost:17.12
# epoch [754/50000] s_loss:-5056.5454 d_loss:-16.4764 val_s_loss:-55.4834 val_d_loss:-5.9527 heightest auc:0.93 cost:16.57
# epoch [755/50000] s_loss:-2480.5681 d_loss:-11.1868 val_s_loss:-28.1112 val_d_loss:-9.2081 heightest auc:0.93 cost:16.93
# epoch [756/50000] s_loss:-238.9408 d_loss:-15.1113 val_s_loss:3.4250 val_d_loss:-13.4582 heightest auc:0.93 cost:16.54
# epoch [757/50000] s_loss:180.2995 d_loss:-14.8150 val_s_loss:3.8073 val_d_loss:-15.1187 heightest auc:0.93 cost:16.91
# epoch [758/50000] s_loss:-1428.4495 d_loss:-20.1949 val_s_loss:-15.1232 val_d_loss:-18.7659 heightest auc:0.93 cost:17.48
# epoch [759/50000] s_loss:-2910.6323 d_loss:-20.0269 val_s_loss:-31.8162 val_d_loss:-14.4800 heightest auc:0.93 cost:18.02
# epoch [760/50000] s_loss:-4831.8076 d_loss:-15.1539 val_s_loss:-42.8217 val_d_loss:-21.1949 heightest auc:0.93 cost:17.94
# epoch [761/50000] s_loss:-6924.6230 d_loss:-40.3136 val_s_loss:-72.0426 val_d_loss:-8.1864 heightest auc:0.93 cost:18.50
# epoch [762/50000] s_loss:-1953.4985 d_loss:-26.1408 val_s_loss:-25.9207 val_d_loss:-7.3978 heightest auc:0.93 cost:18.28
# epoch [763/50000] s_loss:-1496.2433 d_loss:-15.2817 val_s_loss:-14.9144 val_d_loss:-12.6280 heightest auc:0.93 cost:18.23
# epoch [764/50000] s_loss:67.2006 d_loss:-16.2329 val_s_loss:1.5579 val_d_loss:-10.4495 heightest auc:0.93 cost:17.15
# epoch [765/50000] s_loss:-275.1241 d_loss:-17.8105 val_s_loss:-3.1729 val_d_loss:-14.0384 heightest auc:0.93 cost:17.18
# epoch [766/50000] s_loss:-3779.5327 d_loss:-14.6417 val_s_loss:-35.7220 val_d_loss:-11.1213 heightest auc:0.93 cost:17.67
# epoch [767/50000] s_loss:-7707.0400 d_loss:-14.4654 val_s_loss:-78.4022 val_d_loss:-10.3236 heightest auc:0.93 cost:17.25
# epoch [768/50000] s_loss:-4956.8999 d_loss:-19.4143 val_s_loss:-50.9679 val_d_loss:-7.4803 heightest auc:0.93 cost:17.30
# epoch [769/50000] s_loss:-951.8388 d_loss:-17.2599 val_s_loss:-11.9570 val_d_loss:-7.1811 heightest auc:0.93 cost:17.09
# epoch [770/50000] s_loss:1250.6238 d_loss:-17.6218 val_s_loss:9.3317 val_d_loss:-8.5070 heightest auc:0.93 cost:18.00
# epoch [771/50000] s_loss:1062.3738 d_loss:-19.5530 val_s_loss:4.4267 val_d_loss:-11.1297 heightest auc:0.93 cost:17.08
# epoch [772/50000] s_loss:-1058.3702 d_loss:-18.4924 val_s_loss:-12.3980 val_d_loss:-10.6052 heightest auc:0.93 cost:17.52
# epoch [773/50000] s_loss:-3151.5476 d_loss:-16.0209 val_s_loss:-32.6611 val_d_loss:-9.0984 heightest auc:0.93 cost:17.92
# epoch [774/50000] s_loss:-3891.8118 d_loss:-16.1547 val_s_loss:-40.7664 val_d_loss:-10.0575 heightest auc:0.93 cost:17.86
# epoch [775/50000] s_loss:-4993.9116 d_loss:-17.0270 val_s_loss:-46.0574 val_d_loss:-9.7141 heightest auc:0.93 cost:17.23
# epoch [776/50000] s_loss:-2068.9756 d_loss:-16.6275 val_s_loss:-21.2188 val_d_loss:-15.1666 heightest auc:0.93 cost:17.33
# epoch [777/50000] s_loss:-1060.3624 d_loss:-15.8245 val_s_loss:-13.6484 val_d_loss:-14.7761 heightest auc:0.93 cost:17.03
# epoch [778/50000] s_loss:-2706.1086 d_loss:-19.2904 val_s_loss:-27.4999 val_d_loss:-9.8336 heightest auc:0.93 cost:16.84
# epoch [779/50000] s_loss:-4380.4932 d_loss:-19.9756 val_s_loss:-38.9988 val_d_loss:-15.4640 heightest auc:0.93 cost:18.21
# epoch [780/50000] s_loss:-5435.3994 d_loss:-16.8310 val_s_loss:-52.4462 val_d_loss:-15.9634 heightest auc:0.93 cost:18.16
# epoch [781/50000] s_loss:-5588.0957 d_loss:-17.0328 val_s_loss:-54.0321 val_d_loss:-9.8094 heightest auc:0.93 cost:17.98
# epoch [782/50000] s_loss:-2903.4429 d_loss:-13.2868 val_s_loss:-29.3394 val_d_loss:-9.7346 heightest auc:0.93 cost:16.93
# epoch [783/50000] s_loss:635.6758 d_loss:-15.6837 val_s_loss:8.7178 val_d_loss:-15.4381 heightest auc:0.93 cost:17.47
# epoch [784/50000] s_loss:1105.5903 d_loss:-20.4142 val_s_loss:5.7511 val_d_loss:-18.2649 heightest auc:0.93 cost:17.27
# epoch [785/50000] s_loss:-626.1140 d_loss:-21.3993 val_s_loss:-9.1055 val_d_loss:-17.1506 heightest auc:0.93 cost:18.22
# epoch [786/50000] s_loss:-3877.1084 d_loss:-22.2781 val_s_loss:-39.4418 val_d_loss:-13.6868 heightest auc:0.93 cost:17.96
# epoch [787/50000] s_loss:-5827.4775 d_loss:-20.8992 val_s_loss:-52.8656 val_d_loss:-21.5715 heightest auc:0.93 cost:18.23
# epoch [788/50000] s_loss:-6948.5503 d_loss:-20.9556 val_s_loss:-69.8587 val_d_loss:-9.0553 heightest auc:0.93 cost:17.49
# epoch [789/50000] s_loss:-6879.4922 d_loss:-14.7407 val_s_loss:-64.8117 val_d_loss:-11.3722 heightest auc:0.93 cost:18.05
# epoch [790/50000] s_loss:-7772.8408 d_loss:-28.8338 val_s_loss:-81.1737 val_d_loss:-3.0913 heightest auc:0.93 cost:16.91
# epoch [791/50000] s_loss:-874.0515 d_loss:-10.2391 val_s_loss:-7.3469 val_d_loss:-9.0108 heightest auc:0.93 cost:17.29
# epoch [792/50000] s_loss:4149.0708 d_loss:-17.0082 val_s_loss:38.3251 val_d_loss:-13.3030 heightest auc:0.93 cost:16.67
# epoch [793/50000] s_loss:4571.0068 d_loss:-20.4842 val_s_loss:42.0412 val_d_loss:-15.1486 heightest auc:0.93 cost:17.00
# epoch [794/50000] s_loss:2860.9746 d_loss:-19.3403 val_s_loss:28.3082 val_d_loss:-14.7554 heightest auc:0.93 cost:16.96
# epoch [795/50000] s_loss:936.5607 d_loss:-18.3609 val_s_loss:8.8356 val_d_loss:-13.2950 heightest auc:0.93 cost:16.56
# epoch [796/50000] s_loss:-1614.1898 d_loss:-17.6330 val_s_loss:-11.3200 val_d_loss:-16.0702 heightest auc:0.93 cost:17.23
# epoch [797/50000] s_loss:-3960.5381 d_loss:-15.0834 val_s_loss:-38.3224 val_d_loss:-11.7702 heightest auc:0.93 cost:17.72
# epoch [798/50000] s_loss:-7180.7603 d_loss:-27.0610 val_s_loss:-66.8951 val_d_loss:-6.7511 heightest auc:0.93 cost:19.53
# epoch [799/50000] s_loss:-3996.2590 d_loss:-11.6397 val_s_loss:-35.9679 val_d_loss:-14.6680 heightest auc:0.93 cost:18.30
# epoch [800/50000] s_loss:214.2247 d_loss:-16.3072 val_s_loss:1.8042 val_d_loss:-15.4520 heightest auc:0.93 cost:18.63
# epoch [801/50000] s_loss:1815.4987 d_loss:-18.0372 val_s_loss:14.8762 val_d_loss:-11.9526 heightest auc:0.93 cost:17.96
# epoch [802/50000] s_loss:1235.4163 d_loss:-16.7311 val_s_loss:12.1619 val_d_loss:-18.8422 heightest auc:0.93 cost:17.40
# epoch [803/50000] s_loss:-309.1451 d_loss:-14.4706 val_s_loss:-3.3095 val_d_loss:-9.9598 heightest auc:0.93 cost:17.71
# epoch [804/50000] s_loss:-2066.7021 d_loss:-18.5986 val_s_loss:-20.7151 val_d_loss:-15.1016 heightest auc:0.93 cost:17.32
# epoch [805/50000] s_loss:-2526.6353 d_loss:-13.9825 val_s_loss:-23.4595 val_d_loss:-7.8815 heightest auc:0.93 cost:17.03
# epoch [806/50000] s_loss:-2193.1399 d_loss:-14.1012 val_s_loss:-16.9913 val_d_loss:-17.6469 heightest auc:0.93 cost:17.12
# epoch [807/50000] s_loss:-1356.2170 d_loss:-10.3295 val_s_loss:-8.2150 val_d_loss:-16.8241 heightest auc:0.93 cost:18.23
# epoch [808/50000] s_loss:-1115.4990 d_loss:-15.2746 val_s_loss:-7.2965 val_d_loss:-19.8734 heightest auc:0.93 cost:16.85
# epoch [809/50000] s_loss:-2502.7725 d_loss:-15.6895 val_s_loss:-26.2349 val_d_loss:-9.0586 heightest auc:0.93 cost:16.86
# epoch [810/50000] s_loss:-3744.1509 d_loss:-18.9994 val_s_loss:-32.6755 val_d_loss:-14.3979 heightest auc:0.93 cost:17.11
# epoch [811/50000] s_loss:-1700.6920 d_loss:-15.4324 val_s_loss:-18.0552 val_d_loss:-10.0800 heightest auc:0.93 cost:17.67
# epoch [812/50000] s_loss:1157.9323 d_loss:-16.0601 val_s_loss:8.6065 val_d_loss:-14.1856 heightest auc:0.93 cost:17.82
# epoch [813/50000] s_loss:1432.2483 d_loss:-18.7052 val_s_loss:16.8611 val_d_loss:-18.8271 heightest auc:0.93 cost:17.73
# epoch [814/50000] s_loss:412.6290 d_loss:-21.3408 val_s_loss:10.4587 val_d_loss:-22.9393 heightest auc:0.93 cost:17.05
# epoch [815/50000] s_loss:-1046.0842 d_loss:-20.7574 val_s_loss:-12.6819 val_d_loss:-15.5934 heightest auc:0.93 cost:18.63
# epoch [816/50000] s_loss:-2397.1045 d_loss:-22.6780 val_s_loss:-26.2024 val_d_loss:-16.4531 heightest auc:0.93 cost:17.93
# epoch [817/50000] s_loss:-4309.9917 d_loss:-21.0303 val_s_loss:-43.3549 val_d_loss:-13.4793 heightest auc:0.93 cost:19.00
# epoch [818/50000] s_loss:-6911.4097 d_loss:-17.3928 val_s_loss:-60.0495 val_d_loss:-9.1055 heightest auc:0.93 cost:17.86
# epoch [819/50000] s_loss:-3033.6533 d_loss:-12.7314 val_s_loss:-55.9268 val_d_loss:-8.1031 heightest auc:0.93 cost:17.46
# epoch [820/50000] s_loss:-4315.8672 d_loss:-14.4019 val_s_loss:-38.1716 val_d_loss:-13.3688 heightest auc:0.93 cost:17.33
# epoch [821/50000] s_loss:-902.8930 d_loss:-16.5538 val_s_loss:-8.6512 val_d_loss:-9.8501 heightest auc:0.93 cost:17.65
# epoch [822/50000] s_loss:166.2831 d_loss:-19.0601 val_s_loss:-2.8533 val_d_loss:-13.5459 heightest auc:0.93 cost:17.08
# epoch [823/50000] s_loss:-857.6836 d_loss:-20.9840 val_s_loss:-5.8640 val_d_loss:-14.2430 heightest auc:0.93 cost:17.23
# epoch [824/50000] s_loss:-2242.0735 d_loss:-18.0710 val_s_loss:-17.7342 val_d_loss:-5.5800 heightest auc:0.93 cost:16.97
# epoch [825/50000] s_loss:-2488.5266 d_loss:-17.5116 val_s_loss:-23.9928 val_d_loss:-11.7101 heightest auc:0.93 cost:18.33
# epoch [826/50000] s_loss:-2055.7866 d_loss:-16.9363 val_s_loss:-20.3191 val_d_loss:-11.8073 heightest auc:0.93 cost:17.92
# epoch [827/50000] s_loss:-2087.0803 d_loss:-17.1336 val_s_loss:-22.4122 val_d_loss:-9.9040 heightest auc:0.93 cost:17.87
# epoch [828/50000] s_loss:-1054.4973 d_loss:-16.3941 val_s_loss:-10.2306 val_d_loss:-15.3433 heightest auc:0.93 cost:17.66
# epoch [829/50000] s_loss:-853.5050 d_loss:-15.3336 val_s_loss:-10.1015 val_d_loss:-11.1929 heightest auc:0.93 cost:17.12
# epoch [830/50000] s_loss:-2042.8458 d_loss:-18.1273 val_s_loss:-24.0934 val_d_loss:-15.3444 heightest auc:0.93 cost:16.76
# epoch [831/50000] s_loss:-3519.1599 d_loss:-16.9728 val_s_loss:-31.2652 val_d_loss:-10.5604 heightest auc:0.93 cost:17.19
# epoch [832/50000] s_loss:-3177.8281 d_loss:-15.2931 val_s_loss:-29.7901 val_d_loss:-14.4248 heightest auc:0.93 cost:17.00
# epoch [833/50000] s_loss:-109.4358 d_loss:-16.2609 val_s_loss:1.4061 val_d_loss:-14.0228 heightest auc:0.93 cost:17.19
# epoch [834/50000] s_loss:207.5372 d_loss:-17.5594 val_s_loss:-1.7757 val_d_loss:-12.5548 heightest auc:0.93 cost:18.00
# epoch [835/50000] s_loss:-973.0117 d_loss:-19.8870 val_s_loss:-15.3620 val_d_loss:-6.3408 heightest auc:0.93 cost:18.56
# epoch [836/50000] s_loss:-2816.6992 d_loss:-18.1178 val_s_loss:-30.7909 val_d_loss:-7.6920 heightest auc:0.93 cost:17.95
# epoch [837/50000] s_loss:-5853.4727 d_loss:-13.1252 val_s_loss:-62.0944 val_d_loss:-7.1822 heightest auc:0.93 cost:17.64

# %%
AE.eval()
S.eval()
for index, img in enumerate(test_loader):
    test_img = Variable(img[0]).cuda()

    # ======AE======
    blur_image = AE(test_img)
    
    noise = torch.zeros(blur_image.shape[0], 1, blur_image.shape[2], blur_image.shape[3] )
    noise = noise + (0.01**0.5)*torch.randn(blur_image.shape[0], 1, blur_image.shape[2], blur_image.shape[3])
    noise = noise.cuda()
    blur_image_with_noise = torch.cat([blur_image, noise], 1)
    fake_image = S(blur_image_with_noise)
    
    
    vutils.save_image(fake_image[0], './test_result/{}_simulated.png'.format(index))
    vutils.save_image(blur_image[0], './test_result/{}_blur.png'.format(index))
    vutils.save_image(test_img, './test_result/{}_origin.png'.format(index))
