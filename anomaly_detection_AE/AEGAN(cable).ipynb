# %%
import sys
sys.path.append('../')

import os
import time
import numpy as np

from torch.utils.data import DataLoader
from torch.autograd import Variable
from torch import autograd

import torch
import torch.nn as nn
import torch.nn.functional as F


from utils.tools import get_config, default_loader, is_image_file, normalize
from tensorboardX import SummaryWriter
import matplotlib.pyplot as plt
import torchvision.utils as vutils

from sklearn.metrics import roc_auc_score
sys.path.append('../PerceptualSimilarity')
import models as PerceptualSimilarity

# personal library
from networks import autoencoder, simulator, discriminator
from dataloader import MVTecDataset

# %%
# 限制可以使用的 GPU
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="2,3"

# %%
# HYPER parameters
num_epochs = 50000
batch_size = 32
val_batch_size = 4
ae_lr = 1e-4
s_lr = 5e-4
d_lr = 5e-4
weight_decay = 1e-5
UPSET=True
expName = 'AEGAN-exp(cable + L1)'
writer = SummaryWriter('checkpoints/'+expName)
TYPE='cable'

# %%
trainDatset = MVTecDataset.MVTecDataset(TYPE=TYPE, isTrain='train')
testDatset = MVTecDataset.MVTecDataset(TYPE=TYPE, isTrain='test')
valDataset = MVTecDataset.MVTecDataset(TYPE=TYPE, isTrain='val')

val_loader = DataLoader(
    dataset=valDataset,
    batch_size=val_batch_size, 
    shuffle=True,
    num_workers=4
)
train_loader = DataLoader(
    dataset=trainDatset,
    batch_size=batch_size, 
    shuffle=True,
    num_workers=4
)
test_loader = DataLoader(
    dataset=testDatset,
    batch_size=1,
    shuffle=True,
    num_workers=4
)

# %%
# Model
AE = autoencoder.Autoencoder().cuda()
S = nn.DataParallel(simulator.Simulator(3, 8)).cuda()
D = nn.DataParallel(discriminator.Discriminator(6, 16)).cuda()

# Loss
L1_loss = nn.L1Loss()
L2_loss = nn.MSELoss(reduction='none')
perceptual_loss = PerceptualSimilarity.PerceptualLoss(model='net-lin', net='alex', use_gpu=True, gpu_ids=[0])

# Optimizer
optimizer_AE = torch.optim.Adam(
    AE.parameters(), 
    lr=ae_lr,
    weight_decay=weight_decay
)
optimizer_S = torch.optim.Adam(
    S.parameters(), 
    lr=s_lr,
    weight_decay=weight_decay
)
optimizer_D = torch.optim.Adam(
    D.parameters(), 
    lr=d_lr,
    weight_decay=weight_decay
)


Tensor = torch.cuda.FloatTensor
# Out:
# Setting up Perceptual loss...
# Loading model from: /root/AFS/Corn/AEGAN/PerceptualSimilarity/models/weights/v0.1/alex.pth
# ...[net-lin [alex]] initialized
# ...Done

# %%
AE.load_state_dict(torch.load('./save_weight/AE-cable-z-2x2-exp1/AE_4800.npy', map_location="cuda:0"), False)

AE = nn.DataParallel(AE)

# %%
# To Solve: RuntimeError: cuDNN error: CUDNN_STATUS_EXECUTION_FAILED
torch.backends.cudnn.enabled = False 

# 拿掉煩人的 warning
import warnings
warnings.filterwarnings("ignore")

# %%
LAMBDA = 10

def calc_gradient_penalty(netD, real_data, fake_data):
    # print "real_data: ", real_data.size(), fake_data.size()
    BATCH_SIZE = real_data.size(0)
    alpha = torch.rand(BATCH_SIZE, 1)
    alpha = alpha.expand(BATCH_SIZE, real_data.nelement()//BATCH_SIZE).contiguous().view(BATCH_SIZE, 6, 256, 256)
    alpha = alpha.cuda()

    interpolates = alpha * real_data + ((1 - alpha) * fake_data)

    interpolates = interpolates.cuda()
    interpolates = autograd.Variable(interpolates, requires_grad=True)

    disc_interpolates = netD(interpolates)

    gradients = autograd.grad(
        outputs=disc_interpolates, 
        inputs=interpolates,
        grad_outputs=torch.ones(disc_interpolates.size()).cuda(),
        create_graph=True, 
        retain_graph=True, 
        only_inputs=True
    )[0]
    gradients = gradients.view(gradients.size(0), -1)

    gradient_penalty = ((gradients.norm(2, dim=1) - 1) ** 2).mean() * LAMBDA
    return gradient_penalty

def difNormalize(input_matrix, threshold=None):
    _min = torch.min(input_matrix)
    _max = torch.max(input_matrix)
    
    input_matrix = (input_matrix - _min) / (_max - _min)
    
    if threshold != None:
        input_matrix[input_matrix < threshold] = 0
        input_matrix[input_matrix >= threshold] = 1
        
    return input_matrix

def gradient_loss(gen_frames, gt_frames, alpha=1):
    def gradient(x):
        h_x = x.size()[-2]
        w_x = x.size()[-1]
        # gradient step=1
        left = x
        right = F.pad(x, [0, 1, 0, 0])[:, :, :, 1:]
        top = x
        bottom = F.pad(x, [0, 0, 0, 1])[:, :, 1:, :]

        # dx, dy = torch.abs(right - left), torch.abs(bottom - top)
        dx, dy = right - left, bottom - top 
        # dx will always have zeros in the last column, right-left
        # dy will always have zeros in the last row,    bottom-top
        dx[:, :, :, -1] = 0
        dy[:, :, -1, :] = 0

        return dx, dy

    # gradient
    gen_dx, gen_dy = gradient(gen_frames)
    gt_dx, gt_dy = gradient(gt_frames)
    #
    grad_diff_x = torch.abs(gt_dx - gen_dx)
    grad_diff_y = torch.abs(gt_dy - gen_dy)

    # condense into one tensor and avg
    return torch.mean(grad_diff_x ** alpha + grad_diff_y ** alpha)

# %%
heightest_score = 0
for epoch in range(num_epochs): 
    start = time.time()
    ######## GAN ################
    one = torch.FloatTensor([1])
    mone = one * -1
    
    one = one.cuda()
    mone = mone.cuda()
    
    one = one.mean()
    mone = mone.mean()
    ## ==== GAN --> D =====
    for i in range(3):
        for index, img in enumerate(train_loader):
            AE.eval(), S.train(), D.train()

            img = Variable(img).cuda()

            # ====== AE ======
            blur_image = AE(img)

            _bs, _c, _w, _h = blur_image.shape
            noise = torch.zeros(_bs, 1, _w, _h )
            noise = noise + (0.01**0.5)*torch.randn(_bs, 1, _w, _h)
            noise = noise.cuda()

            blur_image_with_noise = torch.cat([blur_image, noise], 1)
            fake_image = S(blur_image_with_noise) # 當成是 residual
            
            fake_image = fake_image + blur_image # blur image + residual
            
            fake_pair = torch.cat([img, fake_image], 1)
            real_pair = torch.cat([img, img[torch.randperm(img.size(0)), :, :, :]], 1) if UPSET else torch.cat([img, img], 1)
            # ====== Train D ======
            for p in D.parameters():
                p.requires_grad = True

            optimizer_AE.zero_grad()
            optimizer_S.zero_grad()
            optimizer_D.zero_grad()


            real_D = D(real_pair)
            real_D = real_D.mean()
            real_D.backward(mone)


            fake_D = D(fake_pair)
            fake_D = fake_D.mean()
            fake_D.backward(one)

            gradient_penalty = calc_gradient_penalty(D, real_pair, fake_pair)
            gradient_penalty.backward()

            cost_D = fake_D - real_D + gradient_penalty
            Wasserstein_D = real_D - fake_D
            optimizer_D.step()
    
    ## ==== GAN --> G =====
    for index, img in enumerate(train_loader):
        AE.eval(), S.train(), D.train()

        img = Variable(img).cuda()
        # ======AE======
        blur_image = AE(img)

        _bs, _c, _w, _h = blur_image.shape
        noise = torch.zeros(_bs, 1, _w, _h )
        noise = noise + (0.01**0.5)*torch.randn(_bs, 1, _w, _h)
        noise = noise.cuda()

        blur_image_with_noise = torch.cat([blur_image, noise], 1)
        fake_image = S(blur_image_with_noise)
        
        fake_image = fake_image + blur_image
        
        fake_pair = torch.cat([img, fake_image], 1)
        # ====== Train G ======
        for p in D.parameters():
            p.requires_grad = False
            
        G_L1 = L1_loss(img, fake_image)
        G = D(fake_pair)
        G = G.mean()
        G = G + G_L1 * ( G / G_L1) * 100
        
        optimizer_AE.zero_grad()
        optimizer_S.zero_grad()
        optimizer_D.zero_grad()
        
        G.backward(mone)
        
        cost_G = -G
        optimizer_S.step()
        
    
    # validation set
    for index, val_img in enumerate(val_loader):
        AE.eval(), S.eval(), D.eval()

        val_img = Variable(val_img).cuda()
        # ======AE======
        val_blur_image = AE(val_img)

        _bs, _c, _w, _h = val_blur_image.shape
        noise = torch.zeros(_bs, 1, _w, _h )
        noise = noise + (0.01**0.5)*torch.randn(_bs, 1, _w, _h)
        noise = noise.cuda()

        val_blur_image_with_noise = torch.cat([val_blur_image, noise], 1)

        val_fake_image = S(val_blur_image_with_noise)       
        val_fake_image = val_fake_image + val_blur_image
        
        
        val_fake_pair = torch.cat([val_img, val_fake_image], 1)
        val_real_pair = torch.cat([val_img, val_img[torch.randperm(val_img.size(0)), :, :, :]], 1) if UPSET else torch.cat([val_img, val_img], 1)
        
        val_real_D = D(val_real_pair)
        val_real_D = val_real_D.mean()
        
        val_fake_D = D(val_fake_pair)
        val_fake_D = val_fake_D.mean()
        
        val_gradient_penalty = calc_gradient_penalty(D, val_real_pair, val_fake_pair)
        
        val_grad_loss = gradient_loss(val_fake_image, val_img)
        val_G_L1 = L1_loss(val_img, val_fake_image)
        # =========== Losses =========
        val_Wasserstein_D = val_real_D - val_fake_D
        
        val_cost_G = -val_fake_D
        val_cost_D = val_fake_D - val_real_D + val_gradient_penalty
    
    # evaluate
    test_total_AUC = 0
    test_total_AUC2 = 0
    test_total_image = 0

    for index, (test_img, mask) in enumerate(test_loader):
        AE.eval(), S.eval(), D.eval()
        test_img = Variable(test_img).cuda()
        test_blur_image = AE(test_img)

        _bs, _c, _w, _h = test_blur_image.shape
        noise = torch.zeros(_bs, 1, _w, _h )
        noise = noise + (0.01**0.5)*torch.randn(_bs, 1, _w, _h)
        noise = noise.cuda()

        test_blur_image_with_noise = torch.cat([test_blur_image, noise], 1)

        test_fake_image = S(test_blur_image_with_noise)       
        test_fake_image = test_fake_image + test_blur_image

        # 計算 dif (相似度以及 L2)
        dif, _ = perceptual_loss.forward(test_fake_image, test_img)
        l2Dif = L2_loss(test_fake_image, test_img)
        l2Dif = torch.mean(l2Dif, 1, True)
        
        pred_mask2 = difNormalize(dif)
        pred_mask2 = torch.flatten(pred_mask2[0])
        
        pred_mask = difNormalize(dif[0] * l2Dif[0])
        pred_mask = torch.flatten(pred_mask)
        
        mask = torch.mean(mask, 1, True)
        true_mask = mask[0].cpu().detach().numpy().flatten()
        true_mask = true_mask.astype(int)

        AUC = roc_auc_score(true_mask, pred_mask.cpu().detach().numpy())
        AUC2 = roc_auc_score(true_mask, pred_mask2.cpu().detach().numpy())

        test_total_AUC += AUC
        test_total_AUC2 += AUC2
        test_total_image += 1
    if heightest_score < (test_total_AUC / test_total_image) :
        heightest_score = (test_total_AUC / test_total_image)
    # =================== GAN log========================
    end = time.time()
    print('epoch [{}/{}] s_loss:{:.4f} d_loss:{:.4f} val_s_loss:{:.4f} val_d_loss:{:.4f} heightest auc:{:.2f} cost:{:.2f}'.format(epoch+1, num_epochs, cost_G.item(), cost_D.item(), val_cost_G.item(), val_cost_D.item(), heightest_score, end-start ))
    writer.add_scalars('eval', {
        "auc_roc_score": test_total_AUC / test_total_image,
        "auc_roc_score(w/o L2)": test_total_AUC2 / test_total_image,
        "heightest roc_score": heightest_score
    }, epoch)
    
    writer.add_scalars('loss', {
        "Wasserstein Distance": Wasserstein_D.item(),
        "Val Wasserstein Distance": val_Wasserstein_D.item(),
        "gradient penalty": gradient_penalty,
        "val gradient penalty": val_gradient_penalty
    }, epoch)
    
    writer.add_scalars('gan loss', {
        "l1_loss": G_L1.item(),
        "g_loss": cost_G.item(),
        "d_loss": cost_D.item(),
        "val_l1_loss": val_G_L1.item(),
        "val_g_loss": val_cost_G.item(),
        "val_d_loss": val_cost_D.item()
    }, epoch)

    writer.add_images('Blur', blur_image, epoch)
    writer.add_images('Reconstruct', fake_image, epoch)
    writer.add_images('Origin', img, epoch)

    writer.add_images('Val Blur', val_blur_image, epoch)
    writer.add_images('Val Reconstruct', val_fake_image, epoch)
    writer.add_images('Val Origin', val_img, epoch)


        
    if epoch % 10 == 0:
        if not os.path.exists('./save_weight/{}'.format(expName)):
            os.makedirs('./save_weight/{}'.format(expName))
        torch.save(S.state_dict(), './save_weight/{}/S_{}.npy'.format(expName, epoch))
        torch.save(D.state_dict(), './save_weight/{}/D_{}.npy'.format(expName, epoch))
# Out:
# epoch [1/50000] s_loss:73448.2266 d_loss:-264.8117 val_s_loss:736.3297 val_d_loss:37.0251 heightest auc:0.67 cost:24.81
# epoch [2/50000] s_loss:132854.5625 d_loss:-424.3993 val_s_loss:1352.0348 val_d_loss:-140.8354 heightest auc:0.67 cost:19.44
# epoch [3/50000] s_loss:93527.9922 d_loss:-297.1892 val_s_loss:742.4600 val_d_loss:13.4698 heightest auc:0.69 cost:20.23
# epoch [4/50000] s_loss:94687.6094 d_loss:-291.8166 val_s_loss:1091.3484 val_d_loss:-293.1441 heightest auc:0.69 cost:19.81
# epoch [5/50000] s_loss:77998.3594 d_loss:-241.8849 val_s_loss:530.1040 val_d_loss:67.8010 heightest auc:0.75 cost:20.37
# epoch [6/50000] s_loss:73946.9141 d_loss:-227.9984 val_s_loss:557.6768 val_d_loss:1.6665 heightest auc:0.75 cost:20.37
# epoch [7/50000] s_loss:63224.2930 d_loss:-229.9867 val_s_loss:625.2786 val_d_loss:-152.9929 heightest auc:0.75 cost:20.17
# epoch [8/50000] s_loss:49060.6523 d_loss:-211.5894 val_s_loss:336.6675 val_d_loss:-6.9580 heightest auc:0.82 cost:20.41
# epoch [9/50000] s_loss:41376.6523 d_loss:-192.5883 val_s_loss:272.0209 val_d_loss:14.5068 heightest auc:0.85 cost:20.93
# epoch [10/50000] s_loss:43672.7070 d_loss:-145.9921 val_s_loss:702.9263 val_d_loss:-372.5063 heightest auc:0.85 cost:20.57
# epoch [11/50000] s_loss:40888.8164 d_loss:-149.5497 val_s_loss:453.4232 val_d_loss:-160.4370 heightest auc:0.85 cost:20.19
# epoch [12/50000] s_loss:35983.2969 d_loss:-112.0542 val_s_loss:223.6626 val_d_loss:-8.8491 heightest auc:0.85 cost:20.02
# epoch [13/50000] s_loss:45873.1602 d_loss:-153.4053 val_s_loss:716.1454 val_d_loss:-352.7407 heightest auc:0.85 cost:20.43
# epoch [14/50000] s_loss:33931.2070 d_loss:-97.2286 val_s_loss:705.2563 val_d_loss:-432.6762 heightest auc:0.85 cost:20.87
# epoch [15/50000] s_loss:21956.8242 d_loss:-85.4336 val_s_loss:117.1160 val_d_loss:-12.4640 heightest auc:0.85 cost:21.04
# epoch [16/50000] s_loss:44263.5820 d_loss:-262.7513 val_s_loss:1050.7563 val_d_loss:-569.3167 heightest auc:0.85 cost:20.16
# epoch [17/50000] s_loss:15634.1064 d_loss:-77.3964 val_s_loss:151.7709 val_d_loss:-41.2917 heightest auc:0.85 cost:19.67
# epoch [18/50000] s_loss:31534.0195 d_loss:-70.3428 val_s_loss:451.1243 val_d_loss:-183.5566 heightest auc:0.85 cost:19.78
# epoch [19/50000] s_loss:18467.2969 d_loss:-85.5655 val_s_loss:117.1672 val_d_loss:10.5256 heightest auc:0.85 cost:20.35
# epoch [20/50000] s_loss:26788.0625 d_loss:-103.7743 val_s_loss:407.6504 val_d_loss:-196.0596 heightest auc:0.85 cost:19.89
# epoch [21/50000] s_loss:15454.6582 d_loss:-66.2483 val_s_loss:80.1266 val_d_loss:5.5793 heightest auc:0.85 cost:20.11
# epoch [22/50000] s_loss:16451.1133 d_loss:-78.2536 val_s_loss:106.0851 val_d_loss:1.0313 heightest auc:0.85 cost:21.04
# epoch [23/50000] s_loss:11474.6357 d_loss:-49.3980 val_s_loss:70.8172 val_d_loss:-11.4142 heightest auc:0.85 cost:20.59
# epoch [24/50000] s_loss:13297.9580 d_loss:-55.5148 val_s_loss:312.8316 val_d_loss:-211.6852 heightest auc:0.85 cost:21.00
# epoch [25/50000] s_loss:8491.2256 d_loss:-45.5099 val_s_loss:45.2894 val_d_loss:3.1630 heightest auc:0.85 cost:20.45
# epoch [26/50000] s_loss:10946.4014 d_loss:-45.7992 val_s_loss:38.5742 val_d_loss:0.8883 heightest auc:0.85 cost:20.39
# epoch [27/50000] s_loss:7375.5513 d_loss:-38.8803 val_s_loss:29.8630 val_d_loss:-1.1151 heightest auc:0.85 cost:19.91
# epoch [28/50000] s_loss:10751.7588 d_loss:-30.6689 val_s_loss:101.0089 val_d_loss:-47.0234 heightest auc:0.85 cost:19.93
# epoch [29/50000] s_loss:7445.6050 d_loss:-48.0053 val_s_loss:78.6655 val_d_loss:-53.9629 heightest auc:0.85 cost:19.52
# epoch [30/50000] s_loss:3986.0774 d_loss:-30.6606 val_s_loss:1.7719 val_d_loss:0.7967 heightest auc:0.85 cost:20.76
# epoch [31/50000] s_loss:56997.5664 d_loss:-370.9928 val_s_loss:1372.1121 val_d_loss:-768.0947 heightest auc:0.85 cost:21.01
# epoch [32/50000] s_loss:17628.0840 d_loss:-56.6011 val_s_loss:160.9548 val_d_loss:-35.8192 heightest auc:0.85 cost:21.34
# epoch [33/50000] s_loss:35434.4023 d_loss:-109.0574 val_s_loss:318.7328 val_d_loss:-34.2598 heightest auc:0.85 cost:20.12
# epoch [34/50000] s_loss:22864.2129 d_loss:-68.5489 val_s_loss:354.8669 val_d_loss:-161.2016 heightest auc:0.85 cost:19.50
# epoch [35/50000] s_loss:16549.6660 d_loss:-88.3845 val_s_loss:196.6558 val_d_loss:-50.0411 heightest auc:0.85 cost:19.87
# epoch [36/50000] s_loss:62002.7188 d_loss:-264.4172 val_s_loss:828.4097 val_d_loss:-211.2731 heightest auc:0.85 cost:20.39
# epoch [37/50000] s_loss:40716.7578 d_loss:-86.4799 val_s_loss:456.5449 val_d_loss:-113.2957 heightest auc:0.85 cost:20.89
# epoch [38/50000] s_loss:27476.3438 d_loss:-112.1846 val_s_loss:283.3645 val_d_loss:-7.3179 heightest auc:0.85 cost:20.99
# epoch [39/50000] s_loss:43880.5312 d_loss:-143.5002 val_s_loss:306.1345 val_d_loss:-19.5184 heightest auc:0.85 cost:20.74
# epoch [40/50000] s_loss:44215.1484 d_loss:-310.6403 val_s_loss:457.1593 val_d_loss:55.8542 heightest auc:0.85 cost:20.42
# epoch [41/50000] s_loss:32690.1758 d_loss:-141.1383 val_s_loss:713.0981 val_d_loss:-474.9602 heightest auc:0.85 cost:19.93
# epoch [42/50000] s_loss:50251.1875 d_loss:-210.0826 val_s_loss:1111.4395 val_d_loss:-656.9292 heightest auc:0.85 cost:19.50
# epoch [43/50000] s_loss:33477.6719 d_loss:-165.3944 val_s_loss:909.2635 val_d_loss:-587.7683 heightest auc:0.85 cost:19.60
# epoch [44/50000] s_loss:44955.1094 d_loss:-145.9521 val_s_loss:896.1943 val_d_loss:-467.9894 heightest auc:0.85 cost:19.55
# epoch [45/50000] s_loss:28458.5801 d_loss:-106.4442 val_s_loss:590.1028 val_d_loss:-277.4878 heightest auc:0.85 cost:19.63
# epoch [46/50000] s_loss:45443.0938 d_loss:-125.3063 val_s_loss:810.6616 val_d_loss:-444.8892 heightest auc:0.85 cost:19.24
# epoch [47/50000] s_loss:42777.4688 d_loss:-161.9087 val_s_loss:795.0372 val_d_loss:-394.0570 heightest auc:0.85 cost:21.71
# epoch [48/50000] s_loss:47102.1875 d_loss:-123.6368 val_s_loss:1005.0286 val_d_loss:-536.6017 heightest auc:0.85 cost:21.73
# epoch [49/50000] s_loss:24251.0078 d_loss:-72.4763 val_s_loss:861.7129 val_d_loss:-593.7305 heightest auc:0.85 cost:20.93
# epoch [50/50000] s_loss:9621.3145 d_loss:-9.3011 val_s_loss:317.8912 val_d_loss:-222.9379 heightest auc:0.85 cost:20.19
# epoch [51/50000] s_loss:12744.8760 d_loss:-15.0236 val_s_loss:293.2087 val_d_loss:-182.1910 heightest auc:0.85 cost:21.00
# epoch [52/50000] s_loss:16343.7031 d_loss:-28.0861 val_s_loss:368.0487 val_d_loss:-228.5061 heightest auc:0.85 cost:20.37
# epoch [53/50000] s_loss:22684.8887 d_loss:-52.3109 val_s_loss:559.2047 val_d_loss:-372.4344 heightest auc:0.85 cost:20.68
# epoch [54/50000] s_loss:27455.2324 d_loss:-47.5558 val_s_loss:687.0030 val_d_loss:-442.2050 heightest auc:0.85 cost:20.31
# epoch [55/50000] s_loss:22691.4473 d_loss:-69.4991 val_s_loss:458.4766 val_d_loss:-284.3130 heightest auc:0.85 cost:20.19
# epoch [56/50000] s_loss:19013.6211 d_loss:-55.8966 val_s_loss:408.1840 val_d_loss:-266.6474 heightest auc:0.85 cost:21.20
# epoch [57/50000] s_loss:12849.6416 d_loss:-62.9248 val_s_loss:245.5697 val_d_loss:-166.0089 heightest auc:0.85 cost:19.91
# epoch [58/50000] s_loss:12031.0479 d_loss:-52.9802 val_s_loss:273.2632 val_d_loss:-203.7490 heightest auc:0.85 cost:19.65
# epoch [59/50000] s_loss:12205.8291 d_loss:-67.7134 val_s_loss:132.6846 val_d_loss:-46.9924 heightest auc:0.85 cost:19.58
# epoch [60/50000] s_loss:27898.2871 d_loss:-135.1128 val_s_loss:1045.0261 val_d_loss:-735.6185 heightest auc:0.85 cost:19.71
# epoch [61/50000] s_loss:31943.0586 d_loss:-73.1846 val_s_loss:382.3883 val_d_loss:-94.3360 heightest auc:0.85 cost:19.76
# epoch [62/50000] s_loss:16239.6152 d_loss:-59.4371 val_s_loss:124.8089 val_d_loss:17.2979 heightest auc:0.85 cost:19.82
# epoch [63/50000] s_loss:12504.4551 d_loss:-46.6440 val_s_loss:103.2257 val_d_loss:-19.9087 heightest auc:0.85 cost:19.88
# epoch [64/50000] s_loss:14528.1426 d_loss:-35.8475 val_s_loss:185.4832 val_d_loss:-73.5926 heightest auc:0.85 cost:21.96
# epoch [65/50000] s_loss:11645.5781 d_loss:-44.9176 val_s_loss:133.1757 val_d_loss:-52.0503 heightest auc:0.85 cost:22.34
# epoch [66/50000] s_loss:13647.7539 d_loss:-40.2291 val_s_loss:71.1317 val_d_loss:-14.8062 heightest auc:0.85 cost:20.98
# epoch [67/50000] s_loss:11775.3301 d_loss:-33.0828 val_s_loss:152.8327 val_d_loss:-52.4160 heightest auc:0.85 cost:20.38
# epoch [68/50000] s_loss:10114.1562 d_loss:-53.1678 val_s_loss:263.8894 val_d_loss:-120.5611 heightest auc:0.85 cost:20.19
# epoch [69/50000] s_loss:13858.8750 d_loss:-41.1335 val_s_loss:154.3034 val_d_loss:-83.3712 heightest auc:0.85 cost:19.89
# epoch [70/50000] s_loss:15315.8809 d_loss:-73.0126 val_s_loss:156.5743 val_d_loss:-25.1175 heightest auc:0.85 cost:20.44
# epoch [71/50000] s_loss:10602.9746 d_loss:-30.7821 val_s_loss:114.0038 val_d_loss:-64.1074 heightest auc:0.85 cost:19.48
# epoch [72/50000] s_loss:5556.4609 d_loss:-56.6843 val_s_loss:146.3167 val_d_loss:-79.2307 heightest auc:0.85 cost:19.49
# epoch [73/50000] s_loss:7394.6475 d_loss:-69.9106 val_s_loss:102.5576 val_d_loss:-47.4722 heightest auc:0.85 cost:20.61
# epoch [74/50000] s_loss:319.3041 d_loss:-52.5470 val_s_loss:-33.6836 val_d_loss:-25.8852 heightest auc:0.85 cost:19.99
# epoch [75/50000] s_loss:14085.7549 d_loss:-57.2415 val_s_loss:193.3015 val_d_loss:-110.0657 heightest auc:0.85 cost:19.71
# epoch [76/50000] s_loss:4635.3828 d_loss:-42.8085 val_s_loss:-16.7107 val_d_loss:8.2323 heightest auc:0.85 cost:19.72
# epoch [77/50000] s_loss:6750.9038 d_loss:-75.2770 val_s_loss:54.8037 val_d_loss:1.9573 heightest auc:0.85 cost:19.50
# epoch [78/50000] s_loss:-6312.3555 d_loss:-38.9234 val_s_loss:-74.1956 val_d_loss:29.5210 heightest auc:0.85 cost:20.37
# epoch [79/50000] s_loss:80639.1797 d_loss:-427.9678 val_s_loss:1739.4875 val_d_loss:-747.0634 heightest auc:0.85 cost:20.82
# epoch [80/50000] s_loss:1276.1830 d_loss:-12.5506 val_s_loss:-8.8399 val_d_loss:15.6075 heightest auc:0.85 cost:21.21
# epoch [81/50000] s_loss:8536.6924 d_loss:-29.3405 val_s_loss:91.0775 val_d_loss:-34.1309 heightest auc:0.85 cost:21.80
# epoch [82/50000] s_loss:23560.5586 d_loss:-56.3751 val_s_loss:146.4899 val_d_loss:9.4078 heightest auc:0.85 cost:21.33
# epoch [83/50000] s_loss:18553.9648 d_loss:-55.3497 val_s_loss:123.1932 val_d_loss:4.7164 heightest auc:0.85 cost:20.42
# epoch [84/50000] s_loss:16245.9414 d_loss:-68.9545 val_s_loss:86.2254 val_d_loss:-7.3052 heightest auc:0.85 cost:19.53
# epoch [85/50000] s_loss:8057.9614 d_loss:-46.1471 val_s_loss:123.4268 val_d_loss:-65.9040 heightest auc:0.85 cost:19.89
# epoch [86/50000] s_loss:4416.9683 d_loss:-49.3976 val_s_loss:-14.9578 val_d_loss:2.1198 heightest auc:0.85 cost:20.41
# epoch [87/50000] s_loss:9343.5723 d_loss:-74.8131 val_s_loss:78.7707 val_d_loss:-32.6689 heightest auc:0.85 cost:19.65
# epoch [88/50000] s_loss:40225.2109 d_loss:-169.0337 val_s_loss:393.7159 val_d_loss:-15.7208 heightest auc:0.85 cost:19.74
# epoch [89/50000] s_loss:15653.7725 d_loss:-65.2399 val_s_loss:108.0662 val_d_loss:13.9540 heightest auc:0.85 cost:20.45
# epoch [90/50000] s_loss:14608.1602 d_loss:-61.1122 val_s_loss:125.8858 val_d_loss:-32.0180 heightest auc:0.85 cost:20.08
# epoch [91/50000] s_loss:8247.0674 d_loss:-65.1994 val_s_loss:32.2021 val_d_loss:4.3696 heightest auc:0.85 cost:20.15
# epoch [92/50000] s_loss:6720.7095 d_loss:-73.6739 val_s_loss:119.6236 val_d_loss:-120.0633 heightest auc:0.85 cost:20.25
# epoch [93/50000] s_loss:3687.4822 d_loss:-73.4138 val_s_loss:1.0303 val_d_loss:-33.9735 heightest auc:0.85 cost:20.43
# epoch [94/50000] s_loss:482.9842 d_loss:-60.0545 val_s_loss:55.9468 val_d_loss:-91.8118 heightest auc:0.85 cost:20.12
# epoch [95/50000] s_loss:1467.9900 d_loss:-86.4829 val_s_loss:-47.8965 val_d_loss:-13.3140 heightest auc:0.85 cost:20.33
# epoch [96/50000] s_loss:194.7737 d_loss:-56.9252 val_s_loss:-25.4317 val_d_loss:-19.3833 heightest auc:0.85 cost:20.14
# epoch [97/50000] s_loss:12923.8223 d_loss:-92.5303 val_s_loss:108.8893 val_d_loss:-25.6525 heightest auc:0.85 cost:20.53
# epoch [98/50000] s_loss:959.4375 d_loss:-45.8528 val_s_loss:39.1782 val_d_loss:-34.5452 heightest auc:0.85 cost:21.24
# epoch [99/50000] s_loss:22802.9062 d_loss:-124.6646 val_s_loss:356.1929 val_d_loss:-200.6111 heightest auc:0.85 cost:21.35
# epoch [100/50000] s_loss:45397.4570 d_loss:-207.0385 val_s_loss:486.7216 val_d_loss:-225.6704 heightest auc:0.85 cost:19.64
# epoch [101/50000] s_loss:32077.8730 d_loss:-241.5088 val_s_loss:186.4610 val_d_loss:102.1185 heightest auc:0.85 cost:20.11
# epoch [102/50000] s_loss:12628.0508 d_loss:-75.3152 val_s_loss:98.6937 val_d_loss:12.7268 heightest auc:0.85 cost:19.81
# epoch [103/50000] s_loss:9607.3701 d_loss:-43.2317 val_s_loss:51.5373 val_d_loss:-9.1685 heightest auc:0.85 cost:19.88
# epoch [104/50000] s_loss:13685.5938 d_loss:-44.1980 val_s_loss:152.2078 val_d_loss:-50.9270 heightest auc:0.85 cost:19.61
# epoch [105/50000] s_loss:14287.0244 d_loss:-74.9482 val_s_loss:161.8909 val_d_loss:-87.6814 heightest auc:0.85 cost:19.80
# epoch [106/50000] s_loss:8964.9424 d_loss:-70.6015 val_s_loss:10.7402 val_d_loss:7.0975 heightest auc:0.85 cost:21.06
# epoch [107/50000] s_loss:4266.2769 d_loss:-73.5593 val_s_loss:44.9239 val_d_loss:-1.2711 heightest auc:0.85 cost:20.74
# epoch [108/50000] s_loss:12657.9268 d_loss:-78.6589 val_s_loss:75.7169 val_d_loss:-40.5350 heightest auc:0.85 cost:20.96
# epoch [109/50000] s_loss:7620.7505 d_loss:-51.5681 val_s_loss:69.0596 val_d_loss:-54.8444 heightest auc:0.85 cost:20.67
# epoch [110/50000] s_loss:5494.7690 d_loss:-58.2897 val_s_loss:67.9258 val_d_loss:-94.0780 heightest auc:0.85 cost:20.06
# epoch [111/50000] s_loss:2847.3301 d_loss:-100.1686 val_s_loss:36.4578 val_d_loss:-43.0522 heightest auc:0.85 cost:19.80
# epoch [112/50000] s_loss:176.5927 d_loss:-50.5484 val_s_loss:-15.9204 val_d_loss:-28.1192 heightest auc:0.85 cost:19.72
# epoch [113/50000] s_loss:-542.0865 d_loss:-51.5590 val_s_loss:-3.7128 val_d_loss:-17.6273 heightest auc:0.85 cost:19.40
# epoch [114/50000] s_loss:-2920.9177 d_loss:-54.0799 val_s_loss:-72.9159 val_d_loss:-17.2612 heightest auc:0.85 cost:21.09
# epoch [115/50000] s_loss:7717.7627 d_loss:-58.3319 val_s_loss:77.8067 val_d_loss:-31.3109 heightest auc:0.85 cost:21.08
# epoch [116/50000] s_loss:8388.1914 d_loss:-72.7744 val_s_loss:138.0798 val_d_loss:-73.3477 heightest auc:0.85 cost:20.80
# epoch [117/50000] s_loss:-3546.2195 d_loss:-40.8214 val_s_loss:-46.0482 val_d_loss:10.3403 heightest auc:0.85 cost:19.86
# epoch [118/50000] s_loss:10033.4082 d_loss:-136.9364 val_s_loss:106.7548 val_d_loss:-65.2076 heightest auc:0.85 cost:19.47
# epoch [119/50000] s_loss:1509.6306 d_loss:-31.5578 val_s_loss:-3.8676 val_d_loss:-12.8435 heightest auc:0.85 cost:19.69
# epoch [120/50000] s_loss:-5841.9058 d_loss:-48.6055 val_s_loss:-50.0280 val_d_loss:-37.7966 heightest auc:0.85 cost:20.24
# epoch [121/50000] s_loss:-9480.9316 d_loss:-55.1048 val_s_loss:-128.2187 val_d_loss:8.2682 heightest auc:0.85 cost:20.41
# epoch [122/50000] s_loss:-9969.4912 d_loss:-46.3759 val_s_loss:-71.1041 val_d_loss:-45.6445 heightest auc:0.85 cost:21.38
# epoch [123/50000] s_loss:-9296.4385 d_loss:-47.0785 val_s_loss:-113.8763 val_d_loss:-41.1171 heightest auc:0.85 cost:21.65
# epoch [124/50000] s_loss:-2075.4292 d_loss:-61.3861 val_s_loss:-50.1529 val_d_loss:9.3158 heightest auc:0.85 cost:20.39
# epoch [125/50000] s_loss:15836.6299 d_loss:-100.2146 val_s_loss:384.5549 val_d_loss:-238.9655 heightest auc:0.85 cost:20.55
# epoch [126/50000] s_loss:-4301.9170 d_loss:-44.0350 val_s_loss:-13.6954 val_d_loss:-77.8012 heightest auc:0.85 cost:20.10
# epoch [127/50000] s_loss:-9893.7002 d_loss:-65.2989 val_s_loss:-123.2246 val_d_loss:-47.2250 heightest auc:0.85 cost:20.03
# epoch [128/50000] s_loss:-7528.1328 d_loss:-62.3571 val_s_loss:-96.7050 val_d_loss:5.2859 heightest auc:0.85 cost:19.75
# epoch [129/50000] s_loss:-6993.2910 d_loss:-59.5125 val_s_loss:-79.4850 val_d_loss:-39.7190 heightest auc:0.85 cost:19.50
# epoch [130/50000] s_loss:1113.0238 d_loss:-52.0195 val_s_loss:33.1748 val_d_loss:-83.6280 heightest auc:0.85 cost:20.11
# epoch [131/50000] s_loss:1093.3950 d_loss:-64.2638 val_s_loss:-30.7089 val_d_loss:-9.5662 heightest auc:0.85 cost:21.18
# epoch [132/50000] s_loss:15236.2988 d_loss:-99.4477 val_s_loss:180.0430 val_d_loss:-23.1370 heightest auc:0.85 cost:21.02
# epoch [133/50000] s_loss:-5202.9155 d_loss:-46.1758 val_s_loss:-86.2986 val_d_loss:5.4975 heightest auc:0.85 cost:21.04
# epoch [134/50000] s_loss:-2243.2356 d_loss:-70.0302 val_s_loss:0.8311 val_d_loss:-15.3066 heightest auc:0.85 cost:19.56
# epoch [135/50000] s_loss:-5685.0425 d_loss:-57.4631 val_s_loss:-54.2357 val_d_loss:9.8431 heightest auc:0.85 cost:20.51
# epoch [136/50000] s_loss:12400.7637 d_loss:-33.4038 val_s_loss:68.1969 val_d_loss:-1.3127 heightest auc:0.85 cost:20.33
# epoch [137/50000] s_loss:8484.2490 d_loss:-76.1398 val_s_loss:41.9642 val_d_loss:-36.6175 heightest auc:0.85 cost:20.56
# epoch [138/50000] s_loss:5206.8584 d_loss:-64.6298 val_s_loss:70.8848 val_d_loss:-52.2061 heightest auc:0.85 cost:20.87
# epoch [139/50000] s_loss:-3522.3296 d_loss:-50.4001 val_s_loss:77.2606 val_d_loss:-118.6143 heightest auc:0.85 cost:20.97
# epoch [140/50000] s_loss:-1738.5287 d_loss:-55.9827 val_s_loss:-0.5653 val_d_loss:-76.3686 heightest auc:0.85 cost:21.45
# epoch [141/50000] s_loss:3869.7551 d_loss:-49.0104 val_s_loss:18.9588 val_d_loss:-39.3406 heightest auc:0.85 cost:20.03
# epoch [142/50000] s_loss:6992.7734 d_loss:-56.1077 val_s_loss:38.1189 val_d_loss:-21.6136 heightest auc:0.85 cost:19.46
# epoch [143/50000] s_loss:1885.6178 d_loss:-78.0891 val_s_loss:-18.3337 val_d_loss:-9.9910 heightest auc:0.85 cost:19.43
# epoch [144/50000] s_loss:7812.4229 d_loss:-107.0845 val_s_loss:59.4337 val_d_loss:-2.5187 heightest auc:0.85 cost:19.56
# epoch [145/50000] s_loss:-2698.9663 d_loss:-50.1810 val_s_loss:-25.2559 val_d_loss:-16.8547 heightest auc:0.85 cost:19.68
# epoch [146/50000] s_loss:-4622.5264 d_loss:-58.8230 val_s_loss:-61.6188 val_d_loss:-40.0702 heightest auc:0.85 cost:19.33
# epoch [147/50000] s_loss:-453.3146 d_loss:-46.5908 val_s_loss:-71.1921 val_d_loss:-24.6405 heightest auc:0.85 cost:20.30
# epoch [148/50000] s_loss:-5107.9526 d_loss:-68.4847 val_s_loss:-48.3581 val_d_loss:-22.9412 heightest auc:0.85 cost:21.31
# epoch [149/50000] s_loss:-8590.4062 d_loss:-55.6444 val_s_loss:-109.8064 val_d_loss:-46.2915 heightest auc:0.85 cost:20.98
# epoch [150/50000] s_loss:-11138.9219 d_loss:-63.5163 val_s_loss:-116.4720 val_d_loss:-43.9057 heightest auc:0.85 cost:21.10
# epoch [151/50000] s_loss:-10271.0986 d_loss:-59.6963 val_s_loss:-106.4811 val_d_loss:-5.1694 heightest auc:0.85 cost:20.62
# epoch [152/50000] s_loss:17498.9414 d_loss:-45.0935 val_s_loss:215.0294 val_d_loss:-27.6554 heightest auc:0.85 cost:20.92
# epoch [153/50000] s_loss:-7993.0542 d_loss:-44.1781 val_s_loss:-88.5656 val_d_loss:-74.1754 heightest auc:0.85 cost:20.52
# epoch [154/50000] s_loss:-10608.4180 d_loss:-71.4999 val_s_loss:-77.7801 val_d_loss:-90.8894 heightest auc:0.85 cost:20.37
# epoch [155/50000] s_loss:-5414.3042 d_loss:-82.1592 val_s_loss:-89.8224 val_d_loss:-36.9378 heightest auc:0.85 cost:20.28
# epoch [156/50000] s_loss:-6677.7754 d_loss:-71.3749 val_s_loss:-71.8388 val_d_loss:-25.6031 heightest auc:0.85 cost:19.62
# epoch [157/50000] s_loss:-7956.6772 d_loss:-62.7222 val_s_loss:-106.0778 val_d_loss:-48.1174 heightest auc:0.85 cost:20.29
# epoch [158/50000] s_loss:6924.6758 d_loss:-54.0728 val_s_loss:-5.7944 val_d_loss:-44.4841 heightest auc:0.85 cost:19.48
# epoch [159/50000] s_loss:13278.0215 d_loss:-31.4442 val_s_loss:114.4515 val_d_loss:-12.1021 heightest auc:0.85 cost:19.69
# epoch [160/50000] s_loss:-4290.3604 d_loss:-53.5592 val_s_loss:-69.4132 val_d_loss:-41.9106 heightest auc:0.85 cost:19.98
# epoch [161/50000] s_loss:-7502.5146 d_loss:-71.8815 val_s_loss:-67.1276 val_d_loss:-34.3049 heightest auc:0.85 cost:19.68
# epoch [162/50000] s_loss:-6956.9214 d_loss:-73.7671 val_s_loss:-98.6095 val_d_loss:-13.1098 heightest auc:0.85 cost:20.01
# epoch [163/50000] s_loss:-7238.3716 d_loss:-58.2952 val_s_loss:-99.9007 val_d_loss:-49.7989 heightest auc:0.85 cost:19.70
# epoch [164/50000] s_loss:-6597.7754 d_loss:-61.8180 val_s_loss:-84.8251 val_d_loss:-48.0214 heightest auc:0.85 cost:20.03
# epoch [165/50000] s_loss:-7754.3799 d_loss:-68.7828 val_s_loss:-107.4650 val_d_loss:-53.8605 heightest auc:0.85 cost:21.84
# epoch [166/50000] s_loss:-1865.1207 d_loss:-63.3972 val_s_loss:-43.8634 val_d_loss:-15.4989 heightest auc:0.85 cost:21.66
# epoch [167/50000] s_loss:15172.9355 d_loss:-72.8295 val_s_loss:122.6675 val_d_loss:-28.6337 heightest auc:0.85 cost:21.45
# epoch [168/50000] s_loss:253.8261 d_loss:-52.1461 val_s_loss:-11.7595 val_d_loss:-21.7389 heightest auc:0.85 cost:20.54
# epoch [169/50000] s_loss:-7398.3003 d_loss:-53.0607 val_s_loss:-74.7181 val_d_loss:-55.2075 heightest auc:0.85 cost:20.22
# epoch [170/50000] s_loss:-3210.2412 d_loss:-58.3082 val_s_loss:-29.4629 val_d_loss:-66.5393 heightest auc:0.85 cost:19.99
# epoch [171/50000] s_loss:-1124.7920 d_loss:-64.4704 val_s_loss:-7.1846 val_d_loss:-26.7476 heightest auc:0.85 cost:19.57
# epoch [172/50000] s_loss:-4528.6841 d_loss:-48.8056 val_s_loss:-45.2986 val_d_loss:-2.4818 heightest auc:0.85 cost:19.88
# epoch [173/50000] s_loss:-3648.7107 d_loss:-50.9881 val_s_loss:-54.7357 val_d_loss:-40.2676 heightest auc:0.85 cost:20.14
# epoch [174/50000] s_loss:992.3435 d_loss:-41.9128 val_s_loss:-7.7735 val_d_loss:-44.8271 heightest auc:0.85 cost:20.93
# epoch [175/50000] s_loss:1873.5432 d_loss:-60.7263 val_s_loss:33.9470 val_d_loss:-65.3703 heightest auc:0.85 cost:19.91
# epoch [176/50000] s_loss:-2201.3123 d_loss:-46.7026 val_s_loss:-41.2148 val_d_loss:-10.0943 heightest auc:0.85 cost:20.02
# epoch [177/50000] s_loss:13885.2969 d_loss:-92.2692 val_s_loss:174.0700 val_d_loss:-44.3380 heightest auc:0.85 cost:19.78
# epoch [178/50000] s_loss:-2877.2900 d_loss:-55.1532 val_s_loss:-39.8158 val_d_loss:-8.3915 heightest auc:0.85 cost:21.06
# epoch [179/50000] s_loss:-9884.6143 d_loss:-64.4964 val_s_loss:-76.2723 val_d_loss:-79.8411 heightest auc:0.85 cost:20.55
# epoch [180/50000] s_loss:-7639.8252 d_loss:-58.6025 val_s_loss:-94.5955 val_d_loss:-1.9263 heightest auc:0.85 cost:20.87
# epoch [181/50000] s_loss:17446.8027 d_loss:-124.4072 val_s_loss:464.2937 val_d_loss:-269.1560 heightest auc:0.85 cost:21.20
# epoch [182/50000] s_loss:2935.3191 d_loss:-31.7697 val_s_loss:-18.4508 val_d_loss:42.7642 heightest auc:0.85 cost:21.42
# epoch [183/50000] s_loss:-1234.1235 d_loss:-37.1636 val_s_loss:-28.3423 val_d_loss:-5.4016 heightest auc:0.85 cost:20.76
# epoch [184/50000] s_loss:-6869.9688 d_loss:-38.4351 val_s_loss:-75.5179 val_d_loss:-8.5320 heightest auc:0.85 cost:20.15
# epoch [185/50000] s_loss:1183.1219 d_loss:-94.7211 val_s_loss:15.1722 val_d_loss:-29.4371 heightest auc:0.85 cost:19.76
# epoch [186/50000] s_loss:5477.0156 d_loss:-69.6572 val_s_loss:19.3376 val_d_loss:-26.6002 heightest auc:0.85 cost:19.76
# epoch [187/50000] s_loss:-3295.1682 d_loss:-64.5862 val_s_loss:-33.7802 val_d_loss:-51.8611 heightest auc:0.85 cost:19.70
# epoch [188/50000] s_loss:-6667.0435 d_loss:-62.1859 val_s_loss:-82.9357 val_d_loss:-53.8121 heightest auc:0.85 cost:20.27
# epoch [189/50000] s_loss:-23.4575 d_loss:-84.2104 val_s_loss:-24.2146 val_d_loss:-27.9909 heightest auc:0.85 cost:20.09
# epoch [190/50000] s_loss:-9644.9775 d_loss:-51.6009 val_s_loss:-99.8603 val_d_loss:11.2181 heightest auc:0.85 cost:21.07
# epoch [191/50000] s_loss:15048.0488 d_loss:-60.0408 val_s_loss:140.4670 val_d_loss:-41.1810 heightest auc:0.85 cost:20.29
# epoch [192/50000] s_loss:-5070.3911 d_loss:-52.3190 val_s_loss:-87.0149 val_d_loss:-27.6513 heightest auc:0.85 cost:20.38
# epoch [193/50000] s_loss:-9634.3936 d_loss:-62.4754 val_s_loss:-105.3102 val_d_loss:-54.4701 heightest auc:0.85 cost:21.12
# epoch [194/50000] s_loss:-7033.7500 d_loss:-59.5811 val_s_loss:-92.3219 val_d_loss:-48.8395 heightest auc:0.85 cost:20.68
# epoch [195/50000] s_loss:-5839.3286 d_loss:-54.5498 val_s_loss:-67.5462 val_d_loss:-29.3981 heightest auc:0.85 cost:20.41
# epoch [196/50000] s_loss:-784.4684 d_loss:-54.9250 val_s_loss:-27.3744 val_d_loss:-42.3015 heightest auc:0.85 cost:20.30
# epoch [197/50000] s_loss:8590.0283 d_loss:-94.4083 val_s_loss:28.1553 val_d_loss:-4.2517 heightest auc:0.85 cost:20.06
# epoch [198/50000] s_loss:870.5357 d_loss:-69.0479 val_s_loss:-20.5966 val_d_loss:-14.4382 heightest auc:0.85 cost:21.15
# epoch [199/50000] s_loss:-8026.2598 d_loss:-69.1205 val_s_loss:-68.4123 val_d_loss:-56.7137 heightest auc:0.85 cost:21.11
# epoch [200/50000] s_loss:-2736.6538 d_loss:-59.6337 val_s_loss:-63.8587 val_d_loss:-13.1932 heightest auc:0.85 cost:20.55
# epoch [201/50000] s_loss:22583.1523 d_loss:-240.5183 val_s_loss:176.2345 val_d_loss:23.1478 heightest auc:0.85 cost:20.16
# epoch [202/50000] s_loss:165.7109 d_loss:-62.1459 val_s_loss:-3.7534 val_d_loss:-44.4237 heightest auc:0.85 cost:20.13
# epoch [203/50000] s_loss:-4799.3711 d_loss:-51.1559 val_s_loss:-43.4001 val_d_loss:-55.8240 heightest auc:0.85 cost:20.79
# epoch [204/50000] s_loss:-6127.4214 d_loss:-71.8852 val_s_loss:-65.2806 val_d_loss:-62.9660 heightest auc:0.85 cost:20.41
# epoch [205/50000] s_loss:-5999.1987 d_loss:-62.9677 val_s_loss:-84.3697 val_d_loss:-9.2527 heightest auc:0.85 cost:20.77
# epoch [206/50000] s_loss:-6322.0430 d_loss:-71.5448 val_s_loss:-48.2705 val_d_loss:-27.5322 heightest auc:0.85 cost:21.09
# epoch [207/50000] s_loss:-4962.1494 d_loss:-49.1927 val_s_loss:-59.8590 val_d_loss:-47.1056 heightest auc:0.85 cost:20.28
# epoch [208/50000] s_loss:146.7307 d_loss:-59.9741 val_s_loss:-11.2464 val_d_loss:-14.2902 heightest auc:0.85 cost:20.20
# epoch [209/50000] s_loss:3848.5044 d_loss:-57.8500 val_s_loss:13.5647 val_d_loss:-16.7906 heightest auc:0.85 cost:19.57
# epoch [210/50000] s_loss:1976.9896 d_loss:-60.8436 val_s_loss:0.9228 val_d_loss:-38.7548 heightest auc:0.85 cost:20.08
# epoch [211/50000] s_loss:18182.0508 d_loss:-147.2018 val_s_loss:232.0197 val_d_loss:-87.1348 heightest auc:0.85 cost:19.89
# epoch [212/50000] s_loss:5395.6875 d_loss:-77.0219 val_s_loss:36.8284 val_d_loss:-23.0583 heightest auc:0.85 cost:19.87
# epoch [213/50000] s_loss:-2845.0366 d_loss:-67.4068 val_s_loss:-64.2330 val_d_loss:-31.4865 heightest auc:0.85 cost:19.77
# epoch [214/50000] s_loss:-6109.6626 d_loss:-74.2439 val_s_loss:-27.3974 val_d_loss:-90.0365 heightest auc:0.85 cost:20.19
# epoch [215/50000] s_loss:-6332.8726 d_loss:-54.2531 val_s_loss:-73.6091 val_d_loss:-61.4075 heightest auc:0.85 cost:21.54
# epoch [216/50000] s_loss:-3337.9507 d_loss:-65.8321 val_s_loss:-62.0330 val_d_loss:-57.8957 heightest auc:0.85 cost:21.82
# epoch [217/50000] s_loss:11077.5430 d_loss:-92.8398 val_s_loss:110.3844 val_d_loss:-21.6158 heightest auc:0.85 cost:21.02
# epoch [218/50000] s_loss:-2849.6931 d_loss:-50.1113 val_s_loss:-50.0826 val_d_loss:-26.4846 heightest auc:0.85 cost:20.97
# epoch [219/50000] s_loss:-3322.9417 d_loss:-46.5432 val_s_loss:-54.1362 val_d_loss:-23.1313 heightest auc:0.85 cost:20.40
# epoch [220/50000] s_loss:7775.9233 d_loss:-127.6655 val_s_loss:105.0143 val_d_loss:-28.3481 heightest auc:0.85 cost:20.24
# epoch [221/50000] s_loss:-2458.6978 d_loss:-57.7657 val_s_loss:-16.6799 val_d_loss:-30.3380 heightest auc:0.85 cost:20.10
# epoch [222/50000] s_loss:-7751.0581 d_loss:-72.9842 val_s_loss:-77.6239 val_d_loss:-54.1288 heightest auc:0.85 cost:19.80
# epoch [223/50000] s_loss:-7753.6118 d_loss:-70.8771 val_s_loss:-58.0940 val_d_loss:-50.8905 heightest auc:0.85 cost:20.81
# epoch [224/50000] s_loss:-5407.9414 d_loss:-64.2476 val_s_loss:-69.5136 val_d_loss:-22.0549 heightest auc:0.85 cost:20.50
# epoch [225/50000] s_loss:6531.2114 d_loss:-85.4419 val_s_loss:19.1582 val_d_loss:5.0795 heightest auc:0.85 cost:20.16
# epoch [226/50000] s_loss:3621.6606 d_loss:-64.9403 val_s_loss:18.6521 val_d_loss:-36.4301 heightest auc:0.85 cost:20.30
# epoch [227/50000] s_loss:-3806.1580 d_loss:-60.4528 val_s_loss:-55.9346 val_d_loss:-10.0414 heightest auc:0.85 cost:19.46
# epoch [228/50000] s_loss:-588.4717 d_loss:-74.1859 val_s_loss:20.6174 val_d_loss:-52.9529 heightest auc:0.85 cost:19.85
# epoch [229/50000] s_loss:-3412.7485 d_loss:-63.1316 val_s_loss:-11.3771 val_d_loss:-38.2694 heightest auc:0.85 cost:20.25
# epoch [230/50000] s_loss:14201.3418 d_loss:-81.6005 val_s_loss:99.0811 val_d_loss:-33.9618 heightest auc:0.85 cost:21.07
# epoch [231/50000] s_loss:3380.3943 d_loss:-63.6046 val_s_loss:25.8128 val_d_loss:-10.7668 heightest auc:0.85 cost:21.86
# epoch [232/50000] s_loss:-3049.7358 d_loss:-63.5058 val_s_loss:-54.4007 val_d_loss:-18.2361 heightest auc:0.85 cost:22.06
# epoch [233/50000] s_loss:-6534.2988 d_loss:-59.3988 val_s_loss:-81.9360 val_d_loss:-35.3039 heightest auc:0.85 cost:21.14
# epoch [234/50000] s_loss:13152.0801 d_loss:-103.6039 val_s_loss:196.6039 val_d_loss:-89.8274 heightest auc:0.85 cost:20.10
# epoch [235/50000] s_loss:-7772.2632 d_loss:-64.1512 val_s_loss:-54.9326 val_d_loss:-55.8984 heightest auc:0.85 cost:19.73
# epoch [236/50000] s_loss:-9868.2881 d_loss:-72.1637 val_s_loss:-110.4992 val_d_loss:-27.3272 heightest auc:0.85 cost:19.87
# epoch [237/50000] s_loss:-8066.8726 d_loss:-75.0643 val_s_loss:-91.6136 val_d_loss:-74.1805 heightest auc:0.85 cost:20.43
# epoch [238/50000] s_loss:-5393.9888 d_loss:-68.2815 val_s_loss:-66.5387 val_d_loss:-57.8296 heightest auc:0.85 cost:20.00
# epoch [239/50000] s_loss:-934.0347 d_loss:-60.9278 val_s_loss:-28.7445 val_d_loss:-44.4031 heightest auc:0.85 cost:19.94
# epoch [240/50000] s_loss:16031.2822 d_loss:-64.4755 val_s_loss:156.0088 val_d_loss:-22.1748 heightest auc:0.85 cost:20.48
# epoch [241/50000] s_loss:631.8597 d_loss:-53.4372 val_s_loss:-11.1671 val_d_loss:-46.0125 heightest auc:0.85 cost:19.98
# epoch [242/50000] s_loss:-5109.6157 d_loss:-69.2851 val_s_loss:-68.5015 val_d_loss:-41.5844 heightest auc:0.85 cost:20.24
# epoch [243/50000] s_loss:-5924.8945 d_loss:-54.2885 val_s_loss:-69.7100 val_d_loss:-29.2698 heightest auc:0.85 cost:20.53
# epoch [244/50000] s_loss:20185.9023 d_loss:-45.6932 val_s_loss:168.9419 val_d_loss:-5.6563 heightest auc:0.85 cost:20.82
# epoch [245/50000] s_loss:-4055.5833 d_loss:-54.7866 val_s_loss:-37.8576 val_d_loss:-28.7033 heightest auc:0.85 cost:20.39
# epoch [246/50000] s_loss:-6925.1143 d_loss:-66.6784 val_s_loss:-98.3938 val_d_loss:-22.2191 heightest auc:0.85 cost:20.63
# epoch [247/50000] s_loss:-7251.3750 d_loss:-74.9880 val_s_loss:-93.0924 val_d_loss:-72.4180 heightest auc:0.85 cost:20.25
# epoch [248/50000] s_loss:-6078.0508 d_loss:-67.3845 val_s_loss:-68.7885 val_d_loss:-43.1986 heightest auc:0.85 cost:21.06
# epoch [249/50000] s_loss:-2310.1108 d_loss:-54.6172 val_s_loss:-33.7313 val_d_loss:-28.1681 heightest auc:0.85 cost:20.85
# epoch [250/50000] s_loss:10728.5000 d_loss:-67.0521 val_s_loss:104.0279 val_d_loss:-25.2555 heightest auc:0.85 cost:19.70
# epoch [251/50000] s_loss:12622.0400 d_loss:-85.1882 val_s_loss:102.5682 val_d_loss:-26.8840 heightest auc:0.85 cost:19.74
# epoch [252/50000] s_loss:1672.8694 d_loss:-59.7249 val_s_loss:-7.1492 val_d_loss:-12.0706 heightest auc:0.85 cost:19.84
# epoch [253/50000] s_loss:-5110.9258 d_loss:-71.5162 val_s_loss:-58.6214 val_d_loss:-31.8389 heightest auc:0.85 cost:19.99
# epoch [254/50000] s_loss:-6391.6431 d_loss:-69.3637 val_s_loss:-75.2633 val_d_loss:-51.9588 heightest auc:0.85 cost:20.45
# epoch [255/50000] s_loss:-7534.1084 d_loss:-53.2304 val_s_loss:-86.4863 val_d_loss:-24.8253 heightest auc:0.85 cost:20.23
# epoch [256/50000] s_loss:-7693.7339 d_loss:-64.6210 val_s_loss:-78.4681 val_d_loss:-51.8830 heightest auc:0.85 cost:21.42
# epoch [257/50000] s_loss:-1239.8101 d_loss:-63.8816 val_s_loss:-29.9018 val_d_loss:-28.8526 heightest auc:0.85 cost:21.04
# epoch [258/50000] s_loss:7198.5771 d_loss:-66.2342 val_s_loss:49.9306 val_d_loss:-23.0058 heightest auc:0.85 cost:20.35
# epoch [259/50000] s_loss:808.5588 d_loss:-53.4316 val_s_loss:-26.8643 val_d_loss:-6.3318 heightest auc:0.85 cost:20.44
# epoch [260/50000] s_loss:1071.5961 d_loss:-57.8662 val_s_loss:-5.1767 val_d_loss:-49.1188 heightest auc:0.85 cost:20.24
# epoch [261/50000] s_loss:924.9539 d_loss:-54.9856 val_s_loss:-9.4709 val_d_loss:-5.0521 heightest auc:0.85 cost:19.50
# epoch [262/50000] s_loss:8299.8965 d_loss:-69.5536 val_s_loss:72.7991 val_d_loss:-46.8616 heightest auc:0.85 cost:19.76
# epoch [263/50000] s_loss:642.4842 d_loss:-56.6087 val_s_loss:-22.4193 val_d_loss:-24.1442 heightest auc:0.85 cost:19.91
# epoch [264/50000] s_loss:-4614.8218 d_loss:-55.7418 val_s_loss:-56.6942 val_d_loss:-14.6255 heightest auc:0.85 cost:20.38
# epoch [265/50000] s_loss:3773.7046 d_loss:-53.1241 val_s_loss:-6.8924 val_d_loss:-22.7136 heightest auc:0.85 cost:21.22
# epoch [266/50000] s_loss:519.6150 d_loss:-54.2909 val_s_loss:6.2911 val_d_loss:-18.0546 heightest auc:0.85 cost:21.14
# epoch [267/50000] s_loss:567.4988 d_loss:-56.8297 val_s_loss:-10.8545 val_d_loss:-37.3402 heightest auc:0.85 cost:20.70
# epoch [268/50000] s_loss:4321.3423 d_loss:-55.5109 val_s_loss:77.2929 val_d_loss:-62.1726 heightest auc:0.85 cost:20.44
# epoch [269/50000] s_loss:9563.4688 d_loss:-93.2472 val_s_loss:80.0667 val_d_loss:-49.5740 heightest auc:0.85 cost:20.55
# epoch [270/50000] s_loss:-2615.6655 d_loss:-44.4300 val_s_loss:-32.6999 val_d_loss:-17.0236 heightest auc:0.85 cost:20.90
# epoch [271/50000] s_loss:-6557.7598 d_loss:-51.0216 val_s_loss:-73.0486 val_d_loss:-23.9322 heightest auc:0.85 cost:20.44
# epoch [272/50000] s_loss:-3688.9246 d_loss:-46.4210 val_s_loss:-43.1821 val_d_loss:-20.2831 heightest auc:0.85 cost:20.42
# epoch [273/50000] s_loss:26325.8066 d_loss:-116.4214 val_s_loss:235.3163 val_d_loss:9.6091 heightest auc:0.85 cost:21.10
# epoch [274/50000] s_loss:-2007.7671 d_loss:-44.5099 val_s_loss:-18.4850 val_d_loss:-33.7424 heightest auc:0.85 cost:19.62
# epoch [275/50000] s_loss:-4906.9565 d_loss:-70.0570 val_s_loss:-68.8402 val_d_loss:-55.7582 heightest auc:0.85 cost:19.32
# epoch [276/50000] s_loss:-4388.9258 d_loss:-75.2127 val_s_loss:-66.1709 val_d_loss:-60.5424 heightest auc:0.85 cost:20.00
# epoch [277/50000] s_loss:-4757.6782 d_loss:-72.4225 val_s_loss:-69.7414 val_d_loss:-61.7388 heightest auc:0.85 cost:20.19
# epoch [278/50000] s_loss:-5259.3896 d_loss:-72.8196 val_s_loss:-64.0213 val_d_loss:-58.6962 heightest auc:0.85 cost:19.82
# epoch [279/50000] s_loss:-1682.0630 d_loss:-61.0944 val_s_loss:-27.4620 val_d_loss:-21.3993 heightest auc:0.85 cost:19.88
# epoch [280/50000] s_loss:10002.6309 d_loss:-75.8363 val_s_loss:80.5444 val_d_loss:-36.3163 heightest auc:0.85 cost:20.19
# epoch [281/50000] s_loss:-3120.9641 d_loss:-47.4350 val_s_loss:-37.6638 val_d_loss:-65.3917 heightest auc:0.85 cost:21.98
# epoch [282/50000] s_loss:-7942.5264 d_loss:-66.2659 val_s_loss:-88.0556 val_d_loss:-32.9177 heightest auc:0.85 cost:22.24
# epoch [283/50000] s_loss:-7982.1245 d_loss:-56.5252 val_s_loss:-91.5731 val_d_loss:-54.1689 heightest auc:0.85 cost:21.14
# epoch [284/50000] s_loss:-4507.1172 d_loss:-58.3673 val_s_loss:-36.6356 val_d_loss:-75.8720 heightest auc:0.85 cost:20.71
# epoch [285/50000] s_loss:-1662.2081 d_loss:-62.3756 val_s_loss:-14.5737 val_d_loss:-29.4604 heightest auc:0.85 cost:20.28
# epoch [286/50000] s_loss:3877.1443 d_loss:-69.1928 val_s_loss:2.9296 val_d_loss:-33.1154 heightest auc:0.85 cost:19.90
# epoch [287/50000] s_loss:5118.4678 d_loss:-59.1178 val_s_loss:53.4871 val_d_loss:-54.2322 heightest auc:0.85 cost:19.89
# epoch [288/50000] s_loss:6196.3296 d_loss:-53.6639 val_s_loss:57.3424 val_d_loss:-43.6784 heightest auc:0.85 cost:20.79
# epoch [289/50000] s_loss:4778.3184 d_loss:-50.5153 val_s_loss:33.3212 val_d_loss:-41.4610 heightest auc:0.85 cost:20.58
# epoch [290/50000] s_loss:9395.4883 d_loss:-50.6531 val_s_loss:81.6419 val_d_loss:-68.7102 heightest auc:0.85 cost:19.71
# epoch [291/50000] s_loss:1270.2203 d_loss:-58.7989 val_s_loss:2.5001 val_d_loss:-48.7452 heightest auc:0.85 cost:20.01
# epoch [292/50000] s_loss:-1012.8519 d_loss:-44.2291 val_s_loss:-19.0090 val_d_loss:-22.7844 heightest auc:0.85 cost:20.19
# epoch [293/50000] s_loss:-3641.0527 d_loss:-59.0289 val_s_loss:-38.3080 val_d_loss:-56.2374 heightest auc:0.85 cost:20.71
# epoch [294/50000] s_loss:7452.1792 d_loss:-88.3941 val_s_loss:52.9291 val_d_loss:-12.9904 heightest auc:0.85 cost:20.62
# epoch [295/50000] s_loss:1763.5510 d_loss:-53.0121 val_s_loss:16.4918 val_d_loss:-36.5480 heightest auc:0.85 cost:20.38
# epoch [296/50000] s_loss:433.9937 d_loss:-46.9734 val_s_loss:-13.6215 val_d_loss:-14.5370 heightest auc:0.85 cost:20.76
# epoch [297/50000] s_loss:8418.3867 d_loss:-61.6757 val_s_loss:56.8120 val_d_loss:-21.4503 heightest auc:0.85 cost:21.06
# epoch [298/50000] s_loss:230.6162 d_loss:-41.5156 val_s_loss:-4.5877 val_d_loss:-18.5361 heightest auc:0.85 cost:21.15
# epoch [299/50000] s_loss:-409.0772 d_loss:-59.7156 val_s_loss:-13.0292 val_d_loss:-13.3235 heightest auc:0.85 cost:20.93
# epoch [300/50000] s_loss:-98.7284 d_loss:-44.9742 val_s_loss:-3.7188 val_d_loss:-38.4600 heightest auc:0.85 cost:19.72
# epoch [301/50000] s_loss:14174.6035 d_loss:-93.0774 val_s_loss:116.5104 val_d_loss:-36.2101 heightest auc:0.85 cost:20.23
# epoch [302/50000] s_loss:874.1415 d_loss:-45.4792 val_s_loss:5.9935 val_d_loss:-47.7784 heightest auc:0.85 cost:20.42
# epoch [303/50000] s_loss:-5082.8911 d_loss:-68.9713 val_s_loss:-47.4355 val_d_loss:-77.7006 heightest auc:0.85 cost:20.13
# epoch [304/50000] s_loss:-7647.0542 d_loss:-58.9281 val_s_loss:-68.9088 val_d_loss:-49.8406 heightest auc:0.85 cost:20.41
# epoch [305/50000] s_loss:-3772.4702 d_loss:-58.6976 val_s_loss:-42.5642 val_d_loss:-67.1804 heightest auc:0.85 cost:20.48
# epoch [306/50000] s_loss:3476.0232 d_loss:-52.0633 val_s_loss:20.9670 val_d_loss:-16.1107 heightest auc:0.85 cost:21.49
# epoch [307/50000] s_loss:18674.3867 d_loss:-62.7090 val_s_loss:167.3659 val_d_loss:-22.1710 heightest auc:0.85 cost:20.74
# epoch [308/50000] s_loss:4459.7686 d_loss:-53.6714 val_s_loss:62.5778 val_d_loss:-74.6824 heightest auc:0.85 cost:20.50
# epoch [309/50000] s_loss:-2919.3284 d_loss:-58.4004 val_s_loss:-22.8950 val_d_loss:-40.3405 heightest auc:0.85 cost:20.26
# epoch [310/50000] s_loss:-2403.5569 d_loss:-62.4486 val_s_loss:-30.5273 val_d_loss:-25.5755 heightest auc:0.85 cost:19.74
# epoch [311/50000] s_loss:11407.6992 d_loss:-55.3912 val_s_loss:119.0294 val_d_loss:-33.7293 heightest auc:0.85 cost:19.87
# epoch [312/50000] s_loss:7130.7822 d_loss:-50.5254 val_s_loss:61.9427 val_d_loss:-26.5497 heightest auc:0.85 cost:19.40
# epoch [313/50000] s_loss:874.8281 d_loss:-52.7029 val_s_loss:-0.3470 val_d_loss:-16.5702 heightest auc:0.85 cost:19.75
# epoch [314/50000] s_loss:-1108.5806 d_loss:-49.3035 val_s_loss:-19.5815 val_d_loss:-8.1049 heightest auc:0.85 cost:21.12
# epoch [315/50000] s_loss:4542.4048 d_loss:-52.6547 val_s_loss:27.7327 val_d_loss:-7.5850 heightest auc:0.85 cost:21.17
# epoch [316/50000] s_loss:6460.5142 d_loss:-52.4312 val_s_loss:62.6286 val_d_loss:-28.7971 heightest auc:0.85 cost:21.15
# epoch [317/50000] s_loss:-728.7195 d_loss:-58.2443 val_s_loss:-18.4887 val_d_loss:-41.0742 heightest auc:0.85 cost:20.16
# epoch [318/50000] s_loss:-2352.7788 d_loss:-52.2627 val_s_loss:-21.7456 val_d_loss:-51.3770 heightest auc:0.85 cost:20.70
# epoch [319/50000] s_loss:-872.4445 d_loss:-59.9011 val_s_loss:-17.2497 val_d_loss:-25.8165 heightest auc:0.85 cost:21.23
# epoch [320/50000] s_loss:6246.3799 d_loss:-49.4550 val_s_loss:38.7889 val_d_loss:-49.4893 heightest auc:0.85 cost:20.37
# epoch [321/50000] s_loss:5159.2241 d_loss:-50.0918 val_s_loss:51.3980 val_d_loss:-21.3439 heightest auc:0.85 cost:20.25
# epoch [322/50000] s_loss:-1652.5972 d_loss:-47.0654 val_s_loss:-25.0762 val_d_loss:-52.8285 heightest auc:0.85 cost:20.15
# epoch [323/50000] s_loss:-4644.8589 d_loss:-57.3788 val_s_loss:-50.3460 val_d_loss:-10.6320 heightest auc:0.85 cost:20.48
# epoch [324/50000] s_loss:-472.7586 d_loss:-48.9701 val_s_loss:-24.1997 val_d_loss:-26.1674 heightest auc:0.85 cost:19.53
# epoch [325/50000] s_loss:13906.7246 d_loss:-61.3468 val_s_loss:126.6022 val_d_loss:-55.4554 heightest auc:0.85 cost:19.65
# epoch [326/50000] s_loss:3749.0435 d_loss:-54.4060 val_s_loss:24.4460 val_d_loss:-4.1941 heightest auc:0.85 cost:19.19
# epoch [327/50000] s_loss:-5365.3247 d_loss:-54.8418 val_s_loss:-61.5810 val_d_loss:-28.1463 heightest auc:0.85 cost:19.60
# epoch [328/50000] s_loss:-5997.6772 d_loss:-58.9663 val_s_loss:-68.0486 val_d_loss:-8.5611 heightest auc:0.85 cost:19.67
# epoch [329/50000] s_loss:4029.5469 d_loss:-52.1937 val_s_loss:28.8771 val_d_loss:-27.2202 heightest auc:0.85 cost:19.77
# epoch [330/50000] s_loss:10401.8223 d_loss:-56.5779 val_s_loss:95.3396 val_d_loss:-34.7457 heightest auc:0.85 cost:20.05
# epoch [331/50000] s_loss:-246.9019 d_loss:-54.0689 val_s_loss:-13.2762 val_d_loss:-49.3194 heightest auc:0.85 cost:21.38
# epoch [332/50000] s_loss:-5387.2729 d_loss:-58.5837 val_s_loss:-50.6067 val_d_loss:-32.9658 heightest auc:0.85 cost:21.63
# epoch [333/50000] s_loss:-5045.8228 d_loss:-52.6584 val_s_loss:-58.0380 val_d_loss:-72.7072 heightest auc:0.85 cost:21.72
# epoch [334/50000] s_loss:584.0796 d_loss:-56.0424 val_s_loss:-12.6325 val_d_loss:-2.6484 heightest auc:0.85 cost:21.03
# epoch [335/50000] s_loss:9118.8916 d_loss:-65.1772 val_s_loss:97.4817 val_d_loss:-48.7017 heightest auc:0.85 cost:20.17
# epoch [336/50000] s_loss:6280.3169 d_loss:-49.6916 val_s_loss:58.7729 val_d_loss:-43.4078 heightest auc:0.85 cost:20.42
# epoch [337/50000] s_loss:-1960.6774 d_loss:-40.4057 val_s_loss:-28.1111 val_d_loss:-62.6205 heightest auc:0.85 cost:19.94
# epoch [338/50000] s_loss:-7018.1270 d_loss:-58.8389 val_s_loss:-64.1234 val_d_loss:-15.3913 heightest auc:0.85 cost:19.97
# epoch [339/50000] s_loss:-6051.9121 d_loss:-46.6680 val_s_loss:-66.4055 val_d_loss:-44.8678 heightest auc:0.85 cost:19.88
# epoch [340/50000] s_loss:8946.8789 d_loss:-92.2013 val_s_loss:51.9109 val_d_loss:-45.5885 heightest auc:0.85 cost:20.50
# epoch [341/50000] s_loss:1044.4962 d_loss:-48.9157 val_s_loss:8.4797 val_d_loss:-21.8101 heightest auc:0.85 cost:20.14
# epoch [342/50000] s_loss:-2804.9258 d_loss:-59.2766 val_s_loss:-32.1678 val_d_loss:-59.6933 heightest auc:0.85 cost:19.57
# epoch [343/50000] s_loss:-1986.1624 d_loss:-62.1697 val_s_loss:-25.3130 val_d_loss:-69.2905 heightest auc:0.85 cost:19.92
# epoch [344/50000] s_loss:594.4517 d_loss:-53.6925 val_s_loss:-5.1375 val_d_loss:-53.2637 heightest auc:0.85 cost:20.35
# epoch [345/50000] s_loss:3653.4341 d_loss:-45.8685 val_s_loss:29.3411 val_d_loss:-51.8602 heightest auc:0.85 cost:20.64
# epoch [346/50000] s_loss:4171.3218 d_loss:-64.9578 val_s_loss:32.3888 val_d_loss:-18.1794 heightest auc:0.85 cost:20.73
# epoch [347/50000] s_loss:4260.4258 d_loss:-55.4622 val_s_loss:28.9931 val_d_loss:-9.7148 heightest auc:0.85 cost:20.03
# epoch [348/50000] s_loss:1133.8888 d_loss:-41.3787 val_s_loss:11.4142 val_d_loss:-13.9424 heightest auc:0.85 cost:20.99
# epoch [349/50000] s_loss:5987.5371 d_loss:-48.1048 val_s_loss:32.0898 val_d_loss:-10.6227 heightest auc:0.85 cost:21.15
# epoch [350/50000] s_loss:4223.0513 d_loss:-56.9612 val_s_loss:35.6100 val_d_loss:-58.0022 heightest auc:0.85 cost:21.17
# epoch [351/50000] s_loss:1493.0471 d_loss:-52.2584 val_s_loss:5.5960 val_d_loss:-39.9870 heightest auc:0.85 cost:19.96
# epoch [352/50000] s_loss:-2892.7363 d_loss:-42.3305 val_s_loss:-37.4436 val_d_loss:-36.9473 heightest auc:0.85 cost:20.06
# epoch [353/50000] s_loss:-3413.8926 d_loss:-61.0545 val_s_loss:-43.4813 val_d_loss:-51.3643 heightest auc:0.85 cost:20.02
# epoch [354/50000] s_loss:3342.9441 d_loss:-59.4935 val_s_loss:26.1644 val_d_loss:-50.9441 heightest auc:0.85 cost:19.58
# epoch [355/50000] s_loss:4176.5693 d_loss:-55.0256 val_s_loss:46.0549 val_d_loss:-24.6067 heightest auc:0.85 cost:19.95
# epoch [356/50000] s_loss:-2878.4656 d_loss:-54.5528 val_s_loss:-25.2854 val_d_loss:-33.1694 heightest auc:0.85 cost:19.65
# epoch [357/50000] s_loss:1929.5004 d_loss:-47.3388 val_s_loss:9.7086 val_d_loss:-43.2326 heightest auc:0.85 cost:20.94
# epoch [358/50000] s_loss:7841.6089 d_loss:-78.1993 val_s_loss:79.2786 val_d_loss:-16.0597 heightest auc:0.85 cost:20.81
# epoch [359/50000] s_loss:-3305.8413 d_loss:-41.9887 val_s_loss:-32.6025 val_d_loss:-40.2534 heightest auc:0.85 cost:20.82
# epoch [360/50000] s_loss:-6112.9580 d_loss:-75.6049 val_s_loss:-59.9417 val_d_loss:-36.4238 heightest auc:0.85 cost:21.03
# epoch [361/50000] s_loss:-7740.3940 d_loss:-59.2207 val_s_loss:-72.6734 val_d_loss:-31.8515 heightest auc:0.85 cost:19.93
# epoch [362/50000] s_loss:6905.5518 d_loss:-71.0274 val_s_loss:38.1106 val_d_loss:-0.3427 heightest auc:0.85 cost:19.95
# epoch [363/50000] s_loss:5244.2749 d_loss:-53.7232 val_s_loss:39.3049 val_d_loss:-40.0383 heightest auc:0.85 cost:19.79
# epoch [364/50000] s_loss:945.2727 d_loss:-50.1481 val_s_loss:5.1351 val_d_loss:-23.6682 heightest auc:0.85 cost:19.47
# epoch [365/50000] s_loss:-1647.6259 d_loss:-56.2844 val_s_loss:-16.2346 val_d_loss:-33.4056 heightest auc:0.85 cost:20.80
# epoch [366/50000] s_loss:2307.8391 d_loss:-51.9990 val_s_loss:15.0791 val_d_loss:-44.7606 heightest auc:0.85 cost:20.64
# epoch [367/50000] s_loss:8794.5908 d_loss:-81.7833 val_s_loss:100.8231 val_d_loss:-35.9298 heightest auc:0.85 cost:21.44
# epoch [368/50000] s_loss:327.3655 d_loss:-54.0410 val_s_loss:-8.0087 val_d_loss:-22.5227 heightest auc:0.85 cost:20.18
# epoch [369/50000] s_loss:-5456.5723 d_loss:-57.8553 val_s_loss:-55.9322 val_d_loss:-64.9967 heightest auc:0.85 cost:19.93
# epoch [370/50000] s_loss:-2577.9714 d_loss:-61.6689 val_s_loss:-32.2455 val_d_loss:-10.5867 heightest auc:0.85 cost:20.74
# epoch [371/50000] s_loss:7254.5693 d_loss:-55.7342 val_s_loss:61.4912 val_d_loss:-44.7291 heightest auc:0.85 cost:20.45
# epoch [372/50000] s_loss:4198.3506 d_loss:-45.7086 val_s_loss:22.1274 val_d_loss:-49.2561 heightest auc:0.85 cost:20.94
# epoch [373/50000] s_loss:-2586.5081 d_loss:-51.1050 val_s_loss:-25.1017 val_d_loss:-37.8925 heightest auc:0.85 cost:20.53
# epoch [374/50000] s_loss:-5212.5186 d_loss:-50.4717 val_s_loss:-50.8466 val_d_loss:-54.8451 heightest auc:0.85 cost:21.40
# epoch [375/50000] s_loss:5406.9956 d_loss:-116.1585 val_s_loss:46.8011 val_d_loss:-37.3803 heightest auc:0.85 cost:19.45
# epoch [376/50000] s_loss:2173.4307 d_loss:-55.6234 val_s_loss:14.8985 val_d_loss:-43.9628 heightest auc:0.85 cost:19.67
# epoch [377/50000] s_loss:2517.4365 d_loss:-66.7911 val_s_loss:2.5136 val_d_loss:-31.3362 heightest auc:0.85 cost:19.44
# epoch [378/50000] s_loss:-2634.6931 d_loss:-34.2178 val_s_loss:-20.9844 val_d_loss:-56.5228 heightest auc:0.85 cost:19.49
# epoch [379/50000] s_loss:-4743.9741 d_loss:-50.3168 val_s_loss:-46.6480 val_d_loss:-19.4727 heightest auc:0.85 cost:20.10
# epoch [380/50000] s_loss:-2239.5095 d_loss:-51.0248 val_s_loss:-42.6180 val_d_loss:2.8253 heightest auc:0.85 cost:19.85
# epoch [381/50000] s_loss:12000.7236 d_loss:-87.0679 val_s_loss:93.1466 val_d_loss:-40.0883 heightest auc:0.85 cost:19.80
# epoch [382/50000] s_loss:3479.8005 d_loss:-51.9915 val_s_loss:18.6934 val_d_loss:-6.1750 heightest auc:0.85 cost:21.44
# epoch [383/50000] s_loss:-7130.1562 d_loss:-68.3983 val_s_loss:-74.9932 val_d_loss:-15.2698 heightest auc:0.85 cost:21.62
# epoch [384/50000] s_loss:-8744.6191 d_loss:-60.2213 val_s_loss:-74.7636 val_d_loss:-21.3175 heightest auc:0.85 cost:21.46
# epoch [385/50000] s_loss:-2030.4976 d_loss:-59.0341 val_s_loss:-18.9061 val_d_loss:-22.0260 heightest auc:0.85 cost:20.42
# epoch [386/50000] s_loss:22359.4766 d_loss:-126.3788 val_s_loss:215.9074 val_d_loss:-46.7598 heightest auc:0.85 cost:20.18
# epoch [387/50000] s_loss:2793.3262 d_loss:-53.5941 val_s_loss:30.7875 val_d_loss:-33.8896 heightest auc:0.85 cost:20.06
# epoch [388/50000] s_loss:-4223.4702 d_loss:-53.6592 val_s_loss:-55.3543 val_d_loss:-66.4627 heightest auc:0.85 cost:20.07
# epoch [389/50000] s_loss:-7581.0166 d_loss:-71.2458 val_s_loss:-74.5414 val_d_loss:-55.8683 heightest auc:0.85 cost:19.80
# epoch [390/50000] s_loss:-6828.4346 d_loss:-63.2038 val_s_loss:-64.3068 val_d_loss:-66.9848 heightest auc:0.85 cost:19.86
# epoch [391/50000] s_loss:8697.1992 d_loss:-75.7795 val_s_loss:82.4938 val_d_loss:-62.2999 heightest auc:0.85 cost:20.18
# epoch [392/50000] s_loss:6089.6416 d_loss:-62.3505 val_s_loss:54.1097 val_d_loss:-50.3637 heightest auc:0.85 cost:19.64
# epoch [393/50000] s_loss:550.0591 d_loss:-57.0571 val_s_loss:-8.9054 val_d_loss:-53.2813 heightest auc:0.85 cost:19.44
# epoch [394/50000] s_loss:-464.1872 d_loss:-53.0500 val_s_loss:-5.1985 val_d_loss:-40.1976 heightest auc:0.85 cost:19.86
# epoch [395/50000] s_loss:871.3237 d_loss:-59.2668 val_s_loss:-7.2279 val_d_loss:-29.2451 heightest auc:0.85 cost:20.43
# epoch [396/50000] s_loss:2805.0376 d_loss:-52.4322 val_s_loss:26.5787 val_d_loss:-60.9084 heightest auc:0.85 cost:20.69
# ...
# epoch [638/50000] s_loss:-1996.8180 d_loss:-46.5582 val_s_loss:-34.5493 val_d_loss:-38.0834 heightest auc:0.85 cost:20.62
# epoch [639/50000] s_loss:-2113.6277 d_loss:-52.6248 val_s_loss:-9.1471 val_d_loss:-40.1293 heightest auc:0.85 cost:21.33
# epoch [640/50000] s_loss:988.5301 d_loss:-52.7686 val_s_loss:5.0416 val_d_loss:-11.3592 heightest auc:0.85 cost:20.80
# epoch [641/50000] s_loss:5574.9004 d_loss:-47.6186 val_s_loss:45.9401 val_d_loss:-52.5187 heightest auc:0.85 cost:19.99
# epoch [642/50000] s_loss:3616.1160 d_loss:-60.7780 val_s_loss:32.3508 val_d_loss:-46.4270 heightest auc:0.85 cost:20.74
# epoch [643/50000] s_loss:-2522.1431 d_loss:-43.5322 val_s_loss:-25.0673 val_d_loss:-40.8848 heightest auc:0.85 cost:20.08
# epoch [644/50000] s_loss:-5746.1997 d_loss:-48.3785 val_s_loss:-51.7369 val_d_loss:-59.7833 heightest auc:0.85 cost:20.08
# epoch [645/50000] s_loss:-2494.9592 d_loss:-52.0197 val_s_loss:-26.0877 val_d_loss:-58.2609 heightest auc:0.85 cost:20.23
# epoch [646/50000] s_loss:3404.6609 d_loss:-53.2811 val_s_loss:30.8285 val_d_loss:-22.1575 heightest auc:0.85 cost:19.71
# epoch [647/50000] s_loss:4737.3550 d_loss:-53.8804 val_s_loss:44.6017 val_d_loss:-45.3778 heightest auc:0.85 cost:20.78
# epoch [648/50000] s_loss:1634.4164 d_loss:-42.6382 val_s_loss:12.2138 val_d_loss:-20.0958 heightest auc:0.85 cost:20.97
# epoch [649/50000] s_loss:-1869.7152 d_loss:-44.6599 val_s_loss:-10.7095 val_d_loss:-22.1764 heightest auc:0.85 cost:20.60
# epoch [650/50000] s_loss:-3106.8875 d_loss:-49.2026 val_s_loss:-30.1020 val_d_loss:-18.6856 heightest auc:0.85 cost:21.66
# epoch [651/50000] s_loss:-2686.0542 d_loss:-44.5254 val_s_loss:-30.6188 val_d_loss:-36.4512 heightest auc:0.85 cost:20.94
# epoch [652/50000] s_loss:-150.1575 d_loss:-48.2533 val_s_loss:-0.9176 val_d_loss:-30.1680 heightest auc:0.85 cost:20.93
# epoch [653/50000] s_loss:1395.6409 d_loss:-49.9613 val_s_loss:9.8114 val_d_loss:-22.9625 heightest auc:0.85 cost:19.89
# epoch [654/50000] s_loss:971.5322 d_loss:-43.2182 val_s_loss:-2.2199 val_d_loss:-27.3962 heightest auc:0.85 cost:20.49
# epoch [655/50000] s_loss:1774.3129 d_loss:-49.9992 val_s_loss:14.2255 val_d_loss:-13.5725 heightest auc:0.85 cost:19.90
# epoch [656/50000] s_loss:2370.2527 d_loss:-48.0117 val_s_loss:20.7154 val_d_loss:-38.2831 heightest auc:0.85 cost:20.09
# epoch [657/50000] s_loss:1617.9062 d_loss:-46.4070 val_s_loss:0.7542 val_d_loss:-15.9271 heightest auc:0.85 cost:20.15
# epoch [658/50000] s_loss:2558.9824 d_loss:-50.5733 val_s_loss:31.2786 val_d_loss:-26.9324 heightest auc:0.85 cost:20.09
# epoch [659/50000] s_loss:2009.9973 d_loss:-51.8464 val_s_loss:16.2159 val_d_loss:-42.3335 heightest auc:0.85 cost:21.04
# epoch [660/50000] s_loss:1080.4637 d_loss:-43.4174 val_s_loss:15.7348 val_d_loss:-40.5405 heightest auc:0.85 cost:20.15
# epoch [661/50000] s_loss:-1744.8829 d_loss:-49.1174 val_s_loss:-23.7081 val_d_loss:-45.2741 heightest auc:0.85 cost:20.81
# epoch [662/50000] s_loss:-3370.1340 d_loss:-40.5483 val_s_loss:-30.3498 val_d_loss:-19.5196 heightest auc:0.85 cost:20.60
# epoch [663/50000] s_loss:-2369.6609 d_loss:-47.2240 val_s_loss:-20.5117 val_d_loss:-54.7814 heightest auc:0.85 cost:20.02
# epoch [664/50000] s_loss:264.6219 d_loss:-51.4122 val_s_loss:9.5808 val_d_loss:-57.0956 heightest auc:0.85 cost:19.75
# epoch [665/50000] s_loss:1425.5967 d_loss:-40.3798 val_s_loss:16.0360 val_d_loss:-37.2879 heightest auc:0.85 cost:19.56
# epoch [666/50000] s_loss:1249.2423 d_loss:-51.9756 val_s_loss:6.9247 val_d_loss:-26.1661 heightest auc:0.85 cost:19.66
# epoch [667/50000] s_loss:-2262.1677 d_loss:-38.8897 val_s_loss:-25.9763 val_d_loss:-35.9320 heightest auc:0.85 cost:21.02
# epoch [668/50000] s_loss:-2993.8416 d_loss:-49.8753 val_s_loss:-33.5763 val_d_loss:-26.2576 heightest auc:0.85 cost:21.28
# epoch [669/50000] s_loss:-70.7676 d_loss:-39.3425 val_s_loss:-6.3617 val_d_loss:-50.9881 heightest auc:0.85 cost:21.48
# epoch [670/50000] s_loss:5442.2871 d_loss:-49.6253 val_s_loss:33.1458 val_d_loss:-28.2570 heightest auc:0.85 cost:19.73
# epoch [671/50000] s_loss:1427.2847 d_loss:-46.4496 val_s_loss:11.9768 val_d_loss:-50.8860 heightest auc:0.85 cost:20.12
# epoch [672/50000] s_loss:-2647.2646 d_loss:-46.9394 val_s_loss:-22.9707 val_d_loss:-9.4901 heightest auc:0.85 cost:20.39
# epoch [673/50000] s_loss:-3059.6113 d_loss:-41.3484 val_s_loss:-26.4354 val_d_loss:-18.8246 heightest auc:0.85 cost:21.21
# epoch [674/50000] s_loss:462.0087 d_loss:-52.7280 val_s_loss:2.8214 val_d_loss:-17.4630 heightest auc:0.85 cost:21.03
# epoch [675/50000] s_loss:-156.0499 d_loss:-38.2710 val_s_loss:-5.2788 val_d_loss:-18.5158 heightest auc:0.85 cost:20.23
# epoch [676/50000] s_loss:-1088.7568 d_loss:-43.7278 val_s_loss:-12.1921 val_d_loss:-52.9398 heightest auc:0.85 cost:21.05
# epoch [677/50000] s_loss:-964.9036 d_loss:-46.5292 val_s_loss:-5.7199 val_d_loss:-16.5460 heightest auc:0.85 cost:20.06
# epoch [678/50000] s_loss:114.6942 d_loss:-49.8206 val_s_loss:0.6324 val_d_loss:-35.0819 heightest auc:0.85 cost:19.95
# epoch [679/50000] s_loss:-1812.9263 d_loss:-38.1890 val_s_loss:-24.1502 val_d_loss:-41.4721 heightest auc:0.85 cost:19.74
# epoch [680/50000] s_loss:-3804.7102 d_loss:-48.9657 val_s_loss:-35.6769 val_d_loss:-61.3285 heightest auc:0.85 cost:19.27
# epoch [681/50000] s_loss:-1134.0117 d_loss:-55.9398 val_s_loss:-20.0751 val_d_loss:-49.0107 heightest auc:0.85 cost:19.85
# epoch [682/50000] s_loss:2978.2998 d_loss:-48.4012 val_s_loss:34.0589 val_d_loss:-44.0760 heightest auc:0.85 cost:19.68
# epoch [683/50000] s_loss:3034.4768 d_loss:-51.6156 val_s_loss:18.1703 val_d_loss:-36.5391 heightest auc:0.85 cost:20.12
# epoch [684/50000] s_loss:-632.1883 d_loss:-52.2189 val_s_loss:-5.9445 val_d_loss:-26.4873 heightest auc:0.85 cost:21.48
# epoch [685/50000] s_loss:-5439.1655 d_loss:-57.7501 val_s_loss:-58.3349 val_d_loss:-38.6618 heightest auc:0.85 cost:22.33
# epoch [686/50000] s_loss:-7800.3174 d_loss:-51.6053 val_s_loss:-76.4659 val_d_loss:-43.4049 heightest auc:0.85 cost:21.26
# epoch [687/50000] s_loss:-5105.3428 d_loss:-49.4788 val_s_loss:-59.2336 val_d_loss:-56.5623 heightest auc:0.85 cost:20.68
# epoch [688/50000] s_loss:-997.2006 d_loss:-53.1128 val_s_loss:-18.7897 val_d_loss:-42.3326 heightest auc:0.85 cost:20.79
# epoch [689/50000] s_loss:3218.4670 d_loss:-49.9548 val_s_loss:28.7697 val_d_loss:-29.5272 heightest auc:0.85 cost:20.60
# epoch [690/50000] s_loss:2060.9131 d_loss:-56.0215 val_s_loss:5.2678 val_d_loss:-29.9878 heightest auc:0.85 cost:20.24
# epoch [691/50000] s_loss:-1280.9055 d_loss:-44.4914 val_s_loss:-4.9902 val_d_loss:-16.1418 heightest auc:0.85 cost:20.09
# epoch [692/50000] s_loss:-1470.2291 d_loss:-49.4701 val_s_loss:-10.5789 val_d_loss:-66.1596 heightest auc:0.85 cost:19.67
# epoch [693/50000] s_loss:1595.3311 d_loss:-52.3023 val_s_loss:6.6931 val_d_loss:-27.9482 heightest auc:0.85 cost:20.66
# epoch [694/50000] s_loss:2756.1921 d_loss:-49.8873 val_s_loss:15.5695 val_d_loss:-10.6481 heightest auc:0.85 cost:19.74
# epoch [695/50000] s_loss:3687.1191 d_loss:-45.7725 val_s_loss:34.4637 val_d_loss:-44.6787 heightest auc:0.85 cost:20.01
# epoch [696/50000] s_loss:1483.5859 d_loss:-52.6404 val_s_loss:13.0245 val_d_loss:-34.0212 heightest auc:0.85 cost:20.07
# epoch [697/50000] s_loss:-1030.4570 d_loss:-43.8531 val_s_loss:-11.3961 val_d_loss:-16.7183 heightest auc:0.85 cost:20.06
# epoch [698/50000] s_loss:-3162.9355 d_loss:-51.9467 val_s_loss:-39.1500 val_d_loss:-1.1439 heightest auc:0.85 cost:20.35
# epoch [699/50000] s_loss:-2987.3677 d_loss:-58.5489 val_s_loss:-37.9463 val_d_loss:-14.7532 heightest auc:0.85 cost:20.58
# epoch [700/50000] s_loss:-2757.7458 d_loss:-48.3287 val_s_loss:-29.1745 val_d_loss:-50.3651 heightest auc:0.85 cost:20.49
# epoch [701/50000] s_loss:-613.3492 d_loss:-51.1873 val_s_loss:-5.2450 val_d_loss:-23.3413 heightest auc:0.85 cost:21.54
# epoch [702/50000] s_loss:-460.0818 d_loss:-50.2376 val_s_loss:4.5081 val_d_loss:-66.3770 heightest auc:0.85 cost:21.32
# epoch [703/50000] s_loss:8.3855 d_loss:-59.7938 val_s_loss:-0.7637 val_d_loss:-20.5464 heightest auc:0.85 cost:19.94
# epoch [704/50000] s_loss:953.5529 d_loss:-49.5261 val_s_loss:9.5121 val_d_loss:-54.3418 heightest auc:0.85 cost:19.62
# epoch [705/50000] s_loss:-537.3427 d_loss:-41.0995 val_s_loss:-7.3965 val_d_loss:-42.1248 heightest auc:0.85 cost:19.89
# epoch [706/50000] s_loss:-1179.4609 d_loss:-45.4715 val_s_loss:-8.2983 val_d_loss:-51.5968 heightest auc:0.85 cost:19.95
# epoch [707/50000] s_loss:-465.7984 d_loss:-50.5841 val_s_loss:-8.5646 val_d_loss:-15.4055 heightest auc:0.85 cost:19.96
# epoch [708/50000] s_loss:1231.8455 d_loss:-56.0366 val_s_loss:11.4073 val_d_loss:-25.7040 heightest auc:0.85 cost:20.04
# epoch [709/50000] s_loss:2095.5798 d_loss:-53.3515 val_s_loss:9.5285 val_d_loss:-19.4277 heightest auc:0.85 cost:20.75
# epoch [710/50000] s_loss:-938.0727 d_loss:-46.0304 val_s_loss:-6.2908 val_d_loss:-49.3059 heightest auc:0.85 cost:20.95
# epoch [711/50000] s_loss:-1522.1902 d_loss:-52.1044 val_s_loss:-8.8131 val_d_loss:-65.3468 heightest auc:0.85 cost:20.89
# epoch [712/50000] s_loss:-953.4905 d_loss:-38.2557 val_s_loss:-16.8004 val_d_loss:-5.2012 heightest auc:0.85 cost:20.71
# epoch [713/50000] s_loss:2357.6904 d_loss:-50.9889 val_s_loss:21.8197 val_d_loss:-58.4030 heightest auc:0.85 cost:20.52
# epoch [714/50000] s_loss:3694.2695 d_loss:-50.2893 val_s_loss:23.6919 val_d_loss:-10.3987 heightest auc:0.85 cost:19.79
# epoch [715/50000] s_loss:-286.2973 d_loss:-48.6833 val_s_loss:-13.4989 val_d_loss:-9.4608 heightest auc:0.85 cost:19.93
# epoch [716/50000] s_loss:-2608.6792 d_loss:-47.4104 val_s_loss:-27.4996 val_d_loss:-25.5583 heightest auc:0.85 cost:20.07
# epoch [717/50000] s_loss:-4697.9341 d_loss:-60.0964 val_s_loss:-46.5245 val_d_loss:-42.7890 heightest auc:0.85 cost:20.56
# epoch [718/50000] s_loss:-1917.5862 d_loss:-46.5728 val_s_loss:-21.0740 val_d_loss:-64.3857 heightest auc:0.85 cost:21.29
# epoch [719/50000] s_loss:978.6049 d_loss:-43.3909 val_s_loss:1.4889 val_d_loss:-19.3953 heightest auc:0.85 cost:21.35
# epoch [720/50000] s_loss:180.6363 d_loss:-54.3628 val_s_loss:4.5525 val_d_loss:-71.8937 heightest auc:0.85 cost:20.47
# epoch [721/50000] s_loss:-593.8020 d_loss:-55.6282 val_s_loss:-8.3254 val_d_loss:-12.6637 heightest auc:0.85 cost:20.56
# epoch [722/50000] s_loss:1737.5759 d_loss:-56.4023 val_s_loss:17.4333 val_d_loss:-49.8977 heightest auc:0.85 cost:20.80
# epoch [723/50000] s_loss:3465.8049 d_loss:-56.0304 val_s_loss:37.2814 val_d_loss:-14.9365 heightest auc:0.85 cost:20.97
# epoch [724/50000] s_loss:1750.8430 d_loss:-39.0461 val_s_loss:8.8126 val_d_loss:-41.8097 heightest auc:0.85 cost:20.50
# epoch [725/50000] s_loss:-819.4625 d_loss:-54.1462 val_s_loss:-19.3668 val_d_loss:-24.6607 heightest auc:0.85 cost:20.48
# epoch [726/50000] s_loss:-3449.5393 d_loss:-52.1573 val_s_loss:-33.7797 val_d_loss:-19.0841 heightest auc:0.85 cost:19.60
# epoch [727/50000] s_loss:-2118.3333 d_loss:-32.3407 val_s_loss:-22.8833 val_d_loss:-10.5674 heightest auc:0.85 cost:20.33
# epoch [728/50000] s_loss:1574.5616 d_loss:-40.7365 val_s_loss:5.7709 val_d_loss:-54.7882 heightest auc:0.85 cost:19.53
# epoch [729/50000] s_loss:2140.3540 d_loss:-40.8482 val_s_loss:12.7968 val_d_loss:-20.4163 heightest auc:0.85 cost:19.72
# epoch [730/50000] s_loss:1621.8613 d_loss:-47.9507 val_s_loss:13.9662 val_d_loss:-55.3154 heightest auc:0.85 cost:20.22
# epoch [731/50000] s_loss:-427.4532 d_loss:-46.4735 val_s_loss:-7.6879 val_d_loss:-11.8147 heightest auc:0.85 cost:20.54
# epoch [732/50000] s_loss:-2565.4314 d_loss:-55.5371 val_s_loss:-24.4194 val_d_loss:-12.2302 heightest auc:0.85 cost:19.85
# epoch [733/50000] s_loss:-1787.0845 d_loss:-55.8658 val_s_loss:-29.5551 val_d_loss:-57.0166 heightest auc:0.85 cost:20.49
# epoch [734/50000] s_loss:-1005.5905 d_loss:-58.7975 val_s_loss:-19.9578 val_d_loss:-13.2858 heightest auc:0.85 cost:20.68
# epoch [735/50000] s_loss:163.3334 d_loss:-45.8069 val_s_loss:-11.7957 val_d_loss:-14.5669 heightest auc:0.85 cost:22.19
# epoch [736/50000] s_loss:-782.4635 d_loss:-47.0334 val_s_loss:-10.4631 val_d_loss:-48.5828 heightest auc:0.85 cost:21.76
# epoch [737/50000] s_loss:-3432.4265 d_loss:-53.0818 val_s_loss:-38.8823 val_d_loss:-19.7955 heightest auc:0.85 cost:20.91
# epoch [738/50000] s_loss:-1075.6937 d_loss:-49.7842 val_s_loss:-29.0260 val_d_loss:-26.9528 heightest auc:0.85 cost:20.61
# epoch [739/50000] s_loss:1882.7805 d_loss:-43.2663 val_s_loss:15.4001 val_d_loss:-37.6138 heightest auc:0.85 cost:20.27
# epoch [740/50000] s_loss:2191.5234 d_loss:-49.9863 val_s_loss:21.5934 val_d_loss:-26.9328 heightest auc:0.85 cost:19.66
# epoch [741/50000] s_loss:-587.7920 d_loss:-50.8508 val_s_loss:-1.8755 val_d_loss:-19.1445 heightest auc:0.85 cost:20.06
# epoch [742/50000] s_loss:-763.2765 d_loss:-44.8027 val_s_loss:-6.5503 val_d_loss:-29.0214 heightest auc:0.85 cost:19.84
# epoch [743/50000] s_loss:1671.1707 d_loss:-47.4287 val_s_loss:14.0187 val_d_loss:-11.7192 heightest auc:0.85 cost:20.96
# epoch [744/50000] s_loss:1594.8334 d_loss:-48.2691 val_s_loss:-4.5534 val_d_loss:-2.2811 heightest auc:0.85 cost:20.15
# epoch [745/50000] s_loss:-744.1956 d_loss:-46.3967 val_s_loss:-20.1804 val_d_loss:-17.4115 heightest auc:0.85 cost:19.97
# epoch [746/50000] s_loss:-1346.0435 d_loss:-38.3376 val_s_loss:-12.5698 val_d_loss:-16.5181 heightest auc:0.85 cost:20.54
# epoch [747/50000] s_loss:-945.2249 d_loss:-58.9329 val_s_loss:-21.4581 val_d_loss:-35.7239 heightest auc:0.85 cost:20.58
# epoch [748/50000] s_loss:-1987.0951 d_loss:-53.5037 val_s_loss:-21.5484 val_d_loss:-17.8060 heightest auc:0.85 cost:21.02
# epoch [749/50000] s_loss:-1401.2124 d_loss:-43.8309 val_s_loss:-20.4159 val_d_loss:-27.1455 heightest auc:0.85 cost:20.19
# epoch [750/50000] s_loss:-595.2531 d_loss:-54.1364 val_s_loss:-13.4100 val_d_loss:-9.7488 heightest auc:0.85 cost:19.88
# epoch [751/50000] s_loss:212.0262 d_loss:-53.7604 val_s_loss:-11.2950 val_d_loss:-6.8166 heightest auc:0.85 cost:21.09
# epoch [752/50000] s_loss:3581.7693 d_loss:-53.3477 val_s_loss:30.7561 val_d_loss:-35.9206 heightest auc:0.85 cost:21.04
# epoch [753/50000] s_loss:1644.5039 d_loss:-41.8522 val_s_loss:12.0362 val_d_loss:-45.4555 heightest auc:0.85 cost:20.81
# epoch [754/50000] s_loss:-770.1057 d_loss:-58.5193 val_s_loss:-17.7072 val_d_loss:-13.4385 heightest auc:0.85 cost:20.07
# epoch [755/50000] s_loss:-2346.2593 d_loss:-35.8370 val_s_loss:-21.7515 val_d_loss:-30.4428 heightest auc:0.85 cost:20.56
# epoch [756/50000] s_loss:785.2380 d_loss:-52.3676 val_s_loss:13.0928 val_d_loss:-50.8223 heightest auc:0.85 cost:20.13
# epoch [757/50000] s_loss:2638.0291 d_loss:-44.9384 val_s_loss:29.6545 val_d_loss:-23.4271 heightest auc:0.85 cost:20.09
# epoch [758/50000] s_loss:1078.7899 d_loss:-41.5005 val_s_loss:4.2501 val_d_loss:-19.1270 heightest auc:0.85 cost:20.49
# epoch [759/50000] s_loss:-2864.1106 d_loss:-40.4139 val_s_loss:-29.8206 val_d_loss:-19.1522 heightest auc:0.85 cost:20.00
# epoch [760/50000] s_loss:-3696.2947 d_loss:-56.9183 val_s_loss:-43.1862 val_d_loss:-29.9640 heightest auc:0.85 cost:21.00
# epoch [761/50000] s_loss:-2534.1558 d_loss:-54.5633 val_s_loss:-34.1929 val_d_loss:-13.1253 heightest auc:0.85 cost:20.76
# epoch [762/50000] s_loss:-831.4803 d_loss:-48.9846 val_s_loss:-16.9920 val_d_loss:-11.8405 heightest auc:0.85 cost:20.13
# epoch [763/50000] s_loss:32.8575 d_loss:-37.1583 val_s_loss:-3.6512 val_d_loss:-24.4068 heightest auc:0.85 cost:19.87
# epoch [764/50000] s_loss:-69.4821 d_loss:-49.4550 val_s_loss:-3.4346 val_d_loss:-25.1336 heightest auc:0.85 cost:20.07
# epoch [765/50000] s_loss:-1500.7809 d_loss:-39.6846 val_s_loss:-5.7510 val_d_loss:-46.8408 heightest auc:0.85 cost:19.92
# epoch [766/50000] s_loss:-1670.8011 d_loss:-52.9934 val_s_loss:-19.9891 val_d_loss:-64.9521 heightest auc:0.85 cost:19.90
# epoch [767/50000] s_loss:-1267.6827 d_loss:-48.0710 val_s_loss:-12.0596 val_d_loss:-41.6823 heightest auc:0.85 cost:19.96
# epoch [768/50000] s_loss:1548.9088 d_loss:-51.5780 val_s_loss:4.3016 val_d_loss:-10.9534 heightest auc:0.85 cost:20.94
# epoch [769/50000] s_loss:2716.2881 d_loss:-42.5835 val_s_loss:25.1865 val_d_loss:-44.4432 heightest auc:0.85 cost:21.36

# %%
AE.eval()
S.eval()
for index, img in enumerate(test_loader):
    test_img = Variable(img[0]).cuda()

    # ======AE======
    blur_image = AE(test_img)
    
    noise = torch.zeros(blur_image.shape[0], 1, blur_image.shape[2], blur_image.shape[3] )
    noise = noise + (0.01**0.5)*torch.randn(blur_image.shape[0], 1, blur_image.shape[2], blur_image.shape[3])
    noise = noise.cuda()
    blur_image_with_noise = torch.cat([blur_image, noise], 1)
    fake_image = S(blur_image_with_noise)
    
    
    vutils.save_image(fake_image[0], './test_result/{}_simulated.png'.format(index))
    vutils.save_image(blur_image[0], './test_result/{}_blur.png'.format(index))
    vutils.save_image(test_img, './test_result/{}_origin.png'.format(index))
